# %%
import pandas as pd, numpy as np

# %%
output_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/'

meta_old = pd.read_csv(output_dir + 'lsff_input_coverage_data_with_metadata.csv')
df_old = pd.read_csv(output_dir + 'lsff_input_coverage_data.csv')

meta_new = pd.read_csv(output_dir + 'test_lsff_input_coverage_data_with_metadata.csv')
df_new = pd.read_csv(output_dir + 'test_lsff_input_coverage_data.csv')

# %%
meta_old.columns
# Out:
# Index(['location_id', 'location_name', 'sub_population', 'vehicle',
#        'value_description', 'nutrient', 'value_mean', 'value_025_percentile',
#        'value_975_percentile', 'u5_applicable', 'wra_applicable',
#        'estimation_status', 'source_citation', 'source_link', 'CI_source',
#        'data_choice_notes'],
#       dtype='object')

# %%
idcols = ['location_id','location_name','sub_population','vehicle','value_description','nutrient','u5_applicable','wra_applicable']

# %%
b427 = pd.read_csv('/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/427b_lsff_input_coverage_data.csv')

# %%
b427.head()
# Out:
#    location_id location_name sub_population      vehicle  \
# 0          179      Ethiopia            NaN  maize flour
# 1          179      Ethiopia            NaN  maize flour
# 2          179      Ethiopia            NaN  maize flour
# 3          179      Ethiopia            NaN  maize flour
# 4          179      Ethiopia            NaN  maize flour
#
#                                    value_description    nutrient  value_mean  \
# 0               percent of population eating vehicle          na   59.263848
# 1  percent of population eating industrially prod...          na   27.167514
# 2     percent of population eating fortified vehicle  folic acid    0.000000
# 3     percent of population eating fortified vehicle        iron    0.000000
# 4     percent of population eating fortified vehicle   vitamin a    0.000000
#
#    value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 0             24.950317             93.577380           True            True
# ...

# %%
b427.merge(df_old, on )

# %%
compare = df_old.merge(b427, on = idcols, how = 'left')

# %%
compare.loc[np.abs(compare.value_mean_x - compare.value_mean_y) > .1].location_name.value_counts()
# Out:
# Series([], Name: location_name, dtype: int64)

# %%
compare.loc[
    (compare.location_name=="Côte d'Ivoire") &
    (np.abs(compare.value_mean_x - compare.value_mean_y) > .1),
    idcols + ['value_mean_x','value_mean_y']
]
# Out:
#      location_id  location_name                         sub_population  \
# 182          205  Côte d'Ivoire                                    NaN
# 183          205  Côte d'Ivoire                                    NaN
# 184          205  Côte d'Ivoire                                    NaN
# 185          205  Côte d'Ivoire                                    NaN
# 186          205  Côte d'Ivoire                                    NaN
# 191          205  Côte d'Ivoire  households with children <2 years old
# 192          205  Côte d'Ivoire                                    NaN
# 193          205  Côte d'Ivoire                                    NaN
# 194          205  Côte d'Ivoire                                    NaN
#
#          vehicle                                  value_description  \
# 182  maize flour  percent of population eating industrially prod...
# 183  maize flour     percent of population eating fortified vehicle
# ...

# %%
compare.loc[
    (compare.location_name=="Angola") &
    (np.abs(compare.value_mean_x - compare.value_mean_y) > .1),
    idcols + ['value_mean_x','value_mean_y']
]
# Out:
#      location_id location_name sub_population      vehicle  \
# 236          168        Angola            NaN  maize flour
# 237          168        Angola            NaN  maize flour
# 238          168        Angola            NaN  maize flour
# 239          168        Angola            NaN  maize flour
# 240          168        Angola            NaN  maize flour
# 242          168        Angola            NaN          oil
# 243          168        Angola            NaN          oil
# 245          168        Angola            NaN  wheat flour
# 246          168        Angola            NaN  wheat flour
# 247          168        Angola            NaN  wheat flour
# 248          168        Angola            NaN  wheat flour
# 249          168        Angola            NaN  wheat flour
#
#                                      value_description    nutrient  \
# 236  percent of population eating industrially prod...          na
# ...

# %%
compare.loc[np.abs(compare.value_mean_x - compare.value_mean_y) > 1].estimation_status.value_counts()
# Out:
# regression        84
# multiplicative     6
# na                 3
# Name: estimation_status, dtype: int64

# %%
compare.loc[np.abs(compare.value_mean_x - compare.value_mean_y) > .1].sort_values(['location_name'])
# Out:
#      location_id location_name sub_population      vehicle  \
# 246          168        Angola            NaN  wheat flour
# 238          168        Angola            NaN  maize flour
# 239          168        Angola            NaN  maize flour
# 240          168        Angola            NaN  maize flour
# 242          168        Angola            NaN          oil
# ..           ...           ...            ...          ...
# 329          522         Sudan            NaN  wheat flour
# 330          522         Sudan            NaN  wheat flour
# 331          522         Sudan            NaN  wheat flour
# 332          522         Sudan            NaN  wheat flour
# 333          522         Sudan            NaN  wheat flour
#
#                                      value_description    nutrient  \
# 246     percent of population eating fortified vehicle  folic acid
# 238     percent of population eating fortified vehicle        iron
# ...
