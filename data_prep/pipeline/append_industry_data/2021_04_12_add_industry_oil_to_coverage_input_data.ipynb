# %%
import pandas as pd, numpy as np

# %% [markdown]
# # Add 'industry oil' to coverage input data

# %%
## pull in (previously final) input data sheet
outputs_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/'
input_data_path = outputs_dir + 'lsff_input_coverage_data.csv'

input_data = pd.read_csv(input_data_path)

loc_id_map = {i:j for(i,j) in zip(input_data.location_name, input_data.location_id) }

# %%
# pull in (previously final) version of input data sheet with metadata
w_meta = pd.read_csv(outputs_dir + 'lsff_input_coverage_data_with_metadata.csv')

# %%
# pull in new numbers from Jonathan / industry
inputs_dir = "/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/"
new_data = pd.read_excel(inputs_dir + "20210411_LSFF_input_data_for_IHME.xlsx", header = [1,2,3])

# %%
# subset to the oil numbers we're interested in
new_data = new_data.set_index(new_data.columns[0])

new_oil = new_data['Baseline coverage']['Oil\n(percent of population eating specified oil)'][['Fortifiable oil.1','Compliance % of fortifiable']]

# %%
# pull columns we're interested in
rename_oil = {
    ('Location', 'Unnamed: 0_level_1', 'Unnamed: 0_level_2'): 'location_name',
 'Fortifiable oil.1': 'percent of population eating industrially produced vehicle',
 'Compliance % of fortifiable': 'percent of population eating fortified vehicle'
}

new_oil = new_oil.reset_index().rename(columns=rename_oil)

# %%
# reshape to our format
new_oil = pd.melt(new_oil, id_vars = 'location_name',
        value_vars = ['percent of population eating industrially produced vehicle',
       'percent of population eating fortified vehicle'],
       var_name='value_description',value_name='value_mean')

# %%
# fix c'ote divoire 
new_oil.loc[new_oil.location_name=="CÃ´te d'Ivoire","location_name"] = "Côte d'Ivoire"

# %%
# make sure we're not missing any locations / don't have any extra
assert(set(new_oil.location_name).symmetric_difference(set(input_data.location_name))==set())

# %%
# formatting
new_oil['vehicle'] = 'industry oil'
new_oil['nutrient'] = 'vitamin a'
new_oil['u5_applicable'] = True
new_oil['wra_applicable'] = True
new_oil['sub_population'] = np.NaN
new_oil['location_id'] = new_oil.location_name.map(loc_id_map)

# %%
# check formatting
new_oil.head()
# Out:
#    location_name                                  value_description  \
# 0         Angola  percent of population eating industrially prod...
# 1     Bangladesh  percent of population eating industrially prod...
# 2   Burkina Faso  percent of population eating industrially prod...
# 3  Côte d'Ivoire  percent of population eating industrially prod...
# 4       Cameroon  percent of population eating industrially prod...
#
#    value_mean       vehicle   nutrient  u5_applicable  wra_applicable  \
# 0      72.320  industry oil  vitamin a           True            True
# 1      87.516  industry oil  vitamin a           True            True
# 2      73.760  industry oil  vitamin a           True            True
# 3      72.000  industry oil  vitamin a           True            True
# 4      72.000  industry oil  vitamin a           True            True
#
#    sub_population  location_id
# 0             NaN          168
# 1             NaN          161
# 2             NaN          201
# 3             NaN          205
# 4             NaN          202

# %%
# from our (previously final) input sheet, select extracted rows of data (no regression or multiplicative results)
# then drop any rows duplicated for different nutrients
w_meta = w_meta[w_meta.estimation_status=='na'].drop(columns = 'nutrient').drop_duplicates()

# %%
# use ratio of scale over mean to estimate scale for new industry datapoints
w_meta['scale_over_mean'] = (w_meta.value_975_percentile - w_meta.value_025_percentile) / w_meta.value_mean
r = w_meta.loc[(w_meta.scale_over_mean!=np.inf) & (w_meta.scale_over_mean!=0),['vehicle','scale_over_mean']]

r_mean = r.scale_over_mean.mean()
r.loc[r.vehicle=="maize flour",'scale_over_mean'] = r_mean

r = r.groupby('vehicle').mean().dropna().rename(columns={'scale_over_mean':'r'}).reset_index()

# %%
r
# Out:
#        vehicle         r
# 0  maize flour  0.564982
# 1          oil  0.379944
# 2  wheat flour  0.688639

# %%
# we'll use the oil-specific ratio
new_oil['r'] = 0.379944

# %%
new_oil.head()
# Out:
#    location_name                                  value_description  \
# 0         Angola  percent of population eating industrially prod...
# 1     Bangladesh  percent of population eating industrially prod...
# 2   Burkina Faso  percent of population eating industrially prod...
# 3  Côte d'Ivoire  percent of population eating industrially prod...
# 4       Cameroon  percent of population eating industrially prod...
#
#    value_mean       vehicle   nutrient  u5_applicable  wra_applicable  \
# 0      72.320  industry oil  vitamin a           True            True
# 1      87.516  industry oil  vitamin a           True            True
# 2      73.760  industry oil  vitamin a           True            True
# 3      72.000  industry oil  vitamin a           True            True
# 4      72.000  industry oil  vitamin a           True            True
#
#    sub_population  location_id         r
# 0             NaN          168  0.379944
# 1             NaN          161  0.379944
# 2             NaN          201  0.379944
# 3             NaN          205  0.379944
# 4             NaN          202  0.379944

# %%
# input estimated CIs
new_oil['value_025_percentile'] = np.clip(new_oil.value_mean - (new_oil.r * new_oil.value_mean)/2, 0, 100)
new_oil['value_975_percentile'] = np.clip(new_oil.value_mean + (new_oil.r * new_oil.value_mean)/2, 0, 100)

# %%
output = input_data.append(new_oil)
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v108/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
#checkout results
output.tail()
# Out:
#     location_id                location_name   nutrient         r  \
# 45          196                 South Africa  vitamin a  0.379944
# 46          522                        Sudan  vitamin a  0.379944
# 47          190                       Uganda  vitamin a  0.379944
# 48          189  United Republic of Tanzania  vitamin a  0.379944
# 49           20                     Viet Nam  vitamin a  0.379944
#
#    sub_population  u5_applicable  value_025_percentile  value_975_percentile  \
# 45            NaN           True              2.430084              3.569916
# 46            NaN           True              0.000000              0.000000
# 47            NaN           True             44.065523             64.734477
# 48            NaN           True             43.417501             63.782499
# 49            NaN           True             56.701960             83.298040
#
#                                  value_description  value_mean       vehicle  \
# 45  percent of population eating fortified vehicle         3.0  industry oil
# 46  percent of population eating fortified vehicle         0.0  industry oil
# 47  percent of population eating fortified vehicle        54.4  industry oil
# 48  percent of population eating fortified vehicle        53.6  industry oil
# 49  percent of population eating fortified vehicle        70.0  industry oil
#
#     wra_applicable
# 45            True
# 46            True
# 47            True
# 48            True
# 49            True

# %%
output.columns
# Out:
# Index(['location_id', 'location_name', 'nutrient', 'r', 'sub_population',
#        'u5_applicable', 'value_025_percentile', 'value_975_percentile',
#        'value_description', 'value_mean', 'vehicle', 'wra_applicable'],
#       dtype='object')

# %%
# checkout problem rows

# %%
output.loc[(output.value_mean > output.value_975_percentile) | (output.value_mean < output.value_025_percentile)]
# Out:
# Empty DataFrame
# Columns: [location_id, location_name, nutrient, r, sub_population, u5_applicable, value_025_percentile, value_975_percentile, value_description, value_mean, vehicle, wra_applicable]
# Index: []

# %%
output.loc[(output.value_mean == output.value_975_percentile) & (output.value_description!='percent of population eating vehicle')]
# Out:
#      location_id                     location_name    nutrient         r  \
# 2            179                          Ethiopia  folic acid       NaN
# 3            179                          Ethiopia        iron       NaN
# 4            179                          Ethiopia   vitamin a       NaN
# 5            179                          Ethiopia        zinc       NaN
# 9            179                          Ethiopia   vitamin a       NaN
# 13           179                          Ethiopia  folic acid       NaN
# 14           179                          Ethiopia        iron       NaN
# 15           179                          Ethiopia   vitamin a       NaN
# 16           179                          Ethiopia        zinc       NaN
# 56           165                          Pakistan   vitamin a       NaN
# 106          201                      Burkina Faso          na       NaN
# 107          201                      Burkina Faso  folic acid       NaN
# 108          201                      Burkina Faso        iron       NaN
# 109          201                      Burkina Faso   vitamin a       NaN
# 110          201                      Burkina Faso        zinc       NaN
# 123          180                             Kenya  folic acid       NaN
# 125          180                             Kenya   vitamin a       NaN
# 126          180                             Kenya        zinc       NaN
# 129          180                             Kenya   vitamin a       NaN
# 143           15                           Myanmar   vitamin a       NaN
# 147          164                             Nepal   vitamin a       NaN
# 153          164                             Nepal        zinc       NaN
# 157           20                          Viet Nam   vitamin a       NaN
# 192          205                     Côte d'Ivoire  folic acid       NaN
# 194          205                     Côte d'Ivoire   vitamin a       NaN
# 195          205                     Côte d'Ivoire        zinc       NaN
# 198          171  Democratic Republic of the Congo  folic acid       NaN
# 199          171  Democratic Republic of the Congo        iron       NaN
# 200          171  Democratic Republic of the Congo   vitamin a       NaN
# 201          171  Democratic Republic of the Congo        zinc       NaN
# 204          171  Democratic Republic of the Congo   vitamin a       NaN
# 207          171  Democratic Republic of the Congo  folic acid       NaN
# 208          171  Democratic Republic of the Congo        iron       NaN
# 209          171  Democratic Republic of the Congo   vitamin a       NaN
# 210          171  Democratic Republic of the Congo        zinc       NaN
# 40            15                           Myanmar   vitamin a  0.379944
# 41           164                             Nepal   vitamin a  0.379944
# 46           522                             Sudan   vitamin a  0.379944
#
#     sub_population  u5_applicable  value_025_percentile  value_975_percentile  \
# 2              NaN           True                   0.0                   0.0
# 3              NaN           True                   0.0                   0.0
# 4              NaN           True                   0.0                   0.0
# 5              NaN           True                   0.0                   0.0
# 9              NaN           True                   0.0                   0.0
# 13             NaN           True                   0.0                   0.0
# 14             NaN           True                   0.0                   0.0
# 15             NaN           True                   0.0                   0.0
# 16             NaN           True                   0.0                   0.0
# 56             NaN           True                   0.0                   0.0
# 106            NaN           True                   0.0                   0.0
# 107            NaN           True                   0.0                   0.0
# 108            NaN           True                   0.0                   0.0
# 109            NaN           True                   0.0                   0.0
# 110            NaN           True                   0.0                   0.0
# 123            NaN           True                   0.0                   0.0
# 125            NaN           True                   0.0                   0.0
# 126            NaN           True                   0.0                   0.0
# 129            NaN           True                   0.0                   0.0
# 143            NaN           True                   0.0                   0.0
# 147            NaN           True                   0.0                   0.0
# 153            NaN           True                   0.0                   0.0
# 157            NaN           True                   0.0                   0.0
# 192            NaN           True                   0.0                   0.0
# 194            NaN           True                   0.0                   0.0
# 195            NaN           True                   0.0                   0.0
# 198            NaN           True                   0.0                   0.0
# 199            NaN           True                   0.0                   0.0
# 200            NaN           True                   0.0                   0.0
# 201            NaN           True                   0.0                   0.0
# 204            NaN           True                   0.0                   0.0
# 207            NaN           True                   0.0                   0.0
# 208            NaN           True                   0.0                   0.0
# 209            NaN           True                   0.0                   0.0
# 210            NaN           True                   0.0                   0.0
# 40             NaN           True                   0.0                   0.0
# 41             NaN           True                   0.0                   0.0
# 46             NaN           True                   0.0                   0.0
#
#                                      value_description  value_mean  \
# 2       percent of population eating fortified vehicle         0.0
# 3       percent of population eating fortified vehicle         0.0
# 4       percent of population eating fortified vehicle         0.0
# 5       percent of population eating fortified vehicle         0.0
# 9       percent of population eating fortified vehicle         0.0
# 13      percent of population eating fortified vehicle         0.0
# 14      percent of population eating fortified vehicle         0.0
# 15      percent of population eating fortified vehicle         0.0
# 16      percent of population eating fortified vehicle         0.0
# 56      percent of population eating fortified vehicle         0.0
# 106  percent of population eating industrially prod...         0.0
# 107     percent of population eating fortified vehicle         0.0
# 108     percent of population eating fortified vehicle         0.0
# 109     percent of population eating fortified vehicle         0.0
# 110     percent of population eating fortified vehicle         0.0
# 123     percent of population eating fortified vehicle         0.0
# 125     percent of population eating fortified vehicle         0.0
# 126     percent of population eating fortified vehicle         0.0
# 129     percent of population eating fortified vehicle         0.0
# 143     percent of population eating fortified vehicle         0.0
# 147     percent of population eating fortified vehicle         0.0
# 153     percent of population eating fortified vehicle         0.0
# 157     percent of population eating fortified vehicle         0.0
# 192     percent of population eating fortified vehicle         0.0
# 194     percent of population eating fortified vehicle         0.0
# 195     percent of population eating fortified vehicle         0.0
# 198     percent of population eating fortified vehicle         0.0
# 199     percent of population eating fortified vehicle         0.0
# 200     percent of population eating fortified vehicle         0.0
# 201     percent of population eating fortified vehicle         0.0
# 204     percent of population eating fortified vehicle         0.0
# 207     percent of population eating fortified vehicle         0.0
# 208     percent of population eating fortified vehicle         0.0
# 209     percent of population eating fortified vehicle         0.0
# 210     percent of population eating fortified vehicle         0.0
# 40      percent of population eating fortified vehicle         0.0
# 41      percent of population eating fortified vehicle         0.0
# 46      percent of population eating fortified vehicle         0.0
#
#           vehicle  wra_applicable
# 2     maize flour            True
# 3     maize flour            True
# 4     maize flour            True
# 5     maize flour            True
# 9             oil            True
# 13    wheat flour            True
# 14    wheat flour            True
# 15    wheat flour            True
# 16    wheat flour            True
# 56    wheat flour            True
# 106   maize flour            True
# 107   maize flour            True
# 108   maize flour            True
# 109   maize flour            True
# 110   maize flour            True
# 123   maize flour            True
# 125   maize flour            True
# 126   maize flour            True
# 129           oil            True
# 143   wheat flour            True
# 147           oil            True
# 153   wheat flour            True
# 157           oil            True
# 192   wheat flour            True
# 194   wheat flour            True
# 195   wheat flour            True
# 198   maize flour            True
# 199   maize flour            True
# 200   maize flour            True
# 201   maize flour            True
# 204           oil            True
# 207   wheat flour            True
# 208   wheat flour            True
# 209   wheat flour            True
# 210   wheat flour            True
# 40   industry oil            True
# 41   industry oil            True
# 46   industry oil            True

# %%
output.loc[(output.value_mean == output.value_025_percentile) & (output.value_description!='percent of population eating vehicle')]
# Out:
#      location_id                     location_name    nutrient         r  \
# 2            179                          Ethiopia  folic acid       NaN
# 3            179                          Ethiopia        iron       NaN
# 4            179                          Ethiopia   vitamin a       NaN
# 5            179                          Ethiopia        zinc       NaN
# 9            179                          Ethiopia   vitamin a       NaN
# 13           179                          Ethiopia  folic acid       NaN
# 14           179                          Ethiopia        iron       NaN
# 15           179                          Ethiopia   vitamin a       NaN
# 16           179                          Ethiopia        zinc       NaN
# 56           165                          Pakistan   vitamin a       NaN
# 106          201                      Burkina Faso          na       NaN
# 107          201                      Burkina Faso  folic acid       NaN
# 108          201                      Burkina Faso        iron       NaN
# 109          201                      Burkina Faso   vitamin a       NaN
# 110          201                      Burkina Faso        zinc       NaN
# 123          180                             Kenya  folic acid       NaN
# 125          180                             Kenya   vitamin a       NaN
# 126          180                             Kenya        zinc       NaN
# 129          180                             Kenya   vitamin a       NaN
# 138           15                           Myanmar   vitamin a       NaN
# 141           15                           Myanmar  folic acid       NaN
# 142           15                           Myanmar        iron       NaN
# 143           15                           Myanmar   vitamin a       NaN
# 144           15                           Myanmar        zinc       NaN
# 147          164                             Nepal   vitamin a       NaN
# 153          164                             Nepal        zinc       NaN
# 157           20                          Viet Nam   vitamin a       NaN
# 192          205                     Côte d'Ivoire  folic acid       NaN
# 194          205                     Côte d'Ivoire   vitamin a       NaN
# 195          205                     Côte d'Ivoire        zinc       NaN
# 198          171  Democratic Republic of the Congo  folic acid       NaN
# 199          171  Democratic Republic of the Congo        iron       NaN
# 200          171  Democratic Republic of the Congo   vitamin a       NaN
# 201          171  Democratic Republic of the Congo        zinc       NaN
# 204          171  Democratic Republic of the Congo   vitamin a       NaN
# 207          171  Democratic Republic of the Congo  folic acid       NaN
# 208          171  Democratic Republic of the Congo        iron       NaN
# 209          171  Democratic Republic of the Congo   vitamin a       NaN
# 210          171  Democratic Republic of the Congo        zinc       NaN
# 40            15                           Myanmar   vitamin a  0.379944
# 41           164                             Nepal   vitamin a  0.379944
# 46           522                             Sudan   vitamin a  0.379944
#
#        sub_population  u5_applicable  value_025_percentile  \
# 2                 NaN           True                   0.0
# 3                 NaN           True                   0.0
# 4                 NaN           True                   0.0
# 5                 NaN           True                   0.0
# 9                 NaN           True                   0.0
# 13                NaN           True                   0.0
# 14                NaN           True                   0.0
# 15                NaN           True                   0.0
# 16                NaN           True                   0.0
# 56                NaN           True                   0.0
# 106               NaN           True                   0.0
# 107               NaN           True                   0.0
# 108               NaN           True                   0.0
# 109               NaN           True                   0.0
# 110               NaN           True                   0.0
# 123               NaN           True                   0.0
# 125               NaN           True                   0.0
# 126               NaN           True                   0.0
# 129               NaN           True                   0.0
# 138  total population           True                   0.0
# 141  total population           True                   0.0
# 142  total population           True                   0.0
# 143               NaN           True                   0.0
# 144  total population           True                   0.0
# 147               NaN           True                   0.0
# 153               NaN           True                   0.0
# 157               NaN           True                   0.0
# 192               NaN           True                   0.0
# 194               NaN           True                   0.0
# 195               NaN           True                   0.0
# 198               NaN           True                   0.0
# 199               NaN           True                   0.0
# 200               NaN           True                   0.0
# 201               NaN           True                   0.0
# 204               NaN           True                   0.0
# 207               NaN           True                   0.0
# 208               NaN           True                   0.0
# 209               NaN           True                   0.0
# 210               NaN           True                   0.0
# 40                NaN           True                   0.0
# 41                NaN           True                   0.0
# 46                NaN           True                   0.0
#
#      value_975_percentile                                  value_description  \
# 2                     0.0     percent of population eating fortified vehicle
# 3                     0.0     percent of population eating fortified vehicle
# 4                     0.0     percent of population eating fortified vehicle
# 5                     0.0     percent of population eating fortified vehicle
# 9                     0.0     percent of population eating fortified vehicle
# 13                    0.0     percent of population eating fortified vehicle
# 14                    0.0     percent of population eating fortified vehicle
# 15                    0.0     percent of population eating fortified vehicle
# 16                    0.0     percent of population eating fortified vehicle
# 56                    0.0     percent of population eating fortified vehicle
# 106                   0.0  percent of population eating industrially prod...
# 107                   0.0     percent of population eating fortified vehicle
# 108                   0.0     percent of population eating fortified vehicle
# 109                   0.0     percent of population eating fortified vehicle
# 110                   0.0     percent of population eating fortified vehicle
# 123                   0.0     percent of population eating fortified vehicle
# 125                   0.0     percent of population eating fortified vehicle
# 126                   0.0     percent of population eating fortified vehicle
# 129                   0.0     percent of population eating fortified vehicle
# 138                   5.0     percent of population eating fortified vehicle
# 141                   5.0     percent of population eating fortified vehicle
# 142                   5.0     percent of population eating fortified vehicle
# 143                   0.0     percent of population eating fortified vehicle
# 144                   5.0     percent of population eating fortified vehicle
# 147                   0.0     percent of population eating fortified vehicle
# 153                   0.0     percent of population eating fortified vehicle
# 157                   0.0     percent of population eating fortified vehicle
# 192                   0.0     percent of population eating fortified vehicle
# 194                   0.0     percent of population eating fortified vehicle
# 195                   0.0     percent of population eating fortified vehicle
# 198                   0.0     percent of population eating fortified vehicle
# 199                   0.0     percent of population eating fortified vehicle
# 200                   0.0     percent of population eating fortified vehicle
# 201                   0.0     percent of population eating fortified vehicle
# 204                   0.0     percent of population eating fortified vehicle
# 207                   0.0     percent of population eating fortified vehicle
# 208                   0.0     percent of population eating fortified vehicle
# 209                   0.0     percent of population eating fortified vehicle
# 210                   0.0     percent of population eating fortified vehicle
# 40                    0.0     percent of population eating fortified vehicle
# 41                    0.0     percent of population eating fortified vehicle
# 46                    0.0     percent of population eating fortified vehicle
#
#      value_mean       vehicle  wra_applicable
# 2           0.0   maize flour            True
# 3           0.0   maize flour            True
# 4           0.0   maize flour            True
# 5           0.0   maize flour            True
# 9           0.0           oil            True
# 13          0.0   wheat flour            True
# 14          0.0   wheat flour            True
# 15          0.0   wheat flour            True
# 16          0.0   wheat flour            True
# 56          0.0   wheat flour            True
# 106         0.0   maize flour            True
# 107         0.0   maize flour            True
# 108         0.0   maize flour            True
# 109         0.0   maize flour            True
# 110         0.0   maize flour            True
# 123         0.0   maize flour            True
# 125         0.0   maize flour            True
# 126         0.0   maize flour            True
# 129         0.0           oil            True
# 138         0.0           oil            True
# 141         0.0   wheat flour            True
# 142         0.0   wheat flour            True
# 143         0.0   wheat flour            True
# 144         0.0   wheat flour            True
# 147         0.0           oil            True
# 153         0.0   wheat flour            True
# 157         0.0           oil            True
# 192         0.0   wheat flour            True
# 194         0.0   wheat flour            True
# 195         0.0   wheat flour            True
# 198         0.0   maize flour            True
# 199         0.0   maize flour            True
# 200         0.0   maize flour            True
# 201         0.0   maize flour            True
# 204         0.0           oil            True
# 207         0.0   wheat flour            True
# 208         0.0   wheat flour            True
# 209         0.0   wheat flour            True
# 210         0.0   wheat flour            True
# 40          0.0  industry oil            True
# 41          0.0  industry oil            True
# 46          0.0  industry oil            True

# %%
output.to_csv('/ihme/homes/beatrixh/repos/scratch/lsff_input_coverage_data.csv')

# %%
save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/lsff_input_coverage_data_w_industry_oil_04_12_2021.csv'
output.to_csv(save_path)
