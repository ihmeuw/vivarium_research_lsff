# %%
import pandas as pd, numpy as np

# %%
path = '/ihme/homes/beatrixh/notebooks/viv_rsc/new_lsff/inputs/extraction_sheet_lsff_01_06_2021.csv'
df = pd.read_csv(path)

# %% [markdown]
# # LSFF

# %% [markdown]
# # Look through data by hand; choose all country-vehicle pairs for which we have all the data we want, and clean up for use.

# %% [markdown]
# IN: extraction sheet + vehicle-nutrient, country-vehicle dicts

# %% [markdown]
# ASSUME: for vehicle-locations where we have some but not all nutrients, we assign, to the remaining nutrients, the same value as the extracted nutrients if there is evidence of fortification (in GFDx), else 0

# %% [markdown]
# OUT: cleaned dataset for india, nigeria, cote d'ivoire, uganda, tanzania, south africa

# %% [markdown]
# ## one country at a time, checkout data quality

# %%
check_cols = ['location_id','location_name','urbanicity','subnational_name','vehicle','value_description','nutrient','value_mean','value_025_percentile',
       'value_975_percentile','sub_population','notes','source_citation']

def filter_data(country, vehicle, val):    
    output = df.loc[(df.location_name==country)
           & (df.vehicle==vehicle)
           & (df.value_description==val)
           & (df.value_mean.notna())
           & (df.value_025_percentile.notna()),check_cols]
    
    return output

# %%
def check_one_country(country):
    vehicles = ['oil', 'wheat flour', 'salt', 'maize flour', 'rice', 'bouillon']
    values_gold = ['percent of population eating fortified vehicle',
               'percent of population eating industrially produced vehicle',
               'percent of population eating vehicle']
    return pd.concat([filter_data(country, vehicle, val) for vehicle in vehicles for val in values_gold])

# %%
usecols = ['location_id','location_name','subnational_name','vehicle','value_description','nutrient','value_mean', 'value_025_percentile',
       'value_975_percentile']
subset_data = {}

# %%
india = check_one_country('India')
india = india[india.vehicle!='salt'] #missing CIs
subset_data['India'] = india[usecols]

# %%
nigeria = check_one_country('Nigeria')
nigeria = nigeria[~nigeria.vehicle.isin(['salt','bouillon'])] #missing proportion of the population eating salt. missing lots for bouillon

subset_data['Nigeria'] = nigeria[usecols]

# %%
pakistan = check_one_country('Pakistan')
pakistan.vehicle.unique()
# for oil and wheat flour: missing percent of population eating fortified vehicle
# Out:
# array(['oil', 'wheat flour'], dtype=object)

# %%
# check_one_country("Burkina Faso")
# missing almost everything

# %%
cotedivoire = check_one_country("CÃ´te d'Ivoire")
cotedivoire = cotedivoire[cotedivoire.vehicle!="wheat flour"]

subset_data["CÃ´te d'Ivoire"] = cotedivoire[usecols]

# %%
uganda = check_one_country("Uganda")
uganda = uganda.loc[(uganda.source_citation!='GFDx') & (uganda.value_025_percentile!='na'),usecols] #duplicate entries
subset_data['Uganda'] = uganda

# %%
tanzania = check_one_country('United Republic of Tanzania')

tanzania = tanzania[tanzania.source_citation=="Grant J Aaron, Valerie M Friesen, Svenja Jungjohann, Greg S Garrett, Lynnette M Neufeld, Mark Myatt, Coverage of Large-Scale Food Fortification of Edible Oil, Wheat Flour, and Maize Flour Varies Greatly by Vehicle and Country but Is Consistently Lower among the Most Vulnerable: Results from Coverage Surveys in 8 Countries, The Journal of Nutrition, Volume 147, Issue 5, May 2017, Pages 984S–994S, https://doi.org/10.3945/jn.116.245770"]
subset_data['United Republic of Tanzania'] = tanzania

# %%
# nepal = check_one_country('Nepal') #missing percent pop eating fortified wheat, + everything else for other vehicles

# %%
safrica = check_one_country('South Africa')

subset_data['South Africa'] = safrica

# %% [markdown]
# ## for usable country-vehicle pairs, subset to a minimal set & clean

# %% [markdown]
# ## clean vehicle names

# %%
all_data = pd.concat(list(subset_data.values()))

# %%
all_data.nutrient.unique()
# Out:
# array(['vitamin a',
#        'd, ergocalciferol-D2, cholecalciferol-D3, alfacalcidol', 'na',
#        'iron', 'folic acid, folate, b9', 'b12', 'zinc', 'b1, thiamine',
#        'b2, riboflavin', 'b3, niacin', 'b6, pyridoxine'], dtype=object)

# %%
nutrient_map = {'d, ergocalciferol-D2, cholecalciferol-D3, alfacalcidol':'vitamin d',
                'folic acid, folate, b9':'folic acid',
                'b12':'vitamin b12',
                'b2, riboflavin':'vitamin b2',
                'b3, niacin':'vitamin b3',
                'b1, thiamine':'vitamin b1',
                'b6, pyridoxine':'vitamin b6',
                'vitamin a':'vitamin a',
                'iron':'iron',
                'zinc':'zinc'
               }

# %%
for country in subset_data.keys():
    subset_data[country]['nutrient'] = subset_data[country]['nutrient'].map(nutrient_map)
# Out:
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
subset_data.keys()
# Out:
# dict_keys(['India', 'Nigeria', "CÃ´te d'Ivoire", 'Uganda', 'United Republic of Tanzania', 'South Africa'])

# %% [markdown]
# # Format and prep per subnational

# %%
final_data = {}

# %% [markdown]
# ## India

# %%
subset_data['India']
# Out:
#      location_id location_name subnational_name      vehicle  \
# 0          163.0         India        Rajasthan          oil
# 481        163.0         India        Rajasthan          oil
# 1          163.0         India        Rajasthan          oil
# 2          163.0         India        Rajasthan          oil
# 3          163.0         India        Rajasthan  wheat flour
# 27         163.0         India        Rajasthan  wheat flour
# 28         163.0         India        Rajasthan  wheat flour
# 4          163.0         India        Rajasthan  wheat flour
# 26         163.0         India        Rajasthan  wheat flour
#
#                                      value_description     nutrient  \
# 0       percent of population eating fortified vehicle    vitamin a
# 481     percent of population eating fortified vehicle    vitamin d
# 1    percent of population eating industrially prod...          NaN
# 2                 percent of population eating vehicle          NaN
# 3       percent of population eating fortified vehicle         iron
# 27      percent of population eating fortified vehicle   folic acid
# 28      percent of population eating fortified vehicle  vitamin b12
# 4    percent of population eating industrially prod...          NaN
# 26                percent of population eating vehicle          NaN
#
#     value_mean value_025_percentile value_975_percentile
# 0         24.3                 21.1                 27.9
# 481       24.3                 21.1                 27.9
# 1         89.4                   87                 91.8
# 2          100                  100                  100
# 3          6.3                  4.8                  7.9
# 27         6.3                  4.8                  7.9
# 28         6.3                  4.8                  7.9
# 4          7.1                  5.6                  9.1
# 26        83.2                 79.5                 86.5

# %%
k = 3
additional_india = pd.DataFrame({'location_id':[163]*k,
                           'location_name':["India"]*k,
                           'vehicle':['wheat flour']*k,
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['zinc','vitamin b1','vitamin a'],
                           'value_mean':[6.3]*k,
                           'value_025_percentile':[4.8]*k,
                           'value_975_percentile':[7.9]*k})
additional_india
# Out:
#    location_id location_name      vehicle  \
# 0          163         India  wheat flour
# 1          163         India  wheat flour
# 2          163         India  wheat flour
#
#                                 value_description    nutrient  value_mean  \
# 0  percent of population eating fortified vehicle        zinc         6.3
# 1  percent of population eating fortified vehicle  vitamin b1         6.3
# 2  percent of population eating fortified vehicle   vitamin a         6.3
#
#    value_025_percentile  value_975_percentile
# 0                   4.8                   7.9
# 1                   4.8                   7.9
# 2                   4.8                   7.9

# %%
def add_additional(df1, df2):
    return pd.concat([df1, df2]).sort_values(['location_name','vehicle','value_description','nutrient'])

# %%
final_data["India"] = add_additional(subset_data['India'], additional_india)

# %%
final_data["India"]
# Out:
#      location_id location_name subnational_name      vehicle  \
# 0          163.0         India        Rajasthan          oil
# 481        163.0         India        Rajasthan          oil
# 1          163.0         India        Rajasthan          oil
# 2          163.0         India        Rajasthan          oil
# 27         163.0         India        Rajasthan  wheat flour
# 3          163.0         India        Rajasthan  wheat flour
# 2          163.0         India              NaN  wheat flour
# 1          163.0         India              NaN  wheat flour
# 28         163.0         India        Rajasthan  wheat flour
# 0          163.0         India              NaN  wheat flour
# 4          163.0         India        Rajasthan  wheat flour
# 26         163.0         India        Rajasthan  wheat flour
#
#                                      value_description     nutrient  \
# 0       percent of population eating fortified vehicle    vitamin a
# 481     percent of population eating fortified vehicle    vitamin d
# 1    percent of population eating industrially prod...          NaN
# 2                 percent of population eating vehicle          NaN
# 27      percent of population eating fortified vehicle   folic acid
# 3       percent of population eating fortified vehicle         iron
# 2       percent of population eating fortified vehicle    vitamin a
# 1       percent of population eating fortified vehicle   vitamin b1
# 28      percent of population eating fortified vehicle  vitamin b12
# 0       percent of population eating fortified vehicle         zinc
# 4    percent of population eating industrially prod...          NaN
# 26                percent of population eating vehicle          NaN
#
#     value_mean value_025_percentile value_975_percentile
# 0         24.3                 21.1                 27.9
# 481       24.3                 21.1                 27.9
# 1         89.4                   87                 91.8
# 2          100                  100                  100
# 27         6.3                  4.8                  7.9
# 3          6.3                  4.8                  7.9
# 2          6.3                  4.8                  7.9
# 1          6.3                  4.8                  7.9
# 28         6.3                  4.8                  7.9
# 0          6.3                  4.8                  7.9
# 4          7.1                  5.6                  9.1
# 26        83.2                 79.5                 86.5

# %% [markdown]
# ## Nigeria

# %%
nigeria1 = subset_data['Nigeria']

# %%
df.columns
# Out:
# Index(['location_id', 'location_name', 'subnational_name',
#        'subnational_location_id', 'urbanicity', 'vehicle', 'nutrient',
#        'nutrient_compound', 'nutrient_mass_ppm', 'fortification_standards',
#        'compliance', 'compliance_source', 'value_description',
#        'fortification_status', 'value_mean', 'value_025_percentile',
#        'value_975_percentile', 'sub_population', 'source_citation',
#        'source_link', 'source_year', 'source_type', 'source_additional',
#        'notes', 'user', 'date_recorded', 'Unnamed: 26'],
#       dtype='object')

# %%
def double_check_data(country, vehicle, val):
    subset = df.loc[(df.location_name==country) &
                    (df.vehicle==vehicle) &
                    (df.value_description==val),
                    ['vehicle','value_description','nutrient','value_mean','value_025_percentile','value_975_percentile']] 
    return subset

# %%
# double check that we have no data on nigeria oil fortified with vitamin d
double_check_data("Nigeria","oil","percent of population eating fortified vehicle")
# Out:
#    vehicle                               value_description  \
# 44     oil  percent of population eating fortified vehicle
# 66     oil  percent of population eating fortified vehicle
# 87     oil  percent of population eating fortified vehicle
# 97     oil  percent of population eating fortified vehicle
#
#                                              nutrient value_mean  \
# 44  d, ergocalciferol-D2, cholecalciferol-D3, alfa...         na
# 66                                          vitamin a        7.2
# 87                                          vitamin a        7.6
# 97  d, ergocalciferol-D2, cholecalciferol-D3, alfa...         na
#
#    value_025_percentile value_975_percentile
# 44                   na                   na
# 66                  5.5                  8.9
# 87                  5.9                  9.4
# 97                   na                   na

# %%
# zero out nigeria oil fortified with vitamin d
nigeria1.loc[(nigeria1.value_description=="percent of population eating fortified vehicle") &
             (nigeria1.nutrient=='vitamin d'),['value_mean','value_025_percentile','value_975_percentile']] = [0,0,5]
# Out:
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# double check we have no nigeria/wheat/b12 info
double_check_data("Nigeria","wheat flour","percent of population eating fortified vehicle")
# Out:
#          vehicle                               value_description  \
# 67   wheat flour  percent of population eating fortified vehicle
# 70   wheat flour  percent of population eating fortified vehicle
# 71   wheat flour  percent of population eating fortified vehicle
# 72   wheat flour  percent of population eating fortified vehicle
# 73   wheat flour  percent of population eating fortified vehicle
# 98   wheat flour  percent of population eating fortified vehicle
# 99   wheat flour  percent of population eating fortified vehicle
# 100  wheat flour  percent of population eating fortified vehicle
# 101  wheat flour  percent of population eating fortified vehicle
# 102  wheat flour  percent of population eating fortified vehicle
#
#                    nutrient value_mean value_025_percentile  \
# 67                     zinc        5.4                  3.8
# 70                     iron        5.4                  3.8
# 71   folic acid, folate, b9        5.4                  3.8
# 72                vitamin a        5.4                  3.8
# 73             b1, thiamine        5.4                  3.8
# 98                     iron       22.7                   20
# 99   folic acid, folate, b9       22.7                   20
# 100               vitamin a       22.7                   20
# 101                    zinc       22.7                   20
# 102            b1, thiamine       22.7                   20
#
#     value_975_percentile
# 67                   6.9
# 70                   6.9
# 71                   6.9
# 72                   6.9
# 73                   6.9
# 98                  25.5
# 99                  25.5
# 100                 25.5
# 101                 25.5
# 102                 25.5

# %%
#add wheat/b12 info
k = 2
additional_nigeria0 = pd.DataFrame({'location_id':[214]*k,
                                   'location_name':["Nigeria"]*k,
                                   'subnational_name':['lagos','kano'],
                                   'vehicle':['wheat flour']*k,
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['vitamin b12']*k,
                           'value_mean':[5.4,22.7],
                           'value_025_percentile':[3.8,20],
                           'value_975_percentile':[6.9,25.5]})
additional_nigeria0
# Out:
#    location_id location_name subnational_name      vehicle  \
# 0          214       Nigeria            lagos  wheat flour
# 1          214       Nigeria             kano  wheat flour
#
#                                 value_description     nutrient  value_mean  \
# 0  percent of population eating fortified vehicle  vitamin b12         5.4
# 1  percent of population eating fortified vehicle  vitamin b12        22.7
#
#    value_025_percentile  value_975_percentile
# 0                   3.8                   6.9
# 1                  20.0                  25.5

# %%
# double check we have no nigeria/maize/b12 info
double_check_data("Nigeria","maize flour","percent of population eating fortified vehicle")
# Out:
#          vehicle                               value_description  \
# 78   maize flour  percent of population eating fortified vehicle
# 79   maize flour  percent of population eating fortified vehicle
# 80   maize flour  percent of population eating fortified vehicle
# 105  maize flour  percent of population eating fortified vehicle
# 106  maize flour  percent of population eating fortified vehicle
# 107  maize flour  percent of population eating fortified vehicle
#
#                    nutrient value_mean value_025_percentile  \
# 78   folic acid, folate, b9        0.2                    0
# 79                vitamin a        0.2                    0
# 80                     zinc        0.2                    0
# 105  folic acid, folate, b9        1.7                  0.9
# 106               vitamin a        1.7                  0.9
# 107                    zinc        1.7                  0.9
#
#     value_975_percentile
# 78                   0.5
# 79                   0.5
# 80                   0.5
# 105                  2.6
# 106                  2.6
# 107                  2.6

# %%
#add maize nutrient info
i = 2
j = 3
k = i*j
additional_nigeria1 = pd.DataFrame({'location_id':[214]*k,
                                   'location_name':["Nigeria"]*k,
                                   'subnational_name':['lagos','kano']*j,
                                   'vehicle':['maize flour']*k,
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['iron','vitamin b1','vitamin b12']*i,
                           'value_mean':[0.2,1.7]*j,
                           'value_025_percentile':[0,0.9]*j,
                           'value_975_percentile':[0.5,2.6]*j})
additional_nigeria1
# Out:
#    location_id location_name subnational_name      vehicle  \
# 0          214       Nigeria            lagos  maize flour
# 1          214       Nigeria             kano  maize flour
# 2          214       Nigeria            lagos  maize flour
# 3          214       Nigeria             kano  maize flour
# 4          214       Nigeria            lagos  maize flour
# 5          214       Nigeria             kano  maize flour
#
#                                 value_description     nutrient  value_mean  \
# 0  percent of population eating fortified vehicle         iron         0.2
# 1  percent of population eating fortified vehicle   vitamin b1         1.7
# 2  percent of population eating fortified vehicle  vitamin b12         0.2
# 3  percent of population eating fortified vehicle         iron         1.7
# 4  percent of population eating fortified vehicle   vitamin b1         0.2
# 5  percent of population eating fortified vehicle  vitamin b12         1.7
#
#    value_025_percentile  value_975_percentile
# 0                   0.0                   0.5
# 1                   0.9                   2.6
# 2                   0.0                   0.5
# 3                   0.9                   2.6
# 4                   0.0                   0.5
# 5                   0.9                   2.6

# %%
# look closer at rice data we have; seems incongruous
df.loc[(df.location_name=="Nigeria") & (df.vehicle=="rice"),['subnational_name','value_description','value_mean','source_link','source_year']]
# Out:
#     subnational_name                                  value_description  \
# 124               na                                                NaN
# 457               na   percent of vehicle that is industrially produced
# 494               na   percent of vehicle that is industrially produced
# 495               na               percent of population eating vehicle
# 508           Ebonyi  percent of population eating industrially prod...
# 509           Sokoto  percent of population eating industrially prod...
#
#     value_mean                                        source_link source_year
# 124        NaN                                                NaN         NaN
# 457         10  https://fortificationdata.org/chart-quantity-a...        2017
# 494         na  https://issuu.com/sight_and_life/docs/sightand...        2013
# 495       14.9  https://issuu.com/sight_and_life/docs/sightand...   2001-2003
# 508        100  https://www.gainhealth.org/sites/default/files...        2018
# 509         99  https://www.gainhealth.org/sites/default/files...        2018

# %%
nigeria2 = add_additional(nigeria1[nigeria1.vehicle!='rice'], pd.concat([additional_nigeria0, additional_nigeria1]))
nigeria2.loc[nigeria2.vehicle!='rice','subnational_weight'] = 'by pop, from year 2015'

# %%
final_data["Nigeria"] = nigeria2

# %% [markdown]
# ## CÃ´te d'Ivoire

# %%
cotedivoire1 = subset_data["CÃ´te d'Ivoire"]
cotedivoire1
# Out:
#      location_id   location_name subnational_name vehicle  \
# 94         205.0  CÃ´te d'Ivoire               na     oil
# 95         205.0  CÃ´te d'Ivoire               na     oil
# 600        205.0  CÃ´te d'Ivoire          Abidjan     oil
# 599        205.0  CÃ´te d'Ivoire          Abidjan     oil
# 598        205.0  CÃ´te d'Ivoire          Abidjan     oil
#
#                                      value_description   nutrient value_mean  \
# 94      percent of population eating fortified vehicle  vitamin a         70
# 95      percent of population eating fortified vehicle  vitamin a         75
# 600     percent of population eating fortified vehicle  vitamin a         98
# 599  percent of population eating industrially prod...        NaN         98
# 598               percent of population eating vehicle        NaN       98.5
#
#     value_025_percentile value_975_percentile
# 94                    na                   na
# 95                    na                   na
# 600                   97                   99
# 599                   97                   99
# 598                 97.5                 99.3

# %%
cotedivoire1 = cotedivoire1[cotedivoire1.value_025_percentile!='na']

# %%
# make sure no data on vitamin d
double_check_data("CÃ´te d'Ivoire","oil","percent of population eating fortified vehicle")
# Out:
#     vehicle                               value_description   nutrient  \
# 94      oil  percent of population eating fortified vehicle  vitamin a
# 95      oil  percent of population eating fortified vehicle  vitamin a
# 600     oil  percent of population eating fortified vehicle  vitamin a
#
#     value_mean value_025_percentile value_975_percentile
# 94          70                   na                   na
# 95          75                   na                   na
# 600         98                   97                   99

# %%
k = 1
additional_cotedivoire = pd.DataFrame({'location_id':[205]*k,
                           'location_name':["CÃ´te d'Ivoire"]*k,
                           'vehicle':['oil']*k,
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['vitamin d'],
                           'value_mean':[0]*k,
                           'value_025_percentile':[0]*k,
                           'value_975_percentile':[5]*k})
additional_cotedivoire
# Out:
#    location_id   location_name vehicle  \
# 0          205  CÃ´te d'Ivoire     oil
#
#                                 value_description   nutrient  value_mean  \
# 0  percent of population eating fortified vehicle  vitamin d           0
#
#    value_025_percentile  value_975_percentile
# 0                     0                     5

# %%
cotedivoire2 = add_additional(cotedivoire1, additional_cotedivoire)

# %%
final_data["CÃ´te d'Ivoire"] = cotedivoire2

# %% [markdown]
# ## Uganda

# %%
subset_data['Uganda']
# Out:
#      location_id location_name subnational_name      vehicle  \
# 269        190.0        Uganda               na          oil
# 272        190.0        Uganda               na          oil
# 271        190.0        Uganda               na          oil
# 300        190.0        Uganda               na  wheat flour
# 301        190.0        Uganda               na  wheat flour
# 302        190.0        Uganda               na  wheat flour
# 303        190.0        Uganda               na  wheat flour
# 304        190.0        Uganda               na  wheat flour
# 305        190.0        Uganda               na  wheat flour
# 298        190.0        Uganda               na  wheat flour
# 299        190.0        Uganda               na  wheat flour
# 169        190.0        Uganda               na  maize flour
# 275        190.0        Uganda               na  maize flour
# 293        190.0        Uganda               na  maize flour
# 294        190.0        Uganda               na  maize flour
# 295        190.0        Uganda               na  maize flour
# 296        190.0        Uganda               na  maize flour
# 273        190.0        Uganda               na  maize flour
# 274        190.0        Uganda               na  maize flour
#
#                                      value_description     nutrient  \
# 269     percent of population eating fortified vehicle    vitamin a
# 272  percent of population eating industrially prod...          NaN
# 271               percent of population eating vehicle          NaN
# 300     percent of population eating fortified vehicle   folic acid
# 301     percent of population eating fortified vehicle         iron
# 302     percent of population eating fortified vehicle    vitamin a
# 303     percent of population eating fortified vehicle   vitamin b1
# 304     percent of population eating fortified vehicle  vitamin b12
# 305     percent of population eating fortified vehicle         zinc
# 298  percent of population eating industrially prod...          NaN
# 299               percent of population eating vehicle          NaN
# 169     percent of population eating fortified vehicle         iron
# 275     percent of population eating fortified vehicle   folic acid
# 293     percent of population eating fortified vehicle         zinc
# 294     percent of population eating fortified vehicle   vitamin b1
# 295     percent of population eating fortified vehicle  vitamin b12
# 296     percent of population eating fortified vehicle    vitamin a
# 273  percent of population eating industrially prod...          NaN
# 274               percent of population eating vehicle          NaN
#
#     value_mean value_025_percentile value_975_percentile
# 269       54.4                 48.3                 60.4
# 272         89                 84.7                 93.2
# 271       89.9                 85.9                   94
# 300        8.5                  5.7                 11.4
# 301        8.5                  5.7                 11.4
# 302        8.5                  5.7                 11.4
# 303        8.5                  5.7                 11.4
# 304        8.5                  5.7                 11.4
# 305        8.5                  5.7                 11.4
# 298       10.6                  7.6                 13.6
# 299       11.2                  7.7                 14.7
# 169        6.5                  3.3                  9.7
# 275        6.5                  3.3                  9.7
# 293        6.5                  3.3                  9.7
# 294        6.5                  3.3                  9.7
# 295        6.5                  3.3                  9.7
# 296        6.5                  3.3                  9.7
# 273       42.4                 32.7                 52.1
# 274       91.8                 87.7                   96

# %%
double_check_data("Uganda","oil","percent of population eating fortified vehicle")
# Out:
#     vehicle                               value_description  \
# 242     oil  percent of population eating fortified vehicle
# 244     oil  percent of population eating fortified vehicle
# 269     oil  percent of population eating fortified vehicle
# 270     oil  percent of population eating fortified vehicle
#
#                                               nutrient value_mean  \
# 242                                          vitamin a       54.4
# 244  d, ergocalciferol-D2, cholecalciferol-D3, alfa...        NaN
# 269                                          vitamin a       54.4
# 270  d, ergocalciferol-D2, cholecalciferol-D3, alfa...          0
#
#     value_025_percentile value_975_percentile
# 242                 48.3                 60.4
# 244                  NaN                  NaN
# 269                 48.3                 60.4
# 270                  NaN                  NaN

# %%
# double checked above paper, didn't find any 0 (under uganda / vitamin D, said "--")

# %%
k = 1
additional_uganda = pd.DataFrame({'location_id':[190]*k,
                           'location_name':["Uganda"]*k,
                           'vehicle':['oil']*k,
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['vitamin d'],
                           'value_mean':[0]*k,
                           'value_025_percentile':[0]*k,
                           'value_975_percentile':[5]*k})
additional_uganda
# Out:
#    location_id location_name vehicle  \
# 0          190        Uganda     oil
#
#                                 value_description   nutrient  value_mean  \
# 0  percent of population eating fortified vehicle  vitamin d           0
#
#    value_025_percentile  value_975_percentile
# 0                     0                     5

# %%
uganda1 = add_additional(subset_data['Uganda'], additional_uganda)
uganda1
# Out:
#      location_id location_name subnational_name      vehicle  \
# 275        190.0        Uganda               na  maize flour
# 169        190.0        Uganda               na  maize flour
# 296        190.0        Uganda               na  maize flour
# 294        190.0        Uganda               na  maize flour
# 295        190.0        Uganda               na  maize flour
# 293        190.0        Uganda               na  maize flour
# 273        190.0        Uganda               na  maize flour
# 274        190.0        Uganda               na  maize flour
# 269        190.0        Uganda               na          oil
# 0          190.0        Uganda              NaN          oil
# 272        190.0        Uganda               na          oil
# 271        190.0        Uganda               na          oil
# 300        190.0        Uganda               na  wheat flour
# 301        190.0        Uganda               na  wheat flour
# 302        190.0        Uganda               na  wheat flour
# 303        190.0        Uganda               na  wheat flour
# 304        190.0        Uganda               na  wheat flour
# 305        190.0        Uganda               na  wheat flour
# 298        190.0        Uganda               na  wheat flour
# 299        190.0        Uganda               na  wheat flour
#
#                                      value_description     nutrient  \
# 275     percent of population eating fortified vehicle   folic acid
# 169     percent of population eating fortified vehicle         iron
# 296     percent of population eating fortified vehicle    vitamin a
# 294     percent of population eating fortified vehicle   vitamin b1
# 295     percent of population eating fortified vehicle  vitamin b12
# 293     percent of population eating fortified vehicle         zinc
# 273  percent of population eating industrially prod...          NaN
# 274               percent of population eating vehicle          NaN
# 269     percent of population eating fortified vehicle    vitamin a
# 0       percent of population eating fortified vehicle    vitamin d
# 272  percent of population eating industrially prod...          NaN
# 271               percent of population eating vehicle          NaN
# 300     percent of population eating fortified vehicle   folic acid
# 301     percent of population eating fortified vehicle         iron
# 302     percent of population eating fortified vehicle    vitamin a
# 303     percent of population eating fortified vehicle   vitamin b1
# 304     percent of population eating fortified vehicle  vitamin b12
# 305     percent of population eating fortified vehicle         zinc
# 298  percent of population eating industrially prod...          NaN
# 299               percent of population eating vehicle          NaN
#
#     value_mean value_025_percentile value_975_percentile
# 275        6.5                  3.3                  9.7
# 169        6.5                  3.3                  9.7
# 296        6.5                  3.3                  9.7
# 294        6.5                  3.3                  9.7
# 295        6.5                  3.3                  9.7
# 293        6.5                  3.3                  9.7
# 273       42.4                 32.7                 52.1
# 274       91.8                 87.7                   96
# 269       54.4                 48.3                 60.4
# 0            0                    0                    5
# 272         89                 84.7                 93.2
# 271       89.9                 85.9                   94
# 300        8.5                  5.7                 11.4
# 301        8.5                  5.7                 11.4
# 302        8.5                  5.7                 11.4
# 303        8.5                  5.7                 11.4
# 304        8.5                  5.7                 11.4
# 305        8.5                  5.7                 11.4
# 298       10.6                  7.6                 13.6
# 299       11.2                  7.7                 14.7

# %%
final_data["Uganda"] = uganda1

# %% [markdown]
# ## Tanzania

# %%
subset_data['United Republic of Tanzania']
# Out:
#      location_id                location_name  urbanicity subnational_name  \
# 213        189.0  United Republic of Tanzania  mixed/both               na
# 214        189.0  United Republic of Tanzania  mixed/both               na
# 215        189.0  United Republic of Tanzania  mixed/both               na
# 233        189.0  United Republic of Tanzania  mixed/both               na
# 234        189.0  United Republic of Tanzania  mixed/both               na
# 235        189.0  United Republic of Tanzania  mixed/both               na
# 236        189.0  United Republic of Tanzania  mixed/both               na
# 237        189.0  United Republic of Tanzania  mixed/both               na
# 238        189.0  United Republic of Tanzania  mixed/both               na
# 225        189.0  United Republic of Tanzania  mixed/both               na
# 226        189.0  United Republic of Tanzania  mixed/both               na
# 219        189.0  United Republic of Tanzania  mixed/both               na
# 220        189.0  United Republic of Tanzania  mixed/both               na
# 221        189.0  United Republic of Tanzania  mixed/both               na
# 222        189.0  United Republic of Tanzania  mixed/both               na
# 223        189.0  United Republic of Tanzania  mixed/both               na
# 224        189.0  United Republic of Tanzania  mixed/both               na
# 217        189.0  United Republic of Tanzania  mixed/both               na
# 218        189.0  United Republic of Tanzania  mixed/both               na
#
#          vehicle                                  value_description  \
# 213          oil     percent of population eating fortified vehicle
# 214          oil  percent of population eating industrially prod...
# 215          oil               percent of population eating vehicle
# 233  wheat flour     percent of population eating fortified vehicle
# 234  wheat flour     percent of population eating fortified vehicle
# 235  wheat flour     percent of population eating fortified vehicle
# 236  wheat flour     percent of population eating fortified vehicle
# 237  wheat flour     percent of population eating fortified vehicle
# 238  wheat flour     percent of population eating fortified vehicle
# 225  wheat flour  percent of population eating industrially prod...
# 226  wheat flour               percent of population eating vehicle
# 219  maize flour     percent of population eating fortified vehicle
# 220  maize flour     percent of population eating fortified vehicle
# 221  maize flour     percent of population eating fortified vehicle
# 222  maize flour     percent of population eating fortified vehicle
# 223  maize flour     percent of population eating fortified vehicle
# 224  maize flour     percent of population eating fortified vehicle
# 217  maize flour  percent of population eating industrially prod...
# 218  maize flour               percent of population eating vehicle
#
#         nutrient value_mean value_025_percentile value_975_percentile  \
# 213    vitamin a       53.6                 46.4                 60.8
# 214          NaN       92.6                   89                 96.3
# 215          NaN       96.2                 93.2                 99.2
# 233   folic acid       33.1                 27.5                 38.7
# 234         iron       33.1                 27.5                 38.7
# 235    vitamin a       33.1                 27.5                 38.7
# 236   vitamin b1       33.1                 27.5                 38.7
# 237  vitamin b12       33.1                 27.5                 38.7
# 238         zinc       33.1                 27.5                 38.7
# 225          NaN       50.5                 43.3                 57.7
# 226          NaN       51.5                 44.5                 58.5
# 219   folic acid        2.5                  1.3                  3.7
# 220         iron        2.5                  1.3                  3.7
# 221         zinc        2.5                  1.3                  3.7
# 222   vitamin b1        2.5                  1.3                  3.7
# 223  vitamin b12        2.5                  1.3                  3.7
# 224    vitamin a        2.5                  1.3                  3.7
# 217          NaN       36.6                 29.2                   44
# 218          NaN         93                 89.7                 96.4
#
#        sub_population notes                                    source_citation
# 213  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 214  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 215  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 233  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 234  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 235  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 236  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 237  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 238  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 225  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 226  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 219  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 220  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 221  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 222  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 223  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 224  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 217  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 218  total population   NaN  Grant J Aaron, Valerie M Friesen, Svenja Jungj...

# %%
# see if we have any info on vitamin d
double_check_data("United Republic of Tanzania","oil","percent of population eating fortified vehicle")
# Out:
#     vehicle                               value_description  \
# 213     oil  percent of population eating fortified vehicle
# 216     oil  percent of population eating fortified vehicle
# 249     oil  percent of population eating fortified vehicle
#
#                                               nutrient value_mean  \
# 213                                          vitamin a       53.6
# 216  d, ergocalciferol-D2, cholecalciferol-D3, alfa...          0
# 249                                          vitamin a       53.6
#
#     value_025_percentile value_975_percentile
# 213                 46.4                 60.8
# 216                  NaN                  NaN
# 249                   na                   na

# %%
# double checked above paper, didn't find any 0 (under uganda / vitamin D, said "--")

# %%
k = 1
additional_tanzania = pd.DataFrame({'location_id':[189]*k,
                           'location_name':["United Republic of Tanzania"]*k,
                           'vehicle':['oil']*k,
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['vitamin d'],
                           'value_mean':[0]*k,
                           'value_025_percentile':[0]*k,
                           'value_975_percentile':[5]*k})
additional_tanzania
# Out:
#    location_id                location_name vehicle  \
# 0          189  United Republic of Tanzania     oil
#
#                                 value_description   nutrient  value_mean  \
# 0  percent of population eating fortified vehicle  vitamin d           0
#
#    value_025_percentile  value_975_percentile
# 0                     0                     5

# %%
tanzania1 = add_additional(subset_data['United Republic of Tanzania'], additional_tanzania)
final_data['United Republic of Tanzania'] = tanzania1

# %% [markdown]
# ## South Africa

# %%
safrica1 = subset_data['South Africa']

# %%
# beatrix extracted for multiple nutrient_mass_ppms
safrica1[safrica1.vehicle=="wheat flour"] = safrica1[safrica1.vehicle=="wheat flour"].drop_duplicates()

# %%
# we don't care about b2, b6, b3 (beatrix you did this to yourself..)
df.loc[(df.location_name=="South Africa") & (df.vehicle=="maize flour") & (df.value_description=="percent of population eating fortified vehicle"),
       ['subnational_name','nutrient_mass_ppm','nutrient','value_mean','notes']].sort_values(by=['nutrient','subnational_name'])
# Out:
#     subnational_name nutrient_mass_ppm                nutrient value_mean  \
# 745     Eastern Cape               2.2            b1, thiamine       16.3
# 756          Gauteng               2.2            b1, thiamine       77.4
# 749     Eastern Cape               NaN                     b12        NaN
# 760          Gauteng               NaN                     b12        NaN
# 746     Eastern Cape               1.7          b2, riboflavin       16.3
# 757          Gauteng               1.7          b2, riboflavin       77.4
# 747     Eastern Cape                25              b3, niacin       16.3
# 758          Gauteng                25              b3, niacin       77.4
# 748     Eastern Cape               3.1          b6, pyridoxine       16.3
# 759          Gauteng               3.1          b6, pyridoxine       77.4
# 742     Eastern Cape                 2  folic acid, folate, b9       16.3
# 753          Gauteng                 2  folic acid, folate, b9       77.4
# 743     Eastern Cape                35                    iron       16.3
# 754          Gauteng                35                    iron       77.4
# 744     Eastern Cape               1.1               vitamin a       16.3
# 755          Gauteng               1.1               vitamin a       77.4
# 750     Eastern Cape                15                    zinc       16.3
# 761          Gauteng                15                    zinc       77.4
#
#                                                  notes
# 745  these are 95%, not 97.5% CIs! survey pop = hou...
# 756  these are 95%, not 97.5% CIs! survey pop = hou...
# 749  these are 95%, not 97.5% CIs! survey pop = hou...
# 760  these are 95%, not 97.5% CIs! survey pop = hou...
# 746  these are 95%, not 97.5% CIs! survey pop = hou...
# 757  these are 95%, not 97.5% CIs! survey pop = hou...
# 747  these are 95%, not 97.5% CIs! survey pop = hou...
# 758  these are 95%, not 97.5% CIs! survey pop = hou...
# 748  these are 95%, not 97.5% CIs! survey pop = hou...
# 759  these are 95%, not 97.5% CIs! survey pop = hou...
# 742  these are 95%, not 97.5% CIs! survey pop = hou...
# 753  these are 95%, not 97.5% CIs! survey pop = hou...
# 743  these are 95%, not 97.5% CIs! survey pop = hou...
# 754  these are 95%, not 97.5% CIs! survey pop = hou...
# 744  these are 95%, not 97.5% CIs! survey pop = hou...
# 755  these are 95%, not 97.5% CIs! survey pop = hou...
# 750  these are 95%, not 97.5% CIs! survey pop = hou...
# 761  these are 95%, not 97.5% CIs! survey pop = hou...

# %%
# shouldn't have extracted these
safrica1 = safrica1[(~safrica1.nutrient.isin(['vitamin b6', 'vitamin b2','vitamin b3'])) & (safrica.value_mean.notna())]

# %%
# assuming maize/b12, wheat/b12 == 0
k = 2
additional_safrica = pd.DataFrame({'location_id':[196]*k,
                           'location_name':["South Africa"]*k,
                           'vehicle':['maize flour', 'wheat flour'],
                           'value_description':['percent of population eating fortified vehicle']*k,
                           'nutrient':['vitamin b12']*k, 
                           'value_mean':[0]*k,
                           'value_025_percentile':[0]*k,
                           'value_975_percentile':[5]*k})
additional_safrica
# Out:
#    location_id location_name      vehicle  \
# 0          196  South Africa  maize flour
# 1          196  South Africa  wheat flour
#
#                                 value_description     nutrient  value_mean  \
# 0  percent of population eating fortified vehicle  vitamin b12           0
# 1  percent of population eating fortified vehicle  vitamin b12           0
#
#    value_025_percentile  value_975_percentile
# 0                     0                     5
# 1                     0                     5

# %%
safrica2 = add_additional(safrica1, additional_safrica)
final_data['South Africa'] = safrica2

# %%
pd.concat(list(final_data.values()))[['location_name','subnational_name']].drop_duplicates()
# Out:
#                    location_name subnational_name
# 0                          India        Rajasthan
# 2                          India              NaN
# 78                       Nigeria            lagos
# 105                      Nigeria             kano
# 600               CÃ´te d'Ivoire          Abidjan
# 0                 CÃ´te d'Ivoire              NaN
# 275                       Uganda               na
# 0                         Uganda              NaN
# 219  United Republic of Tanzania               na
# 0    United Republic of Tanzania              NaN
# 742                 South Africa     Eastern Cape
# 753                 South Africa          Gauteng
# 0                   South Africa              NaN

# %% [markdown]
# # weight by subnational

# %%
def weighted_average(country, loc_a, loc_b, weight_a, weight_b):
    #subset to cols of interest
    country = country[['location_name', 'subnational_name', 'vehicle', 'value_description', 'nutrient', 'value_mean',
       'value_025_percentile', 'value_975_percentile']]
    
    country_name = country.location_name.unique()[0]
    
    #hold out vars not split into subnats
    no_subnationals = country[country.subnational_name.isna()].drop(columns='subnational_name')
    subnats = country[country.subnational_name.isin([loc_a,loc_b])]
    
    assert (len(no_subnationals)+len(subnats) == len(country)), "unexpected vals in subnational_name column"
    
    #add weights
    subnats['sub_weight'] = [weight_a if loc==loc_a else weight_b for loc in subnats.subnational_name]
    
    #convert to correct type
    for col in ['value_mean','value_025_percentile','value_975_percentile']:
        subnats[col] = subnats[col].astype(float)
        
    #weight
    subnats['value_mean'] = subnats.value_mean * subnats.sub_weight
    subnats['value_025_percentile'] = subnats.value_025_percentile * subnats.sub_weight
    subnats['value_975_percentile'] = subnats.value_975_percentile * subnats.sub_weight

    #make sure there are the same number (2) per
    assert len(np.unique(subnats.groupby(['vehicle','value_description','nutrient']).count().subnational_name))==1
    
    #make sure there is an actual val to group on for rows that dont use nutrient
    subnats.loc[subnats.nutrient.isna(),'nutrient'] = 'na'

    #average
    subnats = subnats.groupby(['vehicle','value_description','nutrient']).sum().reset_index()

    output = pd.concat([no_subnationals, subnats]).sort_values(['vehicle','value_description','nutrient'])
    output['location_name'] = country_name
    
    return output.drop(columns=['sub_weight'])

# %%
## combine gauteng and eastern cape

# %%
# south africa location_id = 196
# gauteng location_id = 484
# eastern cape location_id = 482

# from db_queries import get_population as go
# go(age_group_id = 22, location_id = [484,482], year_id = 2015, sex_id = 3, gbd_round_id = 7, decomp_step = 'iterative')

gauteng_pop_2015 = 1.340526e+07
easterncape_pop_2015 = 6.468681e+06

# %%
loc_a = "Eastern Cape"
loc_b = "Gauteng"
weight_a = easterncape_pop_2015/(gauteng_pop_2015+easterncape_pop_2015)
weight_b = gauteng_pop_2015/(gauteng_pop_2015+easterncape_pop_2015)

sa_reweighted = weighted_average(final_data['South Africa'], loc_a, loc_b, weight_a, weight_b)
# Out:
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /share/code/beatrixh/miniconda/envs/gis/lib/python3.6/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
sa_reweighted['location_id'] = 196
sa_reweighted
# Out:
#    location_name      vehicle  \
# 0   South Africa  maize flour
# 1   South Africa  maize flour
# 2   South Africa  maize flour
# 3   South Africa  maize flour
# 0   South Africa  maize flour
# 4   South Africa  maize flour
# 5   South Africa  maize flour
# 6   South Africa  maize flour
# 7   South Africa  wheat flour
# 8   South Africa  wheat flour
# 9   South Africa  wheat flour
# 10  South Africa  wheat flour
# 1   South Africa  wheat flour
# 11  South Africa  wheat flour
# 12  South Africa  wheat flour
# 13  South Africa  wheat flour
#
#                                     value_description     nutrient value_mean  \
# 0      percent of population eating fortified vehicle   folic acid    57.5128
# 1      percent of population eating fortified vehicle         iron    57.5128
# 2      percent of population eating fortified vehicle    vitamin a    57.5128
# 3      percent of population eating fortified vehicle   vitamin b1    57.5128
# 0      percent of population eating fortified vehicle  vitamin b12          0
# 4      percent of population eating fortified vehicle         zinc    57.5128
# 5   percent of population eating industrially prod...           na    96.4741
# 6                percent of population eating vehicle           na     96.609
# 7      percent of population eating fortified vehicle   folic acid    5.84503
# 8      percent of population eating fortified vehicle         iron    5.84503
# 9      percent of population eating fortified vehicle    vitamin a    5.84503
# 10     percent of population eating fortified vehicle   vitamin b1    5.84503
# 1      percent of population eating fortified vehicle  vitamin b12          0
# 11     percent of population eating fortified vehicle         zinc    5.84503
# 12  percent of population eating industrially prod...           na    11.1026
# 13               percent of population eating vehicle           na    11.1026
#
#    value_025_percentile value_975_percentile  location_id
# 0                50.336              71.7254          196
# 1                50.336              71.7254          196
# 2                50.336              71.7254          196
# 3                50.336              71.7254          196
# 0                     0                    5          196
# 4                50.336              71.7254          196
# 5                92.318              98.9208          196
# 6               92.3855              99.0557          196
# 7               3.25486              9.26539          196
# 8               3.25486              9.26539          196
# 9               3.25486              9.26539          196
# 10              3.25486              9.26539          196
# 1                     0                    5          196
# 11              3.25486              9.26539          196
# 12              6.51954              16.2254          196
# 13              6.51954              16.2254          196

# %%
final_data['South Africa'] = sa_reweighted

# %%
## combine kano and lagos

# %%
# nigeria location_id = 214
# kano location_id = 25337
# lagos location_id = 25342

# from db_queries import get_population as go
# go(age_group_id = 22, location_id = [25337,25342], year_id = 2015, sex_id = 3, gbd_round_id = 7, decomp_step = 'iterative')

kano_pop_2015 = 1.389539e+07
lagos_pop_2015 = 7.192101e+06

# %%
final_data["Nigeria"].subnational_name.unique()
# Out:
# array(['lagos', 'kano'], dtype=object)

# %%
loc_a = "kano"
loc_b = "lagos"
weight_a = kano_pop_2015/(kano_pop_2015+lagos_pop_2015)
weight_b = lagos_pop_2015/(kano_pop_2015+lagos_pop_2015)

nigeria_reweighted = weighted_average(final_data['Nigeria'], loc_a, loc_b, weight_a, weight_b)

# %%
nigeria_reweighted.groupby(['vehicle','value_description','nutrient']).count()
# Out:
#                                                                             location_name  \
# vehicle     value_description                                  nutrient
# maize flour percent of population eating fortified vehicle     folic acid               1
#                                                                iron                     1
#                                                                vitamin a                1
#                                                                vitamin b1               1
#                                                                vitamin b12              1
#                                                                zinc                     1
#             percent of population eating industrially produ... na                       1
#             percent of population eating vehicle               na                       1
# oil         percent of population eating fortified vehicle     vitamin a                1
#                                                                vitamin d                1
#             percent of population eating industrially produ... na                       1
#             percent of population eating vehicle               na                       1
# wheat flour percent of population eating fortified vehicle     folic acid               1
#                                                                iron                     1
#                                                                vitamin a                1
#                                                                vitamin b1               1
#                                                                vitamin b12              1
#                                                                zinc                     1
#             percent of population eating industrially produ... na                       1
#             percent of population eating vehicle               na                       1
#
#                                                                             value_mean  \
# vehicle     value_description                                  nutrient
# maize flour percent of population eating fortified vehicle     folic acid            1
#                                                                iron                  1
#                                                                vitamin a             1
#                                                                vitamin b1            1
#                                                                vitamin b12           1
#                                                                zinc                  1
#             percent of population eating industrially produ... na                    1
#             percent of population eating vehicle               na                    1
# oil         percent of population eating fortified vehicle     vitamin a             1
#                                                                vitamin d             1
#             percent of population eating industrially produ... na                    1
#             percent of population eating vehicle               na                    1
# wheat flour percent of population eating fortified vehicle     folic acid            1
#                                                                iron                  1
#                                                                vitamin a             1
#                                                                vitamin b1            1
#                                                                vitamin b12           1
#                                                                zinc                  1
#             percent of population eating industrially produ... na                    1
#             percent of population eating vehicle               na                    1
#
#                                                                             value_025_percentile  \
# vehicle     value_description                                  nutrient
# maize flour percent of population eating fortified vehicle     folic acid                      1
#                                                                iron                            1
#                                                                vitamin a                       1
#                                                                vitamin b1                      1
#                                                                vitamin b12                     1
#                                                                zinc                            1
#             percent of population eating industrially produ... na                              1
#             percent of population eating vehicle               na                              1
# oil         percent of population eating fortified vehicle     vitamin a                       1
#                                                                vitamin d                       1
#             percent of population eating industrially produ... na                              1
#             percent of population eating vehicle               na                              1
# wheat flour percent of population eating fortified vehicle     folic acid                      1
#                                                                iron                            1
#                                                                vitamin a                       1
#                                                                vitamin b1                      1
#                                                                vitamin b12                     1
#                                                                zinc                            1
#             percent of population eating industrially produ... na                              1
#             percent of population eating vehicle               na                              1
#
#                                                                             value_975_percentile
# vehicle     value_description                                  nutrient
# maize flour percent of population eating fortified vehicle     folic acid                      1
#                                                                iron                            1
#                                                                vitamin a                       1
#                                                                vitamin b1                      1
#                                                                vitamin b12                     1
#                                                                zinc                            1
#             percent of population eating industrially produ... na                              1
#             percent of population eating vehicle               na                              1
# oil         percent of population eating fortified vehicle     vitamin a                       1
#                                                                vitamin d                       1
#             percent of population eating industrially produ... na                              1
#             percent of population eating vehicle               na                              1
# wheat flour percent of population eating fortified vehicle     folic acid                      1
#                                                                iron                            1
#                                                                vitamin a                       1
#                                                                vitamin b1                      1
#                                                                vitamin b12                     1
#                                                                zinc                            1
#             percent of population eating industrially produ... na                              1
#             percent of population eating vehicle               na                              1

# %%
nigeria_reweighted['location_id'] = 214
nigeria_reweighted
# Out:
#    location_name      vehicle  \
# 0        Nigeria  maize flour
# 1        Nigeria  maize flour
# 2        Nigeria  maize flour
# 3        Nigeria  maize flour
# 4        Nigeria  maize flour
# 5        Nigeria  maize flour
# 6        Nigeria  maize flour
# 7        Nigeria  maize flour
# 8        Nigeria          oil
# 9        Nigeria          oil
# 10       Nigeria          oil
# 11       Nigeria          oil
# 12       Nigeria  wheat flour
# 13       Nigeria  wheat flour
# 14       Nigeria  wheat flour
# 15       Nigeria  wheat flour
# 16       Nigeria  wheat flour
# 17       Nigeria  wheat flour
# 18       Nigeria  wheat flour
# 19       Nigeria  wheat flour
#
#                                     value_description     nutrient  \
# 0      percent of population eating fortified vehicle   folic acid
# 1      percent of population eating fortified vehicle         iron
# 2      percent of population eating fortified vehicle    vitamin a
# 3      percent of population eating fortified vehicle   vitamin b1
# 4      percent of population eating fortified vehicle  vitamin b12
# 5      percent of population eating fortified vehicle         zinc
# 6   percent of population eating industrially prod...           na
# 7                percent of population eating vehicle           na
# 8      percent of population eating fortified vehicle    vitamin a
# 9      percent of population eating fortified vehicle    vitamin d
# 10  percent of population eating industrially prod...           na
# 11               percent of population eating vehicle           na
# 12     percent of population eating fortified vehicle   folic acid
# 13     percent of population eating fortified vehicle         iron
# 14     percent of population eating fortified vehicle    vitamin a
# 15     percent of population eating fortified vehicle   vitamin b1
# 16     percent of population eating fortified vehicle  vitamin b12
# 17     percent of population eating fortified vehicle         zinc
# 18  percent of population eating industrially prod...           na
# 19               percent of population eating vehicle           na
#
#     value_mean  value_025_percentile  value_975_percentile  location_id
# 0     1.188410              0.593046              1.883774          214
# 1     1.188410              0.593046              1.883774          214
# 2     1.188410              0.593046              1.883774          214
# 3     1.188410              0.593046              1.883774          214
# 4     1.188410              0.593046              1.883774          214
# 5     1.188410              0.593046              1.883774          214
# 6     8.237413              6.544368              9.996353          214
# 7    54.965202             52.435732             57.560566          214
# 8     7.463576              5.763576              9.229470          214
# 9     0.000000              0.000000              5.000000          214
# 10   31.398007             28.334431             34.461583          214
# 11   98.468212             97.668212             99.234106          214
# 12   16.799661             14.474827             19.156283          214
# 13   16.799661             14.474827             19.156283          214
# 14   16.799661             14.474827             19.156283          214
# 15   16.799661             14.474827             19.156283          214
# 16   16.799661             14.474827             19.156283          214
# 17   16.799661             14.474827             19.156283          214
# 18   59.925796             57.559902             62.291690          214
# 19   60.128114             57.728114             62.494008          214

# %%
final_data['Nigeria'] = nigeria_reweighted

# %% [markdown]
# # save and output

# %%
output = pd.concat(list(final_data.values()))

# %%
output_cols = ['location_id', 'location_name', 'vehicle',
       'value_description', 'nutrient', 'value_mean', 'value_025_percentile',
       'value_975_percentile']
output = output[output_cols].reset_index(drop=True) #need to fix nigeria subnationals

# %%
output.loc[output.nutrient.isna(),'nutrient'] = 'na'

# %%
for col in ['value_mean','value_025_percentile','value_975_percentile']:
    output[col] = output[col].astype(float)

# %%
# correct types

# %%
output.dtypes
# Out:
# location_id             float64
# location_name            object
# vehicle                  object
# value_description        object
# nutrient                 object
# value_mean              float64
# value_025_percentile    float64
# value_975_percentile    float64
# dtype: object

# %%
output.location_id = output.location_id.astype(int)
output.location_name = output.location_name.astype(str)
output.vehicle = output.vehicle.astype(str)
output.value_description = output.value_description.astype(str)
output.value_mean = output.value_mean.astype(float)
output.value_025_percentile  = output.value_025_percentile.astype(float)
output.value_975_percentile = output.value_975_percentile.astype(float)

# %%
# quick checks

# %%
assert len(output[output.value_mean < output.value_025_percentile])==0, "some mean/lower is incorrrect"
assert len(output[output.value_mean > output.value_975_percentile])==0 ,"some mean/upper is incorrrect"

# %%
output.head()
# Out:
#    location_id location_name      vehicle  \
# 0          163         India          oil
# 1          163         India          oil
# 2          163         India          oil
# 3          163         India          oil
# 4          163         India  wheat flour
#
#                                    value_description    nutrient  value_mean  \
# 0     percent of population eating fortified vehicle   vitamin a        24.3
# 1     percent of population eating fortified vehicle   vitamin d        24.3
# 2  percent of population eating industrially prod...          na        89.4
# 3               percent of population eating vehicle          na       100.0
# 4     percent of population eating fortified vehicle  folic acid         6.3
#
#    value_025_percentile  value_975_percentile
# 0                  21.1                  27.9
# 1                  21.1                  27.9
# 2                  87.0                  91.8
# 3                 100.0                 100.0
# 4                   4.8                   7.9

# %%
# want to check, for every country-vehicle pair, there exists rows for all three val descrip

# %%
output.groupby(['location_name','vehicle']).nunique().value_description
# Out:
# location_name                vehicle
# CÃ´te d'Ivoire               oil            3
# India                        oil            3
#                              wheat flour    3
# Nigeria                      maize flour    3
#                              oil            3
#                              wheat flour    3
# South Africa                 maize flour    3
#                              wheat flour    3
# Uganda                       maize flour    3
#                              oil            3
#                              wheat flour    3
# United Republic of Tanzania  maize flour    3
#                              oil            3
#                              wheat flour    3
# Name: value_description, dtype: int64

# %%
# check values are uniform
output.nutrient.unique()
# Out:
# array(['vitamin a', 'vitamin d', 'na', 'folic acid', 'iron', 'vitamin b1',
#        'vitamin b12', 'zinc'], dtype=object)

# %%
# make sure nutrient=='na' iff val_descip == percent of population eating fortified vehicle
output[output.nutrient=='na'].value_description.unique()
# Out:
# array(['percent of population eating industrially produced vehicle',
#        'percent of population eating vehicle'], dtype=object)

# %%
output[output.nutrient!='na'].value_description.unique()
# Out:
# array(['percent of population eating fortified vehicle'], dtype=object)

# %%
# check that there is only one location_id per location_name
output.groupby(['location_name']).nunique().location_id.nunique()
# Out:
# 1

# %%
# check that location_id!=na
output.location_id.unique()
# Out:
# array([163, 214, 205, 190, 189, 196])

# %%
## check every country-nutrient and nutrient-pair that we have is one we want
import pickle
data_prep_dir = '/ihme/scratch/users/beatrixh/vivarium_data_analysis/pre_processing/lsff_project/data_prep/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_pairs = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_pairs = pickle.load(handle)

# %%
country_vehicle_pairs["CÃ´te d'Ivoire"] = ['wheat flour', 'oil', 'maize flour', 'bouillon']

# %%
for country in output.location_name.unique():
    for vehicle in output.loc[output.location_name==country].vehicle.unique():
        assert vehicle in country_vehicle_pairs[country], f'error: {country}, {vehicle}'

# %%
for vehicle in output.vehicle.unique():
    for nutrient in output.loc[output.vehicle==vehicle].nutrient.unique():
        if nutrient!='na':
            assert nutrient in vehicle_nutrient_pairs[vehicle], f'error: {vehicle}, {nutrient}'

# %%
output.loc[output.location_name=="CÃ´te d'Ivoire",'location_name'] = "Côte d'Ivoire"

# %%
output.location_name.unique()
# Out:
# array(['India', 'Nigeria', "Côte d'Ivoire", 'Uganda',
#        'United Republic of Tanzania', 'South Africa'], dtype=object)

# %%
check_path = '/ihme/homes/beatrixh/repos/scratch/check_lsff_extraction.csv'
output.to_csv(check_path, index = False, encoding='utf-8')

# %%
save_path = '/ihme/homes/beatrixh/notebooks/viv_rsc/new_lsff/outputs/LSFF_extraction_clean_data_rich_locations_01_11_2021.csv'
output.to_csv(save_path, index = False)

# %%
output.location_name.unique()
# Out:
# array(['India', 'Nigeria', "Côte d'Ivoire", 'Uganda',
#        'United Republic of Tanzania', 'South Africa'], dtype=object)

# %%
a = pd.read_csv(save_path)
a.location_name.unique()
# Out:
# array(['India', 'Nigeria', "Côte d'Ivoire", 'Uganda',
#        'United Republic of Tanzania', 'South Africa'], dtype=object)
