# %%
import pandas as pd, numpy as np

# %% [markdown]
# # Add 'industry {vehicle}' to coverage input data

# %%
## pull in (previously final) input data sheet
outputs_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/'
input_data_path = outputs_dir + 'lsff_input_coverage_data.csv'

input_data = pd.read_csv(input_data_path)

loc_id_map = {i:j for(i,j) in zip(input_data.location_name, input_data.location_id) }

# %%
# pull in (previously final) version of input data sheet with metadata
w_meta = pd.read_csv(outputs_dir + 'lsff_input_coverage_data_with_metadata.csv')

# %% [markdown]
# ## wheat

# %%
# pull in new numbers from Jonathan / industry
inputs_dir = "/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/"
new_wheat = pd.read_excel(inputs_dir + "Kopie_von_20210412_LSFF_input_data_for_IHME_(002)_editLeo.xlsx", header = [1,2,3])

# %%
# set location index
new_wheat = new_wheat.set_index(new_wheat.columns[0])

# %%
# they only asked us to update % fortifiable, but want to check if the % fortified matches us
industry_wheat_fortified = new_wheat['Baseline coverage']['Wheat flour\n(percent of population eating specified wheat flour)']['Wheat flour fortified with iron'].reset_index()
test = input_data.loc[(input_data.vehicle=="wheat flour") & (input_data.u5_applicable) & (input_data.nutrient=="iron"),['location_name','value_mean']]
industry_wheat_fortified.columns = ['location_name','industry_value_mean']
test = test.merge(industry_wheat_fortified, on = 'location_name')
test['diff'] = test.value_mean - test.industry_value_mean
test
# Out:
#                        location_name  value_mean  industry_value_mean  \
# 0                           Ethiopia    0.000000                  0.0
# 1                              India    6.300000                  6.3
# 2                            Nigeria   17.452812                 17.5
# 3                         Bangladesh    0.155875                  0.2
# 4                           Pakistan    3.821239                  3.8
# 5                             Uganda    8.500000                  8.5
# 6        United Republic of Tanzania   33.100000                 33.1
# 7                       South Africa    5.707704                  5.7
# 8                       Burkina Faso   17.389750                 17.4
# 9                              Kenya   27.095201                 27.1
# 10                           Myanmar    0.000000                  0.0
# 11                             Nepal    7.334332                  7.3
# 12                          Viet Nam    4.111875                  4.1
# 13                          Cameroon   53.088564                  6.4
# 14  Democratic Republic of the Congo    0.000000                  0.0
# 15                         Indonesia   73.100000                 73.1
# 16                        Mozambique   12.632500                 12.6
# 17                            Angola   16.888381                 16.9
# 18                             China    6.363472                 10.3
# 19                             Egypt   15.616431                 15.6
# 20                             Ghana   17.121532                 17.1
# 21                        Madagascar    8.630461                  8.6
# 22                             Niger   30.000000                 30.0
# 23                             Sudan    6.525113                  6.5
#
#          diff
# 0    0.000000
# 1    0.000000
# 2   -0.047188
# 3   -0.044125
# 4    0.021239
# 5    0.000000
# 6    0.000000
# 7    0.007704
# 8   -0.010250
# 9   -0.004799
# 10   0.000000
# 11   0.034332
# 12   0.011875
# 13  46.688564
# 14   0.000000
# 15   0.000000
# 16   0.032500
# 17  -0.011619
# 18  -3.936528
# 19   0.016431
# 20   0.021532
# 21   0.030461
# 22   0.000000
# 23   0.025113

# %%
new_wheat = new_wheat['Baseline coverage']['Wheat flour\n(percent of population eating specified wheat flour)']['% fortifiable'].reset_index()

# %%
# # pull columns we're interested in
# rename_oil = {
#     ('Location', 'Unnamed: 0_level_1', 'Unnamed: 0_level_2'): 'location_name',
#  'Fortifiable oil.1': 'percent of population eating industrially produced vehicle',
#  'Compliance % of fortifiable': 'percent of population eating fortified vehicle'
# }

# new_oil = new_oil.reset_index().rename(columns=rename_oil)

# %%
rename_wheat = {
    ('Location', 'Unnamed: 0_level_1', 'Unnamed: 0_level_2'):'location_name',
    '% fortifiable':'percent of population eating industrially produced vehicle'
}

new_wheat = new_wheat.rename(columns=rename_wheat)

# %%
# reshape to our format
new_wheat = pd.melt(new_wheat, id_vars = 'location_name',
        value_vars = ['percent of population eating industrially produced vehicle'],
       var_name='value_description',value_name='value_mean')

# %%
#convert from prop to percent
new_wheat.value_mean = 100 * new_wheat.value_mean

# %%
new_wheat
# Out:
#                        location_name  \
# 0                             Angola
# 1                         Bangladesh
# 2                       Burkina Faso
# 3                     CÃ´te d'Ivoire
# 4                           Cameroon
# 5                              China
# 6   Democratic Republic of the Congo
# 7                              Egypt
# 8                           Ethiopia
# 9                              Ghana
# 10                             India
# 11                         Indonesia
# 12                             Kenya
# 13                        Madagascar
# 14                        Mozambique
# 15                           Myanmar
# 16                             Nepal
# 17                             Niger
# 18                           Nigeria
# 19                          Pakistan
# 20                      South Africa
# 21                             Sudan
# 22                            Uganda
# 23       United Republic of Tanzania
# 24                          Viet Nam
#
#                                     value_description  value_mean
# 0   percent of population eating industrially prod...       100.0
# 1   percent of population eating industrially prod...        79.0
# 2   percent of population eating industrially prod...       100.0
# 3   percent of population eating industrially prod...        98.0
# 4   percent of population eating industrially prod...        80.0
# 5   percent of population eating industrially prod...        89.0
# 6   percent of population eating industrially prod...       100.0
# 7   percent of population eating industrially prod...       100.0
# 8   percent of population eating industrially prod...        55.0
# 9   percent of population eating industrially prod...       100.0
# 10  percent of population eating industrially prod...        30.0
# 11  percent of population eating industrially prod...       100.0
# 12  percent of population eating industrially prod...       100.0
# 13  percent of population eating industrially prod...       100.0
# 14  percent of population eating industrially prod...       100.0
# 15  percent of population eating industrially prod...       100.0
# 16  percent of population eating industrially prod...        25.0
# 17  percent of population eating industrially prod...       100.0
# 18  percent of population eating industrially prod...       100.0
# 19  percent of population eating industrially prod...        60.0
# 20  percent of population eating industrially prod...       100.0
# 21  percent of population eating industrially prod...        90.0
# 22  percent of population eating industrially prod...       100.0
# 23  percent of population eating industrially prod...        85.0
# 24  percent of population eating industrially prod...       100.0

# %%
# fix c'ote divoire 
new_wheat.loc[new_wheat.location_name=="CÃ´te d'Ivoire","location_name"] = "Côte d'Ivoire"

# %%
# make sure we're not missing any locations / don't have any extra
assert(set(new_wheat.location_name).symmetric_difference(set(input_data.location_name))==set())

# %%
# formatting
new_wheat['vehicle'] = 'industry wheat'
new_wheat['nutrient'] = 'na'
new_wheat['u5_applicable'] = True
new_wheat['wra_applicable'] = True
new_wheat['sub_population'] = np.NaN
new_wheat['location_id'] = new_wheat.location_name.map(loc_id_map)

# %%
# grab pct fortified and use for industry wheat
fortified_wheat = input_data.loc[(input_data.vehicle=="wheat flour") & (input_data.value_description=="percent of population eating fortified vehicle")]
fortified_wheat['vehicle'] = "industry wheat"
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_wheat = new_wheat.append(fortified_wheat)
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v108/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %% [markdown]
# ## oil

# %%
# pull in new numbers from Jonathan / industry
inputs_dir = "/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/"
new_oil = pd.read_excel(inputs_dir + "20210411_LSFF_input_data_for_IHME.xlsx", header = [1,2,3])

# %%
# subset to the oil numbers we're interested in
new_oil = new_oil.set_index(new_oil.columns[0])

new_oil = new_oil['Baseline coverage']['Oil\n(percent of population eating specified oil)'][['Fortifiable oil.1','Compliance % of fortifiable']]

# %%
# pull columns we're interested in
rename_oil = {
    ('Location', 'Unnamed: 0_level_1', 'Unnamed: 0_level_2'): 'location_name',
 'Fortifiable oil.1': 'percent of population eating industrially produced vehicle',
 'Compliance % of fortifiable': 'percent of population eating fortified vehicle'
}

new_oil = new_oil.reset_index().rename(columns=rename_oil)

# %%
# reshape to our format
new_oil = pd.melt(new_oil, id_vars = 'location_name',
        value_vars = ['percent of population eating industrially produced vehicle',
       'percent of population eating fortified vehicle'],
       var_name='value_description',value_name='value_mean')

# %%
# fix c'ote divoire 
new_oil.loc[new_oil.location_name=="CÃ´te d'Ivoire","location_name"] = "Côte d'Ivoire"

# %%
# make sure we're not missing any locations / don't have any extra
assert(set(new_oil.location_name).symmetric_difference(set(input_data.location_name))==set())

# %%
# formatting
new_oil['vehicle'] = 'industry oil'
new_oil['nutrient'] = 'vitamin a'
new_oil['u5_applicable'] = True
new_oil['wra_applicable'] = True
new_oil['sub_population'] = np.NaN
new_oil['location_id'] = new_oil.location_name.map(loc_id_map)

# %%
# check formatting
new_oil.head()
# Out:
#    location_name                                  value_description  \
# 0         Angola  percent of population eating industrially prod...
# 1     Bangladesh  percent of population eating industrially prod...
# 2   Burkina Faso  percent of population eating industrially prod...
# 3  Côte d'Ivoire  percent of population eating industrially prod...
# 4       Cameroon  percent of population eating industrially prod...
#
#    value_mean       vehicle   nutrient  u5_applicable  wra_applicable  \
# 0      72.320  industry oil  vitamin a           True            True
# 1      87.516  industry oil  vitamin a           True            True
# 2      73.760  industry oil  vitamin a           True            True
# 3      72.000  industry oil  vitamin a           True            True
# 4      72.000  industry oil  vitamin a           True            True
#
#    sub_population  location_id
# 0             NaN          168
# 1             NaN          161
# 2             NaN          201
# 3             NaN          205
# 4             NaN          202

# %% [markdown]
# ## add CIs

# %%
new_data = new_wheat.append(new_oil)

# %%
# from our (previously final) input sheet, select extracted rows of data (no regression or multiplicative results)
# then drop any rows duplicated for different nutrients
w_meta = w_meta[w_meta.estimation_status=='na'].drop(columns = 'nutrient').drop_duplicates()

# %%
# use ratio of scale over mean to estimate scale for new industry datapoints
w_meta['scale_over_mean'] = (w_meta.value_975_percentile - w_meta.value_025_percentile) / w_meta.value_mean
r = w_meta.loc[(w_meta.scale_over_mean!=np.inf) & (w_meta.scale_over_mean!=0),['vehicle','scale_over_mean']]

r_mean = r.scale_over_mean.mean()
r.loc[r.vehicle=="maize flour",'scale_over_mean'] = r_mean

r = r.groupby('vehicle').mean().dropna().rename(columns={'scale_over_mean':'r'}).reset_index()

# %%
vehicle_map = {'wheat flour':'industry wheat','oil':'industry oil'}
r.vehicle = r.vehicle.map(vehicle_map)

# %%
r
# Out:
#           vehicle         r
# 0             NaN  0.564982
# 1    industry oil  0.379944
# 2  industry wheat  0.688639

# %%
new_data = new_data.merge(r, on = 'vehicle', how = 'left')

# %%
# input estimated CIs
new_data['lower'] = np.clip(new_data.value_mean - (new_data.r * new_data.value_mean)/2, 0, 100)
new_data['upper'] = np.clip(new_data.value_mean + (new_data.r * new_data.value_mean)/2, 0, 100)


new_data.loc[(new_data.value_025_percentile.isna()),'value_025_percentile'] = new_data.lower
new_data.loc[(new_data.value_975_percentile.isna()),'value_975_percentile'] = new_data.upper

# %%
new_data = new_data.drop(columns=['lower','upper','r'])

# %%
output = input_data.append(new_data)[input_data.columns]

# %%
#checkout results
output.tail()
# Out:
#      location_id                location_name sub_population       vehicle  \
# 170          196                 South Africa            NaN  industry oil
# 171          522                        Sudan            NaN  industry oil
# 172          190                       Uganda            NaN  industry oil
# 173          189  United Republic of Tanzania            NaN  industry oil
# 174           20                     Viet Nam            NaN  industry oil
#
#                                   value_description   nutrient  value_mean  \
# 170  percent of population eating fortified vehicle  vitamin a         3.0
# 171  percent of population eating fortified vehicle  vitamin a         0.0
# 172  percent of population eating fortified vehicle  vitamin a        54.4
# 173  percent of population eating fortified vehicle  vitamin a        53.6
# 174  percent of population eating fortified vehicle  vitamin a        70.0
#
#      value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 170              2.430085              3.569915           True            True
# 171              0.000000              0.000000           True            True
# 172             44.065536             64.734464           True            True
# 173             43.417513             63.782487           True            True
# 174             56.701976             83.298024           True            True

# %%
output.columns
# Out:
# Index(['location_id', 'location_name', 'sub_population', 'vehicle',
#        'value_description', 'nutrient', 'value_mean', 'value_025_percentile',
#        'value_975_percentile', 'u5_applicable', 'wra_applicable'],
#       dtype='object')

# %%
# checkout problem rows

# %%
output.loc[(output.value_mean > output.value_975_percentile) | (output.value_mean < output.value_025_percentile)]
# Out:
# Empty DataFrame
# Columns: [location_id, location_name, sub_population, vehicle, value_description, nutrient, value_mean, value_025_percentile, value_975_percentile, u5_applicable, wra_applicable]
# Index: []

# %%
output.loc[(output.value_mean == output.value_975_percentile) & (output.value_description!='percent of population eating vehicle')]
# Out:
#      location_id                     location_name sub_population  \
# 2            179                          Ethiopia            NaN
# 3            179                          Ethiopia            NaN
# 4            179                          Ethiopia            NaN
# 5            179                          Ethiopia            NaN
# 9            179                          Ethiopia            NaN
# ..           ...                               ...            ...
# 87           171  Democratic Republic of the Congo            NaN
# 88           171  Democratic Republic of the Congo            NaN
# 165           15                           Myanmar            NaN
# 166          164                             Nepal            NaN
# 171          522                             Sudan            NaN
#
#             vehicle                               value_description  \
# 2       maize flour  percent of population eating fortified vehicle
# 3       maize flour  percent of population eating fortified vehicle
# 4       maize flour  percent of population eating fortified vehicle
# 5       maize flour  percent of population eating fortified vehicle
# 9               oil  percent of population eating fortified vehicle
# ..              ...                                             ...
# 87   industry wheat  percent of population eating fortified vehicle
# 88   industry wheat  percent of population eating fortified vehicle
# 165    industry oil  percent of population eating fortified vehicle
# 166    industry oil  percent of population eating fortified vehicle
# 171    industry oil  percent of population eating fortified vehicle
#
#        nutrient  value_mean  value_025_percentile  value_975_percentile  \
# 2    folic acid         0.0                   0.0                   0.0
# 3          iron         0.0                   0.0                   0.0
# 4     vitamin a         0.0                   0.0                   0.0
# 5          zinc         0.0                   0.0                   0.0
# 9     vitamin a         0.0                   0.0                   0.0
# ..          ...         ...                   ...                   ...
# 87    vitamin a         0.0                   0.0                   0.0
# 88         zinc         0.0                   0.0                   0.0
# 165   vitamin a         0.0                   0.0                   0.0
# 166   vitamin a         0.0                   0.0                   0.0
# 171   vitamin a         0.0                   0.0                   0.0
#
#      u5_applicable  wra_applicable
# 2             True            True
# 3             True            True
# 4             True            True
# 5             True            True
# 9             True            True
# ..             ...             ...
# 87            True            True
# 88            True            True
# 165           True            True
# 166           True            True
# 171           True            True
#
# [67 rows x 11 columns]

# %%
output.loc[(output.value_mean == output.value_025_percentile) & (output.value_description!='percent of population eating vehicle')]
# Out:
#      location_id                     location_name    sub_population  \
# 2            179                          Ethiopia               NaN
# 3            179                          Ethiopia               NaN
# 4            179                          Ethiopia               NaN
# 5            179                          Ethiopia               NaN
# 9            179                          Ethiopia               NaN
# 13           179                          Ethiopia               NaN
# 14           179                          Ethiopia               NaN
# 15           179                          Ethiopia               NaN
# 16           179                          Ethiopia               NaN
# 56           165                          Pakistan               NaN
# 106          201                      Burkina Faso               NaN
# 107          201                      Burkina Faso               NaN
# 108          201                      Burkina Faso               NaN
# 109          201                      Burkina Faso               NaN
# 110          201                      Burkina Faso               NaN
# 123          180                             Kenya               NaN
# 125          180                             Kenya               NaN
# 126          180                             Kenya               NaN
# 129          180                             Kenya               NaN
# 138           15                           Myanmar  total population
# 141           15                           Myanmar  total population
# 142           15                           Myanmar  total population
# 143           15                           Myanmar               NaN
# 144           15                           Myanmar  total population
# 147          164                             Nepal               NaN
# 153          164                             Nepal               NaN
# 157           20                          Viet Nam               NaN
# 192          205                     Côte d'Ivoire               NaN
# 194          205                     Côte d'Ivoire               NaN
# 195          205                     Côte d'Ivoire               NaN
# 198          171  Democratic Republic of the Congo               NaN
# 199          171  Democratic Republic of the Congo               NaN
# 200          171  Democratic Republic of the Congo               NaN
# 66         iron         0.0                   0.0                   5.0
# 67    vitamin a         0.0                   0.0                   0.0
# 68         zinc         0.0                   0.0                   5.0
# 72         zinc         0.0                   0.0                   0.0
# 81   folic acid         0.0                   0.0                   0.0
# 83    vitamin a         0.0                   0.0                   0.0
# 84         zinc         0.0                   0.0                   0.0
# 85   folic acid         0.0                   0.0                   0.0
# 86         iron         0.0                   0.0                   0.0
# 87    vitamin a         0.0                   0.0                   0.0
# 88         zinc         0.0                   0.0                   0.0
# 165   vitamin a         0.0                   0.0                   0.0
# 166   vitamin a         0.0                   0.0                   0.0
# 171   vitamin a         0.0                   0.0                   0.0
#
#      u5_applicable  wra_applicable
# 2             True            True
# 3             True            True
# 4             True            True
# 5             True            True
# 9             True            True
# 13            True            True
# 14            True            True
# 15            True            True
# 16            True            True
# 56            True            True
# 106           True            True
# 107           True            True
# 108           True            True
# 109           True            True
# 110           True            True
# 123           True            True
# 125           True            True
# 126           True            True
# 129           True            True
# 138           True            True
# 141           True            True
# 142           True            True
# 143           True            True
# 144           True            True
# 147           True            True
# 153           True            True
# 157           True            True
# 192           True            True
# 194           True            True
# 195           True            True
# 198           True            True
# 199           True            True
# 200           True            True
# 201           True            True
# 204           True            True
# 207           True            True
# 208           True            True
# 209           True            True
# 210           True            True
# 25            True            True
# 26            True            True
# 27            True            True
# 28            True            True
# 43            True            True
# 65            True            True
# 66            True            True
# 67            True            True
# 68            True            True
# 72            True            True
# 81            True            True
# 83            True            True
# 84            True            True
# 85            True            True
# 86            True            True
# 87            True            True
# 88            True            True
# 165           True            True
# 166           True            True
# 171           True            True

# %%
output.loc[(output.value_025_percentile.isna()) | (output.value_975_percentile.isna())]
# Out:
#      location_id location_name sub_population vehicle  \
# 252            6         China            NaN     oil
# 267          141         Egypt            NaN     oil
#
#                                   value_description   nutrient  value_mean  \
# 252  percent of population eating fortified vehicle  vitamin a         NaN
# 267  percent of population eating fortified vehicle  vitamin a         NaN
#
#      value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 252                   NaN                   NaN           True            True
# 267                   NaN                   NaN           True            True

# %%
input_data.loc[(input_data.value_025_percentile.isna()) | (input_data.value_975_percentile.isna())]
# Out:
#      location_id location_name sub_population vehicle  \
# 252            6         China            NaN     oil
# 267          141         Egypt            NaN     oil
#
#                                   value_description   nutrient  value_mean  \
# 252  percent of population eating fortified vehicle  vitamin a         NaN
# 267  percent of population eating fortified vehicle  vitamin a         NaN
#
#      value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 252                   NaN                   NaN           True            True
# 267                   NaN                   NaN           True            True

# %%
output.to_csv('/ihme/homes/beatrixh/repos/scratch/lsff_input_coverage_data_w_industry_oil_wheat_v2_04_14_2021.csv')

# %%
save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/lsff_input_coverage_data_w_industry_oil_wheat_v2_04_14_2021.csv'
output.to_csv(save_path)
