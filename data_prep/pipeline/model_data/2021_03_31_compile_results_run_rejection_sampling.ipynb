# %%
import pandas as pd, numpy as np

# %% [markdown]
# # Compile regression estimates / examine for logical consistency

# %%
w_metadata_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/04_27_lsff_input_coverage_data_with_metadata.csv'
df = pd.read_csv(w_metadata_path)

# %%
df.estimation_status.unique()
# Out:
# array(['regression', 'na', 'multiplicative', 'lack of evidence'],
#       dtype=object)

# %%
df[(df.value_mean.isna())]
# Out:
# Empty DataFrame
# Columns: [location_id, location_name, sub_population, vehicle, value_description, nutrient, value_mean, value_025_percentile, value_975_percentile, u5_applicable, wra_applicable, estimation_status, source_citation, source_link, CI_source, data_choice_notes]
# Index: []

# %%
df[df.value_025_percentile.isna()].location_name.unique()
# Out:
# array(['Angola', 'China', 'Egypt', 'Ghana', 'Madagascar', 'Niger',
#        'Sudan'], dtype=object)

# %%
A = df[(df.value_description=="percent of population eating vehicle")].rename(columns={'value_mean':"A",'estimation_status':'A_estimation_status'})
B = df[(df.value_description=="percent of population eating industrially produced vehicle")].rename(columns={'value_mean':"B",'estimation_status':'B_estimation_status'})
C = df[(df.value_description=="percent of population eating fortified vehicle")].rename(columns={'value_mean':"C",'estimation_status':'C_estimation_status'})

A = A.drop(columns=['value_description','nutrient'])
B = B.drop(columns=['value_description','nutrient'])
C = C.drop(columns=['value_description'])

ref = A.merge(B, on = ['location_id','location_name','vehicle'], how = 'left').merge(C, on = ['location_id','location_name','vehicle'], how = 'outer')[['location_name','vehicle','nutrient','A','A_estimation_status','B','B_estimation_status','C','C_estimation_status']]

# %%
ref
# Out:
#     location_name      vehicle    nutrient          A A_estimation_status  \
# 0        Ethiopia  maize flour  folic acid  59.259825          regression
# 1        Ethiopia  maize flour        iron  59.259825          regression
# 2        Ethiopia  maize flour   vitamin a  59.259825          regression
# 3        Ethiopia  maize flour        zinc  59.259825          regression
# 4        Ethiopia          oil   vitamin a  29.350000          regression
# ..            ...          ...         ...        ...                 ...
# 211         Sudan          oil   vitamin a  50.646725          regression
# 212         Sudan  wheat flour  folic acid  88.758036          regression
# 213         Sudan  wheat flour        iron  88.758036          regression
# 214         Sudan  wheat flour   vitamin a  88.758036          regression
# 215         Sudan  wheat flour        zinc  88.758036          regression
#
#              B B_estimation_status          C C_estimation_status
# 0    27.169813          regression   0.000000          regression
# 1    27.169813          regression   0.000000          regression
# 2    27.169813          regression   0.000000          regression
# 3    27.169813          regression   0.000000          regression
# 4    70.000000                  na   0.000000          regression
# ..         ...                 ...        ...                 ...
# 211  80.000000                  na  80.000000                  na
# 212  35.365713          regression   1.760469          regression
# 213  35.365713          regression   1.760469          regression
# 214  35.365713          regression   1.760469          regression
# 215  35.365713          regression   1.760469          regression
#
# [216 rows x 9 columns]

# %%
# problem rows (less fortifiable than is fortified)
ref[(ref.B < ref.C)]
# Out:
#      location_name      vehicle    nutrient          A A_estimation_status  \
# 73    Burkina Faso          oil   vitamin a  92.230000                  na
# 87           Kenya  wheat flour  folic acid  36.580000                  na
# 88           Kenya  wheat flour        iron  36.580000                  na
# 89           Kenya  wheat flour   vitamin a  36.580000                  na
# 90           Kenya  wheat flour        zinc  36.580000                  na
# 124  Côte d'Ivoire  maize flour  folic acid  84.907643          regression
# 125  Côte d'Ivoire  maize flour        iron  84.907643          regression
# 126  Côte d'Ivoire  maize flour   vitamin a  84.907643          regression
# 127  Côte d'Ivoire  maize flour        zinc  84.907643          regression
# 129  Côte d'Ivoire  wheat flour  folic acid  54.700000                  na
# 130  Côte d'Ivoire  wheat flour        iron  54.700000                  na
# 131  Côte d'Ivoire  wheat flour   vitamin a  54.700000                  na
# 143      Indonesia  wheat flour  folic acid  75.728763          regression
# 144      Indonesia  wheat flour        iron  75.728763          regression
# 145      Indonesia  wheat flour   vitamin a  75.728763          regression
# 146      Indonesia  wheat flour        zinc  75.728763          regression
# 156         Angola  maize flour  folic acid  51.172808          regression
# 157         Angola  maize flour        iron  51.172808          regression
# 158         Angola  maize flour   vitamin a  51.172808          regression
# 159         Angola  maize flour        zinc  51.172808          regression
# 160         Angola          oil   vitamin a  90.384708          regression
# 189     Madagascar  maize flour  folic acid  92.959155          regression
# 190     Madagascar  maize flour        iron  92.959155          regression
# 191     Madagascar  maize flour   vitamin a  92.959155          regression
# 192     Madagascar  maize flour        zinc  92.959155          regression
# 194     Madagascar  wheat flour  folic acid  45.221202          regression
# 195     Madagascar  wheat flour        iron  45.221202          regression
# 196     Madagascar  wheat flour   vitamin a  45.221202          regression
# 197     Madagascar  wheat flour        zinc  45.221202          regression
# 198          Niger  maize flour  folic acid  70.426320          regression
# 199          Niger  maize flour        iron  70.426320          regression
# 200          Niger  maize flour   vitamin a  70.426320          regression
# 201          Niger  maize flour        zinc  70.426320          regression
# 202          Niger          oil   vitamin a  85.000000                  na
#
#              B B_estimation_status          C C_estimation_status
# 73   51.975594      multiplicative  75.000000                  na
# 87   30.950000                  na  34.703333      multiplicative
# 88   30.950000                  na  33.835750      multiplicative
# 89   30.950000                  na  34.703333      multiplicative
# 90   30.950000                  na  34.703333      multiplicative
# 124   5.387876          regression  22.793768          regression
# 125   5.387876          regression  22.793768          regression
# 126   5.387876          regression  22.793768          regression
# 127   5.387876          regression  22.793768          regression
# 129  10.200000                  na  10.599703          regression
# 130  10.200000                  na  13.401500      multiplicative
# 131  10.200000                  na  10.599703          regression
# 143  27.574571          regression  73.100000                  na
# 144  27.574571          regression  73.100000                  na
# 145  27.574571          regression  73.100000          regression
# 146  27.574571          regression  73.100000                  na
# 156   5.550861          regression  22.485675          regression
# 157   5.550861          regression  22.485675          regression
# 158   5.550861          regression  22.485675          regression
# 159   5.550861          regression  22.485675          regression
# 160  35.635430          regression  42.655477          regression
# 189   4.485707          regression   6.362469          regression
# 190   4.485707          regression   6.362469          regression
# 191   4.485707          regression   6.362469          regression
# 192   4.485707          regression   6.362469          regression
# 194  25.987012          regression  32.625994          regression
# 195  25.987012          regression  32.625994          regression
# 196  25.987012          regression  32.625994          regression
# 197  25.987012          regression  32.625994          regression
# 198   3.830473          regression   6.220914          regression
# 199   3.830473          regression   6.220914          regression
# 200   3.830473          regression   6.220914          regression
# 201   3.830473          regression   6.220914          regression
# 202  54.403014          regression  75.000000                  na

# %%
ref[(ref.B.isna()) | (ref.C.isna())]
# Out:
# Empty DataFrame
# Columns: [location_name, vehicle, nutrient, A, A_estimation_status, B, B_estimation_status, C, C_estimation_status]
# Index: []

# %%
ref.location_name.nunique()
# Out:
# 25

# %%
oil_est_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_oil_regression_estimates_3_23_2021.csv'
wheat_est_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_wheat_regression_estimates_3_22_2021.csv'
maize_est_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_maize_regression_estimates_3_22_2021.csv'

ip_wheat_path =  '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_fortifiable_wheat_regression_estimates_3_31_2021.csv'
ip_oil_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_fortifiable_oil_regression_estimates_3_31_2021.csv'
ip_maize_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_fortifiable_maize_regression_estimates_3_31_2021.csv'

fort_wheat_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_fortified_wheat_regression_estimates_3_31_2021.csv'
fort_maize_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_fortified_maize_regression_estimates_3_31_2021.csv'
fort_oil_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/pct_eating_fortified_oil_regression_estimates_3_31_2021.csv'

# %%
paths_A = [oil_est_path,wheat_est_path,maize_est_path]
paths_B = [ip_wheat_path,ip_oil_path,ip_maize_path]
paths_C = [fort_wheat_path, fort_maize_path, fort_oil_path]

def format_data(paths, var, n):
    draws = [f'draw_{i}' for i in range(n)]
    df = pd.concat([pd.read_csv(path) for path in paths])
    df[var] = df[draws].mean(axis=1)
    df = df.drop(columns=draws)
    
    return df.groupby(['location_name','vehicle']).mean().reset_index()

# %%
scale_over_mean_map = {
    "maize flour":0.578996, 
    "oil":0.069702,
    "wheat flour":0.507994
}

# %%
df['scale_over_mean'] = 2 * df.vehicle.map(scale_over_mean_map)

# %%
eats = format_data(paths_A, 'reg_A', n = 1_000)
ip = format_data(paths_B, 'reg_B', n = 500)
fort = format_data(paths_C, 'reg_C',n = 500)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys

# %%
eats.head()
# Out:
#   location_name      vehicle      reg_A
# 0        Angola  maize flour  51.100278
# 1        Angola          oil  90.384708
# 2        Angola  wheat flour  27.171970
# 3    Bangladesh          oil  79.200000
# 4    Bangladesh  wheat flour  62.233333

# %%
df = df.merge(eats, on = ['location_name','vehicle'], how = 'outer')

# %%
df['updated'] = False

# %%
df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating vehicle") & 
   (df.reg_A.notna()),'updated'] = True

df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating vehicle") & 
   (df.reg_A.notna()),'estimation_status'] = 'regression'

df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating vehicle") & 
   (df.reg_A.notna()),'value_mean'] = df.reg_A

# %%
ip.head()
# Out:
#   location_name      vehicle      reg_B
# 0        Angola  maize flour   9.158853
# 1        Angola          oil  39.102709
# 2        Angola  wheat flour  26.261094
# 3    Bangladesh          oil  87.950000
# 4    Bangladesh  wheat flour  38.241333

# %%
df = df.merge(ip, on = ['location_name','vehicle'], how = 'outer')

# %%
df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating industrially produced vehicle") & 
   (df.reg_B.notna()),'updated'] = True

df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating industrially produced vehicle") & 
   (df.reg_B.notna()),'estimation_status'] = 'regression'

df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating industrially produced vehicle") & 
   (df.reg_B.notna()),'value_mean'] = df.reg_B

# %%
fort.head()
# Out:
#   location_name      vehicle      reg_C
# 0        Angola  maize flour   9.191133
# 1        Angola          oil   8.805705
# 2        Angola  wheat flour  16.888381
# 3    Bangladesh          oil  12.811708
# 4    Bangladesh  wheat flour   0.000000

# %%
df = df.merge(fort, on = ['location_name','vehicle'], how = 'outer')

# %%
df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating fortified vehicle") & 
   (df.reg_C.notna()),'updated'] = True

df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating fortified vehicle") & 
   (df.reg_B.notna()),'estimation_status'] = 'regression'

df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
   (df.value_description=="percent of population eating fortified vehicle") & 
   (df.reg_B.notna()),'value_mean'] = df.reg_C

# %%
df[(df.updated)].estimation_status.unique()
# Out:
# array(['regression'], dtype=object)

# %%
df['lower'] = np.clip(df.value_mean - (df.scale_over_mean * df.value_mean)/2, 0, 100)
df['upper'] = np.clip(df.value_mean + (df.scale_over_mean * df.value_mean)/2, 0, 100)

# %%
df.loc[(df.updated),'value_025_percentile'] = df.lower
df.loc[(df.updated),'value_975_percentile'] = df.upper

# %%
df.loc[(df.value_025_percentile.isna()),'value_025_percentile'] = df.lower
df.loc[(df.value_975_percentile.isna()),'value_975_percentile'] = df.upper

# %%
A = df[(df.value_description=="percent of population eating vehicle")].rename(
    columns={
        'value_mean':"A",
        'estimation_status':'A_estimation_status',
        'value_025_percentile':'A_lower',
        'value_975_percentile':'A_upper'
    })
B = df[(df.value_description=="percent of population eating industrially produced vehicle")].rename(
    columns={
        'value_mean':"B",
        'estimation_status':'B_estimation_status',
        'value_025_percentile':'B_lower',
        'value_975_percentile':'B_upper'
    })

C = df[(df.value_description=="percent of population eating fortified vehicle")].rename(
    columns={
        'value_mean':"C",
        'estimation_status':'C_estimation_status',
        'value_025_percentile':'C_lower',
        'value_975_percentile':'C_upper'
    })

# %%
# B = df[(df.value_description=="percent of population eating industrially produced vehicle")].rename(columns={'value_mean':"B",'estimation_status':'B_estimation_status'})
# C = df[(df.value_description=="percent of population eating fortified vehicle")].rename(columns={'value_mean':"C",'estimation_status':'C_estimation_status'})

A = A.drop(columns=['value_description','nutrient'])
B = B.drop(columns=['value_description','nutrient'])
C = C.drop(columns=['value_description'])

ref = A.merge(B, on = ['location_id','location_name','vehicle'], how = 'left').merge(C, on = ['location_id','location_name','vehicle'], how = 'outer') #[['location_name','vehicle','nutrient','A','A_estimation_status','B','B_estimation_status','C','C_estimation_status']]

# %%
ref = ref[['location_name','vehicle','nutrient',
           'A','A_lower','A_upper','A_estimation_status',
           'B','B_lower','B_upper','B_estimation_status',
           'C','C_lower','C_upper','C_estimation_status']]

# %%
ref
# Out:
#     location_name      vehicle    nutrient          A    A_lower     A_upper  \
# 0        Ethiopia  maize flour  folic acid  59.263848  24.950317   93.577380
# 1        Ethiopia  maize flour        iron  59.263848  24.950317   93.577380
# 2        Ethiopia  maize flour   vitamin a  59.263848  24.950317   93.577380
# 3        Ethiopia  maize flour        zinc  59.263848  24.950317   93.577380
# 4        Ethiopia          oil   vitamin a  29.350000  27.304246   31.395754
# ..            ...          ...         ...        ...        ...         ...
# 211         Sudan          oil   vitamin a  50.646725  47.116547   54.176903
# 212         Sudan  wheat flour  folic acid  88.823684  43.701786  100.000000
# 213         Sudan  wheat flour        iron  88.823684  43.701786  100.000000
# 214         Sudan  wheat flour   vitamin a  88.823684  43.701786  100.000000
# 215         Sudan  wheat flour        zinc  88.823684  43.701786  100.000000
#
#     A_estimation_status          B    B_lower    B_upper B_estimation_status  \
# 0            regression  27.167514  11.437632  42.897396          regression
# 1            regression  27.167514  11.437632  42.897396          regression
# 2            regression  27.167514  11.437632  42.897396          regression
# 3            regression  27.167514  11.437632  42.897396          regression
# 4            regression  70.000000  64.070691  75.929309                  na
# ..                  ...        ...        ...        ...                 ...
# 211          regression  80.000000  74.423840  85.576160                  na
# 212          regression  57.902255  28.488257  87.316254          regression
# 213          regression  57.902255  28.488257  87.316254          regression
# 214          regression  57.902255  28.488257  87.316254          regression
# 215          regression  57.902255  28.488257  87.316254          regression
#
#              C    C_lower    C_upper C_estimation_status
# 0     0.000000   0.000000   0.000000          regression
# 1     0.000000   0.000000   0.000000          regression
# 2     0.000000   0.000000   0.000000          regression
# 3     0.000000   0.000000   0.000000          regression
# 4     0.000000   0.000000   0.000000          regression
# ..         ...        ...        ...                 ...
# 211  80.000000  74.423840  85.576160                  na
# 212   6.525113   3.210395   9.839831          regression
# 213   6.525113   3.210395   9.839831          regression
# 214   6.525113   3.210395   9.839831          regression
# 215   6.525113   3.210395   9.839831          regression
#
# [216 rows x 15 columns]

# %%
ref[(ref.B < ref.C)][['location_name','A','B','C','B_upper','C_lower']]
# Out:
#      location_name          A          B          C    B_upper    C_lower
# 73    Burkina Faso  92.230000  51.975594  75.000000  77.976411  37.481212
# 87           Kenya  36.580000  30.950000  34.703333  48.296257  15.253480
# 88           Kenya  36.580000  30.950000  33.835750  48.296257  14.872143
# 89           Kenya  36.580000  30.950000  34.703333  48.296257  15.253480
# 90           Kenya  36.580000  30.950000  34.703333  48.296257  15.253480
# 130  Côte d'Ivoire  54.700000  10.200000  13.401500  13.100000   9.082841
# 143      Indonesia  75.761649  29.655911  73.100000  44.720935  49.543388
# 144      Indonesia  75.761649  29.655911  73.100000  44.720935  49.543388
# 146      Indonesia  75.761649  29.655911  73.100000  44.720935  49.543388
# 156         Angola  51.100278   9.158853   9.191133  14.461792   3.869504
# 157         Angola  51.100278   9.158853   9.191133  14.461792   3.869504
# 158         Angola  51.100278   9.158853   9.191133  14.461792   3.869504
# 159         Angola  51.100278   9.158853   9.191133  14.461792   3.869504

# %%
ref[(ref.B.isna()) | (ref.C.isna())][['location_name','vehicle','nutrient','A_estimation_status','A','B_estimation_status','B','C_estimation_status','C']]
# Out:
#     location_name      vehicle   nutrient A_estimation_status          A  \
# 145     Indonesia  wheat flour  vitamin a          regression  75.761649
# 165         China          oil  vitamin a          regression  57.651373
# 174         Egypt          oil  vitamin a          regression  54.973297
#
#     B_estimation_status          B C_estimation_status   C
# 145          regression  29.655911          regression NaN
# 165          regression  63.577005          regression NaN
# 174          regression  70.101964          regression NaN

# %%
ref[(ref.B_upper < ref.C_lower)][['location_name','vehicle','nutrient','A_estimation_status','A','B_estimation_status','B','C_estimation_status','C']]
# Out:
#     location_name      vehicle    nutrient A_estimation_status          A  \
# 143     Indonesia  wheat flour  folic acid          regression  75.761649
# 144     Indonesia  wheat flour        iron          regression  75.761649
# 146     Indonesia  wheat flour        zinc          regression  75.761649
#
#     B_estimation_status          B C_estimation_status     C
# 143          regression  29.655911                  na  73.1
# 144          regression  29.655911                  na  73.1
# 146          regression  29.655911                  na  73.1

# %%
# these are the locations rejection sampling should be able to fix
sub = ref.loc[(ref.B < ref.C) & ~(ref.B_upper < ref.C_lower)]

# %%
sub
# Out:
#      location_name      vehicle    nutrient          A    A_lower     A_upper  \
# 73    Burkina Faso          oil   vitamin a  92.230000  46.091896  100.000000
# 87           Kenya  wheat flour  folic acid  36.580000  16.078349   57.081651
# 88           Kenya  wheat flour        iron  36.580000  16.078349   57.081651
# 89           Kenya  wheat flour   vitamin a  36.580000  16.078349   57.081651
# 90           Kenya  wheat flour        zinc  36.580000  16.078349   57.081651
# 130  Côte d'Ivoire  wheat flour        iron  54.700000  50.100000   59.600000
# 156         Angola  maize flour  folic acid  51.100278  21.513422   80.687135
# 157         Angola  maize flour        iron  51.100278  21.513422   80.687135
# 158         Angola  maize flour   vitamin a  51.100278  21.513422   80.687135
# 159         Angola  maize flour        zinc  51.100278  21.513422   80.687135
#
#     A_estimation_status          B    B_lower    B_upper B_estimation_status  \
# 73                   na  51.975594  25.974777  77.976411      multiplicative
# 87                   na  30.950000  13.603743  48.296257                  na
# 88                   na  30.950000  13.603743  48.296257                  na
# 89                   na  30.950000  13.603743  48.296257                  na
# 90                   na  30.950000  13.603743  48.296257                  na
# 130                  na  10.200000   7.500000  13.100000                  na
# 156          regression   9.158853   3.855914  14.461792          regression
# 157          regression   9.158853   3.855914  14.461792          regression
# 158          regression   9.158853   3.855914  14.461792          regression
# 159          regression   9.158853   3.855914  14.461792          regression
#
#              C    C_lower     C_upper C_estimation_status
# 73   75.000000  37.481212  100.000000                  na
# 87   34.703333  15.253480   54.153186      multiplicative
# 88   33.835750  14.872143   52.799357      multiplicative
# 89   34.703333  15.253480   54.153186      multiplicative
# 90   34.703333  15.253480   54.153186      multiplicative
# 130  13.401500   9.082841   17.720159      multiplicative
# 156   9.191133   3.869504   14.512762          regression
# 157   9.191133   3.869504   14.512762          regression
# 158   9.191133   3.869504   14.512762          regression
# 159   9.191133   3.869504   14.512762          regression

# %%
fortifiable = sub[['location_name','vehicle','nutrient','B','B_lower','B_upper','B_estimation_status']]
fortifiable['value_description'] = 'B'

fortified = sub[['location_name','vehicle','nutrient','C','C_lower','C_upper','C_estimation_status']]
fortified['value_description'] = 'C'
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import scipy.stats
import scipy.integrate as integrate

# %%
sub.head()
# Out:
#    location_name      vehicle    nutrient      A    A_lower     A_upper  \
# 73  Burkina Faso          oil   vitamin a  92.23  46.091896  100.000000
# 87         Kenya  wheat flour  folic acid  36.58  16.078349   57.081651
# 88         Kenya  wheat flour        iron  36.58  16.078349   57.081651
# 89         Kenya  wheat flour   vitamin a  36.58  16.078349   57.081651
# 90         Kenya  wheat flour        zinc  36.58  16.078349   57.081651
#
#    A_estimation_status          B    B_lower    B_upper B_estimation_status  \
# 73                  na  51.975594  25.974777  77.976411      multiplicative
# 87                  na  30.950000  13.603743  48.296257                  na
# 88                  na  30.950000  13.603743  48.296257                  na
# 89                  na  30.950000  13.603743  48.296257                  na
# 90                  na  30.950000  13.603743  48.296257                  na
#
#             C    C_lower     C_upper C_estimation_status
# 73  75.000000  37.481212  100.000000                  na
# 87  34.703333  15.253480   54.153186      multiplicative
# 88  33.835750  14.872143   52.799357      multiplicative
# 89  34.703333  15.253480   54.153186      multiplicative
# 90  34.703333  15.253480   54.153186      multiplicative

# %%
replacement = pd.DataFrame()
for i, row in ref.loc[(ref.B < ref.C) & ~(ref.B_upper < ref.C_lower)].iterrows():
    std_b = np.max([(row.B_upper - row.B),(row.B - row.B_lower)]) / 1.96
    b_a = (0 - row.B) / std_b
    b_b = (100 - row.B) / std_b
    
    b_draws = scipy.stats.truncnorm.rvs(b_a, b_b, row.B, std_b, size = 500_000).tolist()
    
    std_c = np.max([(row.C_upper - row.C),(row.C - row.C_lower)]) / 1.96
    c_a = (0 - row.C) / std_c
    c_b = (100 - row.C) / std_c
    
    c_draws = scipy.stats.truncnorm.rvs(c_a, c_b, row.C, std_c, size = 500_000).tolist()
    
    all_draws = pd.DataFrame({
    'b':b_draws,
    'c':c_draws
    })

    all_draws = all_draws[all_draws.b > all_draws.c].T #only keep logical draws
    means = all_draws.mean(axis=1)
    lowers = all_draws.quantile(.025, axis=1)
    uppers = all_draws.quantile(.975, axis=1)
    
    
    new = pd.DataFrame({
    'location_name': [row.location_name] * 2,
    'vehicle': [row.vehicle] * 2,
    'nutrient': ['na',row.nutrient],
    'value_description':['percent of population eating industrially produced vehicle','percent of population eating fortified vehicle'],
    'value_mean':means,
    'value_025_percentile':lowers,
    'value_975_percentile':uppers,
    'estimation_status': [" + ".join([row.B_estimation_status,"rejection sampling"])," + ".join([row.C_estimation_status,"rejection sampling"])]
    })
    
    replacement = replacement.append(new)

# %%
replacement = replacement.groupby(['location_name','vehicle','value_description','nutrient','estimation_status']).mean().reset_index()

# %%
rename_repl = {
    'value_mean': 'new_value_mean',
    'value_025_percentile': 'new_value_025_percentile',
    'value_975_percentile': 'new_value_975_percentile',
    'estimation_status':'new_estimation_status'
}

replacement = replacement.rename(columns=rename_repl)

# %%
replacement
# Out:
#     location_name      vehicle  \
# 0          Angola  maize flour
# 1          Angola  maize flour
# 2          Angola  maize flour
# 3          Angola  maize flour
# 4          Angola  maize flour
# 5    Burkina Faso          oil
# 6    Burkina Faso          oil
# 7   Côte d'Ivoire  wheat flour
# 8   Côte d'Ivoire  wheat flour
# 9           Kenya  wheat flour
# 10          Kenya  wheat flour
# 11          Kenya  wheat flour
# 12          Kenya  wheat flour
# 13          Kenya  wheat flour
#
#                                     value_description    nutrient  \
# 0      percent of population eating fortified vehicle  folic acid
# 1      percent of population eating fortified vehicle        iron
# 2      percent of population eating fortified vehicle   vitamin a
# 3      percent of population eating fortified vehicle        zinc
# 4   percent of population eating industrially prod...          na
# 5      percent of population eating fortified vehicle   vitamin a
# 6   percent of population eating industrially prod...          na
# 7      percent of population eating fortified vehicle        iron
# 8   percent of population eating industrially prod...          na
# 9      percent of population eating fortified vehicle  folic acid
# 10     percent of population eating fortified vehicle        iron
# 11     percent of population eating fortified vehicle   vitamin a
# 12     percent of population eating fortified vehicle        zinc
# 13  percent of population eating industrially prod...          na
#
#                   new_estimation_status  new_value_mean  \
# 0       regression + rejection sampling        7.658490
# 1       regression + rejection sampling        7.658707
# 2       regression + rejection sampling        7.651943
# 3       regression + rejection sampling        7.649797
# 4       regression + rejection sampling       10.692860
# 5               na + rejection sampling       51.122017
# 6   multiplicative + rejection sampling       63.417476
# 7   multiplicative + rejection sampling       10.307836
# 8               na + rejection sampling       11.597039
# 9   multiplicative + rejection sampling       27.417595
# 10  multiplicative + rejection sampling       27.105320
# 11  multiplicative + rejection sampling       27.448172
# 12  multiplicative + rejection sampling       27.424855
# 13              na + rejection sampling       36.716072
#
#     new_value_025_percentile  new_value_975_percentile
# 0                   3.142445                 11.893078
# 1                   3.126008                 11.900065
# 2                   3.164621                 11.878758
# 3                   3.101712                 11.880930
# 4                   6.464823                 15.230748
# 5                  24.448594                 75.432995
# 6                  41.247528                 85.805233
# 7                   7.337757                 12.991637
# 8                   9.091318                 14.108237
# 9                  11.588142                 42.076972
# 10                 11.530287                 41.590336
# 11                 11.673097                 42.075963
# 12                 11.585467                 42.151540
# 13                 22.620747                 51.483509

# %%
replacement['new_value_025_percentile'] = np.clip(replacement.new_value_025_percentile - 0.75*(replacement.new_value_mean - replacement.new_value_025_percentile), 0, 100)
replacement['new_value_975_percentile'] = np.clip(replacement.new_value_975_percentile + 0.75*(replacement.new_value_975_percentile - replacement.new_value_mean), 0, 100)

# %%
output = df.merge(replacement, on = ['location_name','vehicle','value_description','nutrient'], how = 'left')

# %%
output.loc[(output.new_value_mean.notna()),'value_mean'] = output.new_value_mean
output.loc[(output.new_value_mean.notna()),'value_025_percentile'] = output.new_value_025_percentile
output.loc[(output.new_value_mean.notna()),'value_975_percentile'] = output.new_value_975_percentile

# %%
output.loc[(output.new_value_mean.notna()),'estimation_status'] = output.new_estimation_status

# %%
final_cols = ['location_id', 'location_name', 'sub_population', 'vehicle',
       'value_description', 'nutrient', 'value_mean', 'value_025_percentile',
       'value_975_percentile']

# %%
all_inputted_data_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/lsff_input_coverage_data.csv'

# %%
output[output.value_mean.isna()]
# Out:
#      location_id location_name sub_population      vehicle  \
# 218           11     Indonesia            NaN  wheat flour
# 252            6         China            NaN          oil
# 267          141         Egypt            NaN          oil
#
#                                   value_description   nutrient  value_mean  \
# 218  percent of population eating fortified vehicle  vitamin a         NaN
# 252  percent of population eating fortified vehicle  vitamin a         NaN
# 267  percent of population eating fortified vehicle  vitamin a         NaN
#
#      value_025_percentile  value_975_percentile  u5_applicable  ...  \
# 218             25.986776                 100.0           True  ...
# 252                   NaN                   NaN           True  ...
# 267                   NaN                   NaN           True  ...
#
#          reg_A updated      reg_B reg_C lower upper  new_estimation_status  \
# 218  75.761649   False  29.655911   NaN   NaN   NaN                    NaN
# 252  57.651373   False  63.577005   NaN   NaN   NaN                    NaN
# 267  54.973297   False  70.101964   NaN   NaN   NaN                    NaN
#
#      new_value_mean  new_value_025_percentile  new_value_975_percentile
# 218             NaN                       NaN                       NaN
# 252             NaN                       NaN                       NaN
# 267             NaN                       NaN                       NaN
#
# [3 rows x 27 columns]

# %%
## checkout if anything missing citations

# %%
pd.set_option('display.max_rows', 500)
output[['estimation_status','source_citation','source_link','CI_source','data_choice_notes']].drop_duplicates().sort_values('estimation_status')
# Out:
#                        estimation_status  \
# 56                      lack of evidence
# 54                        multiplicative
# 123                       multiplicative
# 41                        multiplicative
# 132  multiplicative + rejection sampling
# 112  multiplicative + rejection sampling
# 226                                   na
# 114                                   na
# 121                                   na
# 122                                   na
# 313                                   na
# 311                                   na
# 137                                   na
# 138                                   na
# 139                                   na
# 145                                   na
# 148                                   na
# 149                                   na
# 154                                   na
# 156                                   na
# 229                                   na
# 158                                   na
# 283                                   na
# 316                                   na
# 171                                   na
# 174                                   na
# 175                                   na
# 187                                   na
# 189                                   na
# 196                                   na
# 280                                   na
# 202                                   na
# 205                                   na
# 216                                   na
# 220                                   na
# 159                                   na
# 111                                   na
# 327                                   na
# 93                                    na
# 52                                    na
# 51                                    na
# 49                                    na
# 43                                    na
# 42                                    na
# 26                                    na
# 23                                    na
# 22                                    na
# 21                                    na
# 20                                    na
# 19                                    na
# 18                                    na
# 17                                    na
# 11                                    na
# 7                                     na
# 105                                   na
# 60                                    na
# 53                                    na
# 63                                    na
# 88                                    na
# 82                                    na
# 76                                    na
# 73                                    na
# 61                                    na
# 71                                    na
# 72                                    na
# 69                                    na
# 67                                    na
# 66                                    na
# 65                                    na
# 64                                    na
# 70                                    na
# 191              na + rejection sampling
# 131              na + rejection sampling
# 113              na + rejection sampling
# 129                           regression
# 0                             regression
# 236      regression + rejection sampling
#
#                                        source_citation  \
# 56                                                 NaN
# 54                                                 NaN
# 123                                                 na
# 41                                                 NaN
# 132                                                 na
# 112                                                NaN
# 226                                               GFDX
# 114  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 121  Ferguson, Elaine et al. “Zinc, iron and calciu...
# 122  Central Bureau of Statistics (Kenya), UK Depar...
# 313  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 311  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 145                                               GHDx
# 148                                               GHDx
# 149                                               GFDx
# 154  Laillou, A. et al. “An Assessment of the Impac...
# 156                                                NaN
# 229                                               GFDX
# 158  Improvement of the Vietnamese Diet for Women o...
# 283  Ghana and Orc Macro. “Ghana Demographic and He...
# 316              Corner, S. S. Nutrition and Business.
# 171  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 174  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 175  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 187  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 189  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 196  Moumin, N. A., Angel, M. D., Karakochuk, C. D....
# 280  Ghana and Orc Macro. “Ghana Demographic and He...
# 202  Termote, C., Meyi, M. B., Djailo, B. D. A., Hu...
# 205  Kismul, Hallgeir et al. “Diet and kwashiorkor:...
# 216                                                NaN
# 220                                               GFDX
# 159  Laillou, A. et al. “An Assessment of the Impac...
# 111  Dietary habits associated with growth developm...
# 327                                               GFDx
# 93   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 52                                                 NaN
# 51                                                 NaN
# 49   Leyvraz M, Laillou A, Rahman S, et al. An Asse...
# 43   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 42   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 26   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 23   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 22   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 21   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 20   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 19   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 18   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 17   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 11   Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 7    Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 105  Savy, M., Martin-Prével, Y., Traissac, P., Eym...
# 60   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 53                                                 NaN
# 63   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 88   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 82   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 76   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 73   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 61   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 71   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 72   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 69   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 67   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 66   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 65   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 64   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 70   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 191  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 131  Central Bureau of Statistics (Kenya), UK Depar...
# 113  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 129                                                 na
# 0                                                  NaN
# 236                                                NaN
#
#                                            source_link   CI_source  \
# 56                                                  na  extraction
# 54                                                  na    modeling
# 123                                                 na    modeling
# 41                                                 NaN    modeling
# 132                                                 na    modeling
# 112                                                NaN    modeling
# 226  https://fortificationdata.org/country-fortific...    modeling
# 114  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 121  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    modeling
# 122                                           NID 7375    modeling
# 313          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 311  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 137                  Flander’s investment trade report  extraction
# 138                                                NaN  extraction
# 139                                                NaN  extraction
# 145  http://internal-ghdx.healthdata.org/record/nep...  extraction
# 148  http://internal-ghdx.healthdata.org/record/nep...  extraction
# 149  https://fortificationdata.org/country-fortific...    modeling
# 154  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    modeling
# 156  https://www.acutemarketreports.com/report/viet...    modeling
# 229  https://fortificationdata.org/country-fortific...    modeling
# 158  https://journals.plos.org/plosone/article/file...    modeling
# 283    https://dhsprogram.com/pubs/pdf/FR307/FR307.pdf    modeling
# 316  http://www.unscn.org/files/Publications/SCN_Ne...    modeling
# 171  https://watermark.silverchair.com/555.pdf?toke...    modeling
# 174  https://journals.sagepub.com/doi/pdf/10.1177/1...  extraction
# 175  https://journals.sagepub.com/doi/pdf/10.1177/1...  extraction
# 187              https://doi.org/10.3945/jn.116.245753  extraction
# 189          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 196  https://www-ncbi-nlm-nih-gov.offcampus.lib.was...    modeling
# 280    https://dhsprogram.com/pubs/pdf/FR307/FR307.pdf    modeling
# 202  https://www-ncbi-nlm-nih-gov.offcampus.lib.was...    modeling
# 205  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  extraction
# 216  https://www.thejakartapost.com/academia/2020/0...    modeling
# 220  https://fortificationdata.org/country-fortific...    modeling
# 159  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    modeling
# 111  https://nutritionj.biomedcentral.com/articles/...    modeling
# 327  https://fortificationdata.org/country-fortific...    modeling
# 93               https://doi.org/10.3945/jn.116.245753  extraction
# 52   https://fortificationdata.org/full-gfdx-datasets/    modeling
# 51   https://www.gainhealth.org/sites/default/files...    modeling
# 49          https://www.mdpi.com/2072-6643/8/9/541/htm    modeling
# 43               https://doi.org/10.3945/jn.116.245753    modeling
# 42               https://doi.org/10.3945/jn.116.245753  extraction
# 26               https://doi.org/10.3945/jn.116.245753  extraction
# 23               https://doi.org/10.3945/jn.116.245753  extraction
# 22               https://doi.org/10.3945/jn.116.245753  extraction
# 21               https://doi.org/10.3945/jn.116.245753  extraction
# 20               https://doi.org/10.3945/jn.116.245753  extraction
# 19               https://doi.org/10.3945/jn.116.245753  extraction
# 18               https://doi.org/10.3945/jn.116.245753  extraction
# 17               https://doi.org/10.3945/jn.116.245753  extraction
# 11   http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 7    http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 105  https://academic.oup.com/jn/article-abstract/1...    modeling
# 60               https://doi.org/10.3945/jn.116.245753  extraction
# 53   https://www.gainhealth.org/sites/default/files...  extraction
# 63               https://doi.org/10.3945/jn.116.245753  extraction
# 88               https://doi.org/10.3945/jn.116.245753  extraction
# 82               https://doi.org/10.3945/jn.116.245753  extraction
# 76               https://doi.org/10.3945/jn.116.245753  extraction
# 73               https://doi.org/10.3945/jn.116.245753  extraction
# 61               https://doi.org/10.3945/jn.116.245753  extraction
# 71               https://doi.org/10.3945/jn.116.245753  extraction
# 72               https://doi.org/10.3945/jn.116.245753  extraction
# 69               https://doi.org/10.3945/jn.116.245753  extraction
# 67               https://doi.org/10.3945/jn.116.245753  extraction
# 66               https://doi.org/10.3945/jn.116.245753  extraction
# 65               https://doi.org/10.3945/jn.116.245753  extraction
# 64               https://doi.org/10.3945/jn.116.245753  extraction
# 70               https://doi.org/10.3945/jn.116.245753  extraction
# 191              https://doi.org/10.3945/jn.116.245753  extraction
# 131                                           NID 7375    modeling
# 113          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 129                                                 na    modeling
# 0                                                  NaN    modeling
# 236                                                NaN    modeling
#
#                                      data_choice_notes
# 56                                                 NaN
# 54                                                 NaN
# 123                                                NaN
# 41                                                 NaN
# 132                                                NaN
# 112                                                NaN
# 226  Keeping GFDx value (95.2%) for total populatio...
# 114  Only one source; discarding the urban- and rur...
# 121  Excluded central bureau of stats total pop num...
# 122                                   Only one source.
# 313  From two sources, we had an estimate of 55% in...
# 311  Only one source. Discarded urban and rural spe...
# 137                                   Only one source.
# 138  Unable to find data; assuming 0; justification...
# 139  Made assumption due to lack of data. Justifica...
# 145  Keeping overall estimate (99.8%), discarding e...
# 148  Using 52.1% of urban population eating Atta (w...
# 149  Keeping GFDx number (43%) from Nepal National ...
# 154  Only one source. Used value for all under-5 (3...
# 156                                   Only one source.
# 229  Keeping GFDx estimate (16.3%), as it is more r...
# 158  Only one source. Using value for all WRA (38.8...
# 283  Only one source; discarded urban and rural spe...
# 316                                   Only one source.
# 171  Keeping 53.1% for mixed/both urbanicity from E...
# 174  Keeping value from Hess et al. (92%) for mixed...
# 175  Keeping value from Hess et al. (94%) from 2011...
# 187                                    Only one source
# 189  Keeping Sablah et al. estimate of 75% from 201...
# 196  Discareded WRA data from same survey, in addit...
# 280  Discarded 2004 Nyumuah number (98%) in lieu of...
# 202  Took mean of five different subnational estima...
# 205  Only one source. Note: This data is from a 198...
# 216                                    Only one source
# 220                                   Only one source.
# 159  Only one source. Using value for all under-5 (...
# 111  discarded 2003-2007 Becquey numbers for total ...
# 327                                   Only one source.
# 93                                    Only one source.
# 52   Kept GFDx number (85%), discarded FACT survey ...
# 51                                     Only one source
# 49   Keeping Levyraz numbers (42% and 76%), as they...
# 43   Keeping Aaron (survey data) number from 2015 (...
# 42   Keeping Aaron number (88%) and descarding Ragh...
# 26                                    Only one source.
# 23   Only one source. Note source had two numbers: ...
# 22   Only one source. Note source had two numbers: ...
# 21   Only one source. Note source had two numbers: ...
# 20   Only one source. Note source had two numbers: ...
# 19   Only one source. Note source had two numbers: ...
# 18   Only one source. Note source had two numbers: ...
# 17   Only one source. Note source had two numbers: ...
# 11   Excluding 2000 overnment of the Federal Democr...
# 7    kept most recent year / representative populat...
# 105  We had one urban source, and one rural. We wei...
# 60                All sources (Aaron and GFDx) agreed.
# 53                                     Only one source
# 63                All sources (Aaron and GFDx) agreed.
# 88   GFDx held the same values; took this over a nu...
# 82   GFDx held the same values (51%); took this ove...
# 76   GFDx held the same values (93%); took this ove...
# 73   GFDx held the same values (42%); took this ove...
# 61   GFDx held the same values (89%); took this ove...
# 71                All sources (Aaron and GFDx) agreed.
# 72                All sources (Aaron and GFDx) agreed.
# 69                All sources (Aaron and GFDx) agreed.
# 67   GFDx held the same values (11%); took this ove...
# 66                All sources (Aaron and GFDx) agreed.
# 65                All sources (Aaron and GFDx) agreed.
# 64                All sources (Aaron and GFDx) agreed.
# 70                All sources (Aaron and GFDx) agreed.
# 191                                    Only one source
# 131                                   Only one source.
# 113  Out of two numbers from the same source, disca...
# 129                                                NaN
# 0                                                  NaN
# 236                                                NaN

# %%
output.loc[(output.estimation_status=="na"),['value_mean','source_citation','source_link','CI_source','data_choice_notes']].drop_duplicates()
# Out:
#      value_mean                                    source_citation  \
# 7     70.000000  Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 8     50.000000  Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 11    27.000000  Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 12    20.000000  Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 17    99.999000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 18    89.400000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 19    24.300000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 20    83.200000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 21     7.100000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 22     6.300000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 23     6.300000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 26    57.415462  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 27     8.543224  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 28     1.245041  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 32    98.460661  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 33    31.896365  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 34     7.478678  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 35    62.759594  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 36    62.568603  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 37    17.452812  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 42    88.400000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 43   100.000000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 49    41.900000  Leyvraz M, Laillou A, Rahman S, et al. An Asse...
# 50    76.200000  Leyvraz M, Laillou A, Rahman S, et al. An Asse...
# 51    28.492582                                                NaN
# 52    85.000000                                                NaN
# 53   100.000000                                                NaN
# 55     3.821239                                                NaN
# 58    41.525786                                                NaN
# 60    54.400000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 61    89.000000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 62    89.900000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 63     8.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 64     8.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 65     8.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 66     8.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 67    10.600000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 68    11.200000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 69     6.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 70     6.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 71     6.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 72     6.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 73    42.400000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 74    91.800000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 75    53.600000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 76    92.600000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 77    96.200000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 78    33.100000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 82    50.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 83    51.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 84     2.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 88    36.600000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 89    93.000000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 93     5.707704  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 97    10.917484  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 99    58.054148  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 103   96.444866  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 104   96.581541  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 105   26.610000  Savy, M., Martin-Prével, Y., Traissac, P., Eym...
# 111   92.230000  Dietary habits associated with growth developm...
# 114   48.000000  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 115   57.000000  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 121   91.671230  Ferguson, Elaine et al. “Zinc, iron and calciu...
# 122   36.670000  Central Bureau of Statistics (Kenya), UK Depar...
# 127   56.652927  Ferguson, Elaine et al. “Zinc, iron and calciu...
# 128    9.390000  Central Bureau of Statistics (Kenya), UK Depar...
# 130   36.580000  Central Bureau of Statistics (Kenya), UK Depar...
# 137   10.000000                                                NaN
# 138    0.000000                                                NaN
# 139    5.000000                                                NaN
# 145   99.800000                                               GHDx
# 148   52.100000                                               GHDx
# 149   43.000000                                               GFDx
# 154   38.300000  Laillou, A. et al. “An Assessment of the Impac...
# 156   90.000000                                                NaN
# 158   38.800000  Improvement of the Vietnamese Diet for Women o...
# 159   16.400000  Laillou, A. et al. “An Assessment of the Impac...
# 171   53.100000  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 174   92.000000  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 175   94.000000  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 187   98.500000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 188   98.000000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 189   75.000000  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 190   54.700000  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 196   42.190976  Moumin, N. A., Angel, M. D., Karakochuk, C. D....
# 202   95.882000  Termote, C., Meyi, M. B., Djailo, B. D. A., Hu...
# 205    0.580000  Kismul, Hallgeir et al. “Diet and kwashiorkor:...
# 216   73.100000                                                NaN
# 220   79.900000                                               GFDX
# 226   95.200000                                               GFDX
# 229   16.300000                                               GFDX
# 280   95.600000  Ghana and Orc Macro. “Ghana Demographic and He...
# 283   32.900000  Ghana and Orc Macro. “Ghana Demographic and He...
# 311   85.000000  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 313   75.000000  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 316   30.000000              Corner, S. S. Nutrition and Business.
# 327   80.000000                                               GFDx
#
#                                            source_link   CI_source  \
# 7    http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 8    http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 11   http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 12   http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 17               https://doi.org/10.3945/jn.116.245753  extraction
# 18               https://doi.org/10.3945/jn.116.245753  extraction
# 19               https://doi.org/10.3945/jn.116.245753  extraction
# 20               https://doi.org/10.3945/jn.116.245753  extraction
# 21               https://doi.org/10.3945/jn.116.245753  extraction
# 22               https://doi.org/10.3945/jn.116.245753  extraction
# 23               https://doi.org/10.3945/jn.116.245753  extraction
# 26               https://doi.org/10.3945/jn.116.245753  extraction
# 27               https://doi.org/10.3945/jn.116.245753  extraction
# 28               https://doi.org/10.3945/jn.116.245753  extraction
# 32               https://doi.org/10.3945/jn.116.245753  extraction
# 33               https://doi.org/10.3945/jn.116.245753  extraction
# 34               https://doi.org/10.3945/jn.116.245753  extraction
# 35               https://doi.org/10.3945/jn.116.245753  extraction
# 36               https://doi.org/10.3945/jn.116.245753  extraction
# 37               https://doi.org/10.3945/jn.116.245753  extraction
# 42               https://doi.org/10.3945/jn.116.245753  extraction
# 43               https://doi.org/10.3945/jn.116.245753    modeling
# 49          https://www.mdpi.com/2072-6643/8/9/541/htm    modeling
# 50          https://www.mdpi.com/2072-6643/8/9/541/htm    modeling
# 51   https://www.gainhealth.org/sites/default/files...    modeling
# 52   https://fortificationdata.org/full-gfdx-datasets/    modeling
# 53   https://www.gainhealth.org/sites/default/files...  extraction
# 55   https://www.gainhealth.org/sites/default/files...    modeling
# 58   https://www.gainhealth.org/sites/default/files...    modeling
# 60               https://doi.org/10.3945/jn.116.245753  extraction
# 61               https://doi.org/10.3945/jn.116.245753  extraction
# 62               https://doi.org/10.3945/jn.116.245753  extraction
# 63               https://doi.org/10.3945/jn.116.245753  extraction
# 64               https://doi.org/10.3945/jn.116.245753  extraction
# 65               https://doi.org/10.3945/jn.116.245753  extraction
# 66               https://doi.org/10.3945/jn.116.245753  extraction
# 67               https://doi.org/10.3945/jn.116.245753  extraction
# 68               https://doi.org/10.3945/jn.116.245753  extraction
# 69               https://doi.org/10.3945/jn.116.245753  extraction
# 70               https://doi.org/10.3945/jn.116.245753  extraction
# 71               https://doi.org/10.3945/jn.116.245753  extraction
# 72               https://doi.org/10.3945/jn.116.245753  extraction
# 73               https://doi.org/10.3945/jn.116.245753  extraction
# 74               https://doi.org/10.3945/jn.116.245753  extraction
# 75               https://doi.org/10.3945/jn.116.245753  extraction
# 76               https://doi.org/10.3945/jn.116.245753  extraction
# 77               https://doi.org/10.3945/jn.116.245753  extraction
# 78               https://doi.org/10.3945/jn.116.245753  extraction
# 82               https://doi.org/10.3945/jn.116.245753  extraction
# 83               https://doi.org/10.3945/jn.116.245753  extraction
# 84               https://doi.org/10.3945/jn.116.245753  extraction
# 88               https://doi.org/10.3945/jn.116.245753  extraction
# 89               https://doi.org/10.3945/jn.116.245753  extraction
# 93               https://doi.org/10.3945/jn.116.245753  extraction
# 97               https://doi.org/10.3945/jn.116.245753  extraction
# 99               https://doi.org/10.3945/jn.116.245753  extraction
# 103              https://doi.org/10.3945/jn.116.245753  extraction
# 104              https://doi.org/10.3945/jn.116.245753  extraction
# 105  https://academic.oup.com/jn/article-abstract/1...    modeling
# 111  https://nutritionj.biomedcentral.com/articles/...    modeling
# 114  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 115  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 121  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    modeling
# 122                                           NID 7375    modeling
# 127  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    modeling
# 128                                           NID 7375    modeling
# 130                                           NID 7375    modeling
# 137                  Flander’s investment trade report  extraction
# 138                                                NaN  extraction
# 139                                                NaN  extraction
# 145  http://internal-ghdx.healthdata.org/record/nep...  extraction
# 148  http://internal-ghdx.healthdata.org/record/nep...  extraction
# 149  https://fortificationdata.org/country-fortific...    modeling
# 154  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    modeling
# 156  https://www.acutemarketreports.com/report/viet...    modeling
# 158  https://journals.plos.org/plosone/article/file...    modeling
# 159  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    modeling
# 171  https://watermark.silverchair.com/555.pdf?toke...    modeling
# 174  https://journals.sagepub.com/doi/pdf/10.1177/1...  extraction
# 175  https://journals.sagepub.com/doi/pdf/10.1177/1...  extraction
# 187              https://doi.org/10.3945/jn.116.245753  extraction
# 188              https://doi.org/10.3945/jn.116.245753  extraction
# 189          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 190              https://doi.org/10.3945/jn.116.245753  extraction
# 196  https://www-ncbi-nlm-nih-gov.offcampus.lib.was...    modeling
# 202  https://www-ncbi-nlm-nih-gov.offcampus.lib.was...    modeling
# 205  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  extraction
# 216  https://www.thejakartapost.com/academia/2020/0...    modeling
# 220  https://fortificationdata.org/country-fortific...    modeling
# 226  https://fortificationdata.org/country-fortific...    modeling
# 229  https://fortificationdata.org/country-fortific...    modeling
# 280    https://dhsprogram.com/pubs/pdf/FR307/FR307.pdf    modeling
# 283    https://dhsprogram.com/pubs/pdf/FR307/FR307.pdf    modeling
# 311  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 313          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 316  http://www.unscn.org/files/Publications/SCN_Ne...    modeling
# 327  https://fortificationdata.org/country-fortific...    modeling
#
#                                      data_choice_notes
# 7    kept most recent year / representative populat...
# 8    kept most recent year / representative populat...
# 11   Excluding 2000 overnment of the Federal Democr...
# 12   Excluding 2000 overnment of the Federal Democr...
# 17   Only one source. Note source had two numbers: ...
# 18   Only one source. Note source had two numbers: ...
# 19   Only one source. Note source had two numbers: ...
# 20   Only one source. Note source had two numbers: ...
# 21   Only one source. Note source had two numbers: ...
# 22   Only one source. Note source had two numbers: ...
# 23   Only one source. Note source had two numbers: ...
# 26                                    Only one source.
# 27                                    Only one source.
# 28                                    Only one source.
# 32                                    Only one source.
# 33                                    Only one source.
# 34                                    Only one source.
# 35                                    Only one source.
# 36                                    Only one source.
# 37                                    Only one source.
# 42   Keeping Aaron number (88%) and descarding Ragh...
# 43   Keeping Aaron (survey data) number from 2015 (...
# 49   Keeping Levyraz numbers (42% and 76%), as they...
# 50   Keeping Levyraz numbers (42% and 76%), as they...
# 51                                     Only one source
# 52   Kept GFDx number (85%), discarded FACT survey ...
# 53                                     Only one source
# 55                                     Only one source
# 58                                     Only one source
# 60                All sources (Aaron and GFDx) agreed.
# 61   GFDx held the same values (89%); took this ove...
# 62                All sources (Aaron and GFDx) agreed.
# 63                All sources (Aaron and GFDx) agreed.
# 64                All sources (Aaron and GFDx) agreed.
# 65                All sources (Aaron and GFDx) agreed.
# 66                All sources (Aaron and GFDx) agreed.
# 67   GFDx held the same values (11%); took this ove...
# 68                All sources (Aaron and GFDx) agreed.
# 69                All sources (Aaron and GFDx) agreed.
# 70                All sources (Aaron and GFDx) agreed.
# 71                All sources (Aaron and GFDx) agreed.
# 72                All sources (Aaron and GFDx) agreed.
# 73   GFDx held the same values (42%); took this ove...
# 74                All sources (Aaron and GFDx) agreed.
# 75                All sources (Aaron and GFDx) agreed.
# 76   GFDx held the same values (93%); took this ove...
# 77                All sources (Aaron and GFDx) agreed.
# 78                All sources (Aaron and GFDx) agreed.
# 82   GFDx held the same values (51%); took this ove...
# 83                All sources (Aaron and GFDx) agreed.
# 84                All sources (Aaron and GFDx) agreed.
# 88   GFDx held the same values; took this over a nu...
# 89                All sources (Aaron and GFDx) agreed.
# 93                                    Only one source.
# 97                                    Only one source.
# 99                                    Only one source.
# 103                                   Only one source.
# 104                                   Only one source.
# 105  We had one urban source, and one rural. We wei...
# 111  discarded 2003-2007 Becquey numbers for total ...
# 114  Only one source; discarding the urban- and rur...
# 115  Only one source; discarding the urban- and rur...
# 121  Excluded central bureau of stats total pop num...
# 122                                   Only one source.
# 127  Excluded central bureau of stats total pop num...
# 128                                   Only one source.
# 130                                   Only one source.
# 137                                   Only one source.
# 138  Unable to find data; assuming 0; justification...
# 139  Made assumption due to lack of data. Justifica...
# 145  Keeping overall estimate (99.8%), discarding e...
# 148  Using 52.1% of urban population eating Atta (w...
# 149  Keeping GFDx number (43%) from Nepal National ...
# 154  Only one source. Used value for all under-5 (3...
# 156                                   Only one source.
# 158  Only one source. Using value for all WRA (38.8...
# 159  Only one source. Using value for all under-5 (...
# 171  Keeping 53.1% for mixed/both urbanicity from E...
# 174  Keeping value from Hess et al. (92%) for mixed...
# 175  Keeping value from Hess et al. (94%) from 2011...
# 187                                    Only one source
# 188                                    Only one source
# 189  Keeping Sablah et al. estimate of 75% from 201...
# 190                                    Only one source
# 196  Discareded WRA data from same survey, in addit...
# 202  Took mean of five different subnational estima...
# 205  Only one source. Note: This data is from a 198...
# 216                                    Only one source
# 220                                   Only one source.
# 226  Keeping GFDx value (95.2%) for total populatio...
# 229  Keeping GFDx estimate (16.3%), as it is more r...
# 280  Discarded 2004 Nyumuah number (98%) in lieu of...
# 283  Only one source; discarded urban and rural spe...
# 311  Only one source. Discarded urban and rural spe...
# 313  From two sources, we had an estimate of 55% in...
# 316                                   Only one source.
# 327                                   Only one source.

# %%
output.loc[
    (output.estimation_status=="na") &
    (output.source_citation.isna()) & 
    (output.source_link.isna()) & 
    (output.data_choice_notes.isna()),
]
# Out:
# Empty DataFrame
# Columns: [location_id, location_name, sub_population, vehicle, value_description, nutrient, value_mean, value_025_percentile, value_975_percentile, u5_applicable, wra_applicable, estimation_status, source_citation, source_link, CI_source, data_choice_notes, scale_over_mean, reg_A, updated, reg_B, reg_C, lower, upper, new_estimation_status, new_value_mean, new_value_025_percentile, new_value_975_percentile]
# Index: []
#
# [0 rows x 27 columns]

# %%
temp_save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/427b_lsff_input_coverage_data.csv'
output[final_cols + ['u5_applicable','wra_applicable']].to_csv(temp_save_path, index = False)

# %%
wmeta_cols = ['location_id', 'location_name', 'sub_population', 'vehicle',
       'value_description', 'nutrient', 'value_mean', 'value_025_percentile',
       'value_975_percentile', 'u5_applicable', 'wra_applicable',
       'estimation_status', 'source_citation', 'source_link', 'CI_source',
       'data_choice_notes']

wmeta_save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/04_27_lsff_input_coverage_data_with_metadata.csv'
output[wmeta_cols].to_csv(wmeta_save_path, index = False)

# %%
output[['estimation_status','source_citation','source_link','CI_source','data_choice_notes']].sort_values('estimation_status').drop_duplicates()
# Out:
#                        estimation_status  \
# 56                      lack of evidence
# 162                       multiplicative
# 54                        multiplicative
# 123                       multiplicative
# 193  multiplicative + rejection sampling
# 134  multiplicative + rejection sampling
# 311                                   na
# 127                                   na
# 130                                   na
# 226                                   na
# 313                                   na
# 205                                   na
# 115                                   na
# 111                                   na
# 283                                   na
# 202                                   na
# 137                                   na
# 145                                   na
# 139                                   na
# 229                                   na
# 174                                   na
# 175                                   na
# 220                                   na
# 219                                   na
# 280                                   na
# 187                                   na
# 159                                   na
# 189                                   na
# 158                                   na
# 156                                   na
# 154                                   na
# 196                                   na
# 149                                   na
# 148                                   na
# 171                                   na
# 144                                   na
# 105                                   na
# 103                                   na
# 37                                    na
# 42                                    na
# 43                                    na
# 49                                    na
# 51                                    na
# 52                                    na
# 53                                    na
# 60                                    na
# 61                                    na
# 63                                    na
# 64                                    na
# 65                                    na
# 328                                   na
# 7                                     na
# 11                                    na
# 17                                    na
# 18                                    na
# 19                                    na
# 20                                    na
# 21                                    na
# 22                                    na
# 23                                    na
# 66                                    na
# 88                                    na
# 317                                   na
# 67                                    na
# 82                                    na
# 69                                    na
# 70                                    na
# 71                                    na
# 73                                    na
# 76                                    na
# 72                                    na
# 113              na + rejection sampling
# 191              na + rejection sampling
# 131              na + rejection sampling
# 273                           regression
# 129                           regression
# 236      regression + rejection sampling
#
#                                        source_citation  \
# 56                                                 NaN
# 162                                                NaN
# 54                                                 NaN
# 123                                                 na
# 193                                                NaN
# 134                                                 na
# 311  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 127  Ferguson, Elaine et al. “Zinc, iron and calciu...
# 130  Central Bureau of Statistics (Kenya), UK Depar...
# 226                                               GFDX
# 313  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 205  Kismul, Hallgeir et al. “Diet and kwashiorkor:...
# 115  Hess, S. Y., Brown, K. H., Sablah, M., Engle-S...
# 111  Dietary habits associated with growth developm...
# 283  Ghana and Orc Macro. “Ghana Demographic and He...
# 202  Termote, C., Meyi, M. B., Djailo, B. D. A., Hu...
# 137                                                NaN
# 145                                               GHDx
# 139                                                NaN
# 229                                               GFDX
# 174  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 175  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 220                                               GFDX
# 219                                                NaN
# 280  Ghana and Orc Macro. “Ghana Demographic and He...
# 187  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 159  Laillou, A. et al. “An Assessment of the Impac...
# 189  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 158  Improvement of the Vietnamese Diet for Women o...
# 156                                                NaN
# 154  Laillou, A. et al. “An Assessment of the Impac...
# 196  Moumin, N. A., Angel, M. D., Karakochuk, C. D....
# 149                                               GFDx
# 148                                               GHDx
# 171  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 144                                                NaN
# 105  Savy, M., Martin-Prével, Y., Traissac, P., Eym...
# 103  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 37   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 42   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 43   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 49   Leyvraz M, Laillou A, Rahman S, et al. An Asse...
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 60   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 61   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 63   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 64   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 65   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 328                                               GFDx
# 7    Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 11   Hafebo AS, Ndao PBL, Wuehler S, et al. Overvie...
# 17   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 18   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 19   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 20   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 21   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 22   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 23   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 66   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 88   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 317              Corner, S. S. Nutrition and Business.
# 67   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 82   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 69   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 70   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 71   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 73   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 76   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 72   Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 113  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 191  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 131  Central Bureau of Statistics (Kenya), UK Depar...
# 273                                                NaN
# 129                                                 na
# 236                                                NaN
#
#                                            source_link   CI_source  \
# 56                                                  na  extraction
# 162                                                NaN    modeling
# 54                                                  na    modeling
# 123                                                 na    modeling
# 193                                                NaN    modeling
# 134                                                 na    modeling
# 311  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 127  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    modeling
# 130                                           NID 7375    modeling
# 226  https://fortificationdata.org/country-fortific...    modeling
# 313          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 205  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  extraction
# 115  https://journals.sagepub.com/doi/pdf/10.1177/1...    modeling
# 111  https://nutritionj.biomedcentral.com/articles/...    modeling
# 283    https://dhsprogram.com/pubs/pdf/FR307/FR307.pdf    modeling
# 202  https://www-ncbi-nlm-nih-gov.offcampus.lib.was...    modeling
# 137                  Flander’s investment trade report  extraction
# 145  http://internal-ghdx.healthdata.org/record/nep...  extraction
# 139                                                NaN  extraction
# 229  https://fortificationdata.org/country-fortific...    modeling
# 174  https://journals.sagepub.com/doi/pdf/10.1177/1...  extraction
# 175  https://journals.sagepub.com/doi/pdf/10.1177/1...  extraction
# 220  https://fortificationdata.org/country-fortific...    modeling
# 219  https://www.thejakartapost.com/academia/2020/0...    modeling
# 280    https://dhsprogram.com/pubs/pdf/FR307/FR307.pdf    modeling
# 187              https://doi.org/10.3945/jn.116.245753  extraction
# 159  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    modeling
# 189          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 158  https://journals.plos.org/plosone/article/file...    modeling
# 156  https://www.acutemarketreports.com/report/viet...    modeling
# 154  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    modeling
# 196  https://www-ncbi-nlm-nih-gov.offcampus.lib.was...    modeling
# 149  https://fortificationdata.org/country-fortific...    modeling
# 148  http://internal-ghdx.healthdata.org/record/nep...  extraction
# 171  https://watermark.silverchair.com/555.pdf?toke...    modeling
# 144                                                NaN  extraction
# 105  https://academic.oup.com/jn/article-abstract/1...    modeling
# 103              https://doi.org/10.3945/jn.116.245753  extraction
# 37               https://doi.org/10.3945/jn.116.245753  extraction
# 42               https://doi.org/10.3945/jn.116.245753  extraction
# 43               https://doi.org/10.3945/jn.116.245753    modeling
# 49          https://www.mdpi.com/2072-6643/8/9/541/htm    modeling
# 51   https://www.gainhealth.org/sites/default/files...    modeling
# 52   https://fortificationdata.org/full-gfdx-datasets/    modeling
# 53   https://www.gainhealth.org/sites/default/files...  extraction
# 60               https://doi.org/10.3945/jn.116.245753  extraction
# 61               https://doi.org/10.3945/jn.116.245753  extraction
# 63               https://doi.org/10.3945/jn.116.245753  extraction
# 64               https://doi.org/10.3945/jn.116.245753  extraction
# 65               https://doi.org/10.3945/jn.116.245753  extraction
# 328  https://fortificationdata.org/country-fortific...    modeling
# 7    http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 11   http://www.journalejnfs.com/index.php/EJNFS/ar...    modeling
# 17               https://doi.org/10.3945/jn.116.245753  extraction
# 18               https://doi.org/10.3945/jn.116.245753  extraction
# 19               https://doi.org/10.3945/jn.116.245753  extraction
# 20               https://doi.org/10.3945/jn.116.245753  extraction
# 21               https://doi.org/10.3945/jn.116.245753  extraction
# 22               https://doi.org/10.3945/jn.116.245753  extraction
# 23               https://doi.org/10.3945/jn.116.245753  extraction
# 66               https://doi.org/10.3945/jn.116.245753  extraction
# 88               https://doi.org/10.3945/jn.116.245753  extraction
# 317  http://www.unscn.org/files/Publications/SCN_Ne...    modeling
# 67               https://doi.org/10.3945/jn.116.245753  extraction
# 82               https://doi.org/10.3945/jn.116.245753  extraction
# 69               https://doi.org/10.3945/jn.116.245753  extraction
# 70               https://doi.org/10.3945/jn.116.245753  extraction
# 71               https://doi.org/10.3945/jn.116.245753  extraction
# 73               https://doi.org/10.3945/jn.116.245753  extraction
# 76               https://doi.org/10.3945/jn.116.245753  extraction
# 72               https://doi.org/10.3945/jn.116.245753  extraction
# 113          https://pubmed.ncbi.nlm.nih.gov/23444712/    modeling
# 191              https://doi.org/10.3945/jn.116.245753  extraction
# 131                                           NID 7375    modeling
# 273                                                NaN    modeling
# 129                                                 na    modeling
# 236                                                NaN    modeling
#
#                                      data_choice_notes
# 56                                                 NaN
# 162                                                NaN
# 54                                                 NaN
# 123                                                NaN
# 193                                                NaN
# 134                                                NaN
# 311  Only one source. Discarded urban and rural spe...
# 127  Excluded central bureau of stats total pop num...
# 130                                   Only one source.
# 226  Keeping GFDx value (95.2%) for total populatio...
# 313  From two sources, we had an estimate of 55% in...
# 205  Only one source. Note: This data is from a 198...
# 115  Only one source; discarding the urban- and rur...
# 111  discarded 2003-2007 Becquey numbers for total ...
# 283  Only one source; discarded urban and rural spe...
# 202  Took mean of five different subnational estima...
# 137                                   Only one source.
# 145  Keeping overall estimate (99.8%), discarding e...
# 139  Made assumption due to lack of data. Justifica...
# 229  Keeping GFDx estimate (16.3%), as it is more r...
# 174  Keeping value from Hess et al. (92%) for mixed...
# 175  Keeping value from Hess et al. (94%) from 2011...
# 220                                   Only one source.
# 219                                    Only one source
# 280  Discarded 2004 Nyumuah number (98%) in lieu of...
# 187                                    Only one source
# 159  Only one source. Using value for all under-5 (...
# 189  Keeping Sablah et al. estimate of 75% from 201...
# 158  Only one source. Using value for all WRA (38.8...
# 156                                   Only one source.
# 154  Only one source. Used value for all under-5 (3...
# 196  Discareded WRA data from same survey, in addit...
# 149  Keeping GFDx number (43%) from Nepal National ...
# 148  Using 52.1% of urban population eating Atta (w...
# 171  Keeping 53.1% for mixed/both urbanicity from E...
# 144  Unable to find data; assuming 0; justification...
# 105  We had one urban source, and one rural. We wei...
# 103                                   Only one source.
# 37                                    Only one source.
# 42   Keeping Aaron number (88%) and descarding Ragh...
# 43   Keeping Aaron (survey data) number from 2015 (...
# 49   Keeping Levyraz numbers (42% and 76%), as they...
# 51                                     Only one source
# 52   Kept GFDx number (85%), discarded FACT survey ...
# 53                                     Only one source
# 60                All sources (Aaron and GFDx) agreed.
# 61   GFDx held the same values (89%); took this ove...
# 63                All sources (Aaron and GFDx) agreed.
# 64                All sources (Aaron and GFDx) agreed.
# 65                All sources (Aaron and GFDx) agreed.
# 328                                   Only one source.
# 7    kept most recent year / representative populat...
# 11   Excluding 2000 overnment of the Federal Democr...
# 17   Only one source. Note source had two numbers: ...
# 18   Only one source. Note source had two numbers: ...
# 19   Only one source. Note source had two numbers: ...
# 20   Only one source. Note source had two numbers: ...
# 21   Only one source. Note source had two numbers: ...
# 22   Only one source. Note source had two numbers: ...
# 23   Only one source. Note source had two numbers: ...
# 66                All sources (Aaron and GFDx) agreed.
# 88   GFDx held the same values; took this over a nu...
# 317                                   Only one source.
# 67   GFDx held the same values (11%); took this ove...
# 82   GFDx held the same values (51%); took this ove...
# 69                All sources (Aaron and GFDx) agreed.
# 70                All sources (Aaron and GFDx) agreed.
# 71                All sources (Aaron and GFDx) agreed.
# 73   GFDx held the same values (42%); took this ove...
# 76   GFDx held the same values (93%); took this ove...
# 72                All sources (Aaron and GFDx) agreed.
# 113  Out of two numbers from the same source, disca...
# 191                                    Only one source
# 131                                   Only one source.
# 273                                                NaN
# 129                                                NaN
# 236                                                NaN

# %%
# output[final_cols + ['u5_applicable','wra_applicable']].to_csv(all_inputted_data_path)

# output[final_cols + ['u5_applicable','wra_applicable']].to_csv('/ihme/homes/beatrixh/repos/scratch/lsff_input_coverage_data.csv')

# %%
A = output[(output.value_description=="percent of population eating vehicle")].rename(columns={'value_mean':"A",'estimation_status':'A_estimation_status'})
B = output[(output.value_description=="percent of population eating industrially produced vehicle")].rename(columns={'value_mean':"B",'estimation_status':'B_estimation_status'})
C = output[(output.value_description=="percent of population eating fortified vehicle")].rename(columns={'value_mean':"C",'estimation_status':'C_estimation_status'})

A = A.drop(columns=['value_description','nutrient'])
B = B.drop(columns=['value_description','nutrient'])
C = C.drop(columns=['value_description'])

ref2 = A.merge(B, on = ['location_id','location_name','vehicle'], how = 'left').merge(C, on = ['location_id','location_name','vehicle'], how = 'outer')[['location_name','vehicle','nutrient','A','A_estimation_status','B','B_estimation_status','C','C_estimation_status']]

# %%
ref2[(ref2.B < ref2.C)]

# %%
ref2[(ref2.B.isna() | ref2.C.isna())]

# %%
## bug fixes

# %%
output.loc[(output.location_name=="Niger"),'location_id'] = 213

# %%
output.shape, output.drop_duplicates().shape

# %%
output = output.drop_duplicates()

# %%
output[(output.value_mean.isna()) | (output.value_025_percentile.isna()) | (output.value_975_percentile.isna())]

# %%
all_inputted_data_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/lsff_input_coverage_data.csv'

# %%
break

# %%
output[(output.location_name=="Kenya") & (output.vehicle.isin(['maize flour','wheat flour'])) & ((output.nutrient=="folic acid") | (output.value_description=="percent of the population eating industrially produced vehicle"))]

# %%
output[(output.location_name=="Kenya") & (output.vehicle.isin(['maize flour','wheat flour'])) & ((output.value_description=="percent of population eating industrially produced vehicle"))]

# %%
output[final_cols + ['u5_applicable','wra_applicable']].to_csv(all_inputted_data_path, index = False)
output[final_cols + ['u5_applicable','wra_applicable']].to_csv('/ihme/homes/beatrixh/repos/scratch/lsff_input_coverage_data.csv', index = False)

# %% [markdown]
# ## generate data richness scores

# %%
ref2[['A_estimation_status','B_estimation_status','C_estimation_status']].drop_duplicates()

# %%
ref2['score_from'] = ref2.A_estimation_status + '/' + ref2.B_estimation_status + '/' + ref2.C_estimation_status

# %%
score_map = {
    'regression/regression/regression': 0,
     'regression/na/regression': 1,
     'na/na/na': 5,
     'na/na/regression': 3,
     'na/na/multiplicative': 4,
     'na/multiplicative/multiplicative': 3,
     'na/na/lack of evidence': 4,
     'na/multiplicative/regression': 1,
     'na/multiplicative + rejection sampling/na + rejection sampling': 0,
     'na/na + rejection sampling/multiplicative + rejection sampling': 0,
     'regression/na/na': 5,
     'na/multiplicative/na': 4,
     'na/regression/multiplicative': 3,
     'na/regression/regression': 1,
     'na/na + rejection sampling/regression': 2,
     'na/na + rejection sampling/multiplicative': 2,
     'regression/regression/na': 2,
     'regression/regression + rejection sampling/regression + rejection sampling': 0,
     'na/regression/na': 4
    }

# %%
convert_4_pts = {
    0:0,
    1:1,
    2:2,
    3:2,
    4:3,
    5:4
}

# %%
convert_4_pts[score_map['na/na/na']]

# %%
ref2['score'] = ref2.score_from.map(score_map).map(convert_4_pts)

# %%
break

# %%
ref2.A_estimation_status.unique()

# %%
ref2.B_estimation_status.unique()

# %%
ref2.C_estimation_status.unique()

# %%
df[(df.value_mean.isna())]

# %%
break

# %%
## rejection sampling

# %%
df.columns

# %%
df.loc[(df.location_name.isin(['Angola', 'China', 'Ghana', 'Niger', 'Egypt', 'Sudan', 'Madagascar']))][['location_name', 'sub_population', 'vehicle',
       'value_description', 'nutrient', 'value_mean', 'value_025_percentile',
       'value_975_percentile', 
       'estimation_status', 'source_citation', 'source_link', 'CI_source',]].to_csv('/ihme/homes/beatrixh/repos/scratch/tier5_3_31_2021.csv', index = False)

# %%
break

# %%
# df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
#    (df.value_description=="percent of population eating indusrially produced vehicle") & 
#    (df.reg_A.notna()),'estimation_status'] = 'regression'

# df.loc[((df.estimation_status=="regression") | (df.value_mean.isna())) &
#    (df.value_description=="percent of population eating vehicle") & 
#    (df.reg_A.notna()),'value_mean'] = df.reg_A

# %%
break

# %%
# impute A
ref = ref.merge(eats, on = ['location_name','vehicle'], how = 'outer')
ref.loc[(ref.A.isna()),'A'] = ref.reg_A

# %%
df = ref.copy()

# %%
# merge on B and filter
est = pd.concat([pd.read_csv(path) for path in paths_B])

est = est.groupby(['location_name','vehicle']).mean().reset_index()

df = df.merge(est, on = ['location_name','vehicle'], how = 'outer')

draws = [f'draw_{i}' for i in range(500)]

for draw in draws:
    df.loc[(df.A < df[draw]) | 
                 (df.C > df[draw]),draw] = np.nan

df['reg_B'] = df[draws].mean(axis=1)
df = df.drop(columns = draws)

# these are rows you still dont have estimates for
# df[(df.B.isna()) & (df.reg_B.isna())]

df.loc[(df.B.isna()) | (df.B_estimation_status=='regression'),'B'] = df.reg_B

# %%
df[(df.A < df.B) | (df.B < df.C)]

# %%
df[(df.B < df.C) & (df.C_estimation_status=="regression")]

# %%
# merge on C and filter
est = pd.concat([pd.read_csv(path) for path in paths_C])

est = est.groupby(['location_name','vehicle']).mean().reset_index()

df = df.merge(est, on = ['location_name','vehicle'], how = 'outer')

draws = [f'draw_{i}' for i in range(500)]

for draw in draws:
    df.loc[(df.A < df[draw]) | 
                 (df.B < df[draw]),draw] = np.nan

df['reg_C'] = df[draws].mean(axis=1)
df = df.drop(columns = draws)

# these are rows you still dont have estimates for
# df[(df.B.isna()) & (df.reg_B.isna())]

df.loc[(df.C.isna()) | (df.C_estimation_status=='regression'),'C'] = df.reg_C

# %%
df[(df.B < df.C) & (df.C_estimation_status=="regression")]

# %%
df[(df.A < df.B) | (df.B < df.C)].shape

# %%
ref[(ref.A < ref.B) | (ref.B < ref.C)].shape

# %%
df[(df.A < df.B)]

# %%
df[(df.B < df.C)]

# %%
df[(df.A.isna() | df.B.isna() | df.C.isna())]

# %%
df

# %%
temp_a = df[['location_name','vehicle','nutrient','A']].rename(columns = {'A':'value_mean_est'}).drop_duplicates()
temp_a['value_description'] = "percent of the population eating vehicle"

temp_b = df[['location_name','vehicle','nutrient','B']].rename(columns = {'B':'value_mean_est'}).drop_duplicates()
temp_b['value_description'] = "percent of the population eating industrially produced vehicle"

temp_c = df[['location_name','vehicle','nutrient','C']].rename(columns = {'C':'value_mean_est'}).drop_duplicates()
temp_c['value_description'] = "percent of the population eating fortified vehicle"

# %%
imputed = pd.concat([temp_a,temp_b,temp_c])

# %%
imputed.head()

# %%
original = pd.read_csv(w_metadata_path)

# %%
test = original.merge(imputed, on = ['location_name','vehicle','value_description','nutrient'], how = 'outer')

# %%
test.loc[((test.value_mean.isna()) | (test.estimation_status=="regression")) & (test.value_mean_est.notna())][['location_name','vehicle','value_description','nutrient','value_mean_est']]

# %%
imputed.shape, original.shape

# %%
original.location_name.nunique()

# %%
imputed.location_name.nunique()

# %%
imputed

# %%
imputed['ac'] = imputed.groupby(['location_name','vehicle','value_description','nutrient']).transform('count').value_mean_est

# %%
imputed[(imputed.ac > 1)]

# %%
imputed[(imputed.ac > 1)].drop_duplicates()

# %%
test[test.value_mean_est > 1]

# %%
test.value_mean_est.min(), test.value_mean_est.max()
