# %%
import pandas as pd, numpy as np

# %%
temp_save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/427_lsff_input_coverage_data.csv'
save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/lsff_input_coverage_data.csv'

# %%
df = pd.read_csv(save_path)

# %%
alt = pd.read_csv(temp_save_path)

# %%
df.head()
# Out:
#    location_id location_name sub_population      vehicle  \
# 0          179      Ethiopia            NaN  maize flour
# 1          179      Ethiopia            NaN  maize flour
# 2          179      Ethiopia            NaN  maize flour
# 3          179      Ethiopia            NaN  maize flour
# 4          179      Ethiopia            NaN  maize flour
#
#                                    value_description    nutrient  value_mean  \
# 0               percent of population eating vehicle          na   59.263848
# 1  percent of population eating industrially prod...          na   27.167514
# 2     percent of population eating fortified vehicle  folic acid    0.000000
# 3     percent of population eating fortified vehicle        iron    0.000000
# 4     percent of population eating fortified vehicle   vitamin a    0.000000
#
#    value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 0             24.950317             93.577380           True            True
# ...

# %%
alt.head()
# Out:
#    location_id location_name sub_population      vehicle  \
# 0          179      Ethiopia            NaN  maize flour
# 1          179      Ethiopia            NaN  maize flour
# 2          179      Ethiopia            NaN  maize flour
# 3          179      Ethiopia            NaN  maize flour
# 4          179      Ethiopia            NaN  maize flour
#
#                                    value_description    nutrient  value_mean  \
# 0               percent of population eating vehicle          na   59.263848
# 1  percent of population eating industrially prod...          na   27.167514
# 2     percent of population eating fortified vehicle  folic acid    0.000000
# 3     percent of population eating fortified vehicle        iron    0.000000
# 4     percent of population eating fortified vehicle   vitamin a    0.000000
#
#    value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 0             24.950317             93.577380           True            True
# ...

# %%
idcols = ['location_id', 'location_name', 'sub_population', 'vehicle',
       'value_description', 'nutrient']

# %%
compare = df.merge(alt, on = idcols, how = 'left')

# %%
compare.loc[
    np.abs(compare.value_mean_x - compare.value_mean_y) > .1
]
# Out:
# Empty DataFrame
# Columns: [location_id, location_name, sub_population, vehicle, value_description, nutrient, value_mean_x, value_025_percentile_x, value_975_percentile_x, u5_applicable_x, wra_applicable_x, value_mean_y, value_025_percentile_y, value_975_percentile_y, u5_applicable_y, wra_applicable_y]
# Index: []

# %%
compare.loc[
    np.abs(compare.value_025_percentile_x - compare.value_025_percentile_y) > .1
]
# Out:
#      location_id location_name    sub_population vehicle  \
# 113          201  Burkina Faso  total population     oil
#
#                                   value_description   nutrient  value_mean_x  \
# 113  percent of population eating fortified vehicle  vitamin a     51.083142
#
#      value_025_percentile_x  value_975_percentile_x  u5_applicable_x  \
# 113                4.353188               93.493338             True
#
#      wra_applicable_x  value_mean_y  value_025_percentile_y  \
# 113              True     51.014713                3.959244
#
#      value_975_percentile_y  u5_applicable_y  wra_applicable_y
# 113               93.388722             True              True

# %%
compare.loc[
    np.abs(compare.value_975_percentile_x - compare.value_975_percentile_y) > .1
]
# Out:
#      location_id location_name    sub_population      vehicle  \
# 113          201  Burkina Faso  total population          oil
# 134          180         Kenya               NaN  wheat flour
#
#                                   value_description   nutrient  value_mean_x  \
# 113  percent of population eating fortified vehicle  vitamin a     51.083142
# 134  percent of population eating fortified vehicle  vitamin a     27.395570
#
#      value_025_percentile_x  value_975_percentile_x  u5_applicable_x  \
# 113                4.353188               93.493338             True
# 134                0.000000               53.020323             True
#
#      wra_applicable_x  value_mean_y  value_025_percentile_y  \
# 113              True     51.014713                3.959244
# 134              True     27.415019                0.000000
#
#      value_975_percentile_y  u5_applicable_y  wra_applicable_y
# 113               93.388722             True              True
# ...
