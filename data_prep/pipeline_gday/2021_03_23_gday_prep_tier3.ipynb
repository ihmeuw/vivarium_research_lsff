# %%
from db_queries import get_population, get_ids
from db_queries import get_location_metadata as get_locs

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# # Prep g/day for Tier 3 locs

# %% [markdown]
# ## Kenya, Burkina Faso, Myanmar, Vietnam, Nepal

# %%
## load targets
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)

# %%
gday_path =  '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/gday_extraction_sheet_03_22_2021.csv'
gday = pd.read_csv(gday_path)

assert(len(gday[gday.location_name.isna()])==0), "Some rows missing location name"

# %%
output = pd.DataFrame()

# %%
# location_names = ['Pakistan','Bangladesh','United Republic of Tanzania','Uganda','South Africa']

location_names = ['Kenya', 'Burkina Faso', 'Myanmar', 'Vietnam', 'Nepal']
vehicles = ['wheat flour','maize flour','oil']

# %%
# these are the vehicles per country we need
target = pd.DataFrame([(loc,v) for loc in location_names for v in country_vehicle_map[loc]],
            columns=['location_name','vehicle']).sort_values(['location_name','vehicle']).set_index(['location_name','vehicle'])

target
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Burkina Faso, bouillon), (Burkina Faso, maize flour), (Burkina Faso, oil), (Burkina Faso, wheat flour), (Kenya, maize flour), (Kenya, oil), (Kenya, wheat flour), (Myanmar, oil), (Myanmar, wheat flour), (Nepal, oil), (Nepal, wheat flour), (Vietnam, oil), (Vietnam, wheat flour)]

# %%
gday.location_id = gday.location_id.fillna(-1).astype(int)

# %%
gday.location_name.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Burkina Faso',
#        "Côte d'Ivoire", 'Cameroon', 'Chad', 'China ',
#        'Democratic Republic of the Congo', 'Egypt', 'Ethiopia', 'Ghana',
#        'India', 'Indonesia', 'Kenya', 'Madagascar', 'Mozambique',
#        'Myanmar', 'Nepal', 'Niger', 'Nigeria', 'Pakistan', 'Philippines',
#        'South Africa', 'Sudan', 'Uganda', 'United Republic of Tanzania',
#        'Viet Nam', 'Yemen', 'Zambia'], dtype=object)

# %%
# estimate CIs, crude

# clean value_mean
gday.loc[gday.value_mean=='na','value_mean'] = np.nan
gday.value_mean = gday.value_mean.astype(float)

# clean 2.5th %ile
gday.loc[gday.value_025_percentile=='na','value_025_percentile'] = np.nan
gday.value_025_percentile = gday.value_025_percentile.astype(float)

# clean 97.5th %ile
gday.loc[gday.value_975_percentile=='na','value_975_percentile'] = np.nan
gday.value_975_percentile = gday.value_975_percentile.astype(float)

# calc scale_over_mean
gday['scale_over_mean'] = (gday.value_975_percentile - gday.value_025_percentile) / gday.value_mean

#foreach vehicle, average scale_over_mean
r = gday[['vehicle','scale_over_mean']].groupby('vehicle').mean().dropna().rename(columns={'scale_over_mean':'r'})

# %%
# these are the vehicles for which we have a scale_over_mean estimate
r
# Out:
#                     r
# vehicle
# bouillon     0.902591
# wheat flour  0.699893

# %%
# for vehicles without a scale_over_mean value, we'll assign the average of the others (row-wise)
r = r.reset_index().append(pd.DataFrame([(i,gday.scale_over_mean.mean()) for i in ['maize flour', 'wheat(not specifically flour)','salt', 'rice']],
            columns = ['vehicle','r']))
r
# Out:
#                          vehicle         r
# 0                       bouillon  0.902591
# 1                    wheat flour  0.699893
# 0                    maize flour  0.819483
# 1  wheat(not specifically flour)  0.819483
# 2                           salt  0.819483
# 3                           rice  0.819483

# %%
# add uncertainty
gday = gday.merge(r, on = 'vehicle', how = 'outer')
gday['lower'] = gday.value_mean - (gday.r * gday.value_mean)/2
gday['upper'] = gday.value_mean + (gday.r * gday.value_mean)/2

# %%
gday[(gday.location_name.isin(location_names)) & (gday.vehicle.isin(vehicles))].groupby(['location_name','vehicle']).mean()
# Out:
#                            location_id  subnational_location_id  value_mean  \
# location_name vehicle
# Burkina Faso  maize flour          201                      NaN  140.600400
#               wheat flour          201                      NaN   26.888824
# Kenya         maize flour          180                      NaN  226.202500
#               wheat flour          180                      NaN   75.837917
# Myanmar       maize flour           15                      NaN    4.520000
#               wheat flour           15                      NaN   13.837600
# Nepal         wheat flour           -1                      NaN  108.072143
#
#                            value_025_percentile  value_975_percentile  \
# location_name vehicle
# Burkina Faso  maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Kenya         maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Myanmar       maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Nepal         wheat flour                   NaN                   NaN
#
#                            scale_over_mean         r       lower       upper
# location_name vehicle
# Burkina Faso  maize flour              NaN  0.819483   82.990551  198.210249
#               wheat flour              NaN  0.699893   17.479179   36.298468
# Kenya         maize flour              NaN  0.819483  133.517900  318.887100
#               wheat flour              NaN  0.699893   49.298719  102.377115
# Myanmar       maize flour              NaN  0.819483    2.667967    6.372033
#               wheat flour              NaN  0.699893    8.995183   18.680017
# Nepal         wheat flour              NaN  0.699893   70.252697  145.891589

# %%
gday[(gday.location_name=="Nepal")].value_description.unique()
# Out:
# array(['Mean per capita consumption among consumers (g/day)',
#        'Mean per capita consumption (g/day)'], dtype=object)

# %%
## dicts for var cleaning

value_d_to_metric = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'median',
 'Mean per capita consumption (g/day)': 'mean',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'mean',
 'Mean micronutrient intake per capita (mg/day)': 'mean',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'mean'
}

value_d_to_entity = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean per capita consumption (g/day)': 'CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean micronutrient intake per capita (mg/day)': 'nutrient',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'CHECK'
}

value_d_to_mass_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean per capita consumption (g/day)': 'g',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean micronutrient intake per capita (mg/day)': 'mg',
 'Daily per capita consumption (g)': 'g',
 'Daily consumption (mg/d)': 'mg',
 'Consumption per person per day (g)': 'g',
 'Estimated daily contribution from fortified foods (mg/d)': 'mg',
 'kg/capita/year': 'kg',
 'Mean per capita consumption among consumers (g/day)':'g'
}

value_d_to_time_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean per capita consumption (g/day)': 'day',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean micronutrient intake per capita (mg/day)': 'day',
 'Daily per capita consumption (g)': 'day',
 'Daily consumption (mg/d)': 'day',
 'Consumption per person per day (g)': 'day',
 'Estimated daily contribution from fortified foods (mg/d)': 'day',
 'kg/capita/year': 'year',
 'Mean per capita consumption among consumers (g/day)':'day'
}

value_d_to_population = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean per capita consumption (g/day)': 'capita CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean micronutrient intake per capita (mg/day)': 'capita CHECK',
 'Daily per capita consumption (g)': 'capita CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'consumers'
}

# %%
def format_value_d(df):
    df['metric'] = df.value_description.map(value_d_to_metric)
    df['entity'] = df.value_description.map(value_d_to_entity)
    df['mass_unit'] = df.value_description.map(value_d_to_mass_unit)
    df['time_unit'] = df.value_description.map(value_d_to_time_unit)
    df['pop_denom'] = df.value_description.map(value_d_to_population)
    
    return df

# %%
location_names
# Out:
# ['Kenya', 'Burkina Faso', 'Myanmar', 'Vietnam', 'Nepal']

# %%
viewcols = ['location_name','subnational_name', 'metric', 'entity',
            'mass_unit', 'time_unit', 'pop_denom','vehicle',
            'value_mean','value_025_percentile','value_975_percentile',
            'sub_population','urbanicity',
            'source_citation', 'source_link', 'source_year', 'source_type']

# %% [markdown]
# ## Kenya

# %%
kenya = gday[gday.location_name=="Kenya"]
kenya = format_value_d(kenya)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
kenya
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 61           180         Kenya               na                      NaN
# 62           180         Kenya               na                      NaN
# 362          180         Kenya               na                      NaN
# 363          180         Kenya               na                      NaN
# 364          180         Kenya               na                      NaN
# 365          180         Kenya               na                      NaN
# 366          180         Kenya               na                      NaN
# 367          180         Kenya               na                      NaN
# 368          180         Kenya               na                      NaN
# 369          180         Kenya               na                      NaN
# 370          180         Kenya               na                      NaN
# 371          180         Kenya               na                      NaN
# 372          180         Kenya               na                      NaN
# 373          180         Kenya               na                      NaN
# 374          180         Kenya               na                      NaN
# 375          180         Kenya               na                      NaN
# 376          180         Kenya               na                      NaN
# 377          180         Kenya               na                      NaN
# 378          180         Kenya               na                      NaN
# 379          180         Kenya               na                      NaN
# 380          180         Kenya               na                      NaN
# 381          180         Kenya               na                      NaN
# 382          180         Kenya               na                      NaN
# 383          180         Kenya               na                      NaN
# 630          180         Kenya               na                      NaN
# 631          180         Kenya               na                      NaN
# 785          180         Kenya               na                      NaN
# 786          180         Kenya               na                      NaN
# 787          180         Kenya               na                      NaN
# 788          180         Kenya               na                      NaN
# 789          180         Kenya               na                      NaN
# 790          180         Kenya               na                      NaN
# 791          180         Kenya               na                      NaN
# 792          180         Kenya               na                      NaN
# 793          180         Kenya               na                      NaN
# 794          180         Kenya               na                      NaN
# 795          180         Kenya               na                      NaN
# 796          180         Kenya               na                      NaN
# 797          180         Kenya               na                      NaN
# 798          180         Kenya               na                      NaN
# 799          180         Kenya               na                      NaN
# 800          180         Kenya               na                      NaN
# 801          180         Kenya               na                      NaN
# 802          180         Kenya               na                      NaN
# 803          180         Kenya               na                      NaN
# 804          180         Kenya               na                      NaN
# 805          180         Kenya               na                      NaN
# 806          180         Kenya               na                      NaN
# 994          180         Kenya               na                      NaN
#
#      urbanicity                        vehicle nutrient  \
# 61      unknown                    wheat flour       na
# 62   mixed/both                    wheat flour       na
# 362  mixed/both                    wheat flour       na
# 363  mixed/both                    wheat flour       na
# 364  mixed/both                    wheat flour       na
# 365  mixed/both                    wheat flour       na
# 366  mixed/both                    wheat flour       na
# 367  mixed/both                    wheat flour       na
# 368  mixed/both                    wheat flour       na
# 369  mixed/both                    wheat flour       na
# 370  mixed/both                    wheat flour       na
# 371  mixed/both                    wheat flour       na
# 372  mixed/both                    wheat flour       na
# 373  mixed/both                    wheat flour       na
# 374  mixed/both                    wheat flour       na
# 375  mixed/both                    wheat flour       na
# 376  mixed/both                    wheat flour       na
# 377  mixed/both                    wheat flour       na
# 378  mixed/both                    wheat flour       na
# 379  mixed/both                    wheat flour       na
# 380  mixed/both                    wheat flour       na
# 381  mixed/both                    wheat flour       na
# 382  mixed/both                    wheat flour       na
# 383  mixed/both                    wheat flour       na
# 630  mixed/both                    maize flour       na
# 631  mixed/both                    maize flour       na
# 785  mixed/both                    maize flour       na
# 786  mixed/both                    maize flour       na
# 787  mixed/both                    maize flour       na
# 788  mixed/both                    maize flour       na
# 789  mixed/both                    maize flour       na
# 790  mixed/both                    maize flour       na
# 791  mixed/both                    maize flour       na
# 792  mixed/both                    maize flour       na
# 793  mixed/both                    maize flour       na
# 794  mixed/both                    maize flour       na
# 795  mixed/both                    maize flour       na
# 796  mixed/both                    maize flour       na
# 797  mixed/both                    maize flour       na
# 798  mixed/both                    maize flour       na
# 799  mixed/both                    maize flour       na
# 800  mixed/both                    maize flour       na
# 801  mixed/both                    maize flour       na
# 802  mixed/both                    maize flour       na
# 803  mixed/both                    maize flour       na
# 804  mixed/both                    maize flour       na
# 805  mixed/both                    maize flour       na
# 806  mixed/both                    maize flour       na
# 994         NaN  wheat(not specifically flour)       na
#
#                        value_description  value_mean  value_025_percentile  \
# 61   Mean per capita consumption (g/day)       46.00                   NaN
# 62   Mean per capita consumption (g/day)      100.11                   NaN
# 362  Mean per capita consumption (g/day)       53.00                   NaN
# 363  Mean per capita consumption (g/day)       69.00                   NaN
# 364  Mean per capita consumption (g/day)       57.00                   NaN
# 365  Mean per capita consumption (g/day)       63.00                   NaN
# 366  Mean per capita consumption (g/day)       68.00                   NaN
# 367  Mean per capita consumption (g/day)       71.00                   NaN
# 368  Mean per capita consumption (g/day)       75.00                   NaN
# 369  Mean per capita consumption (g/day)       69.00                   NaN
# 370  Mean per capita consumption (g/day)       67.00                   NaN
# 371  Mean per capita consumption (g/day)       60.00                   NaN
# 372  Mean per capita consumption (g/day)       73.00                   NaN
# 373  Mean per capita consumption (g/day)       71.00                   NaN
# 374  Mean per capita consumption (g/day)       72.00                   NaN
# 375  Mean per capita consumption (g/day)       62.00                   NaN
# 376  Mean per capita consumption (g/day)       68.00                   NaN
# 377  Mean per capita consumption (g/day)       88.00                   NaN
# 378  Mean per capita consumption (g/day)       93.00                   NaN
# 379  Mean per capita consumption (g/day)       94.00                   NaN
# 380  Mean per capita consumption (g/day)       95.00                   NaN
# 381  Mean per capita consumption (g/day)      102.44                   NaN
# 382  Mean per capita consumption (g/day)      100.68                   NaN
# 383  Mean per capita consumption (g/day)      102.88                   NaN
# 630  Mean per capita consumption (g/day)      216.68                   NaN
# 631  Mean per capita consumption (g/day)      221.70                   NaN
# 785  Mean per capita consumption (g/day)      258.00                   NaN
# 786  Mean per capita consumption (g/day)      253.00                   NaN
# 787  Mean per capita consumption (g/day)      256.00                   NaN
# 788  Mean per capita consumption (g/day)      246.00                   NaN
# 789  Mean per capita consumption (g/day)      236.00                   NaN
# 790  Mean per capita consumption (g/day)      236.00                   NaN
# 791  Mean per capita consumption (g/day)      233.00                   NaN
# 792  Mean per capita consumption (g/day)      220.00                   NaN
# 793  Mean per capita consumption (g/day)      229.00                   NaN
# 794  Mean per capita consumption (g/day)      227.00                   NaN
# 795  Mean per capita consumption (g/day)      226.00                   NaN
# 796  Mean per capita consumption (g/day)      224.00                   NaN
# 797  Mean per capita consumption (g/day)      216.00                   NaN
# 798  Mean per capita consumption (g/day)      216.00                   NaN
# 799  Mean per capita consumption (g/day)      210.00                   NaN
# 800  Mean per capita consumption (g/day)      215.00                   NaN
# 801  Mean per capita consumption (g/day)      211.00                   NaN
# 802  Mean per capita consumption (g/day)      206.00                   NaN
# 803  Mean per capita consumption (g/day)      209.00                   NaN
# 804  Mean per capita consumption (g/day)      220.00                   NaN
# 805  Mean per capita consumption (g/day)      223.18                   NaN
# 806  Mean per capita consumption (g/day)      220.30                   NaN
# 994  Mean per capita consumption (g/day)       69.48                   NaN
#
#      ...  CI validated scale_over_mean         r       lower       upper  \
# 61   ...           NaN             NaN  0.699893   29.902470   62.097530
# 62   ...           NaN             NaN  0.699893   65.076877  135.143123
# 362  ...           NaN             NaN  0.699893   34.452846   71.547154
# 363  ...           NaN             NaN  0.699893   44.853706   93.146294
# 364  ...           NaN             NaN  0.699893   37.053061   76.946939
# 365  ...           NaN             NaN  0.699893   40.953383   85.046617
# 366  ...           NaN             NaN  0.699893   44.203652   91.796348
# 367  ...           NaN             NaN  0.699893   46.153813   95.846187
# 368  ...           NaN             NaN  0.699893   48.754028  101.245972
# 369  ...           NaN             NaN  0.699893   44.853706   93.146294
# 370  ...           NaN             NaN  0.699893   43.553598   90.446402
# 371  ...           NaN             NaN  0.699893   39.003222   80.996778
# 372  ...           NaN             NaN  0.699893   47.453921   98.546079
# 373  ...           NaN             NaN  0.699893   46.153813   95.846187
# 374  ...           NaN             NaN  0.699893   46.803867   97.196133
# 375  ...           NaN             NaN  0.699893   40.303330   83.696670
# 376  ...           NaN             NaN  0.699893   44.203652   91.796348
# 377  ...           NaN             NaN  0.699893   57.204726  118.795274
# 378  ...           NaN             NaN  0.699893   60.454995  125.545005
# 379  ...           NaN             NaN  0.699893   61.105048  126.894952
# 380  ...           NaN             NaN  0.699893   61.755102  128.244898
# 381  ...           NaN             NaN  0.699893   66.591502  138.288498
# 382  ...           NaN             NaN  0.699893   65.447407  135.912593
# 383  ...           NaN             NaN  0.699893   66.877525  138.882475
# 630  ...           NaN             NaN  0.819483  127.897166  305.462834
# 631  ...           NaN             NaN  0.819483  130.860262  312.539738
# 785  ...           NaN             NaN  0.819483  152.286638  363.713362
# 786  ...           NaN             NaN  0.819483  149.335347  356.664653
# 787  ...           NaN             NaN  0.819483  151.106122  360.893878
# 788  ...           NaN             NaN  0.819483  145.203539  346.796461
# 789  ...           NaN             NaN  0.819483  139.300956  332.699044
# 790  ...           NaN             NaN  0.819483  139.300956  332.699044
# 791  ...           NaN             NaN  0.819483  137.530181  328.469819
# 792  ...           NaN             NaN  0.819483  129.856823  310.143177
# 793  ...           NaN             NaN  0.819483  135.169148  322.830852
# 794  ...           NaN             NaN  0.819483  133.988631  320.011369
# 795  ...           NaN             NaN  0.819483  133.398373  318.601627
# 796  ...           NaN             NaN  0.819483  132.217856  315.782144
# 797  ...           NaN             NaN  0.819483  127.495790  304.504210
# 798  ...           NaN             NaN  0.819483  127.495790  304.504210
# 799  ...           NaN             NaN  0.819483  123.954240  296.045760
# 800  ...           NaN             NaN  0.819483  126.905532  303.094468
# 801  ...           NaN             NaN  0.819483  124.544499  297.455501
# 802  ...           NaN             NaN  0.819483  121.593207  290.406793
# 803  ...           NaN             NaN  0.819483  123.363982  294.636018
# 804  ...           NaN             NaN  0.819483  129.856823  310.143177
# 805  ...           NaN             NaN  0.819483  131.733845  314.626155
# 806  ...           NaN             NaN  0.819483  130.033901  310.566099
# 994  ...           NaN             NaN  0.819483   41.011146   97.948854
#
#     metric entity mass_unit time_unit     pop_denom
# 61    mean  CHECK         g       day  capita CHECK
# 62    mean  CHECK         g       day  capita CHECK
# 362   mean  CHECK         g       day  capita CHECK
# 363   mean  CHECK         g       day  capita CHECK
# 364   mean  CHECK         g       day  capita CHECK
# 365   mean  CHECK         g       day  capita CHECK
# 366   mean  CHECK         g       day  capita CHECK
# 367   mean  CHECK         g       day  capita CHECK
# 368   mean  CHECK         g       day  capita CHECK
# 369   mean  CHECK         g       day  capita CHECK
# 370   mean  CHECK         g       day  capita CHECK
# 371   mean  CHECK         g       day  capita CHECK
# 372   mean  CHECK         g       day  capita CHECK
# 373   mean  CHECK         g       day  capita CHECK
# 374   mean  CHECK         g       day  capita CHECK
# 375   mean  CHECK         g       day  capita CHECK
# 376   mean  CHECK         g       day  capita CHECK
# 377   mean  CHECK         g       day  capita CHECK
# 378   mean  CHECK         g       day  capita CHECK
# 379   mean  CHECK         g       day  capita CHECK
# 380   mean  CHECK         g       day  capita CHECK
# 381   mean  CHECK         g       day  capita CHECK
# 382   mean  CHECK         g       day  capita CHECK
# 383   mean  CHECK         g       day  capita CHECK
# 630   mean  CHECK         g       day  capita CHECK
# 631   mean  CHECK         g       day  capita CHECK
# 785   mean  CHECK         g       day  capita CHECK
# 786   mean  CHECK         g       day  capita CHECK
# 787   mean  CHECK         g       day  capita CHECK
# 788   mean  CHECK         g       day  capita CHECK
# 789   mean  CHECK         g       day  capita CHECK
# 790   mean  CHECK         g       day  capita CHECK
# 791   mean  CHECK         g       day  capita CHECK
# 792   mean  CHECK         g       day  capita CHECK
# 793   mean  CHECK         g       day  capita CHECK
# 794   mean  CHECK         g       day  capita CHECK
# 795   mean  CHECK         g       day  capita CHECK
# 796   mean  CHECK         g       day  capita CHECK
# 797   mean  CHECK         g       day  capita CHECK
# 798   mean  CHECK         g       day  capita CHECK
# 799   mean  CHECK         g       day  capita CHECK
# 800   mean  CHECK         g       day  capita CHECK
# 801   mean  CHECK         g       day  capita CHECK
# 802   mean  CHECK         g       day  capita CHECK
# 803   mean  CHECK         g       day  capita CHECK
# 804   mean  CHECK         g       day  capita CHECK
# 805   mean  CHECK         g       day  capita CHECK
# 806   mean  CHECK         g       day  capita CHECK
# 994   mean  CHECK         g       day  capita CHECK
#
# [49 rows x 30 columns]

# %%
kenya.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)'],
#       dtype=object)

# %%
kenya_wheat = kenya[(kenya.vehicle=="wheat flour")]
kenya_maize = kenya[(kenya.vehicle=="maize flour")]

# %%
kenya_wheat[viewcols]
# Out:
#     location_name subnational_name metric entity mass_unit time_unit  \
# 61          Kenya               na   mean  CHECK         g       day
# 62          Kenya               na   mean  CHECK         g       day
# 362         Kenya               na   mean  CHECK         g       day
# 363         Kenya               na   mean  CHECK         g       day
# 364         Kenya               na   mean  CHECK         g       day
# 365         Kenya               na   mean  CHECK         g       day
# 366         Kenya               na   mean  CHECK         g       day
# 367         Kenya               na   mean  CHECK         g       day
# 368         Kenya               na   mean  CHECK         g       day
# 369         Kenya               na   mean  CHECK         g       day
# 370         Kenya               na   mean  CHECK         g       day
# 371         Kenya               na   mean  CHECK         g       day
# 372         Kenya               na   mean  CHECK         g       day
# 373         Kenya               na   mean  CHECK         g       day
# 374         Kenya               na   mean  CHECK         g       day
# 375         Kenya               na   mean  CHECK         g       day
# 376         Kenya               na   mean  CHECK         g       day
# 377         Kenya               na   mean  CHECK         g       day
# 378         Kenya               na   mean  CHECK         g       day
# 379         Kenya               na   mean  CHECK         g       day
# 380         Kenya               na   mean  CHECK         g       day
# 381         Kenya               na   mean  CHECK         g       day
# 382         Kenya               na   mean  CHECK         g       day
# 383         Kenya               na   mean  CHECK         g       day
#
#         pop_denom      vehicle  value_mean  value_025_percentile  \
# 61   capita CHECK  wheat flour       46.00                   NaN
# 62   capita CHECK  wheat flour      100.11                   NaN
# 362  capita CHECK  wheat flour       53.00                   NaN
# 363  capita CHECK  wheat flour       69.00                   NaN
# 364  capita CHECK  wheat flour       57.00                   NaN
# 365  capita CHECK  wheat flour       63.00                   NaN
# 366  capita CHECK  wheat flour       68.00                   NaN
# 367  capita CHECK  wheat flour       71.00                   NaN
# 368  capita CHECK  wheat flour       75.00                   NaN
# 369  capita CHECK  wheat flour       69.00                   NaN
# 370  capita CHECK  wheat flour       67.00                   NaN
# 371  capita CHECK  wheat flour       60.00                   NaN
# 372  capita CHECK  wheat flour       73.00                   NaN
# 373  capita CHECK  wheat flour       71.00                   NaN
# 374  capita CHECK  wheat flour       72.00                   NaN
# 375  capita CHECK  wheat flour       62.00                   NaN
# 376  capita CHECK  wheat flour       68.00                   NaN
# 377  capita CHECK  wheat flour       88.00                   NaN
# 378  capita CHECK  wheat flour       93.00                   NaN
# 379  capita CHECK  wheat flour       94.00                   NaN
# 380  capita CHECK  wheat flour       95.00                   NaN
# 381  capita CHECK  wheat flour      102.44                   NaN
# 382  capita CHECK  wheat flour      100.68                   NaN
# 383  capita CHECK  wheat flour      102.88                   NaN
#
#      value_975_percentile    sub_population  urbanicity  \
# 61                    NaN  total population     unknown
# 62                    NaN  total population  mixed/both
# 362                   NaN  total population  mixed/both
# 363                   NaN  total population  mixed/both
# 364                   NaN  total population  mixed/both
# 365                   NaN  total population  mixed/both
# 366                   NaN  total population  mixed/both
# 367                   NaN  total population  mixed/both
# 368                   NaN  total population  mixed/both
# 369                   NaN  total population  mixed/both
# 370                   NaN  total population  mixed/both
# 371                   NaN  total population  mixed/both
# 372                   NaN  total population  mixed/both
# 373                   NaN  total population  mixed/both
# 374                   NaN  total population  mixed/both
# 375                   NaN  total population  mixed/both
# 376                   NaN  total population  mixed/both
# 377                   NaN  total population  mixed/both
# 378                   NaN  total population  mixed/both
# 379                   NaN  total population  mixed/both
# 380                   NaN  total population  mixed/both
# 381                   NaN  total population  mixed/both
# 382                   NaN  total population  mixed/both
# 383                   NaN  total population  mixed/both
#
#                                        source_citation  \
# 61   Fortification Handbook: Vitamin and Mineral Fo...
# 62                                                GFDx
# 362                                               GFDx
# 363                                               GFDx
# 364                                               GFDx
# 365                                               GFDx
# 366                                               GFDx
# 367                                               GFDx
# 368                                               GFDx
# 369                                               GFDx
# 370                                               GFDx
# 371                                               GFDx
# 372                                               GFDx
# 373                                               GFDx
# 374                                               GFDx
# 375                                               GFDx
# 376                                               GFDx
# 377                                               GFDx
# 378                                               GFDx
# 379                                               GFDx
# 380                                               GFDx
# 381                                               GFDx
# 382                                               GFDx
# 383                                               GFDx
#
#                                            source_link source_year  \
# 61   https://www.nutritionintl.org/content/user_fil...   1997-2000
# 62   https://fortificationdata.org/country-fortific...        2017
# 362  https://fortificationdata.org/full-gfdx-datasets/        1995
# 363  https://fortificationdata.org/full-gfdx-datasets/        1996
# 364  https://fortificationdata.org/full-gfdx-datasets/        1997
# 365  https://fortificationdata.org/full-gfdx-datasets/        1998
# 366  https://fortificationdata.org/full-gfdx-datasets/        1999
# 367  https://fortificationdata.org/full-gfdx-datasets/        2000
# 368  https://fortificationdata.org/full-gfdx-datasets/        2001
# 369  https://fortificationdata.org/full-gfdx-datasets/        2002
# 370  https://fortificationdata.org/full-gfdx-datasets/        2003
# 371  https://fortificationdata.org/full-gfdx-datasets/        2004
# 372  https://fortificationdata.org/full-gfdx-datasets/        2005
# 373  https://fortificationdata.org/full-gfdx-datasets/        2006
# 374  https://fortificationdata.org/full-gfdx-datasets/        2007
# 375  https://fortificationdata.org/full-gfdx-datasets/        2008
# 376  https://fortificationdata.org/full-gfdx-datasets/        2009
# 377  https://fortificationdata.org/full-gfdx-datasets/        2010
# 378  https://fortificationdata.org/full-gfdx-datasets/        2011
# 379  https://fortificationdata.org/full-gfdx-datasets/        2012
# 380  https://fortificationdata.org/full-gfdx-datasets/        2013
# 381  https://fortificationdata.org/full-gfdx-datasets/        2014
# 382  https://fortificationdata.org/full-gfdx-datasets/        2015
# 383  https://fortificationdata.org/full-gfdx-datasets/        2016
#
#                            source_type
# 61   estimated from FAO balance sheets
# 62   estimated from FAO balance sheets
# 362  estimated from FAO balance sheets
# 363  estimated from FAO balance sheets
# 364  estimated from FAO balance sheets
# 365  estimated from FAO balance sheets
# 366  estimated from FAO balance sheets
# 367  estimated from FAO balance sheets
# 368  estimated from FAO balance sheets
# 369  estimated from FAO balance sheets
# 370  estimated from FAO balance sheets
# 371  estimated from FAO balance sheets
# 372  estimated from FAO balance sheets
# 373  estimated from FAO balance sheets
# 374  estimated from FAO balance sheets
# 375  estimated from FAO balance sheets
# 376  estimated from FAO balance sheets
# 377  estimated from FAO balance sheets
# 378  estimated from FAO balance sheets
# 379  estimated from FAO balance sheets
# 380  estimated from FAO balance sheets
# 381  estimated from FAO balance sheets
# 382  estimated from FAO balance sheets
# 383  estimated from FAO balance sheets

# %%
for i in kenya_wheat[viewcols].source_citation:
    print(i)
# Out:
# Fortification Handbook: Vitamin and Mineral Fortification of Wheat Flour and Maize Meal. Nutrition International. https://www.nutritionintl.org/learning-resource/fortification-handbook-vitamin-and-mineral-fortification-of-wheat-flour-and-maize-meal/ (accessed March 18, 2021).
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx
# GFDx

# %%
kenya_wheat.loc[(kenya_wheat.source_year=="2017"),"data_choice_notes"] = "Between forfication handbook from 1997-2000 number (46 g/day) and GFDx number from 2017 (100.11 g/day), used GFDx number, noting that GFDx has 57 g/day for 1997."

output = output.append(kenya_wheat.loc[(kenya_wheat.source_year=="2017")])

kenya_wheat.loc[(kenya_wheat.source_year=="2017")]
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v107/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v107/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#     location_id location_name subnational_name  subnational_location_id  \
# 62          180         Kenya               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 62  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 62      100.11                   NaN  ...              NaN  0.699893
#
#         lower       upper metric entity mass_unit time_unit     pop_denom  \
# 62  65.076877  135.143123   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 62  Between forfication handbook from 1997-2000 nu...
#
# [1 rows x 31 columns]

# %%
kenya_wheat.loc[(kenya_wheat.source_year=="2017"),'source_type']
# Out:
# 62    estimated from FAO balance sheets
# Name: source_type, dtype: object

# %%
kenya_maize.loc[(kenya_maize.source_year.isin(['2017','2007'])),viewcols]
# Out:
#     location_name subnational_name metric entity mass_unit time_unit  \
# 630         Kenya               na   mean  CHECK         g       day
# 631         Kenya               na   mean  CHECK         g       day
# 797         Kenya               na   mean  CHECK         g       day
#
#         pop_denom      vehicle  value_mean  value_025_percentile  \
# 630  capita CHECK  maize flour      216.68                   NaN
# 631  capita CHECK  maize flour      221.70                   NaN
# 797  capita CHECK  maize flour      216.00                   NaN
#
#      value_975_percentile    sub_population  urbanicity  \
# 630                   NaN  total population  mixed/both
# 631                   NaN  total population  mixed/both
# 797                   NaN  total population  mixed/both
#
#                                        source_citation  \
# 630                                               GFDx
# 631  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 797                                               GFDx
#
#                                            source_link source_year  \
# 630  https://fortificationdata.org/country-fortific...        2017
# 631              https://doi.org/10.3945/an.110.000182        2007
# 797  https://fortificationdata.org/full-gfdx-datasets/        2007
#
#                            source_type
# 630  estimated from FAO balance sheets
# 631  estimated from FAO balance sheets
# 797  estimated from FAO balance sheets

# %%
kenya_maize.loc[(kenya_maize.source_year.isin(['2017'])),viewcols]
# Out:
#     location_name subnational_name metric entity mass_unit time_unit  \
# 630         Kenya               na   mean  CHECK         g       day
#
#         pop_denom      vehicle  value_mean  value_025_percentile  \
# 630  capita CHECK  maize flour      216.68                   NaN
#
#      value_975_percentile    sub_population  urbanicity source_citation  \
# 630                   NaN  total population  mixed/both            GFDx
#
#                                            source_link source_year  \
# 630  https://fortificationdata.org/country-fortific...        2017
#
#                            source_type
# 630  estimated from FAO balance sheets

# %%
kenya_maize.loc[(kenya_maize.source_year.isin(['2017'])),"data_choice_notes"] = "Discarded 2007 Nuss paper that estimated 221.7 g/day from FAO balance sheets, and kept GFDx 2017 estimate of 216.68 g/day, also estimated from FAO balance sheets "

output = output.append(kenya_maize.loc[(kenya_maize.source_year.isin(['2017']))])

kenya_maize.loc[(kenya_maize.source_year.isin(['2017']))]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 630          180         Kenya               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 630  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 630      216.68                   NaN  ...              NaN  0.819483
#
#           lower       upper metric entity mass_unit time_unit     pop_denom  \
# 630  127.897166  305.462834   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 630  Discarded 2007 Nuss paper that estimated 221.7...
#
# [1 rows x 31 columns]

# %% [markdown]
# ## Burkina Faso

# %%
bf = gday[gday.location_name=="Burkina Faso"]
bf = format_value_d(bf)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bf.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)',
#        'bouillon'], dtype=object)

# %%
bf_wheat = bf[(bf.vehicle=="wheat flour")]
bf_maize = bf[(bf.vehicle=="maize flour")]

# %%
bf_wheat[['source_citation','source_year','sub_population','value_mean','source_type']]
# Out:
#                                        source_citation source_year  \
# 12   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 13   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 14   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 15   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 16   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 17   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 18   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 19   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 20   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 21   Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...        1999
# 22                                                GFDx        2017
# 23   Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...        2002
# 318                                               GFDx        1995
# 319                                               GFDx        1996
# 320                                               GFDx        1997
# 321                                               GFDx        1998
# 322                                               GFDx        1999
# 323                                               GFDx        2000
# 324                                               GFDx        2001
# 325                                               GFDx        2002
# 326                                               GFDx        2003
# 327                                               GFDx        2004
# 328                                               GFDx        2005
# 329                                               GFDx        2006
# 330                                               GFDx        2007
# 331                                               GFDx        2008
# 332                                               GFDx        2009
# 333                                               GFDx        2010
# 334                                               GFDx        2011
# 335                                               GFDx        2012
# 336                                               GFDx        2013
# 337                                               GFDx        2014
# 338                                               GFDx        2015
# 339                                               GFDx        2016
#
#                 sub_population  value_mean                        source_type
# 12   women of reproductive age       49.00           Survey - cross-sectional
# 13   women of reproductive age       65.00           Survey - cross-sectional
# 14   women of reproductive age       21.00           Survey - cross-sectional
# 15   women of reproductive age       47.00           Survey - cross-sectional
# 16   women of reproductive age       55.00           Survey - cross-sectional
# 17       children 12-36 months       32.00           Survey - cross-sectional
# 18       children 12-36 months       30.00           Survey - cross-sectional
# 19       children 12-36 months       15.00           Survey - cross-sectional
# 20       children 12-36 months       38.00           Survey - cross-sectional
# 21       children 12-36 months       40.00           Survey - cross-sectional
# 22            total population       37.64  estimated from FAO balance sheets
# 23            total population       14.50           Survey - cross-sectional
# 318           total population       18.00  estimated from FAO balance sheets
# 319           total population       22.00  estimated from FAO balance sheets
# 320           total population       17.00  estimated from FAO balance sheets
# 321           total population       17.00  estimated from FAO balance sheets
# 322           total population       20.00  estimated from FAO balance sheets
# 323           total population       22.00  estimated from FAO balance sheets
# 324           total population       11.00  estimated from FAO balance sheets
# 325           total population       11.00  estimated from FAO balance sheets
# 326           total population        6.00  estimated from FAO balance sheets
# 327           total population       15.00  estimated from FAO balance sheets
# 328           total population       23.00  estimated from FAO balance sheets
# 329           total population       23.00  estimated from FAO balance sheets
# 330           total population       22.00  estimated from FAO balance sheets
# 331           total population       16.00  estimated from FAO balance sheets
# 332           total population       23.00  estimated from FAO balance sheets
# 333           total population       24.00  estimated from FAO balance sheets
# 334           total population       24.00  estimated from FAO balance sheets
# 335           total population       32.00  estimated from FAO balance sheets
# 336           total population       30.00  estimated from FAO balance sheets
# 337           total population       29.23  estimated from FAO balance sheets
# 338           total population       29.78  estimated from FAO balance sheets
# 339           total population       35.07  estimated from FAO balance sheets

# %%
bf_wheat[(bf_wheat.source_year=="2017")]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 22          201  Burkina Faso               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 22    unknown  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  CI validated scale_over_mean  \
# 22       37.64                   NaN  ...           NaN             NaN
#
#            r      lower      upper metric entity mass_unit time_unit  \
# 22  0.699893  24.468022  50.811978   mean  CHECK         g       day
#
#        pop_denom
# 22  capita CHECK
#
# [1 rows x 30 columns]

# %%
bf_wheat.loc[(bf_wheat.source_year=="2017"),"data_choice_notes"] = "Discarded 1999 Hess and Engle-Stone survey number (15-40 g/day) and a 2002 Sablah total population survey number (14.5 g/day) for a 2017 total-pop FAO balance sheet number (37 g/day), as GFDx estimates 11 g/day for 2002 and 20 g/day for 1999"

output = output.append(bf_wheat.loc[(bf_wheat.source_year=="2017"),])

bf_wheat.loc[(bf_wheat.source_year=="2017"),]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 22          201  Burkina Faso               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 22    unknown  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 22       37.64                   NaN  ...              NaN  0.699893
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 22  24.468022  50.811978   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 22  Discarded 1999 Hess and Engle-Stone survey num...
#
# [1 rows x 31 columns]

# %%
bf_maize[['source_citation','source_year','sub_population','value_mean','source_type']]
# Out:
#                                        source_citation source_year  \
# 612                                               GFDx        2017
# 613  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...        2007
# 614  Ranum, P., Peña‐Rosas, J. P., & Garcia‐Casal, ...   2007-2009
# 763                                               GFDx        1995
# 764                                               GFDx        1996
# 765                                               GFDx        1997
# 766                                               GFDx        1998
# 767                                               GFDx        1999
# 768                                               GFDx        2000
# 769                                               GFDx        2001
# 770                                               GFDx        2002
# 771                                               GFDx        2003
# 772                                               GFDx        2004
# 773                                               GFDx        2005
# 774                                               GFDx        2006
# 775                                               GFDx        2007
# 776                                               GFDx        2008
# 777                                               GFDx        2009
# 778                                               GFDx        2010
# 779                                               GFDx        2011
# 780                                               GFDx        2012
# 781                                               GFDx        2013
# 782                                               GFDx        2014
# 783                                               GFDx        2015
# 784                                               GFDx        2016
#
#        sub_population  value_mean                        source_type
# 612  total population      210.99  estimated from FAO balance sheets
# 613  total population      151.90  estimated from FAO balance sheets
# 614  total population      107.00  estimated from FAO balance sheets
# 763  total population       95.00  estimated from FAO balance sheets
# 764  total population       64.00  estimated from FAO balance sheets
# 765  total population       92.00  estimated from FAO balance sheets
# 766  total population       97.00  estimated from FAO balance sheets
# 767  total population       63.00  estimated from FAO balance sheets
# 768  total population      127.00  estimated from FAO balance sheets
# 769  total population       91.00  estimated from FAO balance sheets
# 770  total population      102.00  estimated from FAO balance sheets
# 771  total population      134.00  estimated from FAO balance sheets
# 772  total population      130.00  estimated from FAO balance sheets
# 773  total population      130.00  estimated from FAO balance sheets
# 774  total population      137.00  estimated from FAO balance sheets
# 775  total population      157.00  estimated from FAO balance sheets
# 776  total population      160.00  estimated from FAO balance sheets
# 777  total population      161.00  estimated from FAO balance sheets
# 778  total population      165.00  estimated from FAO balance sheets
# 779  total population      173.00  estimated from FAO balance sheets
# 780  total population      176.00  estimated from FAO balance sheets
# 781  total population      188.00  estimated from FAO balance sheets
# 782  total population      198.63  estimated from FAO balance sheets
# 783  total population      200.90  estimated from FAO balance sheets
# 784  total population      203.59  estimated from FAO balance sheets

# %%
bf_maize.loc[(bf_maize.source_year=="2017"),"data_choice_notes"] = "Discarded 2007 total pop Nuss estimate from FAO balanc esheets (152 g/day) and Ranum 2007-2009 estimate from FAO (107 g/day) in lieu of GFDx estimate from FAO balance sheets from 2017, given that GFDx 2007 estimate was 157 g/day"

output = output.append(bf_maize.loc[(bf_maize.source_year=="2017"),])

bf_maize.loc[(bf_maize.source_year=="2017"),]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 612          201  Burkina Faso               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 612    unknown  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 612      210.99                   NaN  ...              NaN  0.819483
#
#           lower       upper metric entity mass_unit time_unit     pop_denom  \
# 612  124.538596  297.441404   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 612  Discarded 2007 total pop Nuss estimate from FA...
#
# [1 rows x 31 columns]

# %% [markdown]
# ## Myanmar

# %%
checkcols = ['source_citation','source_year','sub_population','value_mean','source_type']

# %%
myanmar = gday[gday.location_name=="Myanmar"]
myanmar = format_value_d(myanmar)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
myanmar.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour'], dtype=object)

# %%
myWheat = myanmar[(myanmar.vehicle=="wheat flour")]
myMaize = myanmar[(myanmar.vehicle=="maize flour")]

# %%
myWheat[checkcols]
# Out:
#                                        source_citation source_year  \
# 67   Fortification Handbook: Vitamin and Mineral Fo...   1997-2000
# 68                                                GFDx        2017
# 69                              FAO food balance sheet         NaN
# 274                                               GFDx        1995
# 275                                               GFDx        1996
# 276                                               GFDx        1997
# 277                                               GFDx        1998
# 278                                               GFDx        1999
# 279                                               GFDx        2000
# 280                                               GFDx        2001
# 281                                               GFDx        2002
# 282                                               GFDx        2003
# 283                                               GFDx        2004
# 284                                               GFDx        2005
# 285                                               GFDx        2006
# 286                                               GFDx        2007
# 287                                               GFDx        2008
# 288                                               GFDx        2009
# 289                                               GFDx        2010
# 290                                               GFDx        2011
# 291                                               GFDx        2012
# 292                                               GFDx        2013
# 293                                               GFDx        2014
# 294                                               GFDx        2015
# 295                                               GFDx        2016
#
#                 sub_population  value_mean                        source_type
# 67            total population        7.00  estimated from FAO balance sheets
# 68            total population       29.92  estimated from FAO balance sheets
# 69   women of reproductive age       10.92  estimated from FAO balance sheets
# 274           total population        9.00  estimated from FAO balance sheets
# 275           total population        8.00  estimated from FAO balance sheets
# 276           total population        7.00  estimated from FAO balance sheets
# 277           total population        7.00  estimated from FAO balance sheets
# 278           total population       11.00  estimated from FAO balance sheets
# 279           total population       10.00  estimated from FAO balance sheets
# 280           total population       11.00  estimated from FAO balance sheets
# 281           total population       10.00  estimated from FAO balance sheets
# 282           total population        9.00  estimated from FAO balance sheets
# 283           total population       11.00  estimated from FAO balance sheets
# 284           total population       14.00  estimated from FAO balance sheets
# 285           total population       11.00  estimated from FAO balance sheets
# 286           total population       13.00  estimated from FAO balance sheets
# 287           total population       10.00  estimated from FAO balance sheets
# 288           total population       14.00  estimated from FAO balance sheets
# 289           total population       18.00  estimated from FAO balance sheets
# 290           total population       17.00  estimated from FAO balance sheets
# 291           total population       20.00  estimated from FAO balance sheets
# 292           total population       17.00  estimated from FAO balance sheets
# 293           total population       21.89  estimated from FAO balance sheets
# 294           total population       24.11  estimated from FAO balance sheets
# 295           total population       25.10  estimated from FAO balance sheets

# %%
myWheat.loc[(myWheat.source_year=='2017'),"data_choice_notes"] = "Discarded fortification handbok number (7 g/day) from 1997-2000 estimated from FAO balance sheets in lieu of 2017 GFDx number from FAO balance sheets"

output = output.append(myWheat.loc[(myWheat.source_year=='2017'),])

myWheat.loc[(myWheat.source_year=='2017'),]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 68           15       Myanmar               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 68    unknown  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 68       29.92                   NaN  ...              NaN  0.699893
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 68  19.449607  40.390393   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 68  Discarded fortification handbok number (7 g/da...
#
# [1 rows x 31 columns]

# %%
myMaize.columns
# Out:
# Index(['location_id', 'location_name', 'subnational_name',
#        'subnational_location_id', 'urbanicity', 'vehicle', 'nutrient',
#        'value_description', 'value_mean', 'value_025_percentile',
#        'value_975_percentile', 'sub_population', 'source_citation',
#        'source_link', 'source_year', 'source_type', 'notes', 'user',
#        'date_recorded', 'definition validated', 'CI validated',
#        'scale_over_mean', 'r', 'lower', 'upper', 'metric', 'entity',
#        'mass_unit', 'time_unit', 'pop_denom'],
#       dtype='object')

# %%
myMaize[checkcols + ['value_025_percentile','value_975_percentile']]
# Out:
#             source_citation source_year             sub_population  \
# 636  FAO food balance sheet         NaN  women of reproductive age
#
#      value_mean                        source_type  value_025_percentile  \
# 636        4.52  estimated from FAO balance sheets                   NaN
#
#      value_975_percentile
# 636                   NaN

# %%
myMaize["data_choice_notes"] = "Only one source."
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
output = output.append(myMaize)

myMaize
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 636           15       Myanmar               na                      NaN
#
#     urbanicity      vehicle nutrient value_description  value_mean  \
# 636    unknown  maize flour       na    kg/capita/year        4.52
#
#      value_025_percentile  ...  scale_over_mean         r     lower     upper  \
# 636                   NaN  ...              NaN  0.819483  2.667967  6.372033
#
#     metric entity mass_unit time_unit pop_denom data_choice_notes
# 636  CHECK  CHECK        kg      year     CHECK  Only one source.
#
# [1 rows x 31 columns]

# %% [markdown]
# ## Vietnam

# %%
vietnam = gday[gday.location_name.isin(['Vietnam','Viet Nam'])]
vietnam = format_value_d(vietnam)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
vietnam.vehicle.unique()
# Out:
# array(['wheat flour'], dtype=object)

# %%
vietnam[checkcols].source_citation.unique()
# Out:
# array(['Improvement of the Vietnamese Diet for Women of Reproductive Age by Micronutrient Fortification of Staples Foods and Condiments. Arnaud Laillou ,Jacques Berger,Bach Mai Le,Van Thuy Pham,Thi Hop Le,Cong Khan Nguyen,Dora Panagides,Fabian Rohner,Frank Wieringa,Regina Moench-Pfanner.Published: November 30, 2012https://doi.org/10.1371/journal.pone.0050538',
#        'Fortification Handbook: Vitamin and Mineral Fortification of Wheat Flour and Maize Meal. Nutrition International. https://www.nutritionintl.org/learning-resource/fortification-handbook-vitamin-and-mineral-fortification-of-wheat-flour-and-maize-meal/ (accessed March 18, 2021).',
#        'GFDx'], dtype=object)

# %%
vietnam[checkcols]
# Out:
#                                        source_citation source_year  \
# 93   Improvement of the Vietnamese Diet for Women o...        2010
# 94   Improvement of the Vietnamese Diet for Women o...        2010
# 95   Improvement of the Vietnamese Diet for Women o...        2010
# 96   Fortification Handbook: Vitamin and Mineral Fo...   1997-2000
# 97                                                GFDx        2017
# 340                                               GFDx        1995
# 341                                               GFDx        1996
# 342                                               GFDx        1997
# 343                                               GFDx        1998
# 344                                               GFDx        1999
# 345                                               GFDx        2000
# 346                                               GFDx        2001
# 347                                               GFDx        2002
# 348                                               GFDx        2003
# 349                                               GFDx        2004
# 350                                               GFDx        2005
# 351                                               GFDx        2006
# 352                                               GFDx        2007
# 353                                               GFDx        2008
# 354                                               GFDx        2009
# 355                                               GFDx        2010
# 356                                               GFDx        2011
# 357                                               GFDx        2012
# 358                                               GFDx        2013
# 359                                               GFDx        2014
# 360                                               GFDx        2015
# 361                                               GFDx        2016
#
#                 sub_population  value_mean                        source_type
# 93   women of reproductive age        1.30           Survey - cross-sectional
# 94   women of reproductive age       36.00           Survey - cross-sectional
# 95   women of reproductive age       33.80           Survey - cross-sectional
# 96            total population       14.00             Survey - other/unknown
# 97            total population       30.36  estimated from FAO balance sheets
# 340           total population       16.00  estimated from FAO balance sheets
# 341           total population       16.00  estimated from FAO balance sheets
# 342           total population       15.00  estimated from FAO balance sheets
# 343           total population       18.00  estimated from FAO balance sheets
# 344           total population       18.00  estimated from FAO balance sheets
# 345           total population       19.00  estimated from FAO balance sheets
# 346           total population       17.00  estimated from FAO balance sheets
# 347           total population       16.00  estimated from FAO balance sheets
# 348           total population       18.00  estimated from FAO balance sheets
# 349           total population       19.00  estimated from FAO balance sheets
# 350           total population       25.00  estimated from FAO balance sheets
# 351           total population       27.00  estimated from FAO balance sheets
# 352           total population       28.00  estimated from FAO balance sheets
# 353           total population       30.00  estimated from FAO balance sheets
# 354           total population       25.00  estimated from FAO balance sheets
# 355           total population       29.00  estimated from FAO balance sheets
# 356           total population       30.00  estimated from FAO balance sheets
# 357           total population       31.00  estimated from FAO balance sheets
# 358           total population       29.00  estimated from FAO balance sheets
# 359           total population       27.62  estimated from FAO balance sheets
# 360           total population       32.49  estimated from FAO balance sheets
# 361           total population       32.36  estimated from FAO balance sheets

# %%
vietnam.loc[(vietnam.source_year=="2017"),"data_choice_notes"] = "Discarded 2010 Laillou survey number for WRA (1-34 g/day) and 1997-2000 fortification handbook survey number (14 g/day) in lieu of GFDx 2017 number (30.36 g/day)"

output = output.append(
    vietnam.loc[(vietnam.source_year=="2017"),]
)

vietnam.loc[(vietnam.source_year=="2017"),]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 97           20      Viet Nam               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 97  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 97       30.36                   NaN  ...              NaN  0.699893
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 97  19.735631  40.984369   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 97  Discarded 2010 Laillou survey number for WRA (...
#
# [1 rows x 31 columns]

# %% [markdown]
# ## Nepal

# %%
nepal = gday[gday.location_name=="Nepal"]
nepal = format_value_d(nepal)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
nepal.vehicle.unique()
# Out:
# array(['wheat flour'], dtype=object)

# %%
nepal[checkcols]
# Out:
#                                        source_citation source_year  \
# 70   Centers for Disease Control and Prevention (CD...        2016
# 71   Centers for Disease Control and Prevention (CD...        2016
# 72   Centers for Disease Control and Prevention (CD...        2016
# 73   Fortification Handbook: Vitamin and Mineral Fo...   1997-2000
# 74                                                GFDx        2017
# 75   Fortifying Flour Where People Eat Rice. Hunger...        2007
# 450                                               GFDx        1995
# 451                                               GFDx        1996
# 452                                               GFDx        1997
# 453                                               GFDx        1998
# 454                                               GFDx        1999
# 455                                               GFDx        2000
# 456                                               GFDx        2001
# 457                                               GFDx        2002
# 458                                               GFDx        2003
# 459                                               GFDx        2004
# 460                                               GFDx        2005
# 461                                               GFDx        2006
# 462                                               GFDx        2007
# 463                                               GFDx        2008
# 464                                               GFDx        2009
# 465                                               GFDx        2010
# 466                                               GFDx        2011
# 467                                               GFDx        2012
# 468                                               GFDx        2013
# 469                                               GFDx        2014
# 470                                               GFDx        2015
# 471                                               GFDx        2016
#
#        sub_population  value_mean                        source_type
# 70   total population        6.10           Survey - cross-sectional
# 71   total population        5.60           Survey - cross-sectional
# 72   total population        5.70           Survey - cross-sectional
# 73   total population       70.00  estimated from FAO balance sheets
# 74   total population      144.85  estimated from FAO balance sheets
# 75   total population      104.00  estimated from FAO balance sheets
# 450  total population      100.00  estimated from FAO balance sheets
# 451  total population      101.00  estimated from FAO balance sheets
# 452  total population      107.00  estimated from FAO balance sheets
# 453  total population      104.00  estimated from FAO balance sheets
# 454  total population      110.00  estimated from FAO balance sheets
# 455  total population      112.00  estimated from FAO balance sheets
# 456  total population      112.00  estimated from FAO balance sheets
# 457  total population      111.00  estimated from FAO balance sheets
# 458  total population      115.00  estimated from FAO balance sheets
# 459  total population      120.00  estimated from FAO balance sheets
# 460  total population      132.00  estimated from FAO balance sheets
# 461  total population      122.00  estimated from FAO balance sheets
# 462  total population      122.00  estimated from FAO balance sheets
# 463  total population      124.00  estimated from FAO balance sheets
# 464  total population      125.00  estimated from FAO balance sheets
# 465  total population      130.00  estimated from FAO balance sheets
# 466  total population      135.00  estimated from FAO balance sheets
# 467  total population      139.00  estimated from FAO balance sheets
# 468  total population      138.00  estimated from FAO balance sheets
# 469  total population      144.27  estimated from FAO balance sheets
# 470  total population      143.18  estimated from FAO balance sheets
# 471  total population      143.32  estimated from FAO balance sheets

# %%
nepal.columns
# Out:
# Index(['location_id', 'location_name', 'subnational_name',
#        'subnational_location_id', 'urbanicity', 'vehicle', 'nutrient',
#        'value_description', 'value_mean', 'value_025_percentile',
#        'value_975_percentile', 'sub_population', 'source_citation',
#        'source_link', 'source_year', 'source_type', 'notes', 'user',
#        'date_recorded', 'definition validated', 'CI validated',
#        'scale_over_mean', 'r', 'lower', 'upper', 'metric', 'entity',
#        'mass_unit', 'time_unit', 'pop_denom'],
#       dtype='object')

# %%
nepal.loc[(nepal.source_year=="2016"),['urbanicity','vehicle','nutrient','value_description','value_mean','source_type','source_link','user','notes']]
# Out:
#      urbanicity      vehicle nutrient  \
# 70        urban  wheat flour       na
# 71        rural  wheat flour       na
# 72   mixed/both  wheat flour       na
# 471  mixed/both  wheat flour       na
#
#                                      value_description  value_mean  \
# 70   Mean per capita consumption among consumers (g...        6.10
# 71   Mean per capita consumption among consumers (g...        5.60
# 72   Mean per capita consumption among consumers (g...        5.70
# 471                Mean per capita consumption (g/day)      143.32
#
#                            source_type  \
# 70            Survey - cross-sectional
# 71            Survey - cross-sectional
# 72            Survey - cross-sectional
# 471  estimated from FAO balance sheets
#
#                                            source_link     user  \
# 70   http://internal-ghdx.healthdata.org/record/nep...  paulina
# 71   http://internal-ghdx.healthdata.org/record/nep...  paulina
# 72   http://internal-ghdx.healthdata.org/record/nep...  paulina
# 471  https://fortificationdata.org/full-gfdx-datasets/  paulina
#
#                                                  notes
# 70   Table 17.4 shows the per-capita availability o...
# 71   Table 17.4 shows the per-capita availability o...
# 72   Table 17.4 shows the per-capita availability o...
# 471  FAO. Food Supply - Crops Primary Equivalent. I...

# %%
nepal.loc[(nepal.urbanicity=="mixed/both") & (nepal.source_type=="Survey - cross-sectional"),
         "data_choice_notes"] = "Discarded GFDx FAO-balance sheet estimate from 2017 (145 g/day) in lieu of 2016 Nepal Micronutrient status survey finding (5.7 g/day)"

output = output.append(
    nepal.loc[(nepal.urbanicity=="mixed/both") & (nepal.source_type=="Survey - cross-sectional")]
)

nepal.loc[(nepal.urbanicity=="mixed/both") & (nepal.source_type=="Survey - cross-sectional")]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 72           -1         Nepal               na                      NaN
#
#     urbanicity      vehicle nutrient  \
# 72  mixed/both  wheat flour       na
#
#                                     value_description  value_mean  \
# 72  Mean per capita consumption among consumers (g...         5.7
#
#     value_025_percentile  ...  scale_over_mean         r     lower     upper  \
# 72                   NaN  ...              NaN  0.699893  3.705306  7.694694
#
#    metric entity mass_unit time_unit  pop_denom  \
# 72   mean  CHECK         g       day  consumers
#
#                                     data_choice_notes
# 72  Discarded GFDx FAO-balance sheet estimate from...
#
# [1 rows x 31 columns]

# %%
for i in nepal.loc[(nepal.urbanicity=="mixed/both") & (nepal.source_type=="Survey - cross-sectional")].value_description:
    print(i)
# Out:
# Mean per capita consumption among consumers (g/day)

# %% [markdown]
# # Format output

# %%
group_cols = ['location_id','location_name','sub_population','vehicle','metric','mass_unit','time_unit','pop_denom','source_citation','source_link','data_choice_notes']

# %%
loc_metadata = get_locs(location_set_id=35, gbd_round_id=6, decomp_step="step4")

# %%
output = output.drop(columns = 'location_id')
output = loc_metadata[['location_id','location_name']].merge(output, on = 'location_name', how = 'right')

# %%
output[['location_id','location_name','vehicle','value_mean','definition validated', 'CI validated']]
# Out:
#    location_id location_name      vehicle  value_mean  \
# 0          164         Nepal  wheat flour        5.70
# 1           15       Myanmar  wheat flour       29.92
# 2           15       Myanmar  maize flour        4.52
# 3           20      Viet Nam  wheat flour       30.36
# 4          180         Kenya  wheat flour      100.11
# 5          180         Kenya  maize flour      216.68
# 6          201  Burkina Faso  wheat flour       37.64
# 7          201  Burkina Faso  maize flour      210.99
#
#              definition validated CI validated
# 0                             Yes          NaN
# 1                             Yes          NaN
# 2  cannot locate source to verify          NaN
# 3                             Yes          NaN
# 4                             Yes          NaN
# 5                             Yes          NaN
# 6                             Yes          NaN
# 7                             Yes          NaN

# %%
output[['location_id','location_name','vehicle','value_mean','value_025_percentile','value_975_percentile','pop_denom','definition validated', 'CI validated']]
# Out:
#    location_id location_name      vehicle  value_mean  value_025_percentile  \
# 0          164         Nepal  wheat flour        5.70                   NaN
# 1           15       Myanmar  wheat flour       29.92                   NaN
# 2           15       Myanmar  maize flour        4.52                   NaN
# 3           20      Viet Nam  wheat flour       30.36                   NaN
# 4          180         Kenya  wheat flour      100.11                   NaN
# 5          180         Kenya  maize flour      216.68                   NaN
# 6          201  Burkina Faso  wheat flour       37.64                   NaN
# 7          201  Burkina Faso  maize flour      210.99                   NaN
#
#    value_975_percentile     pop_denom            definition validated  \
# 0                   NaN     consumers                             Yes
# 1                   NaN  capita CHECK                             Yes
# 2                   NaN         CHECK  cannot locate source to verify
# 3                   NaN  capita CHECK                             Yes
# 4                   NaN  capita CHECK                             Yes
# 5                   NaN  capita CHECK                             Yes
# 6                   NaN  capita CHECK                             Yes
# 7                   NaN  capita CHECK                             Yes
#
#   CI validated
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN

# %%
metric_map = {
    'mean':'mean',
    'CHECK':'mean'
}

pop_denom_map = {
    'capita':'capita',
    'CHECK':'capita',
    'capita CHECK':'capita',
    'consumers':'consumers'
}

output.metric = output.metric.map(metric_map)
output.pop_denom = output.pop_denom.map(pop_denom_map)

# %%
output[['location_id','location_name','vehicle','value_mean','pop_denom','definition validated', 'CI validated']]
# Out:
#    location_id location_name      vehicle  value_mean  pop_denom  \
# 0          164         Nepal  wheat flour        5.70  consumers
# 1           15       Myanmar  wheat flour       29.92     capita
# 2           15       Myanmar  maize flour        4.52     capita
# 3           20      Viet Nam  wheat flour       30.36     capita
# 4          180         Kenya  wheat flour      100.11     capita
# 5          180         Kenya  maize flour      216.68     capita
# 6          201  Burkina Faso  wheat flour       37.64     capita
# 7          201  Burkina Faso  maize flour      210.99     capita
#
#              definition validated CI validated
# 0                             Yes          NaN
# 1                             Yes          NaN
# 2  cannot locate source to verify          NaN
# 3                             Yes          NaN
# 4                             Yes          NaN
# 5                             Yes          NaN
# 6                             Yes          NaN
# 7                             Yes          NaN

# %%
output[['value_mean'] + group_cols]
# Out:
#    value_mean  location_id location_name             sub_population  \
# 0        5.70          164         Nepal           total population
# 1       29.92           15       Myanmar           total population
# 2        4.52           15       Myanmar  women of reproductive age
# 3       30.36           20      Viet Nam           total population
# 4      100.11          180         Kenya           total population
# 5      216.68          180         Kenya           total population
# 6       37.64          201  Burkina Faso           total population
# 7      210.99          201  Burkina Faso           total population
#
#        vehicle metric mass_unit time_unit  pop_denom  \
# 0  wheat flour   mean         g       day  consumers
# 1  wheat flour   mean         g       day     capita
# 2  maize flour   mean        kg      year     capita
# 3  wheat flour   mean         g       day     capita
# 4  wheat flour   mean         g       day     capita
# 5  maize flour   mean         g       day     capita
# 6  wheat flour   mean         g       day     capita
# 7  maize flour   mean         g       day     capita
#
#                                      source_citation  \
# 0  Centers for Disease Control and Prevention (CD...
# 1                                               GFDx
# 2                             FAO food balance sheet
# 3                                               GFDx
# 4                                               GFDx
# 5                                               GFDx
# 6                                               GFDx
# 7                                               GFDx
#
#                                          source_link  \
# 0  http://internal-ghdx.healthdata.org/record/nep...
# 1  https://fortificationdata.org/country-fortific...
# 2                                                NaN
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://fortificationdata.org/country-fortific...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
#
#                                    data_choice_notes
# 0  Discarded GFDx FAO-balance sheet estimate from...
# 1  Discarded fortification handbok number (7 g/da...
# 2                                   Only one source.
# 3  Discarded 2010 Laillou survey number for WRA (...
# 4  Between forfication handbook from 1997-2000 nu...
# 5  Discarded 2007 Nuss paper that estimated 221.7...
# 6  Discarded 1999 Hess and Engle-Stone survey num...
# 7  Discarded 2007 total pop Nuss estimate from FA...

# %%
output.columns
# Out:
# Index(['location_id', 'location_name', 'subnational_name',
#        'subnational_location_id', 'urbanicity', 'vehicle', 'nutrient',
#        'value_description', 'value_mean', 'value_025_percentile',
#        'value_975_percentile', 'sub_population', 'source_citation',
#        'source_link', 'source_year', 'source_type', 'notes', 'user',
#        'date_recorded', 'definition validated', 'CI validated',
#        'scale_over_mean', 'r', 'lower', 'upper', 'metric', 'entity',
#        'mass_unit', 'time_unit', 'pop_denom', 'data_choice_notes'],
#       dtype='object')

# %%
output.loc[(output.mass_unit=="kg"),'value_mean'] = output.value_mean * 1_000

output.loc[(output.mass_unit=="kg"),'lower'] = output.lower * 1_000
output.loc[(output.mass_unit=="kg"),'upper'] = output.upper * 1_000

output.loc[(output.mass_unit=="kg"),'value_025_percentile'] = output.value_025_percentile * 1_000
output.loc[(output.mass_unit=="kg"),'value_975_percentile'] = output.value_975_percentile * 1_000

output.loc[(output.mass_unit=="kg"),'mass_unit'] = 'g'

# %%
output.loc[(output.time_unit=="year"),'value_mean'] = output.value_mean / 365

output.loc[(output.time_unit=="year"),'lower'] = output.lower / 365
output.loc[(output.time_unit=="year"),'upper'] = output.upper / 365

output.loc[(output.time_unit=="year"),'value_025_percentile'] = output.value_025_percentile / 365
output.loc[(output.time_unit=="year"),'value_975_percentile'] = output.value_975_percentile / 365

output.loc[(output.time_unit=="year"),'time_unit'] = 'day'

# %%
output[['value_mean'] + group_cols]
# Out:
#    value_mean  location_id location_name             sub_population  \
# 0    5.700000          164         Nepal           total population
# 1   29.920000           15       Myanmar           total population
# 2   12.383562           15       Myanmar  women of reproductive age
# 3   30.360000           20      Viet Nam           total population
# 4  100.110000          180         Kenya           total population
# 5  216.680000          180         Kenya           total population
# 6   37.640000          201  Burkina Faso           total population
# 7  210.990000          201  Burkina Faso           total population
#
#        vehicle metric mass_unit time_unit  pop_denom  \
# 0  wheat flour   mean         g       day  consumers
# 1  wheat flour   mean         g       day     capita
# 2  maize flour   mean         g       day     capita
# 3  wheat flour   mean         g       day     capita
# 4  wheat flour   mean         g       day     capita
# 5  maize flour   mean         g       day     capita
# 6  wheat flour   mean         g       day     capita
# 7  maize flour   mean         g       day     capita
#
#                                      source_citation  \
# 0  Centers for Disease Control and Prevention (CD...
# 1                                               GFDx
# 2                             FAO food balance sheet
# 3                                               GFDx
# 4                                               GFDx
# 5                                               GFDx
# 6                                               GFDx
# 7                                               GFDx
#
#                                          source_link  \
# 0  http://internal-ghdx.healthdata.org/record/nep...
# 1  https://fortificationdata.org/country-fortific...
# 2                                                NaN
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://fortificationdata.org/country-fortific...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
#
#                                    data_choice_notes
# 0  Discarded GFDx FAO-balance sheet estimate from...
# 1  Discarded fortification handbok number (7 g/da...
# 2                                   Only one source.
# 3  Discarded 2010 Laillou survey number for WRA (...
# 4  Between forfication handbook from 1997-2000 nu...
# 5  Discarded 2007 Nuss paper that estimated 221.7...
# 6  Discarded 1999 Hess and Engle-Stone survey num...
# 7  Discarded 2007 total pop Nuss estimate from FA...

# %%
output[['value_mean','lower','upper'] + group_cols]
# Out:
#    value_mean       lower       upper  location_id location_name  \
# 0    5.700000    3.705306    7.694694          164         Nepal
# 1   29.920000   19.449607   40.390393           15       Myanmar
# 2   12.383562    2.667967    6.372033           15       Myanmar
# 3   30.360000   19.735631   40.984369           20      Viet Nam
# 4  100.110000   65.076877  135.143123          180         Kenya
# 5  216.680000  127.897166  305.462834          180         Kenya
# 6   37.640000   24.468022   50.811978          201  Burkina Faso
# 7  210.990000  124.538596  297.441404          201  Burkina Faso
#
#               sub_population      vehicle metric mass_unit time_unit  \
# 0           total population  wheat flour   mean         g       day
# 1           total population  wheat flour   mean         g       day
# 2  women of reproductive age  maize flour   mean         g       day
# 3           total population  wheat flour   mean         g       day
# 4           total population  wheat flour   mean         g       day
# 5           total population  maize flour   mean         g       day
# 6           total population  wheat flour   mean         g       day
# 7           total population  maize flour   mean         g       day
#
#    pop_denom                                    source_citation  \
# 0  consumers  Centers for Disease Control and Prevention (CD...
# 1     capita                                               GFDx
# 2     capita                             FAO food balance sheet
# 3     capita                                               GFDx
# 4     capita                                               GFDx
# 5     capita                                               GFDx
# 6     capita                                               GFDx
# 7     capita                                               GFDx
#
#                                          source_link  \
# 0  http://internal-ghdx.healthdata.org/record/nep...
# 1  https://fortificationdata.org/country-fortific...
# 2                                                NaN
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://fortificationdata.org/country-fortific...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
#
#                                    data_choice_notes
# 0  Discarded GFDx FAO-balance sheet estimate from...
# 1  Discarded fortification handbok number (7 g/da...
# 2                                   Only one source.
# 3  Discarded 2010 Laillou survey number for WRA (...
# 4  Between forfication handbook from 1997-2000 nu...
# 5  Discarded 2007 Nuss paper that estimated 221.7...
# 6  Discarded 1999 Hess and Engle-Stone survey num...
# 7  Discarded 2007 total pop Nuss estimate from FA...

# %%
output = output.rename(columns = {
    'source_citation':'mean_value_source_citation',
    'source_link':'mean_value_source_link'
})

# %%
assert(len(output[output.value_mean >= output.upper])==0), "check upper"
assert(len(output[output.value_mean <= output.lower])==0), "check lower"

# %% [markdown]
# # check for missing values

# %%
output.loc[(output.location_name=="Viet Nam"),'location_name'] = "Vietnam"

# %%
## load legal combos
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_vehicle_country_pairs.pickle', 'rb') as handle:
    vehicle_country_map = pickle.load(handle)

# %%
target_vehicles = [i for i in vehicle_nutrient_map.keys() if 'iron' in vehicle_nutrient_map[i]]
set([i for j in location_names for i in country_vehicle_map[j]])
# Out:
# {'bouillon', 'maize flour', 'oil', 'wheat flour'}

# %%
# make sure nothing missing. note we're not interested in oil/iron
output.reset_index().merge(target.reset_index(), on = ['location_name','vehicle'], how = 'outer')
# Out:
#     index  location_id location_name subnational_name  \
# 0     0.0        164.0         Nepal               na
# 1     1.0         15.0       Myanmar               na
# 2     2.0         15.0       Myanmar               na
# 3     3.0         20.0       Vietnam               na
# 4     4.0        180.0         Kenya               na
# 5     5.0        180.0         Kenya               na
# 6     6.0        201.0  Burkina Faso               na
# 7     7.0        201.0  Burkina Faso               na
# 8     NaN          NaN  Burkina Faso              NaN
# 9     NaN          NaN  Burkina Faso              NaN
# 10    NaN          NaN         Kenya              NaN
# 11    NaN          NaN       Myanmar              NaN
# 12    NaN          NaN         Nepal              NaN
# 13    NaN          NaN       Vietnam              NaN
#
#     subnational_location_id  urbanicity      vehicle nutrient  \
# 0                       NaN  mixed/both  wheat flour       na
# 1                       NaN     unknown  wheat flour       na
# 2                       NaN     unknown  maize flour       na
# 3                       NaN  mixed/both  wheat flour       na
# 4                       NaN  mixed/both  wheat flour       na
# 5                       NaN  mixed/both  maize flour       na
# 6                       NaN     unknown  wheat flour       na
# 7                       NaN     unknown  maize flour       na
# 8                       NaN         NaN     bouillon      NaN
# 9                       NaN         NaN          oil      NaN
# 10                      NaN         NaN          oil      NaN
# 11                      NaN         NaN          oil      NaN
# 12                      NaN         NaN          oil      NaN
# 13                      NaN         NaN          oil      NaN
#
#                                     value_description  value_mean  ...  \
# 0   Mean per capita consumption among consumers (g...    5.700000  ...
# 1                 Mean per capita consumption (g/day)   29.920000  ...
# 2                                      kg/capita/year   12.383562  ...
# 3                 Mean per capita consumption (g/day)   30.360000  ...
# 4                 Mean per capita consumption (g/day)  100.110000  ...
# 5                 Mean per capita consumption (g/day)  216.680000  ...
# 6                 Mean per capita consumption (g/day)   37.640000  ...
# 7                 Mean per capita consumption (g/day)  210.990000  ...
# 8                                                 NaN         NaN  ...
# 9                                                 NaN         NaN  ...
# 10                                                NaN         NaN  ...
# 11                                                NaN         NaN  ...
# 12                                                NaN         NaN  ...
# 13                                                NaN         NaN  ...
#
#     scale_over_mean         r       lower       upper metric entity mass_unit  \
# 0               NaN  0.699893    3.705306    7.694694   mean  CHECK         g
# 1               NaN  0.699893   19.449607   40.390393   mean  CHECK         g
# 2               NaN  0.819483    2.667967    6.372033   mean  CHECK         g
# 3               NaN  0.699893   19.735631   40.984369   mean  CHECK         g
# 4               NaN  0.699893   65.076877  135.143123   mean  CHECK         g
# 5               NaN  0.819483  127.897166  305.462834   mean  CHECK         g
# 6               NaN  0.699893   24.468022   50.811978   mean  CHECK         g
# 7               NaN  0.819483  124.538596  297.441404   mean  CHECK         g
# 8               NaN       NaN         NaN         NaN    NaN    NaN       NaN
# 9               NaN       NaN         NaN         NaN    NaN    NaN       NaN
# 10              NaN       NaN         NaN         NaN    NaN    NaN       NaN
# 11              NaN       NaN         NaN         NaN    NaN    NaN       NaN
# 12              NaN       NaN         NaN         NaN    NaN    NaN       NaN
# 13              NaN       NaN         NaN         NaN    NaN    NaN       NaN
#
#    time_unit  pop_denom                                  data_choice_notes
# 0        day  consumers  Discarded GFDx FAO-balance sheet estimate from...
# 1        day     capita  Discarded fortification handbok number (7 g/da...
# 2        day     capita                                   Only one source.
# 3        day     capita  Discarded 2010 Laillou survey number for WRA (...
# 4        day     capita  Between forfication handbook from 1997-2000 nu...
# 5        day     capita  Discarded 2007 Nuss paper that estimated 221.7...
# 6        day     capita  Discarded 1999 Hess and Engle-Stone survey num...
# 7        day     capita  Discarded 2007 total pop Nuss estimate from FA...
# 8        NaN        NaN                                                NaN
# 9        NaN        NaN                                                NaN
# 10       NaN        NaN                                                NaN
# 11       NaN        NaN                                                NaN
# 12       NaN        NaN                                                NaN
# 13       NaN        NaN                                                NaN
#
# [14 rows x 32 columns]

# %%
#reorder columns
output = output[['location_id', 'location_name', 'sub_population', 'vehicle', 'metric',
       'mass_unit', 'time_unit', 'pop_denom','value_mean', 'lower',
       'upper', 'mean_value_source_citation',
       'mean_value_source_link', 'data_choice_notes']]

# %%
output
# Out:
#    location_id location_name             sub_population      vehicle metric  \
# 0          164         Nepal           total population  wheat flour   mean
# 1           15       Myanmar           total population  wheat flour   mean
# 2           15       Myanmar  women of reproductive age  maize flour   mean
# 3           20       Vietnam           total population  wheat flour   mean
# 4          180         Kenya           total population  wheat flour   mean
# 5          180         Kenya           total population  maize flour   mean
# 6          201  Burkina Faso           total population  wheat flour   mean
# 7          201  Burkina Faso           total population  maize flour   mean
#
#   mass_unit time_unit  pop_denom  value_mean       lower       upper  \
# 0         g       day  consumers    5.700000    3.705306    7.694694
# 1         g       day     capita   29.920000   19.449607   40.390393
# 2         g       day     capita   12.383562    2.667967    6.372033
# 3         g       day     capita   30.360000   19.735631   40.984369
# 4         g       day     capita  100.110000   65.076877  135.143123
# 5         g       day     capita  216.680000  127.897166  305.462834
# 6         g       day     capita   37.640000   24.468022   50.811978
# 7         g       day     capita  210.990000  124.538596  297.441404
#
#                           mean_value_source_citation  \
# 0  Centers for Disease Control and Prevention (CD...
# 1                                               GFDx
# 2                             FAO food balance sheet
# 3                                               GFDx
# 4                                               GFDx
# 5                                               GFDx
# 6                                               GFDx
# 7                                               GFDx
#
#                               mean_value_source_link  \
# 0  http://internal-ghdx.healthdata.org/record/nep...
# 1  https://fortificationdata.org/country-fortific...
# 2                                                NaN
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://fortificationdata.org/country-fortific...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
#
#                                    data_choice_notes
# 0  Discarded GFDx FAO-balance sheet estimate from...
# 1  Discarded fortification handbok number (7 g/da...
# 2                                   Only one source.
# 3  Discarded 2010 Laillou survey number for WRA (...
# 4  Between forfication handbook from 1997-2000 nu...
# 5  Discarded 2007 Nuss paper that estimated 221.7...
# 6  Discarded 1999 Hess and Engle-Stone survey num...
# 7  Discarded 2007 total pop Nuss estimate from FA...

# %%
output = output.sort_values(['location_name','vehicle'])

# %%
save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/gday_tier3_04_01_2021.csv'
output.to_csv(save_path, index = False)

# %%
save_path = '/ihme/homes/beatrixh/repos/scratch/gday_tier3_04_01_2021.csv'
output.to_csv(save_path, index = False)
