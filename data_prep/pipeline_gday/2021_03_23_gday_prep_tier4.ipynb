# %%
from db_queries import get_population, get_ids
from db_queries import get_location_metadata as get_locs

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# # Prep g/day for Tier 4 locs

# %% [markdown]
# ## Cameroon, Cote d'Ivoire, DRC, Mozambique, Indonesia

# %%
## load targets
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)

# %%
gday_path =  '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/gday_extraction_sheet_03_29_2021.csv'
gday = pd.read_csv(gday_path)

assert(len(gday[gday.location_name.isna()])==0), "Some rows missing location name"

# %%
output = pd.DataFrame()

# %%
country_vehicle_map.keys()
# Out:
# dict_keys(['India', 'Nigeria', 'Ethiopia', 'Democratic Republic of the Congo', 'Indonesia', 'Bangladesh', 'Pakistan', 'Kenya', 'United Republic of Tanzania', 'South Africa', 'Sudan', 'Uganda', 'Myanmar', 'Ghana', 'Egypt', 'Vietnam', 'Nepal', 'Mozambique', 'Cameroon', 'Angola', "Côte d'Ivoire", 'Madagascar', 'Burkina Faso', 'Niger', 'China', nan])

# %%
# location_names = ['Pakistan','Bangladesh','United Republic of Tanzania','Uganda','South Africa']
# location_names = ['Kenya', 'Burkina Faso', 'Myanmar', 'Vietnam', 'Nepal']

location_names = ["Cameroon","Côte d'Ivoire","Democratic Republic of the Congo","Mozambique","Indonesia"]
vehicles = ['wheat flour','maize flour','oil']

# %%
# these are the vehicles per country we need
target = pd.DataFrame([(loc,v) for loc in location_names for v in country_vehicle_map[loc]],
            columns=['location_name','vehicle']).sort_values(['location_name','vehicle']).set_index(['location_name','vehicle'])

target
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Cameroon, bouillon), (Cameroon, maize flour), (Cameroon, oil), (Cameroon, wheat flour), (Côte d'Ivoire, bouillon), (Côte d'Ivoire, maize flour), (Côte d'Ivoire, oil), (Côte d'Ivoire, wheat flour), (Democratic Republic of the Congo, bouillon), (Democratic Republic of the Congo, maize flour), (Democratic Republic of the Congo, oil), (Democratic Republic of the Congo, wheat flour), (Indonesia, oil), (Indonesia, wheat flour), (Mozambique, maize flour), (Mozambique, oil), (Mozambique, wheat flour)]

# %%
gday.location_id = gday.location_id.fillna(-1).astype(int)

# %%
gday.location_name.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Burkina Faso',
#        "Côte d'Ivoire", 'Cameroon', 'Chad', 'China ',
#        'Democratic Republic of the Congo', 'Egypt', 'Ethiopia', 'Ghana',
#        'India', 'Indonesia', 'Kenya', 'Madagascar', 'Mozambique',
#        'Myanmar', 'Nepal', 'Niger', 'Nigeria', 'Pakistan', 'Philippines',
#        'South Africa', 'Sudan', 'Uganda', 'United Republic of Tanzania',
#        'Viet Nam', 'Yemen', 'Zambia'], dtype=object)

# %%
# estimate CIs, crude

# clean value_mean
gday.loc[gday.value_mean=='na','value_mean'] = np.nan
gday.value_mean = gday.value_mean.astype(float)

# clean 2.5th %ile
gday.loc[gday.value_025_percentile=='na','value_025_percentile'] = np.nan
gday.value_025_percentile = gday.value_025_percentile.astype(float)

# clean 97.5th %ile
gday.loc[gday.value_975_percentile=='na','value_975_percentile'] = np.nan
gday.value_975_percentile = gday.value_975_percentile.astype(float)

# calc scale_over_mean
gday['scale_over_mean'] = (gday.value_975_percentile - gday.value_025_percentile) / gday.value_mean

#foreach vehicle, average scale_over_mean
r = gday[['vehicle','scale_over_mean']].groupby('vehicle').mean().dropna().rename(columns={'scale_over_mean':'r'})

# %%
# these are the vehicles for which we have a scale_over_mean estimate
r
# Out:
#                     r
# vehicle
# bouillon     0.902591
# wheat flour  0.699893

# %%
# for vehicles without a scale_over_mean value, we'll assign the average of the others (row-wise)
r = r.reset_index().append(pd.DataFrame([(i,gday.scale_over_mean.mean()) for i in ['maize flour', 'wheat(not specifically flour)','salt', 'rice']],
            columns = ['vehicle','r']))
r
# Out:
#                          vehicle         r
# 0                       bouillon  0.902591
# 1                    wheat flour  0.699893
# 0                    maize flour  0.819483
# 1  wheat(not specifically flour)  0.819483
# 2                           salt  0.819483
# 3                           rice  0.819483

# %%
# add uncertainty
gday = gday.merge(r, on = 'vehicle', how = 'outer')
gday['lower'] = gday.value_mean - (gday.r * gday.value_mean)/2
gday['upper'] = gday.value_mean + (gday.r * gday.value_mean)/2

# %%
gday[(gday.location_name.isin(location_names)) & (gday.vehicle.isin(vehicles))].groupby(['location_name','vehicle']).mean()
# Out:
#                                               location_id  \
# location_name                    vehicle
# Cameroon                         maize flour          202
#                                  wheat flour          202
# Côte d'Ivoire                    maize flour          205
#                                  wheat flour          205
# Democratic Republic of the Congo maize flour          171
#                                  wheat flour          171
# Indonesia                        wheat flour           11
# Mozambique                       maize flour          184
#                                  wheat flour          184
#
#                                               subnational_location_id  \
# location_name                    vehicle
# Cameroon                         maize flour                      NaN
#                                  wheat flour                      NaN
# Côte d'Ivoire                    maize flour                      NaN
#                                  wheat flour                      NaN
# Democratic Republic of the Congo maize flour                      NaN
#                                  wheat flour                      NaN
# Indonesia                        wheat flour                      NaN
# Mozambique                       maize flour                      NaN
#                                  wheat flour                      NaN
#
#                                               value_mean  \
# location_name                    vehicle
# Cameroon                         maize flour  112.623200
#                                  wheat flour   57.609459
# Côte d'Ivoire                    maize flour   60.940833
#                                  wheat flour   49.052800
# Democratic Republic of the Congo maize flour   51.900000
#                                  wheat flour   24.000000
# Indonesia                        wheat flour   56.570417
# Mozambique                       maize flour  154.645200
#                                  wheat flour   45.149583
#
#                                               value_025_percentile  \
# location_name                    vehicle
# Cameroon                         maize flour                   NaN
#                                  wheat flour             57.369231
# Côte d'Ivoire                    maize flour                   NaN
#                                  wheat flour                   NaN
# Democratic Republic of the Congo maize flour                   NaN
#                                  wheat flour                   NaN
# Indonesia                        wheat flour                   NaN
# Mozambique                       maize flour                   NaN
#                                  wheat flour                   NaN
#
#                                               value_975_percentile  \
# location_name                    vehicle
# Cameroon                         maize flour                   NaN
#                                  wheat flour            120.846154
# Côte d'Ivoire                    maize flour                   NaN
#                                  wheat flour                   NaN
# Democratic Republic of the Congo maize flour                   NaN
#                                  wheat flour                   NaN
# Indonesia                        wheat flour                   NaN
# Mozambique                       maize flour                   NaN
#                                  wheat flour                   NaN
#
#                                               scale_over_mean         r  \
# location_name                    vehicle
# Cameroon                         maize flour              NaN  0.819483
#                                  wheat flour         0.855478  0.699893
# Côte d'Ivoire                    maize flour              NaN  0.819483
#                                  wheat flour              NaN  0.699893
# Democratic Republic of the Congo maize flour              NaN  0.819483
#                                  wheat flour              NaN  0.699893
# Indonesia                        wheat flour              NaN  0.699893
# Mozambique                       maize flour              NaN  0.819483
#                                  wheat flour              NaN  0.699893
#
#                                                   lower       upper
# location_name                    vehicle
# Cameroon                         maize flour  66.476777  158.769623
#                                  wheat flour  37.449243   77.769676
# Côte d'Ivoire                    maize flour  35.970832   85.910835
#                                  wheat flour  31.886954   66.218646
# Democratic Republic of the Congo maize flour  30.634405   73.165595
#                                  wheat flour  15.601289   32.398711
# Indonesia                        wheat flour  36.773809   76.367024
# Mozambique                       maize flour  91.280611  218.009789
#                                  wheat flour  29.349654   60.949513

# %%
## dicts for var cleaning

value_d_to_metric = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'median',
 'Mean per capita consumption (g/day)': 'mean',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'mean',
 'Mean micronutrient intake per capita (mg/day)': 'mean',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'mean'
}

value_d_to_entity = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean per capita consumption (g/day)': 'CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean micronutrient intake per capita (mg/day)': 'nutrient',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'CHECK'
}

value_d_to_mass_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean per capita consumption (g/day)': 'g',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean micronutrient intake per capita (mg/day)': 'mg',
 'Daily per capita consumption (g)': 'g',
 'Daily consumption (mg/d)': 'mg',
 'Consumption per person per day (g)': 'g',
 'Estimated daily contribution from fortified foods (mg/d)': 'mg',
 'kg/capita/year': 'kg',
 'Mean per capita consumption among consumers (g/day)':'g'
}

value_d_to_time_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean per capita consumption (g/day)': 'day',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean micronutrient intake per capita (mg/day)': 'day',
 'Daily per capita consumption (g)': 'day',
 'Daily consumption (mg/d)': 'day',
 'Consumption per person per day (g)': 'day',
 'Estimated daily contribution from fortified foods (mg/d)': 'day',
 'kg/capita/year': 'year',
 'Mean per capita consumption among consumers (g/day)':'day'
}

value_d_to_population = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean per capita consumption (g/day)': 'capita CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean micronutrient intake per capita (mg/day)': 'capita CHECK',
 'Daily per capita consumption (g)': 'capita CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'consumers'
}

# %%
def format_value_d(df):
    df['metric'] = df.value_description.map(value_d_to_metric)
    df['entity'] = df.value_description.map(value_d_to_entity)
    df['mass_unit'] = df.value_description.map(value_d_to_mass_unit)
    df['time_unit'] = df.value_description.map(value_d_to_time_unit)
    df['pop_denom'] = df.value_description.map(value_d_to_population)
    
    return df

# %%
location_names
# Out:
# ['Cameroon',
#  "Côte d'Ivoire",
#  'Democratic Republic of the Congo',
#  'Mozambique',
#  'Indonesia']

# %%
viewcols = ['location_name','subnational_name', 'metric', 'entity',
            'mass_unit', 'time_unit', 'pop_denom','vehicle',
            'value_mean','value_025_percentile','value_975_percentile',
            'sub_population','urbanicity',
            'source_citation', 'source_link', 'source_year', 'source_type']

# %%
qcols = ['value_mean','source_citation','source_year','sub_population','source_type']

# %% [markdown]
# ## Cameroon

# %%
cameroon = gday[gday.location_name=="Cameroon"]
cameroon = format_value_d(cameroon)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cameroon.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)',
#        'bouillon'], dtype=object)

# %%
cameroon_wheat = cameroon[(cameroon.vehicle=="wheat flour")]
cameroon_maize = cameroon[(cameroon.vehicle=="maize flour")]

# %%
cameroon_wheat[['value_mean','source_citation','source_year','sub_population']]
# Out:
#      value_mean                                    source_citation  \
# 27        79.00  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 28        90.00  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 29        60.00  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 30        96.00  Engle-Stone R, Nankap M, Ndjebayi AO, Allen LH...
# 31        77.00  Engle-Stone R, Nankap M, Ndjebayi AO, Allen LH...
# 32        90.20  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 33        77.00  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 34        88.90  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 35       104.90  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 36        64.50  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 37        54.80  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 38        49.20  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 39        83.70  Engle-Stone R, Ndjebayi AO, Nankap M, Brown KH...
# 40        27.00  Fortification Handbook: Vitamin and Mineral Fo...
# 41        63.89                                               GFDx
# 384       21.00                                               GFDx
# 385       22.00                                               GFDx
# 386       38.00                                               GFDx
# 387       29.00                                               GFDx
# 388       42.00                                               GFDx
# 389       37.00                                               GFDx
# 390       49.00                                               GFDx
# 391       49.00                                               GFDx
# 392       44.00                                               GFDx
# 393       43.00                                               GFDx
# 394       45.00                                               GFDx
# 395       46.00                                               GFDx
# 396       45.00                                               GFDx
# 397       47.00                                               GFDx
# 398       49.00                                               GFDx
# 399       51.00                                               GFDx
# 400       56.00                                               GFDx
# 401       58.00                                               GFDx
# 402       62.00                                               GFDx
# 403       62.08                                               GFDx
# 404       65.26                                               GFDx
# 405       65.12                                               GFDx
#
#     source_year             sub_population
# 27         2011  women of reproductive age
# 28         2011  women of reproductive age
# 29         2011  women of reproductive age
# 30         2009  women of reproductive age
# 31         2009               12-59 months
# 32         2009  women of reproductive age
# 33         2009  women of reproductive age
# 34         2009  women of reproductive age
# 35         2009  women of reproductive age
# 36         2009               12-59 months
# 37         2009               12-59 months
# 38         2009               12-59 months
# 39         2009               12-59 months
# 40    1997-2000           total population
# 41         2017           total population
# 384        1995           total population
# 385        1996           total population
# 386        1997           total population
# 387        1998           total population
# 388        1999           total population
# 389        2000           total population
# 390        2001           total population
# 391        2002           total population
# 392        2003           total population
# 393        2004           total population
# 394        2005           total population
# 395        2006           total population
# 396        2007           total population
# 397        2008           total population
# 398        2009           total population
# 399        2010           total population
# 400        2011           total population
# 401        2012           total population
# 402        2013           total population
# 403        2014           total population
# 404        2015           total population
# 405        2016           total population

# %%
cameroon_wheat.loc[(cameroon_wheat.source_link=="https://journals.sagepub.com/doi/pdf/10.1177/156482651303400104") & (cameroon_wheat.urbanicity=="mixed/both") & (cameroon_wheat.sub_population=="women of reproductive age"),'data_choice_notes'] = "Took most recent survey data (Hess, 2011) among WRA (79 g/day/consumer). Discarded GFDx FAO-based estimates (64 g/day/capita) and 2009 Engle-Stone survey estimate (77-104 g/day)"

output = output.append(
    cameroon_wheat.loc[(cameroon_wheat.source_link=="https://journals.sagepub.com/doi/pdf/10.1177/156482651303400104") & (cameroon_wheat.urbanicity=="mixed/both") & (cameroon_wheat.sub_population=="women of reproductive age")]
)

cameroon_wheat.loc[(cameroon_wheat.source_link=="https://journals.sagepub.com/doi/pdf/10.1177/156482651303400104") & (cameroon_wheat.urbanicity=="mixed/both") & (cameroon_wheat.sub_population=="women of reproductive age")]
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v107/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v107/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#     location_id location_name subnational_name  subnational_location_id  \
# 27          202      Cameroon               na                      NaN
#
#     urbanicity      vehicle nutrient  \
# 27  mixed/both  wheat flour       na
#
#                                     value_description  value_mean  \
# 27  Median amount of vehicle consumed on previous ...        79.0
#
#     value_025_percentile  ...  scale_over_mean         r      lower  \
# 27                  11.0  ...         2.772152  0.699893  51.354243
#
#          upper  metric   entity mass_unit time_unit  pop_denom  \
# 27  106.645757  median  vehicle         g       day  consumers
#
#                                     data_choice_notes
# 27  Took most recent survey data (Hess, 2011) amon...
#
# [1 rows x 32 columns]

# %%
cameroon_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 617       96.00  Fortification Handbook: Vitamin and Mineral Fo...
# 618      139.34                                               GFDx
# 619      121.90  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 807      105.00                                               GFDx
# 808      110.00                                               GFDx
# 809      106.00                                               GFDx
# 810      107.00                                               GFDx
# 811      135.00                                               GFDx
# 812      118.00                                               GFDx
# 813       97.00                                               GFDx
# 814       86.00                                               GFDx
# 815       96.00                                               GFDx
# 816       97.00                                               GFDx
# 817       97.00                                               GFDx
# 818      105.00                                               GFDx
# 819      105.00                                               GFDx
# 820      113.00                                               GFDx
# 821      112.00                                               GFDx
# 822      114.00                                               GFDx
# 823      114.00                                               GFDx
# 824      115.00                                               GFDx
# 825      115.00                                               GFDx
# 826      134.96                                               GFDx
# 827      135.34                                               GFDx
# 828      141.04                                               GFDx
#
#     source_year    sub_population                        source_type
# 617   1997-2000  total population  estimated from FAO balance sheets
# 618        2017  total population  estimated from FAO balance sheets
# 619        2007  total population  estimated from FAO balance sheets
# 807        1995  total population  estimated from FAO balance sheets
# 808        1996  total population  estimated from FAO balance sheets
# 809        1997  total population  estimated from FAO balance sheets
# 810        1998  total population  estimated from FAO balance sheets
# 811        1999  total population  estimated from FAO balance sheets
# 812        2000  total population  estimated from FAO balance sheets
# 813        2001  total population  estimated from FAO balance sheets
# 814        2002  total population  estimated from FAO balance sheets
# 815        2003  total population  estimated from FAO balance sheets
# 816        2004  total population  estimated from FAO balance sheets
# 817        2005  total population  estimated from FAO balance sheets
# 818        2006  total population  estimated from FAO balance sheets
# 819        2007  total population  estimated from FAO balance sheets
# 820        2008  total population  estimated from FAO balance sheets
# 821        2009  total population  estimated from FAO balance sheets
# 822        2010  total population  estimated from FAO balance sheets
# 823        2011  total population  estimated from FAO balance sheets
# 824        2012  total population  estimated from FAO balance sheets
# 825        2013  total population  estimated from FAO balance sheets
# 826        2014  total population  estimated from FAO balance sheets
# 827        2015  total population  estimated from FAO balance sheets
# 828        2016  total population  estimated from FAO balance sheets

# %%
cameroon_maize.loc[(cameroon_maize.source_year=="2017"),"data_choice_notes"] = "Kept 2017 GFDx number (139 g/day), discarded 2007 Nuss FAO balance estimate (122 g/day) and 1997-2000 FAO balance estimate (96 g/day)"

output = output.append(
    cameroon_maize.loc[(cameroon_maize.source_year=="2017")]
)

cameroon_maize.loc[(cameroon_maize.source_year=="2017")]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 618          202      Cameroon               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 618  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 618      139.34                   NaN  ...              NaN  0.819483
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 618  82.24659  196.43341   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 618  Kept 2017 GFDx number (139 g/day), discarded 2...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Côte d'Ivoire

# %%
civoire = gday[gday.location_name=="Côte d'Ivoire"]
civoire = format_value_d(civoire)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
civoire.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)',
#        'bouillon'], dtype=object)

# %%
civoire_wheat = civoire[(civoire.vehicle=="wheat flour")]
civoire_maize = civoire[(civoire.vehicle=="maize flour")]

# %%
civoire_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 24        33.00  Fortification Handbook: Vitamin and Mineral Fo...
# 25        70.08                                               GFDx
# 26        33.70  Sablah M, Klopp J, Steinberg D, Touaoro Z, Lai...
# 406       44.00                                               GFDx
# 407       43.00                                               GFDx
# 408       39.00                                               GFDx
# 409       50.00                                               GFDx
# 410       49.00                                               GFDx
# 411       46.00                                               GFDx
# 412       47.00                                               GFDx
# 413       48.00                                               GFDx
# 414       48.00                                               GFDx
# 415       45.00                                               GFDx
# 416       46.00                                               GFDx
# 417       48.00                                               GFDx
# 418       48.00                                               GFDx
# 419       40.00                                               GFDx
# 420       50.00                                               GFDx
# 421       52.00                                               GFDx
# 422       55.00                                               GFDx
# 423       58.00                                               GFDx
# 424       57.00                                               GFDx
# 425       55.34                                               GFDx
# 426       56.30                                               GFDx
# 427       64.90                                               GFDx
#
#     source_year    sub_population                        source_type
# 24    1997-2000  total population  estimated from FAO balance sheets
# 25         2017  total population  estimated from FAO balance sheets
# 26         2002  total population           Survey - cross-sectional
# 406        1995  total population  estimated from FAO balance sheets
# 407        1996  total population  estimated from FAO balance sheets
# 408        1997  total population  estimated from FAO balance sheets
# 409        1998  total population  estimated from FAO balance sheets
# 410        1999  total population  estimated from FAO balance sheets
# 411        2000  total population  estimated from FAO balance sheets
# 412        2001  total population  estimated from FAO balance sheets
# 413        2002  total population  estimated from FAO balance sheets
# 414        2003  total population  estimated from FAO balance sheets
# 415        2004  total population  estimated from FAO balance sheets
# 416        2005  total population  estimated from FAO balance sheets
# 417        2006  total population  estimated from FAO balance sheets
# 418        2007  total population  estimated from FAO balance sheets
# 419        2008  total population  estimated from FAO balance sheets
# 420        2009  total population  estimated from FAO balance sheets
# 421        2010  total population  estimated from FAO balance sheets
# 422        2011  total population  estimated from FAO balance sheets
# 423        2012  total population  estimated from FAO balance sheets
# 424        2013  total population  estimated from FAO balance sheets
# 425        2014  total population  estimated from FAO balance sheets
# 426        2015  total population  estimated from FAO balance sheets
# 427        2016  total population  estimated from FAO balance sheets

# %%
civoire_wheat.loc[(civoire_wheat.source_year=="2017"),"data_choice_notes"] = "Kept 2017 GFDx number (70 g/day), discarded Sablah 2002 survey number (33.7 g/day, noting that GFDx estimated 48 g/day for 2002), and discarded and 1997-2000 Forfitifation handbook FAO balance sheet number (33 g/day)"

output = output.append(
    civoire_wheat.loc[(civoire_wheat.source_year=="2017")]
)

civoire_wheat.loc[(civoire_wheat.source_year=="2017")]
# Out:
#     location_id  location_name subnational_name  subnational_location_id  \
# 25          205  Côte d'Ivoire               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 25  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 25       70.08                   NaN  ...              NaN  0.699893
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 25  45.555764  94.604236   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 25  Kept 2017 GFDx number (70 g/day), discarded Sa...
#
# [1 rows x 32 columns]

# %%
civoire_maize[qcols]
# Out:
#      value_mean                                    source_citation  \
# 615       56.05                                               GFDx
# 616       43.90  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 829       76.00                                               GFDx
# 830       75.00                                               GFDx
# 831       72.00                                               GFDx
# 832       72.00                                               GFDx
# 833       65.00                                               GFDx
# 834       63.00                                               GFDx
# 835       64.00                                               GFDx
# 836       61.00                                               GFDx
# 837       59.00                                               GFDx
# 838       59.00                                               GFDx
# 839       64.00                                               GFDx
# 840       61.00                                               GFDx
# 841       49.00                                               GFDx
# 842       62.00                                               GFDx
# 843       60.00                                               GFDx
# 844       61.00                                               GFDx
# 845       60.00                                               GFDx
# 846       61.00                                               GFDx
# 847       60.00                                               GFDx
# 848       55.51                                               GFDx
# 849       51.97                                               GFDx
# 850       51.15                                               GFDx
#
#     source_year    sub_population                        source_type
# 615        2017  total population  estimated from FAO balance sheets
# 616        2007  total population  estimated from FAO balance sheets
# 829        1995  total population  estimated from FAO balance sheets
# 830        1996  total population  estimated from FAO balance sheets
# 831        1997  total population  estimated from FAO balance sheets
# 832        1998  total population  estimated from FAO balance sheets
# 833        1999  total population  estimated from FAO balance sheets
# 834        2000  total population  estimated from FAO balance sheets
# 835        2001  total population  estimated from FAO balance sheets
# 836        2002  total population  estimated from FAO balance sheets
# 837        2003  total population  estimated from FAO balance sheets
# 838        2004  total population  estimated from FAO balance sheets
# 839        2005  total population  estimated from FAO balance sheets
# 840        2006  total population  estimated from FAO balance sheets
# 841        2007  total population  estimated from FAO balance sheets
# 842        2008  total population  estimated from FAO balance sheets
# 843        2009  total population  estimated from FAO balance sheets
# 844        2010  total population  estimated from FAO balance sheets
# 845        2011  total population  estimated from FAO balance sheets
# 846        2012  total population  estimated from FAO balance sheets
# 847        2013  total population  estimated from FAO balance sheets
# 848        2014  total population  estimated from FAO balance sheets
# 849        2015  total population  estimated from FAO balance sheets
# 850        2016  total population  estimated from FAO balance sheets

# %%
civoire_maize.loc[(civoire_maize.source_link=="https://doi.org/10.3945/an.110.000182"),"data_choice_notes"] = "Discarded 2007 Nuss FAO balance sheet estimate (44 g/day) for 2017 GFDx FAO balance sheet estimate (56 g/day)"

output = output.append(
    civoire_maize.loc[(civoire_maize.source_link=="https://doi.org/10.3945/an.110.000182")]
)

civoire_maize.loc[(civoire_maize.source_link=="https://doi.org/10.3945/an.110.000182")]
# Out:
#      location_id  location_name subnational_name  subnational_location_id  \
# 616          205  Côte d'Ivoire              NaN                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 616        NaN  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 616        43.9                   NaN  ...              NaN  0.819483
#
#          lower      upper metric entity mass_unit time_unit     pop_denom  \
# 616  25.912339  61.887661   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 616  Discarded 2007 Nuss FAO balance sheet estimate...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Democratic Republic of the Congo

# %%
drc = gday[gday.location_name=="Democratic Republic of the Congo"]
drc = format_value_d(drc)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
drc.vehicle.unique()
# Out:
# array([nan, 'wheat flour', 'maize flour'], dtype=object)

# %%
drc_wheat = drc[drc.vehicle=="wheat flour"]
drc_maize = drc[drc.vehicle=="maize flour"]

# %%
drc_wheat[qcols + ['value_description']]
# Out:
#     value_mean                                    source_citation source_year  \
# 48        14.0  Fortification Handbook: Vitamin and Mineral Fo...   1997-2000
# 49        34.0                                               GFDx        2000
#
#       sub_population                        source_type  \
# 48  total population  estimated from FAO balance sheets
# 49  total population  estimated from FAO balance sheets
#
#                       value_description
# 48  Mean per capita consumption (g/day)
# 49  Mean per capita consumption (g/day)

# %%
drc_wheat.loc[(drc_wheat.source_year=="2000"),"data_choice_notes"] = "Kept 2000 GFDx number (34 g/day), discarded 1997-2000 fortification handbook number (14 g/day), both from FAO"

output = output.append(
    drc_wheat.loc[(drc_wheat.source_year=="2000")]
)

drc_wheat.loc[(drc_wheat.source_year=="2000")]
# Out:
#     location_id                     location_name subnational_name  \
# 49          171  Democratic Republic of the Congo               na
#
#     subnational_location_id  urbanicity      vehicle nutrient  \
# 49                      NaN  mixed/both  wheat flour       na
#
#                       value_description  value_mean  value_025_percentile  \
# 49  Mean per capita consumption (g/day)        34.0                   NaN
#
#     ...  scale_over_mean         r      lower      upper metric entity  \
# 49  ...              NaN  0.699893  22.101826  45.898174   mean  CHECK
#
#    mass_unit time_unit     pop_denom  \
# 49         g       day  capita CHECK
#
#                                     data_choice_notes
# 49  Kept 2000 GFDx number (34 g/day), discarded 19...
#
# [1 rows x 32 columns]

# %%
drc_maize[qcols + ['value_description']]
# Out:
#      value_mean                                    source_citation  \
# 621        43.0  Fortification Handbook: Vitamin and Mineral Fo...
# 622        60.8  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#     source_year    sub_population                        source_type  \
# 621   1997-2000  total population  estimated from FAO balance sheets
# 622        2007  total population  estimated from FAO balance sheets
#
#                        value_description
# 621  Mean per capita consumption (g/day)
# 622  Mean per capita consumption (g/day)

# %%
drc_maize.loc[(drc_maize.source_year=="2007"),"data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (43 g/day) estimated from FAO balance sheets in lieu of 2007 Nuss number (60.8 g/day), also from FAO balance sheets"

output = output.append(
    drc_maize.loc[(drc_maize.source_year=="2007")]
)

drc_maize.loc[(drc_maize.source_year=="2007")]
# Out:
#      location_id                     location_name subnational_name  \
# 622          171  Democratic Republic of the Congo               na
#
#      subnational_location_id  urbanicity      vehicle nutrient  \
# 622                      NaN  mixed/both  maize flour       na
#
#                        value_description  value_mean  value_025_percentile  \
# 622  Mean per capita consumption (g/day)        60.8                   NaN
#
#      ...  scale_over_mean         r      lower      upper metric entity  \
# 622  ...              NaN  0.819483  35.887704  85.712296   mean  CHECK
#
#     mass_unit time_unit     pop_denom  \
# 622         g       day  capita CHECK
#
#                                      data_choice_notes
# 622  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Mozambique

# %%
moz = gday[gday.location_name=="Mozambique"]
moz = format_value_d(moz)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
moz.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)'],
#       dtype=object)

# %%
moz_wheat = moz[(moz.vehicle=="wheat flour")]
moz_maize = moz[(moz.vehicle=="maize flour")]

# %%
moz_wheat[qcols]
# Out:
#      value_mean                                    source_citation  \
# 65        28.00  Fortification Handbook: Vitamin and Mineral Fo...
# 66        65.92                                               GFDx
# 428       41.00                                               GFDx
# 429       39.00                                               GFDx
# 430       32.00                                               GFDx
# 431       36.00                                               GFDx
# 432       31.00                                               GFDx
# 433       37.00                                               GFDx
# 434       36.00                                               GFDx
# 435       42.00                                               GFDx
# 436       44.00                                               GFDx
# 437       54.00                                               GFDx
# 438       59.00                                               GFDx
# 439       59.00                                               GFDx
# 440       54.00                                               GFDx
# 441       56.00                                               GFDx
# 442       54.00                                               GFDx
# 443       52.00                                               GFDx
# 444       51.00                                               GFDx
# 445       49.00                                               GFDx
# 446       40.00                                               GFDx
# 447       35.86                                               GFDx
# 448       37.32                                               GFDx
# 449       50.49                                               GFDx
#
#     source_year    sub_population                        source_type
# 65    1997-2000  total population  estimated from FAO balance sheets
# 66         2017  total population  estimated from FAO balance sheets
# 428        1995  total population  estimated from FAO balance sheets
# 429        1996  total population  estimated from FAO balance sheets
# 430        1997  total population  estimated from FAO balance sheets
# 431        1998  total population  estimated from FAO balance sheets
# 432        1999  total population  estimated from FAO balance sheets
# 433        2000  total population  estimated from FAO balance sheets
# 434        2001  total population  estimated from FAO balance sheets
# 435        2002  total population  estimated from FAO balance sheets
# 436        2003  total population  estimated from FAO balance sheets
# 437        2004  total population  estimated from FAO balance sheets
# 438        2005  total population  estimated from FAO balance sheets
# 439        2006  total population  estimated from FAO balance sheets
# 440        2007  total population  estimated from FAO balance sheets
# 441        2008  total population  estimated from FAO balance sheets
# 442        2009  total population  estimated from FAO balance sheets
# 443        2010  total population  estimated from FAO balance sheets
# 444        2011  total population  estimated from FAO balance sheets
# 445        2012  total population  estimated from FAO balance sheets
# 446        2013  total population  estimated from FAO balance sheets
# 447        2014  total population  estimated from FAO balance sheets
# 448        2015  total population  estimated from FAO balance sheets
# 449        2016  total population  estimated from FAO balance sheets

# %%
moz_wheat.loc[(moz_wheat.source_year=="2017"),"data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (28 g/day) for 2017 GFDx number (66 g/day), both from FAO balance sheets"

output = output.append(
    moz_wheat.loc[(moz_wheat.source_year=="2017")]
)

moz_wheat.loc[(moz_wheat.source_year=="2017")]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 66          184    Mozambique               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 66  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 66       65.92                   NaN  ...              NaN  0.699893
#
#        lower     upper metric entity mass_unit time_unit     pop_denom  \
# 66  42.85154  88.98846   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 66  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %%
moz_maize[qcols]
# Out:
#      value_mean                                    source_citation  \
# 633      108.00  Fortification Handbook: Vitamin and Mineral Fo...
# 634      180.60                                               GFDx
# 635      140.00  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 851      132.00                                               GFDx
# 852      147.00                                               GFDx
# 853      154.00                                               GFDx
# 854      151.00                                               GFDx
# 855      170.00                                               GFDx
# 856      173.00                                               GFDx
# 857      166.00                                               GFDx
# 858      165.00                                               GFDx
# 859      157.00                                               GFDx
# 860      146.00                                               GFDx
# 861      145.00                                               GFDx
# 862      152.00                                               GFDx
# 863      148.00                                               GFDx
# 864      148.00                                               GFDx
# 865      146.00                                               GFDx
# 866      164.00                                               GFDx
# 867      159.00                                               GFDx
# 868      150.00                                               GFDx
# 869      149.00                                               GFDx
# 870      165.42                                               GFDx
# 871      173.95                                               GFDx
# 872      176.16                                               GFDx
#
#     source_year    sub_population                        source_type
# 633   1997-2000  total population  estimated from FAO balance sheets
# 634        2017  total population  estimated from FAO balance sheets
# 635        2007  total population  estimated from FAO balance sheets
# 851        1995  total population  estimated from FAO balance sheets
# 852        1996  total population  estimated from FAO balance sheets
# 853        1997  total population  estimated from FAO balance sheets
# 854        1998  total population  estimated from FAO balance sheets
# 855        1999  total population  estimated from FAO balance sheets
# 856        2000  total population  estimated from FAO balance sheets
# 857        2001  total population  estimated from FAO balance sheets
# 858        2002  total population  estimated from FAO balance sheets
# 859        2003  total population  estimated from FAO balance sheets
# 860        2004  total population  estimated from FAO balance sheets
# 861        2005  total population  estimated from FAO balance sheets
# 862        2006  total population  estimated from FAO balance sheets
# 863        2007  total population  estimated from FAO balance sheets
# 864        2008  total population  estimated from FAO balance sheets
# 865        2009  total population  estimated from FAO balance sheets
# 866        2010  total population  estimated from FAO balance sheets
# 867        2011  total population  estimated from FAO balance sheets
# 868        2012  total population  estimated from FAO balance sheets
# 869        2013  total population  estimated from FAO balance sheets
# 870        2014  total population  estimated from FAO balance sheets
# 871        2015  total population  estimated from FAO balance sheets
# 872        2016  total population  estimated from FAO balance sheets

# %%
moz_maize.loc[(moz_maize.source_year=="2017"),"data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (108 g/day), along with 2007 Nuss number (140 g/day), in lieu of 2017 GFDx number (180 g/day). All came from FAO balance sheets."

output = output.append(
    moz_maize.loc[(moz_maize.source_year=="2017")]
)

moz_maize.loc[(moz_maize.source_year=="2017")]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 634          184    Mozambique               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 634  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 634       180.6                   NaN  ...              NaN  0.819483
#
#           lower       upper metric entity mass_unit time_unit     pop_denom  \
# 634  106.600647  254.599353   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 634  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Indonesia

# %%
indonesia = gday[gday.location_name=="Indonesia"]
indonesia = format_value_d(indonesia)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
indonesia.vehicle.unique()
# Out:
# array(['wheat flour'], dtype=object)

# %%
indonesia[qcols]
# Out:
#      value_mean                                    source_citation  \
# 59        35.00  Fortification Handbook: Vitamin and Mineral Fo...
# 60        73.59                                               GFDx
# 296       56.00                                               GFDx
# 297       53.00                                               GFDx
# 298       46.00                                               GFDx
# 299       44.00                                               GFDx
# 300       39.00                                               GFDx
# 301       44.00                                               GFDx
# 302       43.00                                               GFDx
# 303       52.00                                               GFDx
# 304       49.00                                               GFDx
# 305       56.00                                               GFDx
# 306       55.00                                               GFDx
# 307       58.00                                               GFDx
# 308       59.00                                               GFDx
# 309       56.00                                               GFDx
# 310       59.00                                               GFDx
# 311       61.00                                               GFDx
# 312       64.00                                               GFDx
# 313       70.00                                               GFDx
# 314       70.00                                               GFDx
# 315       69.95                                               GFDx
# 316       69.18                                               GFDx
# 317       75.97                                               GFDx
#
#     source_year    sub_population                        source_type
# 59    1997-2000  total population  estimated from FAO balance sheets
# 60         2017  total population  estimated from FAO balance sheets
# 296        1995  total population  estimated from FAO balance sheets
# 297        1996  total population  estimated from FAO balance sheets
# 298        1997  total population  estimated from FAO balance sheets
# 299        1998  total population  estimated from FAO balance sheets
# 300        1999  total population  estimated from FAO balance sheets
# 301        2000  total population  estimated from FAO balance sheets
# 302        2001  total population  estimated from FAO balance sheets
# 303        2002  total population  estimated from FAO balance sheets
# 304        2003  total population  estimated from FAO balance sheets
# 305        2004  total population  estimated from FAO balance sheets
# 306        2005  total population  estimated from FAO balance sheets
# 307        2006  total population  estimated from FAO balance sheets
# 308        2007  total population  estimated from FAO balance sheets
# 309        2008  total population  estimated from FAO balance sheets
# 310        2009  total population  estimated from FAO balance sheets
# 311        2010  total population  estimated from FAO balance sheets
# 312        2011  total population  estimated from FAO balance sheets
# 313        2012  total population  estimated from FAO balance sheets
# 314        2013  total population  estimated from FAO balance sheets
# 315        2014  total population  estimated from FAO balance sheets
# 316        2015  total population  estimated from FAO balance sheets
# 317        2016  total population  estimated from FAO balance sheets

# %%
indonesia.loc[(indonesia.source_year=="2017"),"data_choice_notes"] = "discarded 1997-2000 fortification handbook number (35 g/day) for 2017 GFDx number (73 g/day). Both came from FAO balance sheets."

output = output.append(
    indonesia.loc[(indonesia.source_year=="2017")]
)

indonesia.loc[(indonesia.source_year=="2017")]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 60           11     Indonesia               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 60    unknown  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 60       73.59                   NaN  ...              NaN  0.699893
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 60  47.837452  99.342548   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 60  discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %% [markdown]
# # Format output

# %%
group_cols = ['location_id','location_name','sub_population','vehicle','metric','mass_unit','time_unit','pop_denom','source_citation','source_link','data_choice_notes']

# %%
loc_metadata = get_locs(location_set_id=35, gbd_round_id=6, decomp_step="step4")

# %%
output = output.drop(columns = 'location_id')
output = loc_metadata[['location_id','location_name']].merge(output, on = 'location_name', how = 'right')

# %%
output[['location_id','location_name','vehicle','value_mean','definition validated', 'CI validated']]
# Out:
#    location_id                     location_name      vehicle  value_mean  \
# 0           11                         Indonesia  wheat flour       73.59
# 1          171  Democratic Republic of the Congo  wheat flour       34.00
# 2          171  Democratic Republic of the Congo  maize flour       60.80
# 3          184                        Mozambique  wheat flour       65.92
# 4          184                        Mozambique  maize flour      180.60
# 5          202                          Cameroon  wheat flour       79.00
# 6          202                          Cameroon  maize flour      139.34
# 7          205                     Côte d'Ivoire  wheat flour       70.08
# 8          205                     Côte d'Ivoire  maize flour       43.90
#
#   definition validated CI validated
# 0                  Yes          NaN
# 1                  Yes          NaN
# 2                  Yes          NaN
# 3                  Yes          NaN
# 4                  Yes          NaN
# 5                  Yes          Yes
# 6                  Yes          NaN
# 7                  Yes          NaN
# 8                  Yes          NaN

# %%
metric_map = {
    'mean':'mean',
    'CHECK':'mean'
}

pop_denom_map = {
    'capita':'capita',
    'CHECK':'capita',
    'capita CHECK':'capita',
    'consumers':'consumers'
}

output.metric = output.metric.map(metric_map)
output.pop_denom = output.pop_denom.map(pop_denom_map)

# %%
output[['value_mean'] + group_cols]
# Out:
#    value_mean  location_id                     location_name  \
# 0       73.59           11                         Indonesia
# 1       34.00          171  Democratic Republic of the Congo
# 2       60.80          171  Democratic Republic of the Congo
# 3       65.92          184                        Mozambique
# 4      180.60          184                        Mozambique
# 5       79.00          202                          Cameroon
# 6      139.34          202                          Cameroon
# 7       70.08          205                     Côte d'Ivoire
# 8       43.90          205                     Côte d'Ivoire
#
#               sub_population      vehicle metric mass_unit time_unit  \
# 0           total population  wheat flour   mean         g       day
# 1           total population  wheat flour   mean         g       day
# 2           total population  maize flour   mean         g       day
# 3           total population  wheat flour   mean         g       day
# 4           total population  maize flour   mean         g       day
# 5  women of reproductive age  wheat flour    NaN         g       day
# 6           total population  maize flour   mean         g       day
# 7           total population  wheat flour   mean         g       day
# 8           total population  maize flour   mean         g       day
#
#    pop_denom                                    source_citation  \
# 0     capita                                               GFDx
# 1     capita                                               GFDx
# 2     capita  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 3     capita                                               GFDx
# 4     capita                                               GFDx
# 5  consumers  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 6     capita                                               GFDx
# 7     capita                                               GFDx
# 8     capita  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#                                          source_link  \
# 0  https://fortificationdata.org/country-fortific...
# 1  https://fortificationdata.org/country-fortific...
# 2              https://doi.org/10.3945/an.110.000182
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://journals.sagepub.com/doi/pdf/10.1177/1...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
# 8              https://doi.org/10.3945/an.110.000182
#
#                                    data_choice_notes
# 0  discarded 1997-2000 fortification handbook num...
# 1  Kept 2000 GFDx number (34 g/day), discarded 19...
# 2  Discarded 1997-2000 fortification handbook num...
# 3  Discarded 1997-2000 fortification handbook num...
# 4  Discarded 1997-2000 fortification handbook num...
# 5  Took most recent survey data (Hess, 2011) amon...
# 6  Kept 2017 GFDx number (139 g/day), discarded 2...
# 7  Kept 2017 GFDx number (70 g/day), discarded Sa...
# 8  Discarded 2007 Nuss FAO balance sheet estimate...

# %%
output.loc[(output.mass_unit=="kg"),'value_mean'] = output.value_mean * 1_000

output.loc[(output.mass_unit=="kg"),'lower'] = output.lower * 1_000
output.loc[(output.mass_unit=="kg"),'upper'] = output.upper * 1_000

output.loc[(output.mass_unit=="kg"),'value_025_percentile'] = output.value_025_percentile * 1_000
output.loc[(output.mass_unit=="kg"),'value_975_percentile'] = output.value_975_percentile * 1_000

output.loc[(output.mass_unit=="kg"),'mass_unit'] = 'g'

# %%
output.loc[(output.time_unit=="year"),'value_mean'] = output.value_mean / 365

output.loc[(output.time_unit=="year"),'lower'] = output.lower / 365
output.loc[(output.time_unit=="year"),'upper'] = output.upper / 365

output.loc[(output.time_unit=="year"),'value_025_percentile'] = output.value_025_percentile / 365
output.loc[(output.time_unit=="year"),'value_975_percentile'] = output.value_975_percentile / 365

output.loc[(output.time_unit=="year"),'time_unit'] = 'day'

# %%
output[['value_mean'] + group_cols]
# Out:
#    value_mean  location_id                     location_name  \
# 0       73.59           11                         Indonesia
# 1       34.00          171  Democratic Republic of the Congo
# 2       60.80          171  Democratic Republic of the Congo
# 3       65.92          184                        Mozambique
# 4      180.60          184                        Mozambique
# 5       79.00          202                          Cameroon
# 6      139.34          202                          Cameroon
# 7       70.08          205                     Côte d'Ivoire
# 8       43.90          205                     Côte d'Ivoire
#
#               sub_population      vehicle metric mass_unit time_unit  \
# 0           total population  wheat flour   mean         g       day
# 1           total population  wheat flour   mean         g       day
# 2           total population  maize flour   mean         g       day
# 3           total population  wheat flour   mean         g       day
# 4           total population  maize flour   mean         g       day
# 5  women of reproductive age  wheat flour    NaN         g       day
# 6           total population  maize flour   mean         g       day
# 7           total population  wheat flour   mean         g       day
# 8           total population  maize flour   mean         g       day
#
#    pop_denom                                    source_citation  \
# 0     capita                                               GFDx
# 1     capita                                               GFDx
# 2     capita  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 3     capita                                               GFDx
# 4     capita                                               GFDx
# 5  consumers  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 6     capita                                               GFDx
# 7     capita                                               GFDx
# 8     capita  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#                                          source_link  \
# 0  https://fortificationdata.org/country-fortific...
# 1  https://fortificationdata.org/country-fortific...
# 2              https://doi.org/10.3945/an.110.000182
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://journals.sagepub.com/doi/pdf/10.1177/1...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
# 8              https://doi.org/10.3945/an.110.000182
#
#                                    data_choice_notes
# 0  discarded 1997-2000 fortification handbook num...
# 1  Kept 2000 GFDx number (34 g/day), discarded 19...
# 2  Discarded 1997-2000 fortification handbook num...
# 3  Discarded 1997-2000 fortification handbook num...
# 4  Discarded 1997-2000 fortification handbook num...
# 5  Took most recent survey data (Hess, 2011) amon...
# 6  Kept 2017 GFDx number (139 g/day), discarded 2...
# 7  Kept 2017 GFDx number (70 g/day), discarded Sa...
# 8  Discarded 2007 Nuss FAO balance sheet estimate...

# %%
output[['value_mean','lower','upper'] + group_cols]
# Out:
#    value_mean       lower       upper  location_id  \
# 0       73.59   47.837452   99.342548           11
# 1       34.00   22.101826   45.898174          171
# 2       60.80   35.887704   85.712296          171
# 3       65.92   42.851540   88.988460          184
# 4      180.60  106.600647  254.599353          184
# 5       79.00   51.354243  106.645757          202
# 6      139.34   82.246590  196.433410          202
# 7       70.08   45.555764   94.604236          205
# 8       43.90   25.912339   61.887661          205
#
#                       location_name             sub_population      vehicle  \
# 0                         Indonesia           total population  wheat flour
# 1  Democratic Republic of the Congo           total population  wheat flour
# 2  Democratic Republic of the Congo           total population  maize flour
# 3                        Mozambique           total population  wheat flour
# 4                        Mozambique           total population  maize flour
# 5                          Cameroon  women of reproductive age  wheat flour
# 6                          Cameroon           total population  maize flour
# 7                     Côte d'Ivoire           total population  wheat flour
# 8                     Côte d'Ivoire           total population  maize flour
#
#   metric mass_unit time_unit  pop_denom  \
# 0   mean         g       day     capita
# 1   mean         g       day     capita
# 2   mean         g       day     capita
# 3   mean         g       day     capita
# 4   mean         g       day     capita
# 5    NaN         g       day  consumers
# 6   mean         g       day     capita
# 7   mean         g       day     capita
# 8   mean         g       day     capita
#
#                                      source_citation  \
# 0                                               GFDx
# 1                                               GFDx
# 2  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 3                                               GFDx
# 4                                               GFDx
# 5  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 6                                               GFDx
# 7                                               GFDx
# 8  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#                                          source_link  \
# 0  https://fortificationdata.org/country-fortific...
# 1  https://fortificationdata.org/country-fortific...
# 2              https://doi.org/10.3945/an.110.000182
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://journals.sagepub.com/doi/pdf/10.1177/1...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
# 8              https://doi.org/10.3945/an.110.000182
#
#                                    data_choice_notes
# 0  discarded 1997-2000 fortification handbook num...
# 1  Kept 2000 GFDx number (34 g/day), discarded 19...
# 2  Discarded 1997-2000 fortification handbook num...
# 3  Discarded 1997-2000 fortification handbook num...
# 4  Discarded 1997-2000 fortification handbook num...
# 5  Took most recent survey data (Hess, 2011) amon...
# 6  Kept 2017 GFDx number (139 g/day), discarded 2...
# 7  Kept 2017 GFDx number (70 g/day), discarded Sa...
# 8  Discarded 2007 Nuss FAO balance sheet estimate...

# %%
output = output.rename(columns = {
    'source_citation':'mean_value_source_citation',
    'source_link':'mean_value_source_link'
})

# %%
assert(len(output[output.value_mean >= output.upper])==0), "check upper"
assert(len(output[output.value_mean <= output.lower])==0), "check lower"

# %% [markdown]
# # check for missing values

# %%
output.loc[(output.location_name=="Viet Nam"),'location_name'] = "Vietnam"

# %%
## load legal combos
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_vehicle_country_pairs.pickle', 'rb') as handle:
    vehicle_country_map = pickle.load(handle)

# %%
target_vehicles = [i for i in vehicle_nutrient_map.keys() if 'iron' in vehicle_nutrient_map[i]]
set([i for j in location_names for i in country_vehicle_map[j]])
# Out:
# {'bouillon', 'maize flour', 'oil', 'wheat flour'}

# %%
# make sure nothing missing. note we're not interested in oil/iron
output.reset_index().merge(target.reset_index(), on = ['location_name','vehicle'], how = 'outer')
# Out:
#     index  location_id                     location_name subnational_name  \
# 0     0.0         11.0                         Indonesia               na
# 1     1.0        171.0  Democratic Republic of the Congo               na
# 2     2.0        171.0  Democratic Republic of the Congo               na
# 3     3.0        184.0                        Mozambique               na
# 4     4.0        184.0                        Mozambique               na
# 5     5.0        202.0                          Cameroon               na
# 6     6.0        202.0                          Cameroon               na
# 7     7.0        205.0                     Côte d'Ivoire               na
# 8     8.0        205.0                     Côte d'Ivoire              NaN
# 9     NaN          NaN                          Cameroon              NaN
# 10    NaN          NaN                          Cameroon              NaN
# 11    NaN          NaN                     Côte d'Ivoire              NaN
# 12    NaN          NaN                     Côte d'Ivoire              NaN
# 13    NaN          NaN  Democratic Republic of the Congo              NaN
# 14    NaN          NaN  Democratic Republic of the Congo              NaN
# 15    NaN          NaN                         Indonesia              NaN
# 16    NaN          NaN                        Mozambique              NaN
#
#     subnational_location_id  urbanicity      vehicle nutrient  \
# 0                       NaN     unknown  wheat flour       na
# 1                       NaN  mixed/both  wheat flour       na
# 2                       NaN  mixed/both  maize flour       na
# 3                       NaN  mixed/both  wheat flour       na
# 4                       NaN  mixed/both  maize flour       na
# 5                       NaN  mixed/both  wheat flour       na
# 6                       NaN  mixed/both  maize flour       na
# 7                       NaN  mixed/both  wheat flour       na
# 8                       NaN         NaN  maize flour       na
# 9                       NaN         NaN     bouillon      NaN
# 10                      NaN         NaN          oil      NaN
# 11                      NaN         NaN     bouillon      NaN
# 12                      NaN         NaN          oil      NaN
# 13                      NaN         NaN     bouillon      NaN
# 14                      NaN         NaN          oil      NaN
# 15                      NaN         NaN          oil      NaN
# 16                      NaN         NaN          oil      NaN
#
#                                     value_description  value_mean  ...  \
# 0                 Mean per capita consumption (g/day)       73.59  ...
# 1                 Mean per capita consumption (g/day)       34.00  ...
# 2                 Mean per capita consumption (g/day)       60.80  ...
# 3                 Mean per capita consumption (g/day)       65.92  ...
# 4                 Mean per capita consumption (g/day)      180.60  ...
# 5   Median amount of vehicle consumed on previous ...       79.00  ...
# 6                 Mean per capita consumption (g/day)      139.34  ...
# 7                 Mean per capita consumption (g/day)       70.08  ...
# 8                 Mean per capita consumption (g/day)       43.90  ...
# 9                                                 NaN         NaN  ...
# 10                                                NaN         NaN  ...
# 11                                                NaN         NaN  ...
# 12                                                NaN         NaN  ...
# 13                                                NaN         NaN  ...
# 14                                                NaN         NaN  ...
# 15                                                NaN         NaN  ...
# 16                                                NaN         NaN  ...
#
#     scale_over_mean         r       lower       upper metric   entity  \
# 0               NaN  0.699893   47.837452   99.342548   mean    CHECK
# 1               NaN  0.699893   22.101826   45.898174   mean    CHECK
# 2               NaN  0.819483   35.887704   85.712296   mean    CHECK
# 3               NaN  0.699893   42.851540   88.988460   mean    CHECK
# 4               NaN  0.819483  106.600647  254.599353   mean    CHECK
# 5          2.772152  0.699893   51.354243  106.645757    NaN  vehicle
# 6               NaN  0.819483   82.246590  196.433410   mean    CHECK
# 7               NaN  0.699893   45.555764   94.604236   mean    CHECK
# 8               NaN  0.819483   25.912339   61.887661   mean    CHECK
# 9               NaN       NaN         NaN         NaN    NaN      NaN
# 10              NaN       NaN         NaN         NaN    NaN      NaN
# 11              NaN       NaN         NaN         NaN    NaN      NaN
# 12              NaN       NaN         NaN         NaN    NaN      NaN
# 13              NaN       NaN         NaN         NaN    NaN      NaN
# 14              NaN       NaN         NaN         NaN    NaN      NaN
# 15              NaN       NaN         NaN         NaN    NaN      NaN
# 16              NaN       NaN         NaN         NaN    NaN      NaN
#
#    mass_unit time_unit  pop_denom  \
# 0          g       day     capita
# 1          g       day     capita
# 2          g       day     capita
# 3          g       day     capita
# 4          g       day     capita
# 5          g       day  consumers
# 6          g       day     capita
# 7          g       day     capita
# 8          g       day     capita
# 9        NaN       NaN        NaN
# 10       NaN       NaN        NaN
# 11       NaN       NaN        NaN
# 12       NaN       NaN        NaN
# 13       NaN       NaN        NaN
# 14       NaN       NaN        NaN
# 15       NaN       NaN        NaN
# 16       NaN       NaN        NaN
#
#                                     data_choice_notes
# 0   discarded 1997-2000 fortification handbook num...
# 1   Kept 2000 GFDx number (34 g/day), discarded 19...
# 2   Discarded 1997-2000 fortification handbook num...
# 3   Discarded 1997-2000 fortification handbook num...
# 4   Discarded 1997-2000 fortification handbook num...
# 5   Took most recent survey data (Hess, 2011) amon...
# 6   Kept 2017 GFDx number (139 g/day), discarded 2...
# 7   Kept 2017 GFDx number (70 g/day), discarded Sa...
# 8   Discarded 2007 Nuss FAO balance sheet estimate...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
# [17 rows x 33 columns]

# %%
#reorder columns
output = output[['location_id', 'location_name', 'sub_population', 'vehicle', 'metric',
       'mass_unit', 'time_unit', 'pop_denom','value_mean', 'lower',
       'upper', 'mean_value_source_citation',
       'mean_value_source_link', 'data_choice_notes']]

# %%
output
# Out:
#    location_id                     location_name             sub_population  \
# 0           11                         Indonesia           total population
# 1          171  Democratic Republic of the Congo           total population
# 2          171  Democratic Republic of the Congo           total population
# 3          184                        Mozambique           total population
# 4          184                        Mozambique           total population
# 5          202                          Cameroon  women of reproductive age
# 6          202                          Cameroon           total population
# 7          205                     Côte d'Ivoire           total population
# 8          205                     Côte d'Ivoire           total population
#
#        vehicle metric mass_unit time_unit  pop_denom  value_mean       lower  \
# 0  wheat flour   mean         g       day     capita       73.59   47.837452
# 1  wheat flour   mean         g       day     capita       34.00   22.101826
# 2  maize flour   mean         g       day     capita       60.80   35.887704
# 3  wheat flour   mean         g       day     capita       65.92   42.851540
# 4  maize flour   mean         g       day     capita      180.60  106.600647
# 5  wheat flour    NaN         g       day  consumers       79.00   51.354243
# 6  maize flour   mean         g       day     capita      139.34   82.246590
# 7  wheat flour   mean         g       day     capita       70.08   45.555764
# 8  maize flour   mean         g       day     capita       43.90   25.912339
#
#         upper                         mean_value_source_citation  \
# 0   99.342548                                               GFDx
# 1   45.898174                                               GFDx
# 2   85.712296  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 3   88.988460                                               GFDx
# 4  254.599353                                               GFDx
# 5  106.645757  Hess SY, Brown KH, Sablah M, Engle-Stone R, Aa...
# 6  196.433410                                               GFDx
# 7   94.604236                                               GFDx
# 8   61.887661  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#                               mean_value_source_link  \
# 0  https://fortificationdata.org/country-fortific...
# 1  https://fortificationdata.org/country-fortific...
# 2              https://doi.org/10.3945/an.110.000182
# 3  https://fortificationdata.org/country-fortific...
# 4  https://fortificationdata.org/country-fortific...
# 5  https://journals.sagepub.com/doi/pdf/10.1177/1...
# 6  https://fortificationdata.org/country-fortific...
# 7  https://fortificationdata.org/country-fortific...
# 8              https://doi.org/10.3945/an.110.000182
#
#                                    data_choice_notes
# 0  discarded 1997-2000 fortification handbook num...
# 1  Kept 2000 GFDx number (34 g/day), discarded 19...
# 2  Discarded 1997-2000 fortification handbook num...
# 3  Discarded 1997-2000 fortification handbook num...
# 4  Discarded 1997-2000 fortification handbook num...
# 5  Took most recent survey data (Hess, 2011) amon...
# 6  Kept 2017 GFDx number (139 g/day), discarded 2...
# 7  Kept 2017 GFDx number (70 g/day), discarded Sa...
# 8  Discarded 2007 Nuss FAO balance sheet estimate...

# %%
output = output.sort_values(['location_name','vehicle'])

# %%
save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/gday_tier4_04_02_2021.csv'
output.to_csv(save_path, index = False)

# %%
save_path = '/ihme/homes/beatrixh/repos/scratch/gday_tier4_04_02_2021.csv'
output.to_csv(save_path, index = False)
