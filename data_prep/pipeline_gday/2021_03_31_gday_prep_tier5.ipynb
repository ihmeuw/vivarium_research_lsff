# %%
from db_queries import get_population, get_ids
from db_queries import get_location_metadata as get_locs

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# # Prep g/day for Tier 5 locs

# %% [markdown]
# ## 	Angola, China, Ghana, Niger, Egypt, Sudan, Madagascar

# %%
## load targets
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)

# %%
ls /ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/ | grep gday_extraction_
# Out:
# gday_extraction_sheet_02_19_2021.csv
# gday_extraction_sheet_02_22_2021.csv
# gday_extraction_sheet_03_16_2021.csv
# gday_extraction_sheet_03_22_2021.csv
# gday_extraction_sheet_03_24_2021.csv
# gday_extraction_sheet_03_29_2021.csv

# %%
gday_path =  '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/gday_extraction_sheet_03_29_2021.csv'
gday = pd.read_csv(gday_path)

assert(len(gday[gday.location_name.isna()])==0), "Some rows missing location name"

# %%
gday.location_name = gday.location_name.str.strip(' ')
gday.subnational_name = gday.subnational_name.str.strip(' ')
gday.vehicle = gday.vehicle.str.strip(' ')
gday.nutrient = gday.nutrient.str.strip(' ')
gday.urbanicity = gday.urbanicity.str.strip(' ')
gday.nutrient = gday.nutrient.str.strip(' ')

# %%
output = pd.DataFrame()

# %%
country_vehicle_map.keys()
# Out:
# dict_keys(['India', 'Nigeria', 'Ethiopia', 'Democratic Republic of the Congo', 'Indonesia', 'Bangladesh', 'Pakistan', 'Kenya', 'United Republic of Tanzania', 'South Africa', 'Sudan', 'Uganda', 'Myanmar', 'Ghana', 'Egypt', 'Vietnam', 'Nepal', 'Mozambique', 'Cameroon', 'Angola', "Côte d'Ivoire", 'Madagascar', 'Burkina Faso', 'Niger', 'China', nan])

# %%
# location_names = ['Pakistan','Bangladesh','United Republic of Tanzania','Uganda','South Africa']
# location_names = ['Kenya', 'Burkina Faso', 'Myanmar', 'Vietnam', 'Nepal']

location_names = ['Angola', 'China', 'Ghana', 'Niger', 'Egypt', 'Sudan', 'Madagascar']
vehicles = ['wheat flour','maize flour','oil']

# %%
# these are the vehicles per country we need
target = pd.DataFrame([(loc,v) for loc in location_names for v in country_vehicle_map[loc]],
            columns=['location_name','vehicle']).sort_values(['location_name','vehicle']).set_index(['location_name','vehicle'])

target
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Angola, maize flour), (Angola, oil), (Angola, wheat flour), (China, oil), (China, wheat flour), (Egypt, maize flour), (Egypt, oil), (Egypt, wheat flour), (Ghana, bouillon), (Ghana, maize flour), (Ghana, oil), (Ghana, rice), (Ghana, wheat flour), (Madagascar, maize flour), (Madagascar, oil), (Madagascar, wheat flour), (Niger, bouillon), (Niger, maize flour), (Niger, oil), (Niger, wheat flour), (Sudan, maize flour), (Sudan, oil), (Sudan, wheat flour)]

# %%
gday.location_id = gday.location_id.fillna(-1).astype(int)

# %%
gday.location_name.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Burkina Faso',
#        "Côte d'Ivoire", 'Cameroon', 'Chad', 'China',
#        'Democratic Republic of the Congo', 'Egypt', 'Ethiopia', 'Ghana',
#        'India', 'Indonesia', 'Kenya', 'Madagascar', 'Mozambique',
#        'Myanmar', 'Nepal', 'Niger', 'Nigeria', 'Pakistan', 'Philippines',
#        'South Africa', 'Sudan', 'Uganda', 'United Republic of Tanzania',
#        'Viet Nam', 'Yemen', 'Zambia'], dtype=object)

# %%
# estimate CIs, crude

# clean value_mean
gday.loc[gday.value_mean=='na','value_mean'] = np.nan
gday.value_mean = gday.value_mean.astype(float)

# clean 2.5th %ile
gday.loc[gday.value_025_percentile=='na','value_025_percentile'] = np.nan
gday.value_025_percentile = gday.value_025_percentile.astype(float)

# clean 97.5th %ile
gday.loc[gday.value_975_percentile=='na','value_975_percentile'] = np.nan
gday.value_975_percentile = gday.value_975_percentile.astype(float)

# calc scale_over_mean
gday['scale_over_mean'] = (gday.value_975_percentile - gday.value_025_percentile) / gday.value_mean

#foreach vehicle, average scale_over_mean
r = gday[['vehicle','scale_over_mean']].groupby('vehicle').mean().dropna().rename(columns={'scale_over_mean':'r'})

# %%
# these are the vehicles for which we have a scale_over_mean estimate
r
# Out:
#                     r
# vehicle
# bouillon     0.902591
# wheat flour  0.699893

# %%
# for vehicles without a scale_over_mean value, we'll assign the average of the others (row-wise)
r = r.reset_index().append(pd.DataFrame([(i,gday.scale_over_mean.mean()) for i in ['maize flour', 'wheat(not specifically flour)','salt', 'rice']],
            columns = ['vehicle','r']))
r
# Out:
#                          vehicle         r
# 0                       bouillon  0.902591
# 1                    wheat flour  0.699893
# 0                    maize flour  0.819483
# 1  wheat(not specifically flour)  0.819483
# 2                           salt  0.819483
# 3                           rice  0.819483

# %%
# add uncertainty
gday = gday.merge(r, on = 'vehicle', how = 'outer')
gday['lower'] = gday.value_mean - (gday.r * gday.value_mean)/2
gday['upper'] = gday.value_mean + (gday.r * gday.value_mean)/2

# %%
gday[(gday.location_name.isin(location_names)) & (gday.vehicle.isin(vehicles))].groupby(['location_name','vehicle']).mean()
# Out:
#                            location_id  subnational_location_id  value_mean  \
# location_name vehicle
# Angola        maize flour          168                      NaN  107.486400
#               wheat flour          168                      NaN   81.020833
# China         maize flour           -1                      NaN   38.000000
#               wheat flour           -1                      NaN  181.056429
# Egypt         maize flour           -1                      NaN  163.435833
#               wheat flour           -1                      NaN  389.919583
# Ghana         maize flour          207                      NaN   65.144800
#               wheat flour          207                      NaN   39.483200
# Madagascar    maize flour          181                      NaN   40.117826
#               wheat flour          181                      NaN   20.330417
# Niger         maize flour          213                      NaN   10.317083
#               wheat flour          213                      NaN   13.068750
# Sudan         maize flour          522                      NaN    4.567143
#               wheat flour          522                      NaN   94.215714
#
#                            value_025_percentile  value_975_percentile  \
# location_name vehicle
# Angola        maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# China         maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Egypt         maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Ghana         maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Madagascar    maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Niger         maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
# Sudan         maize flour                   NaN                   NaN
#               wheat flour                   NaN                   NaN
#
#                            scale_over_mean         r       lower       upper
# location_name vehicle
# Angola        maize flour              NaN  0.819483   63.444738  151.528062
#               wheat flour              NaN  0.699893   52.667893  109.373774
# China         maize flour              NaN  0.819483   22.429815   53.570185
#               wheat flour              NaN  0.699893  117.696402  244.416455
# Egypt         maize flour              NaN  0.819483   96.469355  230.402312
#               wheat flour              NaN  0.699893  253.468670  526.370496
# Ghana         maize flour              NaN  0.819483   38.452258   91.837342
#               wheat flour              NaN  0.699893   25.666200   53.300200
# Madagascar    maize flour              NaN  0.819483   23.679879   56.555773
#               wheat flour              NaN  0.699893   13.215863   27.444971
# Niger         maize flour              NaN  0.819483    6.089744   14.544423
#               wheat flour              NaN  0.699893    8.495389   17.642111
# Sudan         maize flour              NaN  0.819483    2.695794    6.438492
#               wheat flour              NaN  0.699893   61.245274  127.186154

# %%
gday.value_description.unique()
# Out:
# array([nan, 'Mean daily consumption (mg)',
#        'Mean per capita consumption (g/day)',
#        'Median amount of vehicle consumed on previous day among consumers (g/day)',
#        'Mean amount of vehicle consumed on previous day among consumers (g/day)',
#        'Estimated daily contribution from fortified foods (mg/d)',
#        'kg/capita/year',
#        'Mean per capita consumption among consumers (g/day)',
#        'Consumption per person per day (g)',
#        'Median daily contribution from fortified foods among consumers (mg/day)'],
#       dtype=object)

# %%
## dicts for var cleaning

value_d_to_metric = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'median',
 'Mean per capita consumption (g/day)': 'mean',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'mean',
 'Mean micronutrient intake per capita (mg/day)': 'mean',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'mean'
}

value_d_to_entity = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean per capita consumption (g/day)': 'CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean micronutrient intake per capita (mg/day)': 'nutrient',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK',
 'Mean per capita consumption among consumers (g/day)':'CHECK'
}

value_d_to_mass_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean per capita consumption (g/day)': 'g',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean micronutrient intake per capita (mg/day)': 'mg',
 'Daily per capita consumption (g)': 'g',
 'Daily consumption (mg/d)': 'mg',
 'Consumption per person per day (g)': 'g',
 'Estimated daily contribution from fortified foods (mg/d)': 'mg',
 'kg/capita/year': 'kg',
 'Mean per capita consumption among consumers (g/day)':'g'
}

value_d_to_time_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean per capita consumption (g/day)': 'day',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean micronutrient intake per capita (mg/day)': 'day',
 'Daily per capita consumption (g)': 'day',
 'Daily consumption (mg/d)': 'day',
 'Consumption per person per day (g)': 'day',
 'Estimated daily contribution from fortified foods (mg/d)': 'day',
 'kg/capita/year': 'year',
 'Mean per capita consumption among consumers (g/day)':'day'
}

value_d_to_population = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean per capita consumption (g/day)': 'capita CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean micronutrient intake per capita (mg/day)': 'capita CHECK',
 'Daily per capita consumption (g)': 'capita CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'capita CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'capita CHECK',
 'Mean per capita consumption among consumers (g/day)':'consumers'
}

# %%
def format_value_d(df):
    df['metric'] = df.value_description.map(value_d_to_metric)
    df['entity'] = df.value_description.map(value_d_to_entity)
    df['mass_unit'] = df.value_description.map(value_d_to_mass_unit)
    df['time_unit'] = df.value_description.map(value_d_to_time_unit)
    df['pop_denom'] = df.value_description.map(value_d_to_population)
    
    return df

# %%
location_names
# Out:
# ['Angola', 'China', 'Ghana', 'Niger', 'Egypt', 'Sudan', 'Madagascar']

# %%
viewcols = ['location_name','subnational_name', 'metric', 'entity',
            'mass_unit', 'time_unit', 'pop_denom','vehicle',
            'value_mean','value_025_percentile','value_975_percentile',
            'sub_population','urbanicity',
            'source_citation', 'source_link', 'source_year', 'source_type']

# %%
qcols = ['value_mean','source_citation','source_year','sub_population','source_type']

# %% [markdown]
# ## Angola

# %%
angola = format_value_d(gday[gday.location_name=="Angola"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
angola.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)'],
#       dtype=object)

# %%
angola_wheat = angola[(angola.vehicle=="wheat flour")]
angola_maize = angola[(angola.vehicle=="maize flour")]

# %%
angola_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 7         49.00  Fortification Handbook: Vitamin and Mineral Fo...
# 8         89.32                                               GFDx
# 472       58.00                                               GFDx
# 473       61.00                                               GFDx
# 474       63.00                                               GFDx
# 475       62.00                                               GFDx
# 476       63.00                                               GFDx
# 477       71.00                                               GFDx
# 478       66.00                                               GFDx
# 479       67.00                                               GFDx
# 480       74.00                                               GFDx
# 481       82.00                                               GFDx
# 482       86.00                                               GFDx
# 483       91.00                                               GFDx
# 484       94.00                                               GFDx
# 485       96.00                                               GFDx
# 486       95.00                                               GFDx
# 487       97.00                                               GFDx
# 488      105.00                                               GFDx
# 489      110.00                                               GFDx
# 490      112.00                                               GFDx
# 491       86.52                                               GFDx
# 492       84.11                                               GFDx
# 493       82.55                                               GFDx
#
#     source_year    sub_population                        source_type
# 7     1997-2000  total population  estimated from FAO balance sheets
# 8          2017  total population  estimated from FAO balance sheets
# 472        1995  total population  estimated from FAO balance sheets
# 473        1996  total population  estimated from FAO balance sheets
# 474        1997  total population  estimated from FAO balance sheets
# 475        1998  total population  estimated from FAO balance sheets
# 476        1999  total population  estimated from FAO balance sheets
# 477        2000  total population  estimated from FAO balance sheets
# 478        2001  total population  estimated from FAO balance sheets
# 479        2002  total population  estimated from FAO balance sheets
# 480        2003  total population  estimated from FAO balance sheets
# 481        2004  total population  estimated from FAO balance sheets
# 482        2005  total population  estimated from FAO balance sheets
# 483        2006  total population  estimated from FAO balance sheets
# 484        2007  total population  estimated from FAO balance sheets
# 485        2008  total population  estimated from FAO balance sheets
# 486        2009  total population  estimated from FAO balance sheets
# 487        2010  total population  estimated from FAO balance sheets
# 488        2011  total population  estimated from FAO balance sheets
# 489        2012  total population  estimated from FAO balance sheets
# 490        2013  total population  estimated from FAO balance sheets
# 491        2014  total population  estimated from FAO balance sheets
# 492        2015  total population  estimated from FAO balance sheets
# 493        2016  total population  estimated from FAO balance sheets

# %%
angola_wheat.loc[(angola_wheat.source_year=="2017"),'data_choice_notes'] = "Discarded 1997-2000 fortification handbook (49 g/day) in lieu of 2017 gfdx number (89 g/day). Noting gfdx had 63-71 g/day 1997-2000. All estimates from FAO"

output = output.append(
    angola_wheat.loc[(angola_wheat.source_year=="2017")]
)

angola_wheat.loc[(angola_wheat.source_year=="2017")]
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v107/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v107/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#    location_id location_name subnational_name  subnational_location_id  \
# 8          168        Angola               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 8  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#    value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 8       89.32                   NaN  ...              NaN  0.699893
#
#        lower       upper metric entity mass_unit time_unit     pop_denom  \
# 8  58.062797  120.577203   mean  CHECK         g       day  capita CHECK
#
#                                    data_choice_notes
# 8  Discarded 1997-2000 fortification handbook (49...
#
# [1 rows x 32 columns]

# %%
angola_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 609       72.00  Fortification Handbook: Vitamin and Mineral Fo...
# 610      154.99                                               GFDx
# 611      103.10  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 873       75.00                                               GFDx
# 874       90.00                                               GFDx
# 875       96.00                                               GFDx
# 876       95.00                                               GFDx
# 877      109.00                                               GFDx
# 878      100.00                                               GFDx
# 879      104.00                                               GFDx
# 880      108.00                                               GFDx
# 881      104.00                                               GFDx
# 882      104.00                                               GFDx
# 883      101.00                                               GFDx
# 884      101.00                                               GFDx
# 885      100.00                                               GFDx
# 886      106.00                                               GFDx
# 887      106.00                                               GFDx
# 888      110.00                                               GFDx
# 889      108.00                                               GFDx
# 890      101.00                                               GFDx
# 891      106.00                                               GFDx
# 892      137.70                                               GFDx
# 893      145.23                                               GFDx
# 894      150.14                                               GFDx
#
#     source_year    sub_population                        source_type
# 609   1997-2000  total population  estimated from FAO balance sheets
# 610        2017  total population  estimated from FAO balance sheets
# 611        2007  total population  estimated from FAO balance sheets
# 873        1995  total population  estimated from FAO balance sheets
# 874        1996  total population  estimated from FAO balance sheets
# 875        1997  total population  estimated from FAO balance sheets
# 876        1998  total population  estimated from FAO balance sheets
# 877        1999  total population  estimated from FAO balance sheets
# 878        2000  total population  estimated from FAO balance sheets
# 879        2001  total population  estimated from FAO balance sheets
# 880        2002  total population  estimated from FAO balance sheets
# 881        2003  total population  estimated from FAO balance sheets
# 882        2004  total population  estimated from FAO balance sheets
# 883        2005  total population  estimated from FAO balance sheets
# 884        2006  total population  estimated from FAO balance sheets
# 885        2007  total population  estimated from FAO balance sheets
# 886        2008  total population  estimated from FAO balance sheets
# 887        2009  total population  estimated from FAO balance sheets
# 888        2010  total population  estimated from FAO balance sheets
# 889        2011  total population  estimated from FAO balance sheets
# 890        2012  total population  estimated from FAO balance sheets
# 891        2013  total population  estimated from FAO balance sheets
# 892        2014  total population  estimated from FAO balance sheets
# 893        2015  total population  estimated from FAO balance sheets
# 894        2016  total population  estimated from FAO balance sheets

# %%
angola_maize.loc[angola_maize.source_year=="2017","data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (72 g/day) and 2007 Nuss number (103 g/day) in lieu of 2017 GFDx number (154 g/day). All numbers from FAO balance sheets."

output = output.append(
    angola_maize.loc[angola_maize.source_year=="2017"]
)

angola_maize.loc[angola_maize.source_year=="2017"]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 610          168        Angola               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 610  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 610      154.99                   NaN  ...              NaN  0.819483
#
#          lower       upper metric entity mass_unit time_unit     pop_denom  \
# 610  91.484132  218.495868   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 610  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## China

# %%
china = format_value_d(gday[gday.location_name=="China"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
china.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour'], dtype=object)

# %%
china_wheat = china[(china.vehicle=="wheat flour")]

# %%
china_wheat[['value_mean','source_citation','source_year','sub_population','source_type','pop_denom']]
# Out:
#      value_mean                                    source_citation  \
# 42       162.00  Fortification Handbook: Vitamin and Mineral Fo...
# 43       140.30                         GHDx, cite don't share DUA
# 44       131.90                         GHDx, cite don't share DUA
# 45       143.50                         GHDx, cite don't share DUA
# 46       171.92                                               GFDx
# 47       185.00  Fortifying Flour Where People Eat Rice. Hunger...
# 494      216.00                                               GFDx
# 495      215.00                                               GFDx
# 496      213.00                                               GFDx
# 497      212.00                                               GFDx
# 498      208.00                                               GFDx
# 499      201.00                                               GFDx
# 500      197.00                                               GFDx
# 501      192.00                                               GFDx
# 502      188.00                                               GFDx
# 503      187.00                                               GFDx
# 504      185.00                                               GFDx
# 505      184.00                                               GFDx
# 506      181.00                                               GFDx
# 507      176.00                                               GFDx
# 508      170.00                                               GFDx
# 509      171.00                                               GFDx
# 510      174.00                                               GFDx
# 511      174.00                                               GFDx
# 512      174.00                                               GFDx
# 513      171.78                                               GFDx
# 514      172.88                                               GFDx
# 515      172.30                                               GFDx
#
#     source_year    sub_population                        source_type  \
# 42    1997-2000  total population  estimated from FAO balance sheets
# 43         2002  total population           Survey - cross-sectional
# 44         2002  total population           Survey - cross-sectional
# 45         2002  total population           Survey - cross-sectional
# 46         2017  total population  estimated from FAO balance sheets
# 47         2007  total population  estimated from FAO balance sheets
# 494        1995  total population  estimated from FAO balance sheets
# 495        1996  total population  estimated from FAO balance sheets
# 496        1997  total population  estimated from FAO balance sheets
# 497        1998  total population  estimated from FAO balance sheets
# 498        1999  total population  estimated from FAO balance sheets
# 499        2000  total population  estimated from FAO balance sheets
# 500        2001  total population  estimated from FAO balance sheets
# 501        2002  total population  estimated from FAO balance sheets
# 502        2003  total population  estimated from FAO balance sheets
# 503        2004  total population  estimated from FAO balance sheets
# 504        2005  total population  estimated from FAO balance sheets
# 505        2006  total population  estimated from FAO balance sheets
# 506        2007  total population  estimated from FAO balance sheets
# 507        2008  total population  estimated from FAO balance sheets
# 508        2009  total population  estimated from FAO balance sheets
# 509        2010  total population  estimated from FAO balance sheets
# 510        2011  total population  estimated from FAO balance sheets
# 511        2012  total population  estimated from FAO balance sheets
# 512        2013  total population  estimated from FAO balance sheets
# 513        2014  total population  estimated from FAO balance sheets
# 514        2015  total population  estimated from FAO balance sheets
# 515        2016  total population  estimated from FAO balance sheets
#
#         pop_denom
# 42   capita CHECK
# 43      consumers
# 44      consumers
# 45      consumers
# 46   capita CHECK
# 47   capita CHECK
# 494  capita CHECK
# 495  capita CHECK
# 496  capita CHECK
# 497  capita CHECK
# 498  capita CHECK
# 499  capita CHECK
# 500  capita CHECK
# 501  capita CHECK
# 502  capita CHECK
# 503  capita CHECK
# 504  capita CHECK
# 505  capita CHECK
# 506  capita CHECK
# 507  capita CHECK
# 508  capita CHECK
# 509  capita CHECK
# 510  capita CHECK
# 511  capita CHECK
# 512  capita CHECK
# 513  capita CHECK
# 514  capita CHECK
# 515  capita CHECK

# %%
china_wheat.loc[(china_wheat.source_year=="2017"),"data_choice_notes"] = "Discarded earlier FAO estimates for 2017 GFDx FAO estimate"

output = output.append(
    china_wheat.loc[(china_wheat.source_year=="2017")]
)

china_wheat.loc[(china_wheat.source_year=="2017")]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 46           -1         China               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 46  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 46      171.92                   NaN  ...              NaN  0.699893
#
#          lower       upper metric entity mass_unit time_unit     pop_denom  \
# 46  111.757233  232.082767   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 46  Discarded earlier FAO estimates for 2017 GFDx ...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Ghana

# %%
ghana = format_value_d(gday[gday.location_name=="Ghana"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ghana.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)',
#        'bouillon', 'rice'], dtype=object)

# %%
ghana_wheat = ghana[(ghana.vehicle=="wheat flour")]
ghana_maize = ghana[(ghana.vehicle=="maize flour")]

# %%
ghana_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 54        23.00  Fortification Handbook: Vitamin and Mineral Fo...
# 55        86.36                                               GFDx
# 56         0.80  Nyumuah RO, Hoang TC, Amoaful EF, Agble R, Mey...
# 516       21.00                                               GFDx
# 517       16.00                                               GFDx
# 518       31.00                                               GFDx
# 519       32.00                                               GFDx
# 520       37.00                                               GFDx
# 521       40.00                                               GFDx
# 522       35.00                                               GFDx
# 523       31.00                                               GFDx
# 524       33.00                                               GFDx
# 525       37.00                                               GFDx
# 526       53.00                                               GFDx
# 527       48.00                                               GFDx
# 528       52.00                                               GFDx
# 529       49.00                                               GFDx
# 530       45.00                                               GFDx
# 531       46.00                                               GFDx
# 532       46.00                                               GFDx
# 533       41.00                                               GFDx
# 534       40.00                                               GFDx
# 535       47.62                                               GFDx
# 536       44.63                                               GFDx
# 537       51.67                                               GFDx
#
#     source_year    sub_population                        source_type
# 54    1997-2000  total population  estimated from FAO balance sheets
# 55         2017  total population  estimated from FAO balance sheets
# 56         2010  total population           Survey - cross-sectional
# 516        1995  total population  estimated from FAO balance sheets
# 517        1996  total population  estimated from FAO balance sheets
# 518        1997  total population  estimated from FAO balance sheets
# 519        1998  total population  estimated from FAO balance sheets
# 520        1999  total population  estimated from FAO balance sheets
# 521        2000  total population  estimated from FAO balance sheets
# 522        2001  total population  estimated from FAO balance sheets
# 523        2002  total population  estimated from FAO balance sheets
# 524        2003  total population  estimated from FAO balance sheets
# 525        2004  total population  estimated from FAO balance sheets
# 526        2005  total population  estimated from FAO balance sheets
# 527        2006  total population  estimated from FAO balance sheets
# 528        2007  total population  estimated from FAO balance sheets
# 529        2008  total population  estimated from FAO balance sheets
# 530        2009  total population  estimated from FAO balance sheets
# 531        2010  total population  estimated from FAO balance sheets
# 532        2011  total population  estimated from FAO balance sheets
# 533        2012  total population  estimated from FAO balance sheets
# 534        2013  total population  estimated from FAO balance sheets
# 535        2014  total population  estimated from FAO balance sheets
# 536        2015  total population  estimated from FAO balance sheets
# 537        2016  total population  estimated from FAO balance sheets

# %%
ghana_wheat.loc[ghana_wheat.source_year=="2017","data_choice_notes"] = "Discarded 2017 1997-2000 fortification handbook number estimated from fao (23 g/day) and 2010 Nyumuah survey number (0.8 g/day; this might be a misextraction for nutrient) in lieu of 2017 GFDx number (86 g/day)"

output = output.append(
    ghana_wheat.loc[ghana_wheat.source_year=="2017"]
)

ghana_wheat.loc[ghana_wheat.source_year=="2017"]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 55          207         Ghana               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 55  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 55       86.36                   NaN  ...              NaN  0.699893
#
#         lower       upper metric entity mass_unit time_unit     pop_denom  \
# 55  56.138638  116.581362   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 55  Discarded 2017 1997-2000 fortification handboo...
#
# [1 rows x 32 columns]

# %%
ghana_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 627       81.00  Fortification Handbook: Vitamin and Mineral Fo...
# 628       69.23                                               GFDx
# 629       99.40  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 895       61.00                                               GFDx
# 896       58.00                                               GFDx
# 897       57.00                                               GFDx
# 898       54.00                                               GFDx
# 899       55.00                                               GFDx
# 900       55.00                                               GFDx
# 901       49.00                                               GFDx
# 902       38.00                                               GFDx
# 903       59.00                                               GFDx
# 904       64.00                                               GFDx
# 905       61.00                                               GFDx
# 906       61.00                                               GFDx
# 907       66.00                                               GFDx
# 908       63.00                                               GFDx
# 909       72.00                                               GFDx
# 910       79.00                                               GFDx
# 911       70.00                                               GFDx
# 912       84.00                                               GFDx
# 913       70.00                                               GFDx
# 914       67.32                                               GFDx
# 915       68.00                                               GFDx
# 916       67.67                                               GFDx
#
#     source_year    sub_population                        source_type
# 627   1997-2000  total population  estimated from FAO balance sheets
# 628        2017  total population  estimated from FAO balance sheets
# 629        2007  total population  estimated from FAO balance sheets
# 895        1995  total population  estimated from FAO balance sheets
# 896        1996  total population  estimated from FAO balance sheets
# 897        1997  total population  estimated from FAO balance sheets
# 898        1998  total population  estimated from FAO balance sheets
# 899        1999  total population  estimated from FAO balance sheets
# 900        2000  total population  estimated from FAO balance sheets
# 901        2001  total population  estimated from FAO balance sheets
# 902        2002  total population  estimated from FAO balance sheets
# 903        2003  total population  estimated from FAO balance sheets
# 904        2004  total population  estimated from FAO balance sheets
# 905        2005  total population  estimated from FAO balance sheets
# 906        2006  total population  estimated from FAO balance sheets
# 907        2007  total population  estimated from FAO balance sheets
# 908        2008  total population  estimated from FAO balance sheets
# 909        2009  total population  estimated from FAO balance sheets
# 910        2010  total population  estimated from FAO balance sheets
# 911        2011  total population  estimated from FAO balance sheets
# 912        2012  total population  estimated from FAO balance sheets
# 913        2013  total population  estimated from FAO balance sheets
# 914        2014  total population  estimated from FAO balance sheets
# 915        2015  total population  estimated from FAO balance sheets
# 916        2016  total population  estimated from FAO balance sheets

# %%
ghana_maize.loc[(ghana_maize.source_year=="2017"),"data_choice_notes"] = "Discarded 1997-2000 number (81 g/day) and 2007 Nuss number (99 g/day) in lieu of 2017 GFDx number (69 g/day). All FAO balance sheet estimates."

output = output.append(
    ghana_maize.loc[(ghana_maize.source_year=="2017")]
)

ghana_maize.loc[(ghana_maize.source_year=="2017")]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 628          207         Ghana               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 628  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 628       69.23                   NaN  ...              NaN  0.819483
#
#          lower      upper metric entity mass_unit time_unit     pop_denom  \
# 628  40.863581  97.596419   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 628  Discarded 1997-2000 number (81 g/day) and 2007...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Niger

# %%
niger = format_value_d(gday[gday.location_name=="Niger"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
niger.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)',
#        'bouillon'], dtype=object)

# %%
niger_wheat = niger[(niger.vehicle=="wheat flour")]
niger_maize = niger[(niger.vehicle=="maize flour")]

# %%
niger_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 76        10.00  Fortification Handbook: Vitamin and Mineral Fo...
# 77        11.45                                               GFDx
# 538        7.00                                               GFDx
# 539       15.00                                               GFDx
# 540        9.00                                               GFDx
# 541       14.00                                               GFDx
# 542       14.00                                               GFDx
# 543       15.00                                               GFDx
# 544       17.00                                               GFDx
# 545       19.00                                               GFDx
# 546       15.00                                               GFDx
# 547       14.00                                               GFDx
# 548       17.00                                               GFDx
# 549       13.00                                               GFDx
# 550       13.00                                               GFDx
# 551       12.00                                               GFDx
# 552       14.00                                               GFDx
# 553       17.00                                               GFDx
# 554       10.00                                               GFDx
# 555       16.00                                               GFDx
# 556       13.00                                               GFDx
# 557       10.58                                               GFDx
# 558        9.10                                               GFDx
# 559        8.52                                               GFDx
#
#     source_year    sub_population                        source_type
# 76    1997-2000  total population  estimated from FAO balance sheets
# 77         2017  total population  estimated from FAO balance sheets
# 538        1995  total population  estimated from FAO balance sheets
# 539        1996  total population  estimated from FAO balance sheets
# 540        1997  total population  estimated from FAO balance sheets
# 541        1998  total population  estimated from FAO balance sheets
# 542        1999  total population  estimated from FAO balance sheets
# 543        2000  total population  estimated from FAO balance sheets
# 544        2001  total population  estimated from FAO balance sheets
# 545        2002  total population  estimated from FAO balance sheets
# 546        2003  total population  estimated from FAO balance sheets
# 547        2004  total population  estimated from FAO balance sheets
# 548        2005  total population  estimated from FAO balance sheets
# 549        2006  total population  estimated from FAO balance sheets
# 550        2007  total population  estimated from FAO balance sheets
# 551        2008  total population  estimated from FAO balance sheets
# 552        2009  total population  estimated from FAO balance sheets
# 553        2010  total population  estimated from FAO balance sheets
# 554        2011  total population  estimated from FAO balance sheets
# 555        2012  total population  estimated from FAO balance sheets
# 556        2013  total population  estimated from FAO balance sheets
# 557        2014  total population  estimated from FAO balance sheets
# 558        2015  total population  estimated from FAO balance sheets
# 559        2016  total population  estimated from FAO balance sheets

# %%
niger_wheat.loc[niger_wheat.source_year=="2017","data_choice_notes"] = "Discarded 2017 1997-2000 fortification handbook number estimated from fao (10 g/day)in lieu of 2017 GFDx number (11 g/day)"

output = output.append(
    niger_wheat.loc[niger_wheat.source_year=="2017"]
)

niger_wheat.loc[niger_wheat.source_year=="2017"]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 77          213         Niger               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 77    unknown  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 77       11.45                   NaN  ...              NaN  0.699893
#
#        lower      upper metric entity mass_unit time_unit     pop_denom  \
# 77  7.443115  15.456885   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 77  Discarded 2017 1997-2000 fortification handboo...
#
# [1 rows x 32 columns]

# %%
niger_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 637       10.63                                               GFDx
# 638        8.30  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 917        6.00                                               GFDx
# 918        5.00                                               GFDx
# 919       13.00                                               GFDx
# 920       25.00                                               GFDx
# 921        8.00                                               GFDx
# 922       18.00                                               GFDx
# 923        9.00                                               GFDx
# 924       15.00                                               GFDx
# 925        7.00                                               GFDx
# 926       17.00                                               GFDx
# 927        8.00                                               GFDx
# 928        8.00                                               GFDx
# 929        8.00                                               GFDx
# 930        8.00                                               GFDx
# 931        8.00                                               GFDx
# 932        7.00                                               GFDx
# 933        7.00                                               GFDx
# 934        9.00                                               GFDx
# 935       10.00                                               GFDx
# 936       10.03                                               GFDx
# 937       11.64                                               GFDx
# 938       11.01                                               GFDx
#
#     source_year    sub_population                        source_type
# 637        2017  total population  estimated from FAO balance sheets
# 638        2007  total population  estimated from FAO balance sheets
# 917        1995  total population  estimated from FAO balance sheets
# 918        1996  total population  estimated from FAO balance sheets
# 919        1997  total population  estimated from FAO balance sheets
# 920        1998  total population  estimated from FAO balance sheets
# 921        1999  total population  estimated from FAO balance sheets
# 922        2000  total population  estimated from FAO balance sheets
# 923        2001  total population  estimated from FAO balance sheets
# 924        2002  total population  estimated from FAO balance sheets
# 925        2003  total population  estimated from FAO balance sheets
# 926        2004  total population  estimated from FAO balance sheets
# 927        2005  total population  estimated from FAO balance sheets
# 928        2006  total population  estimated from FAO balance sheets
# 929        2007  total population  estimated from FAO balance sheets
# 930        2008  total population  estimated from FAO balance sheets
# 931        2009  total population  estimated from FAO balance sheets
# 932        2010  total population  estimated from FAO balance sheets
# 933        2011  total population  estimated from FAO balance sheets
# 934        2012  total population  estimated from FAO balance sheets
# 935        2013  total population  estimated from FAO balance sheets
# 936        2014  total population  estimated from FAO balance sheets
# 937        2015  total population  estimated from FAO balance sheets
# 938        2016  total population  estimated from FAO balance sheets

# %%
niger_maize.loc[niger_maize.source_year=="2017","data_choice_notes"] = "Discarded 2007 Nuss number (8 g/day) in lieu of 2017 GFDx number (11 g/day). Both are FAO estimates"

output = output.append(
    niger_maize.loc[niger_maize.source_year=="2017"]
)

niger_maize.loc[niger_maize.source_year=="2017"]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 637          213         Niger               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 637    unknown  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 637       10.63                   NaN  ...              NaN  0.819483
#
#         lower      upper metric entity mass_unit time_unit     pop_denom  \
# 637  6.274446  14.985554   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 637  Discarded 2007 Nuss number (8 g/day) in lieu o...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Egypt

# %%
egypt = format_value_d(gday[gday.location_name=="Egypt"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
egypt.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour'], dtype=object)

# %%
egypt_wheat = egypt[(egypt.vehicle=="wheat flour")]
egypt_maize = egypt[(egypt.vehicle=="maize flour")]

# %%
egypt_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 50       281.00  Fortification Handbook: Vitamin and Mineral Fo...
# 51       399.23                                               GFDx
# 560      412.00                                               GFDx
# 561      414.00                                               GFDx
# 562      414.00                                               GFDx
# 563      401.00                                               GFDx
# 564      377.00                                               GFDx
# 565      373.00                                               GFDx
# 566      395.00                                               GFDx
# 567      377.00                                               GFDx
# 568      364.00                                               GFDx
# 569      371.00                                               GFDx
# 570      396.00                                               GFDx
# 571      391.00                                               GFDx
# 572      389.00                                               GFDx
# 573      399.00                                               GFDx
# 574      398.00                                               GFDx
# 575      399.00                                               GFDx
# 576      400.00                                               GFDx
# 577      400.00                                               GFDx
# 578      402.00                                               GFDx
# 579      404.55                                               GFDx
# 580      402.14                                               GFDx
# 581      399.15                                               GFDx
#
#     source_year    sub_population                        source_type
# 50    1997-2000  total population  estimated from FAO balance sheets
# 51         2017  total population  estimated from FAO balance sheets
# 560        1995  total population  estimated from FAO balance sheets
# 561        1996  total population  estimated from FAO balance sheets
# 562        1997  total population  estimated from FAO balance sheets
# 563        1998  total population  estimated from FAO balance sheets
# 564        1999  total population  estimated from FAO balance sheets
# 565        2000  total population  estimated from FAO balance sheets
# 566        2001  total population  estimated from FAO balance sheets
# 567        2002  total population  estimated from FAO balance sheets
# 568        2003  total population  estimated from FAO balance sheets
# 569        2004  total population  estimated from FAO balance sheets
# 570        2005  total population  estimated from FAO balance sheets
# 571        2006  total population  estimated from FAO balance sheets
# 572        2007  total population  estimated from FAO balance sheets
# 573        2008  total population  estimated from FAO balance sheets
# 574        2009  total population  estimated from FAO balance sheets
# 575        2010  total population  estimated from FAO balance sheets
# 576        2011  total population  estimated from FAO balance sheets
# 577        2012  total population  estimated from FAO balance sheets
# 578        2013  total population  estimated from FAO balance sheets
# 579        2014  total population  estimated from FAO balance sheets
# 580        2015  total population  estimated from FAO balance sheets
# 581        2016  total population  estimated from FAO balance sheets

# %%
egypt_wheat.loc[egypt_wheat.source_year=="2017","data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (281 g/day) in lieu of 2017 GFDx estimate (399 g/day). Both are FAO estimates."

output = output.append(
    egypt_wheat.loc[egypt_wheat.source_year=="2017"]
)

egypt_wheat.loc[egypt_wheat.source_year=="2017"]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 51           -1         Egypt               na                      NaN
#
#    urbanicity      vehicle nutrient                    value_description  \
# 51    unknown  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 51      399.23                   NaN  ...              NaN  0.699893
#
#          lower       upper metric entity mass_unit time_unit     pop_denom  \
# 51  259.520941  538.939059   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 51  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %%
egypt_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 623      114.00  Fortification Handbook: Vitamin and Mineral Fo...
# 624      167.21                                               GFDx
# 939      154.00                                               GFDx
# 940      151.00                                               GFDx
# 941      159.00                                               GFDx
# 942      165.00                                               GFDx
# 943      171.00                                               GFDx
# 944      167.00                                               GFDx
# 945      162.00                                               GFDx
# 946      167.00                                               GFDx
# 947      170.00                                               GFDx
# 948      163.00                                               GFDx
# 949      161.00                                               GFDx
# 950      162.00                                               GFDx
# 951      163.00                                               GFDx
# 952      164.00                                               GFDx
# 953      172.00                                               GFDx
# 954      171.00                                               GFDx
# 955      173.00                                               GFDx
# 956      173.00                                               GFDx
# 957      171.00                                               GFDx
# 958      169.75                                               GFDx
# 959      165.21                                               GFDx
# 960      167.29                                               GFDx
#
#     source_year    sub_population                        source_type
# 623   1997-2000  total population  estimated from FAO balance sheets
# 624        2017  total population  estimated from FAO balance sheets
# 939        1995  total population  estimated from FAO balance sheets
# 940        1996  total population  estimated from FAO balance sheets
# 941        1997  total population  estimated from FAO balance sheets
# 942        1998  total population  estimated from FAO balance sheets
# 943        1999  total population  estimated from FAO balance sheets
# 944        2000  total population  estimated from FAO balance sheets
# 945        2001  total population  estimated from FAO balance sheets
# 946        2002  total population  estimated from FAO balance sheets
# 947        2003  total population  estimated from FAO balance sheets
# 948        2004  total population  estimated from FAO balance sheets
# 949        2005  total population  estimated from FAO balance sheets
# 950        2006  total population  estimated from FAO balance sheets
# 951        2007  total population  estimated from FAO balance sheets
# 952        2008  total population  estimated from FAO balance sheets
# 953        2009  total population  estimated from FAO balance sheets
# 954        2010  total population  estimated from FAO balance sheets
# 955        2011  total population  estimated from FAO balance sheets
# 956        2012  total population  estimated from FAO balance sheets
# 957        2013  total population  estimated from FAO balance sheets
# 958        2014  total population  estimated from FAO balance sheets
# 959        2015  total population  estimated from FAO balance sheets
# 960        2016  total population  estimated from FAO balance sheets

# %%
egypt_maize.loc[egypt_maize.source_year=="2017","data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (114 g/day) in lieu of 2017 GFDx estimate (167 g/day). Both are FAO estimates."

output = output.append(
    egypt_maize.loc[egypt_maize.source_year=="2017"]
)

egypt_maize.loc[egypt_maize.source_year=="2017"]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 624           -1         Egypt               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 624    unknown  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 624      167.21                   NaN  ...              NaN  0.819483
#
#          lower       upper metric entity mass_unit time_unit     pop_denom  \
# 624  98.697088  235.722912   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 624  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Sudan

# %%
sudan = format_value_d(gday[gday.location_name=="Sudan"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sudan.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)'],
#       dtype=object)

# %%
sudan_wheat = sudan[(sudan.vehicle=="wheat flour")]
sudan_maize = sudan[(sudan.vehicle=="maize flour")]

# %%
sudan_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 87        69.00  Fortification Handbook: Vitamin and Mineral Fo...
# 88       123.45                                               GFDx
# 582       68.00                                               GFDx
# 583       62.00                                               GFDx
# 584      106.68                                               GFDx
# 585      111.01                                               GFDx
# 586      119.37                                               GFDx
#
#     source_year    sub_population                        source_type
# 87    1997-2000  total population  estimated from FAO balance sheets
# 88         2017  total population  estimated from FAO balance sheets
# 582        2012  total population  estimated from FAO balance sheets
# 583        2013  total population  estimated from FAO balance sheets
# 584        2014  total population  estimated from FAO balance sheets
# 585        2015  total population  estimated from FAO balance sheets
# 586        2016  total population  estimated from FAO balance sheets

# %%
sudan_wheat.loc[sudan_wheat.source_year=="2017","data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (69 g/day) in lieu of 2017 GFDx estimate (123 g/day). Both are FAO estimates."

output = output.append(
    sudan_wheat.loc[sudan_wheat.source_year=="2017"]
)

sudan_wheat.loc[sudan_wheat.source_year=="2017"]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 88          522         Sudan               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 88  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 88      123.45                   NaN  ...              NaN  0.699893
#
#        lower      upper metric entity mass_unit time_unit     pop_denom  \
# 88  80.24913  166.65087   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 88  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %%
sudan_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 645        5.40                                               GFDx
# 646        6.70  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 961        1.00                                               GFDx
# 962        1.00                                               GFDx
# 963        6.58                                               GFDx
# 964        5.56                                               GFDx
# 965        5.73                                               GFDx
#
#     source_year    sub_population                        source_type
# 645        2017  total population  estimated from FAO balance sheets
# 646        2007  total population  estimated from FAO balance sheets
# 961        2012  total population  estimated from FAO balance sheets
# 962        2013  total population  estimated from FAO balance sheets
# 963        2014  total population  estimated from FAO balance sheets
# 964        2015  total population  estimated from FAO balance sheets
# 965        2016  total population  estimated from FAO balance sheets

# %%
sudan_maize.loc[sudan_maize.source_year=="2017","data_choice_notes"] = "Discarded 2007 Nuss number (6.7 g/day) in lieu of 2017 GFDx estimate (5.4 g/day). Both are FAO estimates."

output = output.append(
    sudan_maize.loc[sudan_maize.source_year=="2017"]
)

sudan_maize.loc[sudan_maize.source_year=="2017"]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 645          522         Sudan               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 645  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 645         5.4                   NaN  ...              NaN  0.819483
#
#         lower     upper metric entity mass_unit time_unit     pop_denom  \
# 645  3.187395  7.612605   mean  CHECK         g       day  capita CHECK
#
#                                      data_choice_notes
# 645  Discarded 2007 Nuss number (6.7 g/day) in lieu...
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Madagascar

# %%
madagascar = format_value_d(gday[gday.location_name=="Madagascar"])
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
madagascar.vehicle.unique()
# Out:
# array(['wheat flour', 'maize flour', 'wheat(not specifically flour)'],
#       dtype=object)

# %%
madagascar_wheat = madagascar[(madagascar.vehicle=="wheat flour")]
madagascar_maize = madagascar[(madagascar.vehicle=="maize flour")]

# %%
madagascar_wheat[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean                                    source_citation  \
# 63        12.00  Fortification Handbook: Vitamin and Mineral Fo...
# 64        35.37                                               GFDx
# 587       19.00                                               GFDx
# 588       14.00                                               GFDx
# 589       13.00                                               GFDx
# 590       16.00                                               GFDx
# 591       17.00                                               GFDx
# 592       18.00                                               GFDx
# 593       19.00                                               GFDx
# 594       15.00                                               GFDx
# 595       20.00                                               GFDx
# 596       17.00                                               GFDx
# 597       20.00                                               GFDx
# 598       20.00                                               GFDx
# 599       25.00                                               GFDx
# 600       18.00                                               GFDx
# 601       16.00                                               GFDx
# 602       21.00                                               GFDx
# 603       23.00                                               GFDx
# 604       23.00                                               GFDx
# 605       25.00                                               GFDx
# 606       24.03                                               GFDx
# 607       26.41                                               GFDx
# 608       31.12                                               GFDx
#
#     source_year    sub_population                        source_type
# 63    1997-2000  total population  estimated from FAO balance sheets
# 64         2017  total population  estimated from FAO balance sheets
# 587        1995  total population  estimated from FAO balance sheets
# 588        1996  total population  estimated from FAO balance sheets
# 589        1997  total population  estimated from FAO balance sheets
# 590        1998  total population  estimated from FAO balance sheets
# 591        1999  total population  estimated from FAO balance sheets
# 592        2000  total population  estimated from FAO balance sheets
# 593        2001  total population  estimated from FAO balance sheets
# 594        2002  total population  estimated from FAO balance sheets
# 595        2003  total population  estimated from FAO balance sheets
# 596        2004  total population  estimated from FAO balance sheets
# 597        2005  total population  estimated from FAO balance sheets
# 598        2006  total population  estimated from FAO balance sheets
# 599        2007  total population  estimated from FAO balance sheets
# 600        2008  total population  estimated from FAO balance sheets
# 601        2009  total population  estimated from FAO balance sheets
# 602        2010  total population  estimated from FAO balance sheets
# 603        2011  total population  estimated from FAO balance sheets
# 604        2012  total population  estimated from FAO balance sheets
# 605        2013  total population  estimated from FAO balance sheets
# 606        2014  total population  estimated from FAO balance sheets
# 607        2015  total population  estimated from FAO balance sheets
# 608        2016  total population  estimated from FAO balance sheets

# %%
madagascar_wheat.loc[madagascar_wheat.source_year=="2017","data_choice_notes"] = "Discarded 1997-2000 fortification handbook number (12 g/day) in lieu of 2017 GFDx estimate (35 g/day). Both are FAO estimates."

output = output.append(
    madagascar_wheat.loc[madagascar_wheat.source_year=="2017"]
)

madagascar_wheat.loc[madagascar_wheat.source_year=="2017"]
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 64          181    Madagascar               na                      NaN
#
#     urbanicity      vehicle nutrient                    value_description  \
# 64  mixed/both  wheat flour       na  Mean per capita consumption (g/day)
#
#     value_mean  value_025_percentile  ...  scale_over_mean         r    lower  \
# 64       35.37                   NaN  ...              NaN  0.699893  22.9924
#
#       upper metric entity mass_unit time_unit     pop_denom  \
# 64  47.7476   mean  CHECK         g       day  capita CHECK
#
#                                     data_choice_notes
# 64  Discarded 1997-2000 fortification handbook num...
#
# [1 rows x 32 columns]

# %%
madagascar_maize[['value_mean','source_citation','source_year','sub_population','source_type']]
# Out:
#      value_mean source_citation source_year    sub_population  \
# 632       33.86            GFDx        2017  total population
# 966       30.00            GFDx        1995  total population
# 967       31.00            GFDx        1996  total population
# 968       28.00            GFDx        1997  total population
# 969       24.00            GFDx        1998  total population
# 970       27.00            GFDx        1999  total population
# 971       26.00            GFDx        2000  total population
# 972       27.00            GFDx        2001  total population
# 973       25.00            GFDx        2002  total population
# 974       46.00            GFDx        2003  total population
# 975       49.00            GFDx        2004  total population
# 976       52.00            GFDx        2005  total population
# 977       53.00            GFDx        2006  total population
# 978       53.00            GFDx        2007  total population
# 979       52.00            GFDx        2008  total population
# 980       51.00            GFDx        2009  total population
# 981       48.00            GFDx        2010  total population
# 982       49.00            GFDx        2011  total population
# 983       50.00            GFDx        2012  total population
# 984       49.00            GFDx        2013  total population
# 985       43.10            GFDx        2014  total population
# 986       38.85            GFDx        2015  total population
# 987       36.90            GFDx        2016  total population
#
#                            source_type
# 632  estimated from FAO balance sheets
# 966  estimated from FAO balance sheets
# 967  estimated from FAO balance sheets
# 968  estimated from FAO balance sheets
# 969  estimated from FAO balance sheets
# 970  estimated from FAO balance sheets
# 971  estimated from FAO balance sheets
# 972  estimated from FAO balance sheets
# 973  estimated from FAO balance sheets
# 974  estimated from FAO balance sheets
# 975  estimated from FAO balance sheets
# 976  estimated from FAO balance sheets
# 977  estimated from FAO balance sheets
# 978  estimated from FAO balance sheets
# 979  estimated from FAO balance sheets
# 980  estimated from FAO balance sheets
# 981  estimated from FAO balance sheets
# 982  estimated from FAO balance sheets
# 983  estimated from FAO balance sheets
# 984  estimated from FAO balance sheets
# 985  estimated from FAO balance sheets
# 986  estimated from FAO balance sheets
# 987  estimated from FAO balance sheets

# %%
madagascar_maize.loc[madagascar_maize.source_year=="2017","data_choice_notes"] = "Only one source."

output = output.append(
    madagascar_maize.loc[madagascar_maize.source_year=="2017"]
)

madagascar_maize.loc[madagascar_maize.source_year=="2017"]
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 632          181    Madagascar               na                      NaN
#
#      urbanicity      vehicle nutrient                    value_description  \
# 632  mixed/both  maize flour       na  Mean per capita consumption (g/day)
#
#      value_mean  value_025_percentile  ...  scale_over_mean         r  \
# 632       33.86                   NaN  ...              NaN  0.819483
#
#          lower      upper metric entity mass_unit time_unit     pop_denom  \
# 632  19.986146  47.733854   mean  CHECK         g       day  capita CHECK
#
#     data_choice_notes
# 632  Only one source.
#
# [1 rows x 32 columns]

# %% [markdown]
# # Format output

# %%
group_cols = ['location_id','location_name','sub_population','vehicle','metric','mass_unit','time_unit','pop_denom','source_citation','source_link','data_choice_notes']

# %%
loc_metadata = get_locs(location_set_id=35, gbd_round_id=6, decomp_step="step4")

# %%
loc_metadata = loc_metadata.loc[(loc_metadata.location_name.isin(location_names)) & (loc_metadata.level==3),['location_id','location_name']]

# %%
output = output.drop(columns = 'location_id')
output = loc_metadata.merge(output, on = 'location_name', how = 'right')

# %%
output[['location_id','location_name','vehicle','value_mean','value_description','definition validated', 'CI validated']]
# Out:
#     location_id location_name      vehicle  value_mean  \
# 0           141         Egypt  wheat flour      399.23
# 1           141         Egypt  maize flour      167.21
# 2           522         Sudan  wheat flour      123.45
# 3           522         Sudan  maize flour        5.40
# 4             6         China  wheat flour      171.92
# 5           168        Angola  wheat flour       89.32
# 6           168        Angola  maize flour      154.99
# 7           181    Madagascar  wheat flour       35.37
# 8           181    Madagascar  maize flour       33.86
# 9           207         Ghana  wheat flour       86.36
# 10          207         Ghana  maize flour       69.23
# 11          213         Niger  wheat flour       11.45
# 12          213         Niger  maize flour       10.63
#
#                       value_description definition validated CI validated
# 0   Mean per capita consumption (g/day)                  Yes          NaN
# 1   Mean per capita consumption (g/day)                  Yes          NaN
# 2   Mean per capita consumption (g/day)                  Yes          NaN
# 3   Mean per capita consumption (g/day)                  Yes          NaN
# 4   Mean per capita consumption (g/day)                  Yes          NaN
# 5   Mean per capita consumption (g/day)                  Yes          NaN
# 6   Mean per capita consumption (g/day)                  Yes          NaN
# 7   Mean per capita consumption (g/day)                  Yes          NaN
# 8   Mean per capita consumption (g/day)                  Yes          NaN
# 9   Mean per capita consumption (g/day)                  Yes          NaN
# 10  Mean per capita consumption (g/day)                  Yes          NaN
# 11  Mean per capita consumption (g/day)                  Yes          NaN
# 12  Mean per capita consumption (g/day)                  Yes          NaN

# %%
metric_map = {
    'mean':'mean',
    'CHECK':'mean'
}

pop_denom_map = {
    'capita':'capita',
    'CHECK':'capita',
    'capita CHECK':'capita',
    'consumers':'consumers'
}

output.metric = output.metric.map(metric_map)
output.pop_denom = output.pop_denom.map(pop_denom_map)

# %%
output[['value_mean'] + group_cols]
# Out:
#     value_mean  location_id location_name    sub_population      vehicle  \
# 0       399.23          141         Egypt  total population  wheat flour
# 1       167.21          141         Egypt  total population  maize flour
# 2       123.45          522         Sudan  total population  wheat flour
# 3         5.40          522         Sudan  total population  maize flour
# 4       171.92            6         China  total population  wheat flour
# 5        89.32          168        Angola  total population  wheat flour
# 6       154.99          168        Angola  total population  maize flour
# 7        35.37          181    Madagascar  total population  wheat flour
# 8        33.86          181    Madagascar  total population  maize flour
# 9        86.36          207         Ghana  total population  wheat flour
# 10       69.23          207         Ghana  total population  maize flour
# 11       11.45          213         Niger  total population  wheat flour
# 12       10.63          213         Niger  total population  maize flour
#
#    metric mass_unit time_unit pop_denom source_citation  \
# 0    mean         g       day    capita            GFDx
# 1    mean         g       day    capita            GFDx
# 2    mean         g       day    capita            GFDx
# 3    mean         g       day    capita            GFDx
# 4    mean         g       day    capita            GFDx
# 5    mean         g       day    capita            GFDx
# 6    mean         g       day    capita            GFDx
# 7    mean         g       day    capita            GFDx
# 8    mean         g       day    capita            GFDx
# 9    mean         g       day    capita            GFDx
# 10   mean         g       day    capita            GFDx
# 11   mean         g       day    capita            GFDx
# 12   mean         g       day    capita            GFDx
#
#                                           source_link  \
# 0   https://fortificationdata.org/country-fortific...
# 1   https://fortificationdata.org/country-fortific...
# 2   https://fortificationdata.org/country-fortific...
# 3   https://fortificationdata.org/country-fortific...
# 4   https://fortificationdata.org/country-fortific...
# 5   https://fortificationdata.org/country-fortific...
# 6   https://fortificationdata.org/country-fortific...
# 7   https://fortificationdata.org/country-fortific...
# 8   https://fortificationdata.org/country-fortific...
# 9   https://fortificationdata.org/country-fortific...
# 10  https://fortificationdata.org/country-fortific...
# 11  https://fortificationdata.org/country-fortific...
# 12  https://fortificationdata.org/country-fortific...
#
#                                     data_choice_notes
# 0   Discarded 1997-2000 fortification handbook num...
# 1   Discarded 1997-2000 fortification handbook num...
# 2   Discarded 1997-2000 fortification handbook num...
# 3   Discarded 2007 Nuss number (6.7 g/day) in lieu...
# 4   Discarded earlier FAO estimates for 2017 GFDx ...
# 5   Discarded 1997-2000 fortification handbook (49...
# 6   Discarded 1997-2000 fortification handbook num...
# 7   Discarded 1997-2000 fortification handbook num...
# 8                                    Only one source.
# 9   Discarded 2017 1997-2000 fortification handboo...
# 10  Discarded 1997-2000 number (81 g/day) and 2007...
# 11  Discarded 2017 1997-2000 fortification handboo...
# 12  Discarded 2007 Nuss number (8 g/day) in lieu o...

# %%
output.loc[(output.mass_unit=="kg"),'value_mean'] = output.value_mean * 1_000

output.loc[(output.mass_unit=="kg"),'lower'] = output.lower * 1_000
output.loc[(output.mass_unit=="kg"),'upper'] = output.upper * 1_000

output.loc[(output.mass_unit=="kg"),'value_025_percentile'] = output.value_025_percentile * 1_000
output.loc[(output.mass_unit=="kg"),'value_975_percentile'] = output.value_975_percentile * 1_000

output.loc[(output.mass_unit=="kg"),'mass_unit'] = 'g'

# %%
output.loc[(output.time_unit=="year"),'value_mean'] = output.value_mean / 365

output.loc[(output.time_unit=="year"),'lower'] = output.lower / 365
output.loc[(output.time_unit=="year"),'upper'] = output.upper / 365

output.loc[(output.time_unit=="year"),'value_025_percentile'] = output.value_025_percentile / 365
output.loc[(output.time_unit=="year"),'value_975_percentile'] = output.value_975_percentile / 365

output.loc[(output.time_unit=="year"),'time_unit'] = 'day'

# %%
output[['value_mean'] + group_cols]
# Out:
#     value_mean  location_id location_name    sub_population      vehicle  \
# 0       399.23          141         Egypt  total population  wheat flour
# 1       167.21          141         Egypt  total population  maize flour
# 2       123.45          522         Sudan  total population  wheat flour
# 3         5.40          522         Sudan  total population  maize flour
# 4       171.92            6         China  total population  wheat flour
# 5        89.32          168        Angola  total population  wheat flour
# 6       154.99          168        Angola  total population  maize flour
# 7        35.37          181    Madagascar  total population  wheat flour
# 8        33.86          181    Madagascar  total population  maize flour
# 9        86.36          207         Ghana  total population  wheat flour
# 10       69.23          207         Ghana  total population  maize flour
# 11       11.45          213         Niger  total population  wheat flour
# 12       10.63          213         Niger  total population  maize flour
#
#    metric mass_unit time_unit pop_denom source_citation  \
# 0    mean         g       day    capita            GFDx
# 1    mean         g       day    capita            GFDx
# 2    mean         g       day    capita            GFDx
# 3    mean         g       day    capita            GFDx
# 4    mean         g       day    capita            GFDx
# 5    mean         g       day    capita            GFDx
# 6    mean         g       day    capita            GFDx
# 7    mean         g       day    capita            GFDx
# 8    mean         g       day    capita            GFDx
# 9    mean         g       day    capita            GFDx
# 10   mean         g       day    capita            GFDx
# 11   mean         g       day    capita            GFDx
# 12   mean         g       day    capita            GFDx
#
#                                           source_link  \
# 0   https://fortificationdata.org/country-fortific...
# 1   https://fortificationdata.org/country-fortific...
# 2   https://fortificationdata.org/country-fortific...
# 3   https://fortificationdata.org/country-fortific...
# 4   https://fortificationdata.org/country-fortific...
# 5   https://fortificationdata.org/country-fortific...
# 6   https://fortificationdata.org/country-fortific...
# 7   https://fortificationdata.org/country-fortific...
# 8   https://fortificationdata.org/country-fortific...
# 9   https://fortificationdata.org/country-fortific...
# 10  https://fortificationdata.org/country-fortific...
# 11  https://fortificationdata.org/country-fortific...
# 12  https://fortificationdata.org/country-fortific...
#
#                                     data_choice_notes
# 0   Discarded 1997-2000 fortification handbook num...
# 1   Discarded 1997-2000 fortification handbook num...
# 2   Discarded 1997-2000 fortification handbook num...
# 3   Discarded 2007 Nuss number (6.7 g/day) in lieu...
# 4   Discarded earlier FAO estimates for 2017 GFDx ...
# 5   Discarded 1997-2000 fortification handbook (49...
# 6   Discarded 1997-2000 fortification handbook num...
# 7   Discarded 1997-2000 fortification handbook num...
# 8                                    Only one source.
# 9   Discarded 2017 1997-2000 fortification handboo...
# 10  Discarded 1997-2000 number (81 g/day) and 2007...
# 11  Discarded 2017 1997-2000 fortification handboo...
# 12  Discarded 2007 Nuss number (8 g/day) in lieu o...

# %%
output[['value_mean','lower','upper'] + group_cols]
# Out:
#     value_mean       lower       upper  location_id location_name  \
# 0       399.23  259.520941  538.939059          141         Egypt
# 1       167.21   98.697088  235.722912          141         Egypt
# 2       123.45   80.249130  166.650870          522         Sudan
# 3         5.40    3.187395    7.612605          522         Sudan
# 4       171.92  111.757233  232.082767            6         China
# 5        89.32   58.062797  120.577203          168        Angola
# 6       154.99   91.484132  218.495868          168        Angola
# 7        35.37   22.992400   47.747600          181    Madagascar
# 8        33.86   19.986146   47.733854          181    Madagascar
# 9        86.36   56.138638  116.581362          207         Ghana
# 10       69.23   40.863581   97.596419          207         Ghana
# 11       11.45    7.443115   15.456885          213         Niger
# 12       10.63    6.274446   14.985554          213         Niger
#
#       sub_population      vehicle metric mass_unit time_unit pop_denom  \
# 0   total population  wheat flour   mean         g       day    capita
# 1   total population  maize flour   mean         g       day    capita
# 2   total population  wheat flour   mean         g       day    capita
# 3   total population  maize flour   mean         g       day    capita
# 4   total population  wheat flour   mean         g       day    capita
# 5   total population  wheat flour   mean         g       day    capita
# 6   total population  maize flour   mean         g       day    capita
# 7   total population  wheat flour   mean         g       day    capita
# 8   total population  maize flour   mean         g       day    capita
# 9   total population  wheat flour   mean         g       day    capita
# 10  total population  maize flour   mean         g       day    capita
# 11  total population  wheat flour   mean         g       day    capita
# 12  total population  maize flour   mean         g       day    capita
#
#    source_citation                                        source_link  \
# 0             GFDx  https://fortificationdata.org/country-fortific...
# 1             GFDx  https://fortificationdata.org/country-fortific...
# 2             GFDx  https://fortificationdata.org/country-fortific...
# 3             GFDx  https://fortificationdata.org/country-fortific...
# 4             GFDx  https://fortificationdata.org/country-fortific...
# 5             GFDx  https://fortificationdata.org/country-fortific...
# 6             GFDx  https://fortificationdata.org/country-fortific...
# 7             GFDx  https://fortificationdata.org/country-fortific...
# 8             GFDx  https://fortificationdata.org/country-fortific...
# 9             GFDx  https://fortificationdata.org/country-fortific...
# 10            GFDx  https://fortificationdata.org/country-fortific...
# 11            GFDx  https://fortificationdata.org/country-fortific...
# 12            GFDx  https://fortificationdata.org/country-fortific...
#
#                                     data_choice_notes
# 0   Discarded 1997-2000 fortification handbook num...
# 1   Discarded 1997-2000 fortification handbook num...
# 2   Discarded 1997-2000 fortification handbook num...
# 3   Discarded 2007 Nuss number (6.7 g/day) in lieu...
# 4   Discarded earlier FAO estimates for 2017 GFDx ...
# 5   Discarded 1997-2000 fortification handbook (49...
# 6   Discarded 1997-2000 fortification handbook num...
# 7   Discarded 1997-2000 fortification handbook num...
# 8                                    Only one source.
# 9   Discarded 2017 1997-2000 fortification handboo...
# 10  Discarded 1997-2000 number (81 g/day) and 2007...
# 11  Discarded 2017 1997-2000 fortification handboo...
# 12  Discarded 2007 Nuss number (8 g/day) in lieu o...

# %%
output = output.rename(columns = {
    'source_citation':'mean_value_source_citation',
    'source_link':'mean_value_source_link'
})

# %%
assert(len(output[output.value_mean >= output.upper])==0), "check upper"
assert(len(output[output.value_mean <= output.lower])==0), "check lower"

# %% [markdown]
# # check for missing values

# %%
output.loc[(output.location_name=="Vietnam"),'location_name'] = "Viet Nam"

# %%
## load legal combos
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_vehicle_country_pairs.pickle', 'rb') as handle:
    vehicle_country_map = pickle.load(handle)

# %%
target_vehicles = [i for i in vehicle_nutrient_map.keys() if 'iron' in vehicle_nutrient_map[i]]
set([i for j in location_names for i in country_vehicle_map[j]])
# Out:
# {'bouillon', 'maize flour', 'oil', 'rice', 'wheat flour'}

# %%
# make sure nothing missing. note we're not interested in oil/iron
output.reset_index().merge(target.reset_index(), on = ['location_name','vehicle'], how = 'outer')
# Out:
#     index  location_id location_name subnational_name  \
# 0     0.0        141.0         Egypt               na
# 1     1.0        141.0         Egypt               na
# 2     2.0        522.0         Sudan               na
# 3     3.0        522.0         Sudan               na
# 4     4.0          6.0         China               na
# 5     5.0        168.0        Angola               na
# 6     6.0        168.0        Angola               na
# 7     7.0        181.0    Madagascar               na
# 8     8.0        181.0    Madagascar               na
# 9     9.0        207.0         Ghana               na
# 10   10.0        207.0         Ghana               na
# 11   11.0        213.0         Niger               na
# 12   12.0        213.0         Niger               na
# 13    NaN          NaN        Angola              NaN
# 14    NaN          NaN         China              NaN
# 15    NaN          NaN         Egypt              NaN
# 16    NaN          NaN         Ghana              NaN
# 17    NaN          NaN         Ghana              NaN
# 18    NaN          NaN         Ghana              NaN
# 19    NaN          NaN    Madagascar              NaN
# 20    NaN          NaN         Niger              NaN
# 21    NaN          NaN         Niger              NaN
# 22    NaN          NaN         Sudan              NaN
#
#     subnational_location_id  urbanicity      vehicle nutrient  \
# 0                       NaN     unknown  wheat flour       na
# 1                       NaN     unknown  maize flour       na
# 2                       NaN  mixed/both  wheat flour       na
# 3                       NaN  mixed/both  maize flour       na
# 4                       NaN  mixed/both  wheat flour       na
# 5                       NaN  mixed/both  wheat flour       na
# 6                       NaN  mixed/both  maize flour       na
# 7                       NaN  mixed/both  wheat flour       na
# 8                       NaN  mixed/both  maize flour       na
# 9                       NaN  mixed/both  wheat flour       na
# 10                      NaN  mixed/both  maize flour       na
# 11                      NaN     unknown  wheat flour       na
# 12                      NaN     unknown  maize flour       na
# 13                      NaN         NaN          oil      NaN
# 14                      NaN         NaN          oil      NaN
# 15                      NaN         NaN          oil      NaN
# 16                      NaN         NaN     bouillon      NaN
# 17                      NaN         NaN          oil      NaN
# 18                      NaN         NaN         rice      NaN
# 19                      NaN         NaN          oil      NaN
# 20                      NaN         NaN     bouillon      NaN
# 21                      NaN         NaN          oil      NaN
# 22                      NaN         NaN          oil      NaN
#
#                       value_description  value_mean  ...  scale_over_mean  \
# 0   Mean per capita consumption (g/day)      399.23  ...              NaN
# 1   Mean per capita consumption (g/day)      167.21  ...              NaN
# 2   Mean per capita consumption (g/day)      123.45  ...              NaN
# 3   Mean per capita consumption (g/day)        5.40  ...              NaN
# 4   Mean per capita consumption (g/day)      171.92  ...              NaN
# 5   Mean per capita consumption (g/day)       89.32  ...              NaN
# 6   Mean per capita consumption (g/day)      154.99  ...              NaN
# 7   Mean per capita consumption (g/day)       35.37  ...              NaN
# 8   Mean per capita consumption (g/day)       33.86  ...              NaN
# 9   Mean per capita consumption (g/day)       86.36  ...              NaN
# 10  Mean per capita consumption (g/day)       69.23  ...              NaN
# 11  Mean per capita consumption (g/day)       11.45  ...              NaN
# 12  Mean per capita consumption (g/day)       10.63  ...              NaN
# 13                                  NaN         NaN  ...              NaN
# 14                                  NaN         NaN  ...              NaN
# 15                                  NaN         NaN  ...              NaN
# 16                                  NaN         NaN  ...              NaN
# 17                                  NaN         NaN  ...              NaN
# 18                                  NaN         NaN  ...              NaN
# 19                                  NaN         NaN  ...              NaN
# 20                                  NaN         NaN  ...              NaN
# 21                                  NaN         NaN  ...              NaN
# 22                                  NaN         NaN  ...              NaN
#
#            r       lower       upper metric entity mass_unit time_unit  \
# 0   0.699893  259.520941  538.939059   mean  CHECK         g       day
# 1   0.819483   98.697088  235.722912   mean  CHECK         g       day
# 2   0.699893   80.249130  166.650870   mean  CHECK         g       day
# 3   0.819483    3.187395    7.612605   mean  CHECK         g       day
# 4   0.699893  111.757233  232.082767   mean  CHECK         g       day
# 5   0.699893   58.062797  120.577203   mean  CHECK         g       day
# 6   0.819483   91.484132  218.495868   mean  CHECK         g       day
# 7   0.699893   22.992400   47.747600   mean  CHECK         g       day
# 8   0.819483   19.986146   47.733854   mean  CHECK         g       day
# 9   0.699893   56.138638  116.581362   mean  CHECK         g       day
# 10  0.819483   40.863581   97.596419   mean  CHECK         g       day
# 11  0.699893    7.443115   15.456885   mean  CHECK         g       day
# 12  0.819483    6.274446   14.985554   mean  CHECK         g       day
# 13       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 14       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 15       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 16       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 17       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 18       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 19       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 20       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 21       NaN         NaN         NaN    NaN    NaN       NaN       NaN
# 22       NaN         NaN         NaN    NaN    NaN       NaN       NaN
#
#    pop_denom                                  data_choice_notes
# 0     capita  Discarded 1997-2000 fortification handbook num...
# 1     capita  Discarded 1997-2000 fortification handbook num...
# 2     capita  Discarded 1997-2000 fortification handbook num...
# 3     capita  Discarded 2007 Nuss number (6.7 g/day) in lieu...
# 4     capita  Discarded earlier FAO estimates for 2017 GFDx ...
# 5     capita  Discarded 1997-2000 fortification handbook (49...
# 6     capita  Discarded 1997-2000 fortification handbook num...
# 7     capita  Discarded 1997-2000 fortification handbook num...
# 8     capita                                   Only one source.
# 9     capita  Discarded 2017 1997-2000 fortification handboo...
# 10    capita  Discarded 1997-2000 number (81 g/day) and 2007...
# 11    capita  Discarded 2017 1997-2000 fortification handboo...
# 12    capita  Discarded 2007 Nuss number (8 g/day) in lieu o...
# 13       NaN                                                NaN
# 14       NaN                                                NaN
# 15       NaN                                                NaN
# 16       NaN                                                NaN
# 17       NaN                                                NaN
# 18       NaN                                                NaN
# 19       NaN                                                NaN
# 20       NaN                                                NaN
# 21       NaN                                                NaN
# 22       NaN                                                NaN
#
# [23 rows x 33 columns]

# %%
#reorder columns
output = output[['location_id', 'location_name', 'sub_population', 'vehicle', 'metric',
       'mass_unit', 'time_unit', 'pop_denom','value_mean', 'lower',
       'upper', 'mean_value_source_citation',
       'mean_value_source_link', 'data_choice_notes']]

# %%
output
# Out:
#     location_id location_name    sub_population      vehicle metric mass_unit  \
# 0           141         Egypt  total population  wheat flour   mean         g
# 1           141         Egypt  total population  maize flour   mean         g
# 2           522         Sudan  total population  wheat flour   mean         g
# 3           522         Sudan  total population  maize flour   mean         g
# 4             6         China  total population  wheat flour   mean         g
# 5           168        Angola  total population  wheat flour   mean         g
# 6           168        Angola  total population  maize flour   mean         g
# 7           181    Madagascar  total population  wheat flour   mean         g
# 8           181    Madagascar  total population  maize flour   mean         g
# 9           207         Ghana  total population  wheat flour   mean         g
# 10          207         Ghana  total population  maize flour   mean         g
# 11          213         Niger  total population  wheat flour   mean         g
# 12          213         Niger  total population  maize flour   mean         g
#
#    time_unit pop_denom  value_mean       lower       upper  \
# 0        day    capita      399.23  259.520941  538.939059
# 1        day    capita      167.21   98.697088  235.722912
# 2        day    capita      123.45   80.249130  166.650870
# 3        day    capita        5.40    3.187395    7.612605
# 4        day    capita      171.92  111.757233  232.082767
# 5        day    capita       89.32   58.062797  120.577203
# 6        day    capita      154.99   91.484132  218.495868
# 7        day    capita       35.37   22.992400   47.747600
# 8        day    capita       33.86   19.986146   47.733854
# 9        day    capita       86.36   56.138638  116.581362
# 10       day    capita       69.23   40.863581   97.596419
# 11       day    capita       11.45    7.443115   15.456885
# 12       day    capita       10.63    6.274446   14.985554
#
#    mean_value_source_citation  \
# 0                        GFDx
# 1                        GFDx
# 2                        GFDx
# 3                        GFDx
# 4                        GFDx
# 5                        GFDx
# 6                        GFDx
# 7                        GFDx
# 8                        GFDx
# 9                        GFDx
# 10                       GFDx
# 11                       GFDx
# 12                       GFDx
#
#                                mean_value_source_link  \
# 0   https://fortificationdata.org/country-fortific...
# 1   https://fortificationdata.org/country-fortific...
# 2   https://fortificationdata.org/country-fortific...
# 3   https://fortificationdata.org/country-fortific...
# 4   https://fortificationdata.org/country-fortific...
# 5   https://fortificationdata.org/country-fortific...
# 6   https://fortificationdata.org/country-fortific...
# 7   https://fortificationdata.org/country-fortific...
# 8   https://fortificationdata.org/country-fortific...
# 9   https://fortificationdata.org/country-fortific...
# 10  https://fortificationdata.org/country-fortific...
# 11  https://fortificationdata.org/country-fortific...
# 12  https://fortificationdata.org/country-fortific...
#
#                                     data_choice_notes
# 0   Discarded 1997-2000 fortification handbook num...
# 1   Discarded 1997-2000 fortification handbook num...
# 2   Discarded 1997-2000 fortification handbook num...
# 3   Discarded 2007 Nuss number (6.7 g/day) in lieu...
# 4   Discarded earlier FAO estimates for 2017 GFDx ...
# 5   Discarded 1997-2000 fortification handbook (49...
# 6   Discarded 1997-2000 fortification handbook num...
# 7   Discarded 1997-2000 fortification handbook num...
# 8                                    Only one source.
# 9   Discarded 2017 1997-2000 fortification handboo...
# 10  Discarded 1997-2000 number (81 g/day) and 2007...
# 11  Discarded 2017 1997-2000 fortification handboo...
# 12  Discarded 2007 Nuss number (8 g/day) in lieu o...

# %%
output = output.sort_values(['location_name','vehicle'])

# %%
save_path = '/ihme/homes/beatrixh/vivarium_research_lsff/data_prep/outputs/gday_tier5_04_02_2021.csv'
output.to_csv(save_path, index = False)

# %%
save_path = '/ihme/homes/beatrixh/repos/scratch/gday_tier5_04_02_2021.csv'
output.to_csv(save_path, index = False)
