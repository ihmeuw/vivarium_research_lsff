# %%
import pandas as pd, numpy as np
from tqdm import tqdm

import data_processing
import lbwsg_boe
import iron_bw_calc_industry
# import lbwsg
# import lsff_interventions
# import demography

# !date
# !whoami
# !pwd
# Out:
# Wed Apr 14 23:33:24 PDT 2021
# ndbs
# /ihme/homes/ndbs/vivarium_research_lsff/nanosim_models

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Check what the new "industry wheat" coverage data looks like

# %%
# !ls results_industry/
# Out:
# lsff_input_coverage_data_w_industry_oil_wheat_v3_04_14_2021.csv
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
industry_coverage = pd.read_csv(
    'results_industry/lsff_input_coverage_data_w_industry_oil_wheat_v3_04_14_2021.csv', index_col=0)
industry_coverage.head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    location_id location_name sub_population      vehicle  \
# 0          179      Ethiopia            NaN  maize flour
# 1          179      Ethiopia            NaN  maize flour
# 2          179      Ethiopia            NaN  maize flour
# 3          179      Ethiopia            NaN  maize flour
# 4          179      Ethiopia            NaN  maize flour
#
#                                    value_description    nutrient  value_mean  \
# 0               percent of population eating vehicle          na   59.263848
# 1  percent of population eating industrially prod...          na   27.167514
# 2     percent of population eating fortified vehicle  folic acid    0.000000
# 3     percent of population eating fortified vehicle        iron    0.000000
# 4     percent of population eating fortified vehicle   vitamin a    0.000000
#
#    value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 0             24.950317             93.577380           True            True
# 1             11.437632             42.897396           True            True
# 2              0.000000              0.000000           True            True
# 3              0.000000              0.000000           True            True
# 4              0.000000              0.000000           True            True

# %%
industry_coverage.vehicle.unique()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['maize flour', 'oil', 'wheat flour', 'industry wheat',
#        'industry oil'], dtype=object)

# %%
industry_coverage.query("vehicle == 'industry wheat'")
# Out:
#      location_id  location_name sub_population         vehicle  \
# 0            168         Angola            NaN  industry wheat
# 1            161     Bangladesh            NaN  industry wheat
# 2            201   Burkina Faso            NaN  industry wheat
# 3            205  Côte d'Ivoire            NaN  industry wheat
# 4            202       Cameroon            NaN  industry wheat
# ..           ...            ...            ...             ...
# 120          213          Niger            NaN  industry wheat
# 121          522          Sudan            NaN  industry wheat
# 122          522          Sudan            NaN  industry wheat
# 123          522          Sudan            NaN  industry wheat
# 124          522          Sudan            NaN  industry wheat
#
#                                      value_description    nutrient  \
# 0    percent of population eating industrially prod...          na
# 1    percent of population eating industrially prod...          na
# 2    percent of population eating industrially prod...          na
# 3    percent of population eating industrially prod...          na
# 4    percent of population eating industrially prod...          na
# ..                                                 ...         ...
# 120     percent of population eating fortified vehicle        zinc
# 121     percent of population eating fortified vehicle  folic acid
# 122     percent of population eating fortified vehicle        iron
# 123     percent of population eating fortified vehicle   vitamin a
# 124     percent of population eating fortified vehicle        zinc
#
#      value_mean  value_025_percentile  value_975_percentile  u5_applicable  \
# 0     27.200000             17.834510             36.565490           True
# 1     33.101000             21.703681             44.498319           True
# 2     48.000000             31.472665             64.527335           True
# 3     90.160000             59.116156            100.000000           True
# 4     65.440000             42.907733             87.972267           True
# ..          ...                   ...                   ...            ...
# 120   30.000000             14.760180             45.239820           True
# 121    6.525113              3.210395              9.839831           True
# 122    6.525113              3.210395              9.839831           True
# 123    6.525113              3.210395              9.839831           True
# 124    6.525113              3.210395              9.839831           True
#
#      wra_applicable
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ..              ...
# 120            True
# 121            True
# 122            True
# 123            True
# 124            True
#
# [125 rows x 11 columns]

# %%
industry_coverage.query("vehicle == 'industry wheat'").value_description.unique()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['percent of population eating industrially produced vehicle',
#        'percent of population eating fortified vehicle'], dtype=object)

# %%
input_data = data_processing.get_fortification_input_data()
input_data.consumption.head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    location_id    sub_population      vehicle metric mass_unit time_unit  \
# 0          163  total population  wheat flour   mean         g       day
# 1          179  total population  maize flour   mean         g       day
# 2          179  total population  wheat flour   mean         g       day
# 3          214  total population  maize flour   mean         g       day
# 4          214  total population  wheat flour   mean         g       day
#
#   pop_denom  value_mean_gday       lower       upper location_name  \
# 0    capita           169.62  113.134860  226.105140         India
# 1    capita           113.84   68.762191  158.917809      Ethiopia
# 2    capita            97.64   65.124913  130.155087      Ethiopia
# 3    capita            95.10   57.442765  132.757235       Nigeria
# 4    capita            49.15   32.782563   65.517437       Nigeria
#
#    value_mean_coverage  value_025_percentile  value_975_percentile
# 0            83.200000             79.500000             86.500000
# 1            59.263848             24.950317             93.577380
# 2            28.000000             13.776168             42.223832
# 3            57.415462             54.867114             60.033478
# 4            62.759594             60.359594             65.129264

# %% [markdown]
# # Write a function to add a new "industry wheat" vehicle in the `consumption` and `concentration` input dataframes, to match the `coverage` data
#
# All I need to do is copy the "wheat flour" data, since the consumption patterns and iron concentration won't change for industry wheat.
#
# Note that the "Percent of population eating vehicle" also didn't change for industry wheat, so when this data gets merged into the consumption dataframe from the wheat flour coverage data, I don't need to worry about changing that either, just copy it.

# %%
def append_duplicate_vehicle_data(df, vehicle, duplicated_vehicle_name):
    vehicle_df = df.query("vehicle == @vehicle").assign(vehicle=duplicated_vehicle_name)
    return pd.concat([df, vehicle_df], ignore_index=True)
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(input_data.consumption.shape)
print(input_data.consumption.query("vehicle=='wheat flour'").shape)
# Out:
# (42, 14)
# (25, 14)

# %%
df = append_duplicate_vehicle_data(
    input_data.consumption, 'wheat flour', 'industry wheat')
df.shape
# Out:
# (67, 14)

# %%
df.query("vehicle == 'industry wheat'")
# Out:
#     location_id             sub_population         vehicle  metric mass_unit  \
# 42          163           total population  industry wheat    mean         g
# 43          179           total population  industry wheat    mean         g
# 44          214           total population  industry wheat    mean         g
# 45          161  women of reproductive age  industry wheat    mean         g
# 46          165  women of reproductive age  industry wheat    mean         g
# 47          189           total population  industry wheat    mean         g
# 48          190           total population  industry wheat    mean         g
# 49          196           total population  industry wheat    mean         g
# 50          201           total population  industry wheat    mean         g
# 51          180           total population  industry wheat    mean         g
# 52           15           total population  industry wheat    mean         g
# 53          164           total population  industry wheat    mean         g
# 54           20           total population  industry wheat    mean         g
# 55          202  women of reproductive age  industry wheat  median         g
# 56          205           total population  industry wheat    mean         g
# 57          171           total population  industry wheat    mean         g
# 58           11           total population  industry wheat    mean         g
# 59          184           total population  industry wheat    mean         g
# 60          168           total population  industry wheat    mean         g
# 61            6           total population  industry wheat    mean         g
# 62          141           total population  industry wheat    mean         g
# 63          207           total population  industry wheat    mean         g
# 64          181           total population  industry wheat    mean         g
# 65          213           total population  industry wheat    mean         g
# 66          522           total population  industry wheat    mean         g
#
#    time_unit  pop_denom  value_mean_gday       lower       upper  \
# 42       day     capita        169.62000  113.134860  226.105140
# 43       day     capita         97.64000   65.124913  130.155087
# 44       day     capita         49.15000   32.782563   65.517437
# 45       day     capita         77.90000   51.958528  103.841472
# 46       day     capita         86.17526   57.478045  114.872475
# 47       day     capita         32.96000   21.983994   43.936006
# 48       day     capita         30.27000   20.189790   40.350210
# 49       day     capita        156.36000  104.290571  208.429429
# 50       day     capita         37.64000   24.468022   50.811978
# 51       day     capita        100.11000   65.076877  135.143123
# 52       day     capita         29.92000   19.449607   40.390393
# 53       day  consumers          5.70000    3.705306    7.694694
# 54       day     capita         30.36000   19.735631   40.984369
# 55       day  consumers         79.00000   51.354243  106.645757
# 56       day     capita         70.08000   45.555764   94.604236
# 57       day     capita         34.00000   22.101826   45.898174
# 58       day     capita         73.59000   47.837452   99.342548
# 59       day     capita         65.92000   42.851540   88.988460
# 60       day     capita         89.32000   58.062797  120.577203
# 61       day     capita        171.92000  111.757233  232.082767
# 62       day     capita        399.23000  259.520941  538.939059
# 63       day     capita         86.36000   56.138638  116.581362
# 64       day     capita         35.37000   22.992400   47.747600
# 65       day     capita         11.45000    7.443115   15.456885
# 66       day     capita        123.45000   80.249130  166.650870
#
#                        location_name  value_mean_coverage  \
# 42                             India            83.200000
# 43                          Ethiopia            28.000000
# 44                           Nigeria            62.759594
# 45                        Bangladesh            41.900000
# 46                          Pakistan            99.999980
# 47       United Republic of Tanzania            51.500000
# 48                            Uganda            11.200000
# 49                      South Africa            10.917484
# 50                      Burkina Faso            48.000000
# 51                             Kenya            36.580000
# 52                           Myanmar             5.000000
# 53                             Nepal            52.100000
# 54                          Viet Nam            38.800000
# 55                          Cameroon            92.000000
# 56                     Côte d'Ivoire            54.700000
# 57  Democratic Republic of the Congo             0.580000
# 58                         Indonesia            75.761649
# 59                        Mozambique            16.300000
# 60                            Angola            27.171970
# 61                             China            81.832190
# 62                             Egypt            88.484772
# 63                             Ghana            82.658625
# 64                        Madagascar            45.179608
# 65                             Niger            41.424994
# 66                             Sudan            88.823684
#
#     value_025_percentile  value_975_percentile
# 42             79.500000             86.500000
# 43             13.776168             42.223832
# 44             60.359594             65.129264
# 45             31.257526             52.542474
# 46             99.999970             99.999990
# 47             44.500000             58.500000
# 48              7.700000             14.700000
# 49              6.391078             15.990590
# 50             21.097889             74.902111
# 51             16.078349             57.081651
# 52              0.000010             10.000000
# 53             45.800000             58.400000
# 54             17.054127             60.545873
# 55             90.000000             94.000000
# 56             50.100000             59.600000
# 57              0.000010              1.400000
# 58             37.275186             99.999990
# 59             11.047294             21.552706
# 60             13.368772             40.975168
# 61             40.261928             99.999990
# 62             43.535039             99.999990
# 63             40.668539             99.999990
# 64             22.228638             68.130578
# 65             20.381346             62.468643
# 66             43.701786             99.999990

# %%
input_data.concentration
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           Country Food Vehicle  Indicator Value  NaFeEDTA  location_id  \
# 0      Bangladesh  Wheat flour           55.000     False          161
# 1    Burkina Faso  Wheat flour           60.000     False          201
# 2        Cameroon  Wheat flour           60.000     False          202
# 3           China  Wheat flour           20.000      True            6
# 4   Cote d'Ivoire  Wheat flour           30.000     False          205
# 5        Ethiopia  Wheat flour           30.000      True          179
# 6           Ghana  Wheat flour           58.500     False          207
# 7           India  Wheat flour           17.625      True          163
# 8       Indonesia  Wheat flour           50.000     False           11
# 9           Kenya  Wheat flour           40.000      True          180
# 10     Mozambique  Wheat flour           20.000      True          184
# 11          Nepal  Wheat flour           60.000     False          164
# 12          Niger  Wheat flour           60.000     False          213
# 13        Nigeria  Wheat flour           40.000      True          214
# 14   South Africa  Wheat flour           35.000     False          196
# 15       Tanzania  Wheat flour           40.000      True          189
# 16         Uganda  Wheat flour           30.000      True          190
# 17       Viet Nam  Wheat flour           39.700     False           20
# 18          Kenya  Maize flour           10.000      True          180
# 19     Mozambique  Maize flour           20.000      True          184
# 20        Nigeria  Maize flour           40.000      True          214
# 21   South Africa  Maize flour           35.000     False          196
# 22       Tanzania  Maize flour           15.000      True          189
# 23         Uganda  Maize flour           15.000      True          190
#
#                   location_name      vehicle      value
# 0                    Bangladesh  wheat flour  32.146239
# 1                  Burkina Faso  wheat flour  35.068625
# 2                      Cameroon  wheat flour  35.068625
# 3                         China  wheat flour  20.000000
# 4                 Côte d'Ivoire  wheat flour  17.534312
# 5                      Ethiopia  wheat flour  30.000000
# 6                         Ghana  wheat flour  34.191909
# 7                         India  wheat flour  17.625000
# 8                     Indonesia  wheat flour  29.223854
# 9                         Kenya  wheat flour  40.000000
# 10                   Mozambique  wheat flour  20.000000
# 11                        Nepal  wheat flour  35.068625
# 12                        Niger  wheat flour  35.068625
# 13                      Nigeria  wheat flour  40.000000
# 14                 South Africa  wheat flour  20.456698
# 15  United Republic of Tanzania  wheat flour  40.000000
# 16                       Uganda  wheat flour  30.000000
# 17                     Viet Nam  wheat flour  23.203740
# 18                        Kenya  maize flour  10.000000
# 19                   Mozambique  maize flour  20.000000
# 20                      Nigeria  maize flour  40.000000
# 21                 South Africa  maize flour  20.000000
# 22  United Republic of Tanzania  maize flour  15.000000
# 23                       Uganda  maize flour  15.000000

# %%
df2 = append_duplicate_vehicle_data(
    input_data.concentration, 'wheat flour', 'industry wheat')
df2.shape
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (42, 8)

# %%
df2
# Out:
#           Country Food Vehicle  Indicator Value  NaFeEDTA  location_id  \
# 0      Bangladesh  Wheat flour           55.000     False          161
# 1    Burkina Faso  Wheat flour           60.000     False          201
# 2        Cameroon  Wheat flour           60.000     False          202
# 3           China  Wheat flour           20.000      True            6
# 4   Cote d'Ivoire  Wheat flour           30.000     False          205
# 5        Ethiopia  Wheat flour           30.000      True          179
# 6           Ghana  Wheat flour           58.500     False          207
# 7           India  Wheat flour           17.625      True          163
# 8       Indonesia  Wheat flour           50.000     False           11
# 9           Kenya  Wheat flour           40.000      True          180
# 10     Mozambique  Wheat flour           20.000      True          184
# 11          Nepal  Wheat flour           60.000     False          164
# 12          Niger  Wheat flour           60.000     False          213
# 13        Nigeria  Wheat flour           40.000      True          214
# 14   South Africa  Wheat flour           35.000     False          196
# 15       Tanzania  Wheat flour           40.000      True          189
# 16         Uganda  Wheat flour           30.000      True          190
# 17       Viet Nam  Wheat flour           39.700     False           20
# 18          Kenya  Maize flour           10.000      True          180
# 19     Mozambique  Maize flour           20.000      True          184
# 20        Nigeria  Maize flour           40.000      True          214
# 21   South Africa  Maize flour           35.000     False          196
# 22       Tanzania  Maize flour           15.000      True          189
# 23         Uganda  Maize flour           15.000      True          190
# 24     Bangladesh  Wheat flour           55.000     False          161
# 25   Burkina Faso  Wheat flour           60.000     False          201
# 26       Cameroon  Wheat flour           60.000     False          202
# 27          China  Wheat flour           20.000      True            6
# 28  Cote d'Ivoire  Wheat flour           30.000     False          205
# 29       Ethiopia  Wheat flour           30.000      True          179
# 30          Ghana  Wheat flour           58.500     False          207
# 31          India  Wheat flour           17.625      True          163
# 32      Indonesia  Wheat flour           50.000     False           11
# 33          Kenya  Wheat flour           40.000      True          180
# 34     Mozambique  Wheat flour           20.000      True          184
# 35          Nepal  Wheat flour           60.000     False          164
# 36          Niger  Wheat flour           60.000     False          213
# 37        Nigeria  Wheat flour           40.000      True          214
# 38   South Africa  Wheat flour           35.000     False          196
# 39       Tanzania  Wheat flour           40.000      True          189
# 40         Uganda  Wheat flour           30.000      True          190
# 41       Viet Nam  Wheat flour           39.700     False           20
#
#                   location_name         vehicle      value
# 0                    Bangladesh     wheat flour  32.146239
# 1                  Burkina Faso     wheat flour  35.068625
# 2                      Cameroon     wheat flour  35.068625
# 3                         China     wheat flour  20.000000
# 4                 Côte d'Ivoire     wheat flour  17.534312
# 5                      Ethiopia     wheat flour  30.000000
# 6                         Ghana     wheat flour  34.191909
# 7                         India     wheat flour  17.625000
# 8                     Indonesia     wheat flour  29.223854
# 9                         Kenya     wheat flour  40.000000
# 10                   Mozambique     wheat flour  20.000000
# 11                        Nepal     wheat flour  35.068625
# 12                        Niger     wheat flour  35.068625
# 13                      Nigeria     wheat flour  40.000000
# 14                 South Africa     wheat flour  20.456698
# 15  United Republic of Tanzania     wheat flour  40.000000
# 16                       Uganda     wheat flour  30.000000
# 17                     Viet Nam     wheat flour  23.203740
# 18                        Kenya     maize flour  10.000000
# 19                   Mozambique     maize flour  20.000000
# 20                      Nigeria     maize flour  40.000000
# 21                 South Africa     maize flour  20.000000
# 22  United Republic of Tanzania     maize flour  15.000000
# 23                       Uganda     maize flour  15.000000
# 24                   Bangladesh  industry wheat  32.146239
# 25                 Burkina Faso  industry wheat  35.068625
# 26                     Cameroon  industry wheat  35.068625
# 27                        China  industry wheat  20.000000
# 28                Côte d'Ivoire  industry wheat  17.534312
# 29                     Ethiopia  industry wheat  30.000000
# 30                        Ghana  industry wheat  34.191909
# 31                        India  industry wheat  17.625000
# 32                    Indonesia  industry wheat  29.223854
# 33                        Kenya  industry wheat  40.000000
# 34                   Mozambique  industry wheat  20.000000
# 35                        Nepal  industry wheat  35.068625
# 36                        Niger  industry wheat  35.068625
# 37                      Nigeria  industry wheat  40.000000
# 38                 South Africa  industry wheat  20.456698
# 39  United Republic of Tanzania  industry wheat  40.000000
# 40                       Uganda  industry wheat  30.000000
# 41                     Viet Nam  industry wheat  23.203740

# %%
consumption = pd.read_csv(f'../data_prep/outputs/lsff_gday_data.csv')
consumption
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     location_id                     location_name             sub_population  \
# 0           163                             India           total population
# 1           179                          Ethiopia           total population
# 2           179                          Ethiopia           total population
# 3           214                           Nigeria           total population
# 4           214                           Nigeria           total population
# 5           161                        Bangladesh  women of reproductive age
# 6           165                          Pakistan  women of reproductive age
# 7           189       United Republic of Tanzania           total population
# 8           189       United Republic of Tanzania           total population
# 9           190                            Uganda           total population
# 10          190                            Uganda           total population
# 11          196                      South Africa           total population
# 12          196                      South Africa           total population
# 13          201                      Burkina Faso           total population
# 14          201                      Burkina Faso           total population
# 15          180                             Kenya           total population
# 16          180                             Kenya           total population
# 17           15                           Myanmar  women of reproductive age
# 18           15                           Myanmar           total population
# 19          164                             Nepal           total population
# 20           20                          Viet Nam           total population
# 21          202                          Cameroon           total population
# 22          202                          Cameroon  women of reproductive age
# 23          205                     Côte d'Ivoire           total population
# 24          205                     Côte d'Ivoire           total population
# 25          171  Democratic Republic of the Congo           total population
# 26          171  Democratic Republic of the Congo           total population
# 27           11                         Indonesia           total population
# 28          184                        Mozambique           total population
# 29          184                        Mozambique           total population
# 30          168                            Angola           total population
# 31          168                            Angola           total population
# 32            6                             China           total population
# 33          141                             Egypt           total population
# 34          141                             Egypt           total population
# 35          207                             Ghana           total population
# 36          207                             Ghana           total population
# 37          181                        Madagascar           total population
# 38          181                        Madagascar           total population
# 39          213                             Niger           total population
# 40          213                             Niger           total population
# 41          522                             Sudan           total population
# 42          522                             Sudan           total population
#
#         vehicle  metric mass_unit time_unit  pop_denom  value_mean  \
# 0   wheat flour    mean         g       day     capita  169.620000
# 1   maize flour    mean         g       day     capita  113.840000
# 2   wheat flour    mean         g       day     capita   97.640000
# 3   maize flour    mean         g       day     capita   95.100000
# 4   wheat flour    mean         g       day     capita   49.150000
# 5   wheat flour    mean         g       day     capita   77.900000
# 6   wheat flour    mean         g       day     capita   86.175260
# 7   maize flour    mean         g       day     capita  172.470000
# 8   wheat flour    mean         g       day     capita   32.960000
# 9   maize flour    mean         g       day     capita  126.300000
# 10  wheat flour    mean         g       day     capita   30.270000
# 11  maize flour    mean         g       day     capita  283.290000
# 12  wheat flour    mean         g       day     capita  156.360000
# 13  maize flour    mean         g       day     capita  210.990000
# 14  wheat flour    mean         g       day     capita   37.640000
# 15  maize flour    mean         g       day     capita  216.680000
# 16  wheat flour    mean         g       day     capita  100.110000
# 17  maize flour    mean         g       day     capita   12.383562
# 18  wheat flour    mean         g       day     capita   29.920000
# 19  wheat flour    mean         g       day  consumers    5.700000
# 20  wheat flour    mean         g       day     capita   30.360000
# 21  maize flour    mean         g       day     capita  139.340000
# 22  wheat flour  median         g       day  consumers   79.000000
# 23  maize flour    mean         g       day     capita   43.900000
# 24  wheat flour    mean         g       day     capita   70.080000
# 25  maize flour    mean         g       day     capita   60.800000
# 26  wheat flour    mean         g       day     capita   34.000000
# 27  wheat flour    mean         g       day     capita   73.590000
# 28  maize flour    mean         g       day     capita  180.600000
# 29  wheat flour    mean         g       day     capita   65.920000
# 30  maize flour    mean         g       day     capita  154.990000
# 31  wheat flour    mean         g       day     capita   89.320000
# 32  wheat flour    mean         g       day     capita  171.920000
# 33  maize flour    mean         g       day     capita  167.210000
# 34  wheat flour    mean         g       day     capita  399.230000
# 35  maize flour    mean         g       day     capita   69.230000
# 36  wheat flour    mean         g       day     capita   86.360000
# 37  maize flour    mean         g       day     capita   33.860000
# 38  wheat flour    mean         g       day     capita   35.370000
# 39  maize flour    mean         g       day     capita   10.630000
# 40  wheat flour    mean         g       day     capita   11.450000
# 41  maize flour    mean         g       day     capita    5.400000
# 42  wheat flour    mean         g       day     capita  123.450000
#
#          lower       upper
# 0   113.134860  226.105140
# 1    68.762191  158.917809
# 2    65.124913  130.155087
# 3    57.442765  132.757235
# 4    32.782563   65.517437
# 5    51.958528  103.841472
# 6    57.478045  114.872475
# 7   102.944854  241.995146
# 8    21.983994   43.936006
# 9    75.386647  177.213353
# 10   20.189790   40.350210
# 11  169.091713  397.488287
# 12  104.290571  208.429429
# 13  124.538596  297.441404
# 14   24.468022   50.811978
# 15  127.897166  305.462834
# 16   65.076877  135.143123
# 17    7.309500   17.457623
# 18   19.449607   40.390393
# 19    3.705306    7.694694
# 20   19.735631   40.984369
# 21   82.246590  196.433410
# 22   51.354243  106.645757
# 23   25.912339   61.887661
# 24   45.555764   94.604236
# 25   35.887704   85.712296
# 26   22.101826   45.898174
# 27   47.837452   99.342548
# 28  106.600647  254.599353
# 29   42.851540   88.988460
# 30   91.484132  218.495868
# 31   58.062797  120.577203
# 32  111.757233  232.082767
# 33   98.697088  235.722912
# 34  259.520941  538.939059
# 35   40.863581   97.596419
# 36   56.138638  116.581362
# 37   19.986146   47.733854
# 38   22.992400   47.747600
# 39    6.274446   14.985554
# 40    7.443115   15.456885
# 41    3.187395    7.612605
# 42   80.249130  166.650870

# %% [markdown]
# # Now test reading all data with industry wheat added
#
# ...after incorporating the above function into my `data_processing` module.

# %%
input_data2 = data_processing.get_fortification_input_data(
    coverage_data_path='results_industry/lsff_input_coverage_data_w_industry_oil_wheat_v3_04_14_2021.csv',
)
input_data2.coverage.head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Unnamed: 0  location_id location_name sub_population      vehicle  \
# 0           0          179      Ethiopia            NaN  maize flour
# 1           1          179      Ethiopia            NaN  maize flour
# 2           2          179      Ethiopia            NaN  maize flour
# 3           3          179      Ethiopia            NaN  maize flour
# 4           4          179      Ethiopia            NaN  maize flour
#
#                                    value_description    nutrient  value_mean  \
# 0               percent of population eating vehicle          na   59.263848
# 1  percent of population eating industrially prod...          na   27.167514
# 2     percent of population eating fortified vehicle  folic acid    0.000020
# 3     percent of population eating fortified vehicle        iron    0.000020
# 4     percent of population eating fortified vehicle   vitamin a    0.000020
#
#    value_025_percentile  value_975_percentile  u5_applicable  wra_applicable
# 0             24.950317             93.577380           True            True
# 1             11.437632             42.897396           True            True
# 2              0.000010              0.000030           True            True
# 3              0.000010              0.000030           True            True
# 4              0.000010              0.000030           True            True

# %%
input_data2.concentration
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           Country Food Vehicle  Indicator Value  NaFeEDTA  location_id  \
# 0      Bangladesh  Wheat flour           55.000     False          161
# 1    Burkina Faso  Wheat flour           60.000     False          201
# 2        Cameroon  Wheat flour           60.000     False          202
# 3           China  Wheat flour           20.000      True            6
# 4   Cote d'Ivoire  Wheat flour           30.000     False          205
# 5        Ethiopia  Wheat flour           30.000      True          179
# 6           Ghana  Wheat flour           58.500     False          207
# 7           India  Wheat flour           17.625      True          163
# 8       Indonesia  Wheat flour           50.000     False           11
# 9           Kenya  Wheat flour           40.000      True          180
# 10     Mozambique  Wheat flour           20.000      True          184
# 11          Nepal  Wheat flour           60.000     False          164
# 12          Niger  Wheat flour           60.000     False          213
# 13        Nigeria  Wheat flour           40.000      True          214
# 14   South Africa  Wheat flour           35.000     False          196
# 15       Tanzania  Wheat flour           40.000      True          189
# 16         Uganda  Wheat flour           30.000      True          190
# 17       Viet Nam  Wheat flour           39.700     False           20
# 18          Kenya  Maize flour           10.000      True          180
# 19     Mozambique  Maize flour           20.000      True          184
# 20        Nigeria  Maize flour           40.000      True          214
# 21   South Africa  Maize flour           35.000     False          196
# 22       Tanzania  Maize flour           15.000      True          189
# 23         Uganda  Maize flour           15.000      True          190
# 24     Bangladesh  Wheat flour           55.000     False          161
# 25   Burkina Faso  Wheat flour           60.000     False          201
# 26       Cameroon  Wheat flour           60.000     False          202
# 27          China  Wheat flour           20.000      True            6
# 28  Cote d'Ivoire  Wheat flour           30.000     False          205
# 29       Ethiopia  Wheat flour           30.000      True          179
# 30          Ghana  Wheat flour           58.500     False          207
# 31          India  Wheat flour           17.625      True          163
# 32      Indonesia  Wheat flour           50.000     False           11
# 33          Kenya  Wheat flour           40.000      True          180
# 34     Mozambique  Wheat flour           20.000      True          184
# 35          Nepal  Wheat flour           60.000     False          164
# 36          Niger  Wheat flour           60.000     False          213
# 37        Nigeria  Wheat flour           40.000      True          214
# 38   South Africa  Wheat flour           35.000     False          196
# 39       Tanzania  Wheat flour           40.000      True          189
# 40         Uganda  Wheat flour           30.000      True          190
# 41       Viet Nam  Wheat flour           39.700     False           20
#
#                   location_name         vehicle      value
# 0                    Bangladesh     wheat flour  32.146239
# 1                  Burkina Faso     wheat flour  35.068625
# 2                      Cameroon     wheat flour  35.068625
# 3                         China     wheat flour  20.000000
# 4                 Côte d'Ivoire     wheat flour  17.534312
# 5                      Ethiopia     wheat flour  30.000000
# 6                         Ghana     wheat flour  34.191909
# 7                         India     wheat flour  17.625000
# 8                     Indonesia     wheat flour  29.223854
# 9                         Kenya     wheat flour  40.000000
# 10                   Mozambique     wheat flour  20.000000
# 11                        Nepal     wheat flour  35.068625
# 12                        Niger     wheat flour  35.068625
# 13                      Nigeria     wheat flour  40.000000
# 14                 South Africa     wheat flour  20.456698
# 15  United Republic of Tanzania     wheat flour  40.000000
# 16                       Uganda     wheat flour  30.000000
# 17                     Viet Nam     wheat flour  23.203740
# 18                        Kenya     maize flour  10.000000
# 19                   Mozambique     maize flour  20.000000
# 20                      Nigeria     maize flour  40.000000
# 21                 South Africa     maize flour  20.000000
# 22  United Republic of Tanzania     maize flour  15.000000
# 23                       Uganda     maize flour  15.000000
# 24                   Bangladesh  industry wheat  32.146239
# 25                 Burkina Faso  industry wheat  35.068625
# 26                     Cameroon  industry wheat  35.068625
# 27                        China  industry wheat  20.000000
# 28                Côte d'Ivoire  industry wheat  17.534312
# 29                     Ethiopia  industry wheat  30.000000
# 30                        Ghana  industry wheat  34.191909
# 31                        India  industry wheat  17.625000
# 32                    Indonesia  industry wheat  29.223854
# 33                        Kenya  industry wheat  40.000000
# 34                   Mozambique  industry wheat  20.000000
# 35                        Nepal  industry wheat  35.068625
# 36                        Niger  industry wheat  35.068625
# 37                      Nigeria  industry wheat  40.000000
# 38                 South Africa  industry wheat  20.456698
# 39  United Republic of Tanzania  industry wheat  40.000000
# 40                       Uganda  industry wheat  30.000000
# 41                     Viet Nam  industry wheat  23.203740

# %%
input_data2.consumption
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     location_id    sub_population         vehicle metric mass_unit time_unit  \
# 0           163  total population     wheat flour   mean         g       day
# 1           179  total population     maize flour   mean         g       day
# 2           179  total population     wheat flour   mean         g       day
# 3           214  total population     maize flour   mean         g       day
# 4           214  total population     wheat flour   mean         g       day
# ..          ...               ...             ...    ...       ...       ...
# 62          141  total population  industry wheat   mean         g       day
# 63          207  total population  industry wheat   mean         g       day
# 64          181  total population  industry wheat   mean         g       day
# 65          213  total population  industry wheat   mean         g       day
# 66          522  total population  industry wheat   mean         g       day
#
#    pop_denom  value_mean_gday       lower       upper location_name  \
# 0     capita           169.62  113.134860  226.105140         India
# 1     capita           113.84   68.762191  158.917809      Ethiopia
# 2     capita            97.64   65.124913  130.155087      Ethiopia
# 3     capita            95.10   57.442765  132.757235       Nigeria
# 4     capita            49.15   32.782563   65.517437       Nigeria
# ..       ...              ...         ...         ...           ...
# 62    capita           399.23  259.520941  538.939059         Egypt
# 63    capita            86.36   56.138638  116.581362         Ghana
# 64    capita            35.37   22.992400   47.747600    Madagascar
# 65    capita            11.45    7.443115   15.456885         Niger
# 66    capita           123.45   80.249130  166.650870         Sudan
#
#     value_mean_coverage  value_025_percentile  value_975_percentile
# 0             83.200000             79.500000             86.500000
# 1             59.263848             24.950317             93.577380
# 2             28.000000             13.776168             42.223832
# 3             57.415462             54.867114             60.033478
# 4             62.759594             60.359594             65.129264
# ..                  ...                   ...                   ...
# 62            88.484772             43.535039             99.999990
# 63            82.658625             40.668539             99.999990
# 64            45.179608             22.228638             68.130578
# 65            41.424994             20.381346             62.468643
# 66            88.823684             43.701786             99.999990
#
# [67 rows x 14 columns]

# %%
input_data2.consumption.metric.unique()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['mean', 'median'], dtype=object)

# %%
input_data2.consumption.query("metric=='median'")
# Out:
#     location_id             sub_population         vehicle  metric mass_unit  \
# 21          202  women of reproductive age     wheat flour  median         g
# 55          202  women of reproductive age  industry wheat  median         g
#
#    time_unit  pop_denom  value_mean_gday      lower       upper location_name  \
# 21       day  consumers             79.0  51.354243  106.645757      Cameroon
# 55       day  consumers             79.0  51.354243  106.645757      Cameroon
#
#     value_mean_coverage  value_025_percentile  value_975_percentile
# 21                 92.0                  90.0                  94.0
# 55                 92.0                  90.0                  94.0

# %%
input_data2.consumption.query("location_id==202")
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     location_id             sub_population         vehicle  metric mass_unit  \
# 20          202           total population     maize flour    mean         g
# 21          202  women of reproductive age     wheat flour  median         g
# 55          202  women of reproductive age  industry wheat  median         g
#
#    time_unit  pop_denom  value_mean_gday      lower       upper location_name  \
# 20       day     capita           139.34  82.246590  196.433410      Cameroon
# 21       day  consumers            79.00  51.354243  106.645757      Cameroon
# 55       day  consumers            79.00  51.354243  106.645757      Cameroon
#
#     value_mean_coverage  value_025_percentile  value_975_percentile
# 20            47.295467             19.911581             74.679353
# 21            92.000000             90.000000             94.000000
# 55            92.000000             90.000000             94.000000
