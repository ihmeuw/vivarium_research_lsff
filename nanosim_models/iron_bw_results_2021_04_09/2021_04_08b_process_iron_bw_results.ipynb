# %%
import pandas as pd, numpy as np
import os

from db_queries import get_ids, get_population
from vivarium_helpers.id_helper import *

import data_processing
# import lbwsg_boe
# import lbwsg
# import lsff_interventions
# import demography

# !date
# !whoami
# !pwd
# Out:
# Fri Apr  9 11:51:49 PDT 2021
# ndbs
# /ihme/homes/ndbs/vivarium_research_lsff/nanosim_models

# %%
locations = pd.read_csv('../gbd_data_summary/input_data/bmgf_top_25_countries_20201203.csv')
location_ids = locations.location_id.to_list()
locations
# Out:
#                        location_name  location_id
# 0                             Angola          168
# 1                         Bangladesh          161
# 2                       Burkina Faso          201
# 3                           Cameroon          202
# 4                              China            6
# 5                      Côte d'Ivoire          205
# 6   Democratic Republic of the Congo          171
# 7                              Egypt          141
# 8                           Ethiopia          179
# 9                              Ghana          207
# 10                             India          163
# 11                         Indonesia           11
# 12                             Kenya          180
# 13                        Madagascar          181
# 14                        Mozambique          184
# 15                           Myanmar           15
# 16                             Nepal          164
# 17                             Niger          213
# 18                           Nigeria          214
# 19                          Pakistan          165
# 20                      South Africa          196
# 21                             Sudan          522
# 22                            Uganda          190
# 23       United Republic of Tanzania          189
# 24                          Viet Nam           20

# %%
# !ls results
# Out:
# Angola_parallel.txt
# Bangladesh_parallel.txt
# Burkina Faso_parallel.txt
# Cameroon_parallel.txt
# China_parallel.txt
# Côte d'Ivoire_parallel.txt
# Democratic Republic of the Congo_parallel.txt
# Egypt_parallel.txt
# Ethiopia_parallel.txt
# Ghana_parallel.txt
# India_parallel.txt
# Indonesia_parallel.txt
# iron_bw_results__Angola.csv
# iron_bw_results__Bangladesh.csv
# iron_bw_results__Burkina Faso.csv
# iron_bw_results__Cameroon.csv
# iron_bw_results__China.csv
# iron_bw_results__Côte d'Ivoire.csv
# iron_bw_results__Democratic Republic of the Congo.csv
# iron_bw_results__Egypt.csv
# iron_bw_results__Ethiopia.csv
# iron_bw_results__Ghana.csv
# iron_bw_results__India.csv
# iron_bw_results__Indonesia.csv
# iron_bw_results__Kenya.csv
# iron_bw_results_location_id_214.csv
# iron_bw_results__Madagascar.csv
# Kenya_parallel.txt
# Madagascar_parallel.txt
# Mozambique_parallel.txt

# %%
pd.read_csv('results/iron_bw_results__Angola.csv').head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    location_id      vehicle  coverage_level          measure  age_group_id  \
# 0          168  maize flour             0.2              pif             2
# 1          168  maize flour             0.2              pif             3
# 2          168  maize flour             0.2  categorical_pif             2
# 3          168  maize flour             0.2  categorical_pif             3
# 4          168  maize flour             0.2    averted_dalys             2
#
#        draw_4      draw_6      draw_10    draw_13     draw_16  ...   draw_971  \
# 0    0.000076    0.000400     0.000856   0.000020    0.000282  ...   0.000038
# 1    0.000054    0.000357     0.001053   0.000025    0.000302  ...   0.000051
# 2    0.000045    0.000185     0.000927   0.000046    0.000259  ...   0.000135
# 3    0.000003    0.000276     0.001068   0.000000    0.000035  ...   0.000000
# 4  107.321082  426.865234  1185.160348  23.453895  368.425872  ...  47.227040
#
#     draw_973   draw_974    draw_978    draw_981   draw_985    draw_988  \
# 0   0.000047   0.000065    0.000121    0.000185   0.000047    0.000194
# 1   0.000055   0.000077    0.000156    0.000227   0.000050    0.000235
# 2   0.000065   0.000053    0.000250    0.000159   0.000002    0.000086
# 3   0.000004   0.000025    0.000068    0.000404   0.000000    0.000146
# 4  63.812954  82.990300  160.518617  245.059384  60.599617  285.313963
#
#      draw_992   draw_994    draw_999
# 0    0.000146   0.000023    0.000103
# 1    0.000155   0.000020    0.000132
# 2   -0.000005   0.000000    0.000162
# 3    0.000004   0.000000    0.000003
# 4  212.631486  27.278214  139.694073
#
# [5 rows x 255 columns]

# %%
pd.read_csv('results/iron_bw_results__Cameroon.csv').head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    location_id      vehicle  coverage_level          measure  age_group_id  \
# 0          202  maize flour             0.2              pif             2
# 1          202  maize flour             0.2              pif             3
# 2          202  maize flour             0.2  categorical_pif             2
# 3          202  maize flour             0.2  categorical_pif             3
# 4          202  maize flour             0.2    averted_dalys             2
#
#      draw_43     draw_67     draw_240     draw_298   draw_314    draw_539  \
# 0   0.000011    0.000103     0.008780     0.001950  -0.000065    0.000263
# 1   0.001168    0.005290     0.001479     0.000040   0.000000    0.001631
# 2   0.000000    0.000000     0.000000     0.000000   0.000000    0.000000
# 3   0.000000    0.000000     0.000000     0.000000   0.000000    0.000000
# 4  12.159230  109.099677  6025.249920  2283.317367 -61.340347  250.766044
#
#       draw_558     draw_709   draw_737   draw_767
# 0     0.001578     0.002676  -0.000088  -0.000012
# 1     0.001233     0.003078   0.000441   0.000000
# 2     0.000000     0.000000   0.000000   0.000000
# 3     0.000000     0.000000   0.000000   0.000000
# 4  1554.795738  2505.951533 -95.232936 -10.007815

# %% [markdown]
# # Copy and modify some functions from `vivarium_output_loader.py` to read in and concatenate multiple files

# %%
def load_iron_bw_results(directory: str) -> dict:
    """
    Loads iron-LBW output file into a dataframe,
    and returns a dictionary whose keys are the location names and values are
    are the corresponding dataframes.
    """
    dfs = {}
    for entry in os.scandir(directory):
        filename_root, extension = os.path.splitext(entry.name)
        if extension == '.csv' and filename_root.startswith('iron_bw_results__'):
            location = filename_root.split('__')[1]
#             print(filename_root, type(filename_root), extension, entry.path, location)
            dfs[location] = pd.read_csv(entry.path)
    return dfs

def filter_by_draw_count(locations_outputs:dict, num_draws:int)->dict:
    """Filter output dataframes to only those with the specified number of draws.
    (Necessary because 'results' folder contains data from some preliminary runs
    with fewer than 250 draws.)
    """
    return {location: output_df for location, output_df in locations_outputs.items()
            if len(output_df.filter(like='draw').columns) == num_draws}

def merge_location_outputs(locations_outputs: dict, copy=True) -> pd.DataFrame:
    """
    Concatenate the output DataFrames for all locations stored in locations_outputs into a single DataFrame.
    """
    return pd.concat(locations_outputs.values(), sort=False)

# Master function to read in all data:

def load_and_merge_location_outputs(*directories):
    locations_outputs = {}
    for directory in directories:
        locations_outputs.update(filter_by_draw_count(load_iron_bw_results(directory), 250))
    return merge_location_outputs(locations_outputs)
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Test the above functions

# %%
dfs = load_iron_bw_results('results')
for location, df in dfs.items():
    print(location, f"num_draws = {len(df.filter(like='draw').columns)}")
# Out:
# Bangladesh num_draws = 250
# Democratic Republic of the Congo num_draws = 10
# Ghana num_draws = 10
# Burkina Faso num_draws = 10
# Kenya num_draws = 10
# China num_draws = 10
# India num_draws = 10
# Egypt num_draws = 10
# Angola num_draws = 250
# Cameroon num_draws = 10
# Côte d'Ivoire num_draws = 10
# Ethiopia num_draws = 10
# Madagascar num_draws = 250
# Indonesia num_draws = 10

# %%
dfs = filter_by_draw_count(load_iron_bw_results('results'), 250)
for location, df in dfs.items():
    print(location, f"num_draws = {len(df.filter(like='draw').columns)}", f"{df.shape=}")
# Out:
# Bangladesh num_draws = 250 df.shape=(24, 255)
# Angola num_draws = 250 df.shape=(48, 255)
# Madagascar num_draws = 250 df.shape=(48, 255)

# %%
data = load_and_merge_location_outputs('results')
print(f"{data.shape=}, {data.location_id.unique()}")
# Out:
# data.shape=(120, 255), [161 168 181]

# %%
data = load_and_merge_location_outputs('results2')
print(f"{data.shape=}, {data.location_id.unique()}")
# Out:
# data.shape=(432, 255), [171 214 207 196 180 165 522 141 179  11]

# %%
data = load_and_merge_location_outputs('results2', 'results')
print(f"{data.shape=}, {data.location_id.unique()}")
data.head(15)
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# data.shape=(600, 255), [171 214 190 207 196 180 165 522 141 179  11 161 168 181]
#     location_id      vehicle  coverage_level          measure  age_group_id  \
# 0           171  maize flour             0.2              pif             2
# 1           171  maize flour             0.2              pif             3
# 2           171  maize flour             0.2  categorical_pif             2
# 3           171  maize flour             0.2  categorical_pif             3
# 4           171  maize flour             0.2    averted_dalys             2
# 5           171  maize flour             0.2    averted_dalys             3
# 6           171  maize flour             0.5              pif             2
# 7           171  maize flour             0.5              pif             3
# 8           171  maize flour             0.5  categorical_pif             2
# 9           171  maize flour             0.5  categorical_pif             3
# 10          171  maize flour             0.5    averted_dalys             2
# 11          171  maize flour             0.5    averted_dalys             3
# 12          171  maize flour             0.8              pif             2
# 13          171  maize flour             0.8              pif             3
# 14          171  maize flour             0.8  categorical_pif             2
#
#        draw_4      draw_6     draw_10    draw_13     draw_16  ...   draw_971  \
# 0    0.000016    0.000050    0.000100   0.000012    0.000043  ...   0.000014
# 1    0.000025    0.000076    0.000130   0.000014    0.000048  ...   0.000017
# 2    0.000000    0.000188   -0.000009   0.000000    0.000050  ...   0.000000
# 3    0.000000    0.000271    0.000257   0.000000    0.000000  ...   0.000000
# 4   55.778487  155.684575  338.814487  40.266012  120.421400  ...  49.691671
# 5    9.942200   25.487995   49.787145   4.808979   14.914642  ...   7.943259
# 6    0.000023    0.000082    0.000137   0.000015    0.000049  ...   0.000023
# 7    0.000028    0.000097    0.000155   0.000017    0.000059  ...   0.000021
# 8    0.000000    0.000188   -0.000006   0.000000    0.000050  ...   0.000000
# 9    0.000000    0.000271    0.000261   0.000000    0.000000  ...   0.000000
# 10  79.708673  256.135437  468.705679  55.673387  137.637412  ...  82.320105
# 11  10.964020   32.697466   59.347691   5.951242   18.214060  ...   9.944997
# 12   0.000026    0.000093    0.000158   0.000018    0.000058  ...   0.000026
# 13   0.000032    0.000115    0.000176   0.000019    0.000066  ...   0.000025
# 14   0.000000    0.000182   -0.000006   0.000000    0.000050  ...   0.000000
#
#      draw_973    draw_974    draw_978    draw_981   draw_985   draw_988  \
# 0    0.000016    0.000029    0.000038    0.000025   0.000016   0.000025
# 1    0.000023    0.000041    0.000041    0.000032   0.000021   0.000031
# 2    0.000066    0.000060    0.000121    0.000127   0.000000   0.000000
# 3    0.000000    0.000000    0.000000    0.000000   0.000000   0.000000
# 4   49.505308  128.807198  123.458303   76.093358  48.375703  78.866859
# 5    8.409855   16.999679   11.891784    8.487713   7.251175  12.258019
# 6    0.000023    0.000035    0.000052    0.000036   0.000020   0.000029
# 7    0.000030    0.000051    0.000049    0.000037   0.000025   0.000039
# 8    0.000066    0.000060    0.000121    0.000127   0.000000   0.000000
# 9    0.000000    0.000000    0.000000    0.000000   0.000000   0.000000
# 10  76.503042  153.705647  173.695127  112.310564  62.516396  90.871710
# 11  10.626374   20.928572   14.328309   10.009584   8.697766  15.216321
# 12   0.000027    0.000040    0.000058    0.000040   0.000023   0.000032
# 13   0.000035    0.000056    0.000059    0.000045   0.000029   0.000043
# 14   0.000066    0.000060    0.000121    0.000127   0.000000   0.000000
#
#      draw_992   draw_994   draw_999
# 0    0.000016   0.000018   0.000011
# 1    0.000022   0.000022   0.000016
# 2    0.000000   0.000000   0.000000
# 3    0.000000   0.000000   0.000000
# 4   48.765585  47.017757  30.889271
# 5    6.833221   6.542826   4.154256
# 6    0.000024   0.000024   0.000017
# 7    0.000026   0.000025   0.000020
# 8    0.000000   0.000000   0.000000
# 9    0.000000   0.000000   0.000000
# 10  75.302494  63.574443  47.357699
# 11   8.006674   7.543477   5.077073
# 12   0.000027   0.000029   0.000020
# 13   0.000031   0.000029   0.000023
# 14   0.000000   0.000000   0.000000
#
# [15 rows x 255 columns]

# %% [markdown]
# # Write functions to process concatenated data

# %%
get_ids('age_group').head(10)
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    age_group_id  age_group_name
# 0             1         Under 5
# 1             2  Early Neonatal
# 2             3   Late Neonatal
# 3             4   Post Neonatal
# 4             5          1 to 4
# 5             6          5 to 9
# 6             7        10 to 14
# 7             8        15 to 19
# 8             9        20 to 24
# 9            10        25 to 29

# %%
def filter_measures_and_coverage(data):
    """Filter to coverage levels [0.2, 0.5, 0.8] and measure == 'averted_dalys'
    Leaving out coverage level corresponding to 100% population coverage
    and measure == 'categorical_pif' because these are unneeded for results.
    Leaving out measure=='pif' because we'll compute an aggregate PIF using averted DALYs.
    """
    return data.query("coverage_level in [0.2, 0.5, 0.8] and measure in ['averted_dalys']")

def aggregate_over_age_groups(data):
    """Add draws over different age groups."""
    draw_cols = data.filter(like='draw').columns.to_list()
    index_cols = data.columns.difference(['age_group_id', *draw_cols]).to_list()
    return data.groupby(index_cols)[draw_cols].sum()

def get_dalys_averted_u5(data):
    """ 1. Filter to coverage levels [0.2, 0.5, 0.8] and measure == 'averted_dalys'.
    2. Add averted DALYs for age groups 2 and 3 to get total for Under 5.
    (Note that DALYs exist in age groups 4 and 5 for preterm birth (but not other affected causes),
    but I'm not counting them because RRs are only for age groups 2 and 3, and iron only affects
    birthweight, not gestational age.)
    3. Rename measure 'averted_dalys' to 'counts_averted' to match Ali's code.
    """
    dalys_averted = (
        data
        .query("coverage_level in [0.2, 0.5, 0.8] and measure=='averted_dalys'")
        .replace('averted_dalys', 'counts_averted') # To match Ali's code
        .pipe(aggregate_over_age_groups)
    )
    return dalys_averted
    
def compute_aggregate_pif(dalys_averted):
    """Use aggregated averted DALYs to compute overall PIF (in units of %) for age groups 2 and 3."""
#     draw_cols = data.filter(like='draw').columns.to_list()
    location_ids = dalys_averted.index.unique('location_id')
    hdfstore = '/share/scratch/users/ndbs/vivarium_lsff/gbd_data/lbwsg_data.hdf'
    daly_key = '/gbd_2019/burden/dalys/bmgf_25_countries_all_causes_u5'
    lbwsg_dalys = (
        pd.read_hdf(hdfstore, daly_key)
        .query('age_group_id in [2,3] and metric_id==1')
        .query("location_id in @location_ids") # Filter to locations in data
        .groupby(['location_id'])
        .sum() # Aggregate over age_group and sex
        [dalys_averted.columns] # Filter to draws that exist in data
    )
    pif = (dalys_averted / lbwsg_dalys) * 100 # convert to percent
    pif.index = pif.index.set_levels(['pif'], level='measure') # measure was still counts_averted, so rename
    return pif

def pull_u5_population_for_locations(location_ids):
    pop_u5 = get_population(
        age_group_id=1,
        location_id=location_ids,
        year_id=2019,
        gbd_round_id=6,
        status='best',
        decomp_step='step5',
        with_ui=True
    )
    return pop_u5

def get_u5_population_draws_for_locations(location_ids, draws, random_state=None):
    pop_u5 = pull_u5_population_for_locations(location_ids)
    values = data_processing.generate_normal_draws(
        pop_u5['population'], pop_u5['lower'], pop_u5['upper'],
        shape=(len(draws), len(population)),
        random_state=random_state
    )
    pop_u5_draws = pd.DataFrame(values.T, index=pop_u5['location_id'], columns=draws)
    return pop_u5_draws

def compute_averted_daly_rate(dalys_averted):
    location_ids = dalys_averted.index.unique('location_id').to_list()
    # Set the random state so we'll get consistent results
    pop_u5 = get_u5_population_draws_for_locations(location_ids, dalys_averted.columns, random_state=246)
    dalys_averted_rate = (dalys_averted / pop_u5) * 100_000 # Convert to per 100K person-years
    dalys_averted_rate.index = dalys_averted_rate.index.set_levels(
        ['rates_averted'], level='measure') # measure was still counts_averted, so rename
    return dalys_averted_rate

# Master function to perform all steps

def read_output_and_compute_fiinal_results():
    # .csv's in 'results3/' used 40_000 simulants per location, while .csv's in 'results2/' and 'results/'
    # used 80_000 simulants per location.
    # Read .csv's in opposite order they were generated in order to overwrite results from smaller populations
    # if results for larger populations exist.
    data = load_and_merge_location_outputs('results3', 'results2', 'results')
    dalys_averted = get_dalys_averted_u5(data)
    pif = compute_aggregate_pif(dalys_averted)
    averted_daly_rate = compute_averted_daly_rate(dalys_averted)
    return pd.concat([dalys_averted, pif, averted_daly_rate])

# %%
data = load_and_merge_location_outputs('results3', 'results2', 'results')
dalys_averted = get_dalys_averted_u5(data)
averted_daly_rate = compute_averted_daly_rate(dalys_averted)
daly_rate_path = 'results/iron_bw_averted_daly_rate.csv'
averted_daly_rate.to_csv(daly_rate_path)
pd.read_csv(daly_rate_path).head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    coverage_level  location_id        measure      vehicle    draw_4  \
# 0             0.2            6  rates_averted  wheat flour  3.560361
# 1             0.2           11  rates_averted  wheat flour  0.002150
# 2             0.2           15  rates_averted  wheat flour  0.466076
# 3             0.2           20  rates_averted  wheat flour  0.528231
# 4             0.2          141  rates_averted  maize flour  3.367748
#
#      draw_6    draw_10   draw_13   draw_16   draw_18  ...  draw_971  draw_973  \
# 0  4.813676   7.055063  5.392671  8.809159  1.045529  ...  3.827421  3.498767
# 1  0.274970   1.046606  0.025163  0.764240  0.847538  ...  0.660950  0.518365
# 2  0.816322   1.623066  0.343268  1.664202  0.476514  ...  0.712711  1.052425
# 3  0.575762   0.759898  0.981503  0.886449  0.052241  ...  0.779118  0.246108
# 4  6.571276  18.665152  1.246787  5.639913  4.247574  ...  2.732753  4.557495
#
#    draw_974   draw_978  draw_981  draw_985  draw_988  draw_992  draw_994  \
# 0  3.408697   5.238385  4.560757  4.936616  2.011508  2.819385  2.526812
# 1  0.212758   0.290341  0.354172  0.169202  0.669226  1.679969  0.492787
# 2  0.716176   1.516212  0.515576  0.633784  0.778727  1.102517  0.211440
# 3  1.060223   1.239409  0.488112  0.180419  0.282576  0.436247  0.349485
# 4  8.972857  10.995985  8.408310  3.531514  8.074228  4.441908  4.043120
#
#    draw_999
# 0  4.578389
# 1  0.138997
# 2  1.549961
# 3  0.611190
# 4  3.722850
#
# [5 rows x 254 columns]

# %%
get_u5_population_draws_for_locations(location_ids, range(5))
# Out:
#                         0             1             2             3  \
# location_id
# 6            8.775178e+07  8.413879e+07  8.325151e+07  8.201297e+07
# 11           1.986058e+07  1.991336e+07  1.716248e+07  1.954220e+07
# 15           5.333727e+06  5.342504e+06  5.300854e+06  5.364472e+06
# 20           6.217477e+06  7.226600e+06  6.228560e+06  7.241674e+06
# 141          1.077627e+07  1.080156e+07  1.061516e+07  1.146309e+07
# 161          1.406888e+07  1.408570e+07  1.327883e+07  1.368200e+07
# 163          1.197189e+08  1.368641e+08  1.077251e+08  1.241471e+08
# 164          2.965979e+06  2.916631e+06  2.743101e+06  3.206241e+06
# 165          3.051692e+07  3.020671e+07  3.409152e+07  3.111671e+07
# 168          5.531807e+06  5.378940e+06  5.382239e+06  5.127253e+06
# 171          1.419037e+07  1.716461e+07  1.389733e+07  1.193783e+07
# 179          1.700178e+07  1.925580e+07  1.685903e+07  1.798112e+07
# 180          6.316756e+06  6.331739e+06  6.202193e+06  5.840282e+06
# 181          4.909629e+06  3.640305e+06  3.789117e+06  3.384603e+06
# 184          5.277165e+06  4.813761e+06  4.954592e+06  5.210791e+06
# 189          9.149794e+06  9.843851e+06  9.012922e+06  8.961879e+06
# 190          7.257220e+06  6.634519e+06  7.168382e+06  6.761486e+06
# 196          4.931929e+06  4.656421e+06  5.171835e+06  5.123478e+06
# 201          4.119530e+06  4.147731e+06  4.309086e+06  4.146719e+06
# 202          4.145012e+06  4.129709e+06  4.358135e+06  4.020177e+06
# 205          3.683319e+06  4.176054e+06  4.067274e+06  4.018297e+06
# 207          3.905895e+06  4.240111e+06  4.331493e+06  4.310812e+06
# 213          4.356219e+06  4.964720e+06  4.880407e+06  4.652930e+06
# 214          3.495071e+07  3.080370e+07  3.409986e+07  3.354615e+07
# 522          5.534062e+06  5.691744e+06  5.161663e+06  5.948912e+06
#
#                         4
# location_id
# 6            7.245507e+07
# 11           1.741381e+07
# 15           5.113700e+06
# 20           6.130191e+06
# 141          1.058122e+07
# 161          1.333186e+07
# 163          1.113606e+08
# 164          3.049592e+06
# 165          2.898249e+07
# 168          4.902878e+06
# 171          1.351104e+07
# 179          1.585066e+07
# 180          6.079007e+06
# 181          3.989342e+06
# 184          5.039862e+06
# 189          9.554174e+06
# 190          7.051782e+06
# 196          5.015972e+06
# 201          3.975168e+06
# 202          4.406546e+06
# 205          4.119673e+06
# 207          3.812757e+06
# 213          4.889764e+06
# 214          3.268884e+07
# 522          5.927681e+06

# %%
population = pull_u5_population_for_locations(location_ids)
population
# Out:
#     age_group_id  location_id  year_id  sex_id    population         upper  \
# 0              1            6     2019       3  8.149086e+07  9.152573e+07
# 1              1           11     2019       3  1.970635e+07  2.217715e+07
# 2              1           15     2019       3  5.018670e+06  5.528959e+06
# 3              1           20     2019       3  6.937449e+06  7.846919e+06
# 4              1          141     2019       3  1.082519e+07  1.174810e+07
# 5              1          161     2019       3  1.374591e+07  1.535069e+07
# 6              1          163     2019       3  1.170708e+08  1.312186e+08
# 7              1          164     2019       3  2.995968e+06  3.372471e+06
# 8              1          165     2019       3  3.052648e+07  3.292357e+07
# 9              1          168     2019       3  5.147150e+06  5.655763e+06
# 10             1          171     2019       3  1.362947e+07  1.750358e+07
# 11             1          179     2019       3  1.667967e+07  1.903378e+07
# 12             1          180     2019       3  6.416043e+06  7.249351e+06
# 13             1          181     2019       3  3.939182e+06  4.847437e+06
# 14             1          184     2019       3  5.105036e+06  5.499272e+06
# 15             1          189     2019       3  9.307277e+06  1.037264e+07
# 16             1          190     2019       3  7.089750e+06  7.751458e+06
# 17             1          196     2019       3  5.094527e+06  5.748547e+06
# 18             1          201     2019       3  4.044957e+06  4.665555e+06
# 19             1          202     2019       3  4.207109e+06  4.858077e+06
# 20             1          205     2019       3  4.011999e+06  4.426120e+06
# 21             1          207     2019       3  3.970635e+06  4.430136e+06
# 22             1          213     2019       3  4.852864e+06  5.402050e+06
# 23             1          214     2019       3  3.352164e+07  3.691554e+07
# 24             1          522     2019       3  5.512747e+06  6.215381e+06
#
#            lower  run_id
# 0   7.098894e+07     192
# 1   1.722869e+07     192
# 2   4.489139e+06     192
# 3   5.979573e+06     192
# 4   9.896663e+06     192
# 5   1.218713e+07     192
# 6   1.041967e+08     192
# 7   2.621183e+06     192
# 8   2.821236e+07     192
# 9   4.620510e+06     192
# 10  9.599596e+06     192
# 11  1.426636e+07     192
# 12  5.575947e+06     192
# 13  3.006933e+06     192
# 14  4.677981e+06     192
# 15  8.283532e+06     192
# 16  6.383814e+06     192
# 17  4.506267e+06     192
# 18  3.455204e+06     192
# 19  3.582747e+06     192
# 20  3.613672e+06     192
# 21  3.455554e+06     192
# 22  4.332547e+06     192
# 23  3.013688e+07     192
# 24  4.776202e+06     192

# %%
num_draws=5
data_processing.generate_normal_draws(
    population.population, population.lower, population.upper, shape=(num_draws, len(population)))
# Out:
# array([[7.33438905e+07, 1.89950092e+07, 4.80960999e+06, 7.13840155e+06,
#         1.12867358e+07, 1.34858917e+07, 1.15856842e+08, 3.13147017e+06,
#         3.06986610e+07, 4.95264102e+06, 1.37196803e+07, 1.74834779e+07,
#         6.22061575e+06, 4.36439281e+06, 5.05752080e+06, 9.73614501e+06,
#         7.09057354e+06, 5.23593351e+06, 4.68794618e+06, 3.89879482e+06,
#         4.13655903e+06, 4.05146470e+06, 4.52356517e+06, 3.70722253e+07,
#         5.65837344e+06],
#        [7.78612549e+07, 1.87132882e+07, 5.17979025e+06, 6.34770506e+06,
#         1.08204072e+07, 1.39100206e+07, 1.26817756e+08, 3.01444763e+06,
#         3.31463952e+07, 5.40140341e+06, 1.41077062e+07, 1.73445353e+07,
#         5.64710269e+06, 4.29735284e+06, 5.06612669e+06, 9.27711075e+06,
#         7.28007533e+06, 5.21285647e+06, 3.64539415e+06, 4.05491102e+06,
#         3.91959776e+06, 4.21223957e+06, 4.90011803e+06, 3.23101220e+07,
#         5.87672543e+06],
#        [8.54667777e+07, 2.14024725e+07, 4.99595188e+06, 7.00682378e+06,
#         1.03826540e+07, 1.40632994e+07, 1.22200388e+08, 2.61889565e+06,
#         3.19860729e+07, 5.43304737e+06, 1.20779205e+07, 1.88943293e+07,
#         6.99418239e+06, 3.73775930e+06, 5.30007348e+06, 9.62883998e+06,
#         7.46094487e+06, 4.66998205e+06, 4.02338145e+06, 4.06389631e+06,
#         4.21112445e+06, 4.00975808e+06, 4.84569598e+06, 3.17339885e+07,
#         5.78040136e+06],
#        [8.27782798e+07, 1.96985589e+07, 4.99595535e+06, 6.33383313e+06,
#         1.09737748e+07, 1.39643289e+07, 1.06281129e+08, 2.59968126e+06,
#         2.87840384e+07, 5.33704763e+06, 1.32295037e+07, 1.52780598e+07,
#         6.39831359e+06, 4.49734661e+06, 5.01888508e+06, 8.63642832e+06,
#         7.59541448e+06, 5.08839144e+06, 4.42405852e+06, 4.73403527e+06,
#         4.11571174e+06, 3.74594156e+06, 5.11783313e+06, 3.58642824e+07,
#         6.08644613e+06],
#        [7.50580088e+07, 1.93350584e+07, 4.72539302e+06, 7.31748261e+06,
#         1.10460587e+07, 1.30111969e+07, 1.23305687e+08, 3.34998043e+06,
#         3.09763143e+07, 4.58146239e+06, 1.71272019e+07, 1.60036652e+07,
#         6.70126977e+06, 4.07214702e+06, 5.22918004e+06, 9.90423537e+06,
#         7.53210583e+06, 4.98618933e+06, 3.68253861e+06, 4.47268041e+06,
#         4.34105541e+06, 4.17231872e+06, 5.24794886e+06, 3.31832793e+07,
#         5.13441180e+06]])

# %% [markdown]
# # Compute final results

# %%
results = read_output_and_compute_fiinal_results()
print(results.shape)
results.head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (378, 250)
#                                                             draw_4  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  2904.543372
#                11          counts_averted wheat flour     0.410664
#                15          counts_averted wheat flour    22.630438
#                20          counts_averted wheat flour    40.655603
#                141         counts_averted maize flour   366.596716
#
#                                                             draw_6  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3749.252406
#                11          counts_averted wheat flour    55.025127
#                15          counts_averted wheat flour    39.480737
#                20          counts_averted wheat flour    36.804245
#                141         counts_averted maize flour   698.946383
#
#                                                            draw_10  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  5431.758587
#                11          counts_averted wheat flour   205.150746
#                15          counts_averted wheat flour    83.344657
#                20          counts_averted wheat flour    51.674548
#                141         counts_averted maize flour  2010.007523
#
#                                                            draw_13  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  4862.595241
#                11          counts_averted wheat flour     4.903218
#                15          counts_averted wheat flour    17.356558
#                20          counts_averted wheat flour    65.486548
#                141         counts_averted maize flour   146.087604
#
#                                                            draw_16  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  6909.634628
#                11          counts_averted wheat flour   147.438639
#                15          counts_averted wheat flour    85.796009
#                20          counts_averted wheat flour    63.615450
#                141         counts_averted maize flour   643.183569
#
#                                                           draw_18  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  917.572898
#                11          counts_averted wheat flour  166.470581
#                15          counts_averted wheat flour   25.949345
#                20          counts_averted wheat flour    3.636705
#                141         counts_averted maize flour  472.132097
#
#                                                            draw_20  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3296.807780
#                11          counts_averted wheat flour     1.516400
#                15          counts_averted wheat flour    68.935341
#                20          counts_averted wheat flour    44.082658
#                141         counts_averted maize flour   517.260651
#
#                                                            draw_25  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  9407.861584
#                11          counts_averted wheat flour   520.124735
#                15          counts_averted wheat flour    72.999888
#                20          counts_averted wheat flour   117.303784
#                141         counts_averted maize flour   651.662968
#
#                                                            draw_26  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  2395.424488
#                11          counts_averted wheat flour    91.149686
#                15          counts_averted wheat flour    34.429009
#                20          counts_averted wheat flour    24.968393
#                141         counts_averted maize flour   134.725070
#
#                                                            draw_27  ...  \
# coverage_level location_id measure        vehicle                   ...
# 0.2            6           counts_averted wheat flour  4172.471261  ...
#                11          counts_averted wheat flour   200.195966  ...
#                15          counts_averted wheat flour    75.115903  ...
#                20          counts_averted wheat flour    48.237836  ...
#                141         counts_averted maize flour   990.969210  ...
#
#                                                           draw_971  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3247.119810
#                11          counts_averted wheat flour   130.557224
#                15          counts_averted wheat flour    32.987038
#                20          counts_averted wheat flour    51.911889
#                141         counts_averted maize flour   292.371701
#
#                                                           draw_973  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  2945.899057
#                11          counts_averted wheat flour    99.136743
#                15          counts_averted wheat flour    51.778511
#                20          counts_averted wheat flour    18.471326
#                141         counts_averted maize flour   470.511168
#
#                                                           draw_974  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3093.888739
#                11          counts_averted wheat flour    43.440180
#                15          counts_averted wheat flour    36.298628
#                20          counts_averted wheat flour    69.239954
#                141         counts_averted maize flour  1017.240468
#
#                                                           draw_978  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  4450.653495
#                11          counts_averted wheat flour    55.307435
#                15          counts_averted wheat flour    75.879004
#                20          counts_averted wheat flour    98.195414
#                141         counts_averted maize flour  1083.183300
#
#                                                           draw_981  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3373.314205
#                11          counts_averted wheat flour    68.835866
#                15          counts_averted wheat flour    24.705208
#                20          counts_averted wheat flour    33.785295
#                141         counts_averted maize flour   892.482109
#
#                                                           draw_985  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3980.202743
#                11          counts_averted wheat flour    36.359475
#                15          counts_averted wheat flour    29.401829
#                20          counts_averted wheat flour    13.679045
#                141         counts_averted maize flour   384.333877
#
#                                                           draw_988  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  1443.065174
#                11          counts_averted wheat flour   130.843194
#                15          counts_averted wheat flour    44.477208
#                20          counts_averted wheat flour    21.388484
#                141         counts_averted maize flour   923.678018
#
#                                                           draw_992  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  2202.609063
#                11          counts_averted wheat flour   318.490189
#                15          counts_averted wheat flour    51.528323
#                20          counts_averted wheat flour    30.470178
#                141         counts_averted maize flour   458.504144
#
#                                                           draw_994  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  1817.149521
#                11          counts_averted wheat flour    87.106196
#                15          counts_averted wheat flour    10.900119
#                20          counts_averted wheat flour    24.439117
#                141         counts_averted maize flour   454.108400
#
#                                                           draw_999
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted wheat flour  3654.702138
#                11          counts_averted wheat flour    30.681769
#                15          counts_averted wheat flour    84.762431
#                20          counts_averted wheat flour    36.171505
#                141         counts_averted maize flour   385.494035
#
# [5 rows x 250 columns]

# %%
results.tail()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                          draw_4      draw_6  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour   0.841504    6.149650
#                214         rates_averted maize flour  19.125454   21.549244
#                                          wheat flour  56.591854  109.557781
#                522         rates_averted maize flour   0.731469    2.735075
#                                          wheat flour  44.203699  159.650481
#
#                                                         draw_10    draw_13  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour   5.518668   3.486776
#                214         rates_averted maize flour  28.070239  26.944525
#                                          wheat flour  93.363314  80.781251
#                522         rates_averted maize flour   3.622326   0.330624
#                                          wheat flour  56.705351  57.819426
#
#                                                          draw_16    draw_18  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour    2.414448   4.518680
#                214         rates_averted maize flour   28.512850  10.911511
#                                          wheat flour   84.927964  80.439866
#                522         rates_averted maize flour    1.729329   1.219792
#                                          wheat flour  122.540750  64.234792
#
#                                                          draw_20    draw_25  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour    6.467820   0.988565
#                214         rates_averted maize flour   20.761274  48.536926
#                                          wheat flour  107.591319  60.963722
#                522         rates_averted maize flour    1.550288   1.816429
#                                          wheat flour   73.486730  71.322649
#
#                                                         draw_26    draw_27  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour   0.673322   2.539150
#                214         rates_averted maize flour  13.526135  20.700991
#                                          wheat flour  39.500040  60.948414
#                522         rates_averted maize flour   0.354787   1.676445
#                                          wheat flour  30.453126  54.657737
#
#                                                       ...    draw_971  \
# coverage_level location_id measure       vehicle      ...
# 0.8            213         rates_averted wheat flour  ...    9.077703
#                214         rates_averted maize flour  ...   18.956849
#                                          wheat flour  ...   52.620923
#                522         rates_averted maize flour  ...    0.760824
#                                          wheat flour  ...  119.616335
#
#                                                        draw_973    draw_974  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour   3.141022   13.584283
#                214         rates_averted maize flour  17.607207   26.247011
#                                          wheat flour  67.908133  126.881164
#                522         rates_averted maize flour   0.772951    1.800393
#                                          wheat flour  32.826305  101.283815
#
#                                                         draw_978   draw_981  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour    6.909061   1.003046
#                214         rates_averted maize flour   28.517921  13.667188
#                                          wheat flour  105.052370  36.995599
#                522         rates_averted maize flour    1.789138   1.265822
#                                          wheat flour   69.507042  46.184182
#
#                                                         draw_985   draw_988  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour    0.722279   0.645572
#                214         rates_averted maize flour   15.321182  10.415844
#                                          wheat flour   57.221349  68.952131
#                522         rates_averted maize flour    0.871326   1.345431
#                                          wheat flour  102.927172  22.709573
#
#                                                        draw_992   draw_994  \
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour   2.981718   0.805894
#                214         rates_averted maize flour  13.185177   9.454239
#                                          wheat flour  39.368308  41.024718
#                522         rates_averted maize flour   0.790690   0.829112
#                                          wheat flour  93.320083  36.569070
#
#                                                        draw_999
# coverage_level location_id measure       vehicle
# 0.8            213         rates_averted wheat flour   2.521343
#                214         rates_averted maize flour  15.641838
#                                          wheat flour  49.549697
#                522         rates_averted maize flour   0.407335
#                                          wheat flour  46.242691
#
# [5 rows x 250 columns]

# %%
print(len(results.index.unique('location_id')))
print(results.index.unique('vehicle'))
print(results.index.unique('coverage_level'))
# Out:
# 25
# Index(['wheat flour', 'maize flour'], dtype='object', name='vehicle')
# Float64Index([0.2, 0.5, 0.8], dtype='float64', name='coverage_level')
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
out_path = 'results/iron_bw_results.csv'
results.to_csv(out_path)
pd.read_csv(out_path).head()
# Out:
#    coverage_level  location_id         measure      vehicle       draw_4  \
# 0             0.2            6  counts_averted  wheat flour  2904.543372
# 1             0.2           11  counts_averted  wheat flour     0.410664
# 2             0.2           15  counts_averted  wheat flour    22.630438
# 3             0.2           20  counts_averted  wheat flour    40.655603
# 4             0.2          141  counts_averted  maize flour   366.596716
#
#         draw_6      draw_10      draw_13      draw_16     draw_18  ...  \
# 0  3749.252406  5431.758587  4862.595241  6909.634628  917.572898  ...
# 1    55.025127   205.150746     4.903218   147.438639  166.470581  ...
# 2    39.480737    83.344657    17.356558    85.796009   25.949345  ...
# 3    36.804245    51.674548    65.486548    63.615450    3.636705  ...
# 4   698.946383  2010.007523   146.087604   643.183569  472.132097  ...
#
#       draw_971     draw_973     draw_974     draw_978     draw_981  \
# 0  3247.119810  2945.899057  3093.888739  4450.653495  3373.314205
# 1   130.557224    99.136743    43.440180    55.307435    68.835866
# 2    32.987038    51.778511    36.298628    75.879004    24.705208
# 3    51.911889    18.471326    69.239954    98.195414    33.785295
# 4   292.371701   470.511168  1017.240468  1083.183300   892.482109
#
#       draw_985     draw_988     draw_992     draw_994     draw_999
# 0  3980.202743  1443.065174  2202.609063  1817.149521  3654.702138
# 1    36.359475   130.843194   318.490189    87.106196    30.681769
# 2    29.401829    44.477208    51.528323    10.900119    84.762431
# 3    13.679045    21.388484    30.470178    24.439117    36.171505
# 4   384.333877   923.678018   458.504144   454.108400   385.494035
#
# [5 rows x 254 columns]

# %%
data = load_and_merge_location_outputs('results3', 'results2', 'results')
print(f"{data.shape=}, {data.location_id.nunique()} {data.location_id.unique()}")
dalys_averted = get_dalys_averted_u5(data)
print(dalys_averted.shape)
pif = compute_aggregate_pif(dalys_averted)
print(pif.shape)
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# data.shape=(1008, 255), 25 [164 201   6 163 189 202 205  20  15 171 214 190 207 196 180 165 522 141
#  213 179  11 161 184 168 181]
# (126, 250)
# (126, 250)

# %%
dalys_averted.head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                             draw_4  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  4039.703147
#                168         counts_averted maize flour   116.942173
#                                           wheat flour   544.029093
#                181         counts_averted maize flour     4.338620
#                                           wheat flour   119.660414
#
#                                                             draw_6  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  4344.685554
#                168         counts_averted maize flour   471.418704
#                                           wheat flour   588.303588
#                181         counts_averted maize flour    37.086488
#                                           wheat flour   626.476449
#
#                                                            draw_10  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  5925.874375
#                168         counts_averted maize flour  1333.554944
#                                           wheat flour   484.540065
#                181         counts_averted maize flour    74.501514
#                                           wheat flour   249.623517
#
#                                                            draw_13  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  4040.636668
#                168         counts_averted maize flour    26.696682
#                                           wheat flour   141.337924
#                181         counts_averted maize flour    19.041651
#                                           wheat flour   284.609425
#
#                                                            draw_16  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  7068.400088
#                168         counts_averted maize flour   419.201567
#                                           wheat flour  1000.981797
#                181         counts_averted maize flour    14.906254
#                                           wheat flour   430.731598
#
#                                                            draw_18  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  2712.618438
#                168         counts_averted maize flour   305.990376
#                                           wheat flour   303.681088
#                181         counts_averted maize flour    31.148117
#                                           wheat flour   248.973486
#
#                                                            draw_20  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  3662.478501
#                168         counts_averted maize flour    54.584979
#                                           wheat flour   756.238141
#                181         counts_averted maize flour    28.613892
#                                           wheat flour   183.304203
#
#                                                            draw_25  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  7990.779684
#                168         counts_averted maize flour   274.975526
#                                           wheat flour   369.947750
#                181         counts_averted maize flour    17.542474
#                                           wheat flour   304.663733
#
#                                                            draw_26  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  2433.817854
#                168         counts_averted maize flour    17.275644
#                                           wheat flour   297.897889
#                181         counts_averted maize flour     7.851186
#                                           wheat flour   133.336814
#
#                                                            draw_27  ...  \
# coverage_level location_id measure        vehicle                   ...
# 0.2            161         counts_averted wheat flour  4228.639880  ...
#                168         counts_averted maize flour   199.955724  ...
#                                           wheat flour   395.093891  ...
#                181         counts_averted maize flour    10.332545  ...
#                                           wheat flour   244.973702  ...
#
#                                                           draw_971  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  3365.291745
#                168         counts_averted maize flour    54.887772
#                                           wheat flour   328.629359
#                181         counts_averted maize flour    30.618837
#                                           wheat flour   655.208231
#
#                                                           draw_973  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  3349.548296
#                168         counts_averted maize flour    71.464280
#                                           wheat flour   145.518986
#                181         counts_averted maize flour    23.196010
#                                           wheat flour   181.419450
#
#                                                           draw_974  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  4200.984673
#                168         counts_averted maize flour    94.413106
#                                           wheat flour   576.876996
#                181         counts_averted maize flour    10.977395
#                                           wheat flour   355.523479
#
#                                                           draw_978  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  5062.500108
#                168         counts_averted maize flour   178.530620
#                                           wheat flour   383.339021
#                181         counts_averted maize flour     0.202730
#                                           wheat flour   228.345488
#
#                                                           draw_981  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  3342.735003
#                168         counts_averted maize flour   268.516617
#                                           wheat flour   467.115461
#                181         counts_averted maize flour    10.278480
#                                           wheat flour   182.979180
#
#                                                           draw_985  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  4094.276352
#                168         counts_averted maize flour    70.119366
#                                           wheat flour   375.468441
#                181         counts_averted maize flour    12.890760
#                                           wheat flour   377.824894
#
#                                                           draw_988  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  2871.976418
#                168         counts_averted maize flour   314.463709
#                                           wheat flour    72.188444
#                181         counts_averted maize flour    25.019267
#                                           wheat flour    80.488883
#
#                                                           draw_992  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  3221.948837
#                168         counts_averted maize flour   233.058271
#                                           wheat flour   572.533315
#                181         counts_averted maize flour     6.092590
#                                           wheat flour   328.119413
#
#                                                           draw_994  \
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  2589.085328
#                168         counts_averted maize flour    30.424647
#                                           wheat flour   360.220510
#                181         counts_averted maize flour     3.578925
#                                           wheat flour   120.973058
#
#                                                           draw_999
# coverage_level location_id measure        vehicle
# 0.2            161         counts_averted wheat flour  3948.490478
#                168         counts_averted maize flour   151.873750
#                                           wheat flour   352.265379
#                181         counts_averted maize flour     3.120449
#                                           wheat flour   159.338587
#
# [5 rows x 250 columns]

# %%
pif.head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                   draw_4    draw_6   draw_10  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.117011  0.166081  0.180064
#                168         pif     maize flour  0.007279  0.039132  0.088495
#                                    wheat flour  0.033863  0.048835  0.032154
#                181         pif     maize flour  0.000329  0.003364  0.006233
#                                    wheat flour  0.009077  0.056821  0.020883
#
#                                                  draw_13   draw_16   draw_18  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.142562  0.200354  0.087153
#                168         pif     maize flour  0.002036  0.028411  0.021182
#                                    wheat flour  0.010777  0.067840  0.021022
#                181         pif     maize flour  0.001473  0.001580  0.002596
#                                    wheat flour  0.022018  0.045667  0.020747
#
#                                                  draw_20   draw_25   draw_26  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.121747  0.252872  0.074350
#                168         pif     maize flour  0.003876  0.017345  0.001113
#                                    wheat flour  0.053700  0.023336  0.019189
#                181         pif     maize flour  0.002415  0.001191  0.000691
#                                    wheat flour  0.015468  0.020690  0.011735
#
#                                                  draw_27  ...  draw_971  \
# coverage_level location_id measure vehicle                ...
# 0.2            161         pif     wheat flour  0.117968  ...  0.104561
#                168         pif     maize flour  0.013859  ...  0.004053
#                                    wheat flour  0.027384  ...  0.024266
#                181         pif     maize flour  0.000845  ...  0.002438
#                                    wheat flour  0.020039  ...  0.052178
#
#                                                 draw_973  draw_974  draw_978  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.091855  0.128181  0.165663
#                168         pif     maize flour  0.004917  0.006608  0.012726
#                                    wheat flour  0.010013  0.040378  0.027325
#                181         pif     maize flour  0.001980  0.000867  0.000016
#                                    wheat flour  0.015489  0.028075  0.017868
#
#                                                 draw_981  draw_985  draw_988  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.090923  0.101902  0.072870
#                168         pif     maize flour  0.019067  0.004601  0.019795
#                                    wheat flour  0.033169  0.024636  0.004544
#                181         pif     maize flour  0.000840  0.001171  0.002112
#                                    wheat flour  0.014955  0.034332  0.006795
#
#                                                 draw_992  draw_994  draw_999
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.076823  0.065607  0.118763
#                168         pif     maize flour  0.014687  0.002243  0.010733
#                                    wheat flour  0.036081  0.026558  0.024894
#                181         pif     maize flour  0.000569  0.000375  0.000262
#                                    wheat flour  0.030618  0.012690  0.013393
#
# [5 rows x 250 columns]

# %%
data = (
    load_and_merge_location_outputs('results')
    .pipe(filter_measures_and_coverage)
    .pipe(aggregate_over_age_groups)
)
data.head()
# Out:
#                                                            draw_4  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  4039.703147
#                168         averted_dalys maize flour   116.942173
#                                          wheat flour   544.029093
#                181         averted_dalys maize flour     4.338620
#                                          wheat flour   119.660414
#
#                                                            draw_6  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  4344.685554
#                168         averted_dalys maize flour   471.418704
#                                          wheat flour   588.303588
#                181         averted_dalys maize flour    37.086488
#                                          wheat flour   626.476449
#
#                                                           draw_10  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  5925.874375
#                168         averted_dalys maize flour  1333.554944
#                                          wheat flour   484.540065
#                181         averted_dalys maize flour    74.501514
#                                          wheat flour   249.623517
#
#                                                           draw_13  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  4040.636668
#                168         averted_dalys maize flour    26.696682
#                                          wheat flour   141.337924
#                181         averted_dalys maize flour    19.041651
#                                          wheat flour   284.609425
#
#                                                           draw_16  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  7068.400088
#                168         averted_dalys maize flour   419.201567
#                                          wheat flour  1000.981797
#                181         averted_dalys maize flour    14.906254
#                                          wheat flour   430.731598
#
#                                                           draw_18  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  2712.618438
#                168         averted_dalys maize flour   305.990376
#                                          wheat flour   303.681088
#                181         averted_dalys maize flour    31.148117
#                                          wheat flour   248.973486
#
#                                                           draw_20  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  3662.478501
#                168         averted_dalys maize flour    54.584979
#                                          wheat flour   756.238141
#                181         averted_dalys maize flour    28.613892
#                                          wheat flour   183.304203
#
#                                                           draw_25  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  7990.779684
#                168         averted_dalys maize flour   274.975526
#                                          wheat flour   369.947750
#                181         averted_dalys maize flour    17.542474
#                                          wheat flour   304.663733
#
#                                                           draw_26  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  2433.817854
#                168         averted_dalys maize flour    17.275644
#                                          wheat flour   297.897889
#                181         averted_dalys maize flour     7.851186
#                                          wheat flour   133.336814
#
#                                                           draw_27  ...  \
# coverage_level location_id measure       vehicle                   ...
# 0.2            161         averted_dalys wheat flour  4228.639880  ...
#                168         averted_dalys maize flour   199.955724  ...
#                                          wheat flour   395.093891  ...
#                181         averted_dalys maize flour    10.332545  ...
#                                          wheat flour   244.973702  ...
#
#                                                          draw_971  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  3365.291745
#                168         averted_dalys maize flour    54.887772
#                                          wheat flour   328.629359
#                181         averted_dalys maize flour    30.618837
#                                          wheat flour   655.208231
#
#                                                          draw_973  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  3349.548296
#                168         averted_dalys maize flour    71.464280
#                                          wheat flour   145.518986
#                181         averted_dalys maize flour    23.196010
#                                          wheat flour   181.419450
#
#                                                          draw_974  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  4200.984673
#                168         averted_dalys maize flour    94.413106
#                                          wheat flour   576.876996
#                181         averted_dalys maize flour    10.977395
#                                          wheat flour   355.523479
#
#                                                          draw_978  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  5062.500108
#                168         averted_dalys maize flour   178.530620
#                                          wheat flour   383.339021
#                181         averted_dalys maize flour     0.202730
#                                          wheat flour   228.345488
#
#                                                          draw_981  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  3342.735003
#                168         averted_dalys maize flour   268.516617
#                                          wheat flour   467.115461
#                181         averted_dalys maize flour    10.278480
#                                          wheat flour   182.979180
#
#                                                          draw_985  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  4094.276352
#                168         averted_dalys maize flour    70.119366
#                                          wheat flour   375.468441
#                181         averted_dalys maize flour    12.890760
#                                          wheat flour   377.824894
#
#                                                          draw_988  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  2871.976418
#                168         averted_dalys maize flour   314.463709
#                                          wheat flour    72.188444
#                181         averted_dalys maize flour    25.019267
#                                          wheat flour    80.488883
#
#                                                          draw_992  \
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  3221.948837
#                168         averted_dalys maize flour   233.058271
#                                          wheat flour   572.533315
#                181         averted_dalys maize flour     6.092590
#                                          wheat flour   328.119413
#
#                                                          draw_994     draw_999
# coverage_level location_id measure       vehicle
# 0.2            161         averted_dalys wheat flour  2589.085328  3948.490478
#                168         averted_dalys maize flour    30.424647   151.873750
#                                          wheat flour   360.220510   352.265379
#                181         averted_dalys maize flour     3.578925     3.120449
#                                          wheat flour   120.973058   159.338587
#
# [5 rows x 250 columns]

# %%
data.index.unique('measure')
# Out:
# Index(['averted_dalys'], dtype='object', name='measure')

# %%
data.index.levels
# Out:
# FrozenList([[0.2, 0.5, 0.8], [161, 168, 181, 184], ['averted_dalys'], ['maize flour', 'wheat flour']])

# %%
pif = compute_aggregate_pif(data)
pif.head()
# Out:
#                                                   draw_4    draw_6   draw_10  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.117011  0.166081  0.180064
#                168         pif     maize flour  0.007279  0.039132  0.088495
#                                    wheat flour  0.033863  0.048835  0.032154
#                181         pif     maize flour  0.000329  0.003364  0.006233
#                                    wheat flour  0.009077  0.056821  0.020883
#
#                                                  draw_13   draw_16   draw_18  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.142562  0.200354  0.087153
#                168         pif     maize flour  0.002036  0.028411  0.021182
#                                    wheat flour  0.010777  0.067840  0.021022
#                181         pif     maize flour  0.001473  0.001580  0.002596
#                                    wheat flour  0.022018  0.045667  0.020747
#
#                                                  draw_20   draw_25   draw_26  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.121747  0.252872  0.074350
#                168         pif     maize flour  0.003876  0.017345  0.001113
#                                    wheat flour  0.053700  0.023336  0.019189
#                181         pif     maize flour  0.002415  0.001191  0.000691
#                                    wheat flour  0.015468  0.020690  0.011735
#
#                                                  draw_27  ...  draw_971  \
# coverage_level location_id measure vehicle                ...
# 0.2            161         pif     wheat flour  0.117968  ...  0.104561
#                168         pif     maize flour  0.013859  ...  0.004053
#                                    wheat flour  0.027384  ...  0.024266
#                181         pif     maize flour  0.000845  ...  0.002438
#                                    wheat flour  0.020039  ...  0.052178
#
#                                                 draw_973  draw_974  draw_978  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.091855  0.128181  0.165663
#                168         pif     maize flour  0.004917  0.006608  0.012726
#                                    wheat flour  0.010013  0.040378  0.027325
#                181         pif     maize flour  0.001980  0.000867  0.000016
#                                    wheat flour  0.015489  0.028075  0.017868
#
#                                                 draw_981  draw_985  draw_988  \
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.090923  0.101902  0.072870
#                168         pif     maize flour  0.019067  0.004601  0.019795
#                                    wheat flour  0.033169  0.024636  0.004544
#                181         pif     maize flour  0.000840  0.001171  0.002112
#                                    wheat flour  0.014955  0.034332  0.006795
#
#                                                 draw_992  draw_994  draw_999
# coverage_level location_id measure vehicle
# 0.2            161         pif     wheat flour  0.076823  0.065607  0.118763
#                168         pif     maize flour  0.014687  0.002243  0.010733
#                                    wheat flour  0.036081  0.026558  0.024894
#                181         pif     maize flour  0.000569  0.000375  0.000262
#                                    wheat flour  0.030618  0.012690  0.013393
#
# [5 rows x 250 columns]

# %%
pif.index.levels
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# FrozenList([[0.2, 0.5, 0.8], [161, 168, 181, 184], ['averted_dalys'], ['maize flour', 'wheat flour']])

# %%
pif.index.set_levels(['pif'], level='measure')
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# MultiIndex([(0.2, 161, 'pif', 'wheat flour'),
#             (0.2, 168, 'pif', 'maize flour'),
#             (0.2, 168, 'pif', 'wheat flour'),
#             (0.2, 181, 'pif', 'maize flour'),
#             (0.2, 181, 'pif', 'wheat flour'),
#             (0.2, 184, 'pif', 'maize flour'),
#             (0.2, 184, 'pif', 'wheat flour'),
#             (0.5, 161, 'pif', 'wheat flour'),
#             (0.5, 168, 'pif', 'maize flour'),
#             (0.5, 168, 'pif', 'wheat flour'),
#             (0.5, 181, 'pif', 'maize flour'),
#             (0.5, 181, 'pif', 'wheat flour'),
#             (0.5, 184, 'pif', 'maize flour'),
#             (0.5, 184, 'pif', 'wheat flour'),
#             (0.8, 161, 'pif', 'wheat flour'),
#             (0.8, 168, 'pif', 'maize flour'),
#             (0.8, 168, 'pif', 'wheat flour'),
#             (0.8, 181, 'pif', 'maize flour'),
#             (0.8, 181, 'pif', 'wheat flour'),
#             (0.8, 184, 'pif', 'maize flour'),
#             (0.8, 184, 'pif', 'wheat flour')],
#            names=['coverage_level', 'location_id', 'measure', 'vehicle'])

# %%
lbwsg_dalys.index.unique('location_id')
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Int64Index([161, 168, 181, 184], dtype='int64', name='location_id')

# %%
data = load_and_merge_location_outputs('results')
print(f"{data.shape=}, {data.location_id.unique()}")
lbwsg_dalys = compute_aggregate_pif(data)
lbwsg_dalys.head()
# Out:
# data.shape=(168, 255), [161 184 168 181]
#                    draw_4        draw_6       draw_10       draw_13  \
# location_id
# 161          3.452412e+06  2.616006e+06  3.290978e+06  2.834305e+06
# 168          1.606580e+06  1.204686e+06  1.506925e+06  1.311504e+06
# 181          1.318275e+06  1.102536e+06  1.195370e+06  1.292647e+06
# 184          1.916294e+06  1.814400e+06  1.817148e+06  2.059403e+06
#
#                   draw_16       draw_18       draw_20       draw_25  \
# location_id
# 161          3.527947e+06  3.112482e+06  3.008264e+06  3.160012e+06
# 168          1.475511e+06  1.444593e+06  1.408275e+06  1.585300e+06
# 181          9.432022e+05  1.200056e+06  1.185071e+06  1.472549e+06
# 184          1.422511e+06  1.785566e+06  1.901446e+06  2.127346e+06
#
#                   draw_26       draw_27  ...      draw_971      draw_973  \
# location_id                              ...
# 161          3.273450e+06  3.584562e+06  ...  3.218507e+06  3.646573e+06
# 168          1.552451e+06  1.442782e+06  ...  1.354306e+06  1.453335e+06
# 181          1.136237e+06  1.222469e+06  ...  1.255718e+06  1.171263e+06
# 184          1.962983e+06  1.781247e+06  ...  2.013524e+06  1.801178e+06
#
#                  draw_974      draw_978      draw_981      draw_985  \
# location_id
# 161          3.277380e+06  3.055904e+06  3.676459e+06  4.017869e+06
# 168          1.428701e+06  1.402886e+06  1.408289e+06  1.524053e+06
# 181          1.266339e+06  1.277945e+06  1.223536e+06  1.100504e+06
# 184          2.198098e+06  1.875532e+06  1.724597e+06  1.767008e+06
#
#                  draw_988      draw_992      draw_994      draw_999
# location_id
# 161          3.941235e+06  4.194015e+06  3.946352e+06  3.324671e+06
# 168          1.588589e+06  1.586804e+06  1.356378e+06  1.415038e+06
# 181          1.184534e+06  1.071645e+06  9.533037e+05  1.189689e+06
# 184          1.685108e+06  1.704085e+06  1.435956e+06  1.552111e+06
#
# [4 rows x 250 columns]

# %%
lbwsg_dalys.metric_id.unique()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([1, 2])

# %%
lbwsg_dalys.measure_id.unique()
# Out:
# array([2])

# %%
# !ls results2
# Out:
# Côte d'Ivoire_parallel.txt
# Democratic Republic of the Congo_parallel.txt
# Egypt_parallel.txt
# Ethiopia_parallel.txt
# Ghana_parallel.txt
# India_parallel.txt
# Indonesia_parallel.txt
# iron_bw_results__Democratic Republic of the Congo.csv
# iron_bw_results__Egypt.csv
# iron_bw_results__Ethiopia.csv
# iron_bw_results__Ghana.csv
# iron_bw_results__Indonesia.csv
# iron_bw_results__Kenya.csv
# iron_bw_results__Nigeria.csv
# iron_bw_results__Pakistan.csv
# iron_bw_results__South Africa.csv
# iron_bw_results__Sudan.csv
# iron_bw_results__Uganda.csv
# Kenya_parallel.txt
# Nigeria_parallel.txt
# Niger_parallel.txt
# Pakistan_parallel.txt
# South Africa_parallel.txt
# Sudan_parallel.txt
# Uganda_parallel.txt
