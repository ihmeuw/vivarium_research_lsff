# %%
import pandas as pd, numpy as np
import os

from db_queries import get_ids, get_population
from vivarium_helpers.id_helper import *

import data_processing
import process_iron_bw
# import lbwsg_boe
# import lbwsg
# import lsff_interventions
# import demography

# !date
# !whoami
# !pwd
# Out:
# Thu Apr 15 14:26:41 PDT 2021
# ndbs
# /ihme/homes/ndbs/vivarium_research_lsff/nanosim_models

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Combine and process 'industry wheat' iron-BW results from all locations
#
# And count unique locations to check whether all jobs have completed.

# %%
results = process_iron_bw.read_output_and_compute_final_results(
    'results_industry', num_draws=250, filters=None#["coverage_level==0.8"]
)
results
# Out:
#                                                                draw_4  \
# coverage_level location_id measure        vehicle
# 0.2            6           counts_averted industry wheat  2940.723846
#                11          counts_averted industry wheat    47.131220
#                15          counts_averted industry wheat    37.016375
#                20          counts_averted industry wheat    77.114544
#                141         counts_averted industry wheat  3576.712185
# ...                                                               ...
# 0.8            205         rates_averted  industry wheat    59.528647
#                207         rates_averted  industry wheat    54.026166
#                213         rates_averted  industry wheat     3.249961
#                214         rates_averted  industry wheat    72.021435
#                522         rates_averted  industry wheat    77.393123
#
#                                                                draw_6  \
# ...

# %%
len(results.index.unique('location_id'))
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 25

# %% [markdown]
# # Save 'industry wheat' iron-BW results and read `.csv` file to check format

# %%
filepath='results_industry/iron_bw_results_industry_wheat_2021_04_15.csv'
results.to_csv(filepath)
pd.read_csv(filepath).head()
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    coverage_level  location_id         measure         vehicle       draw_4  \
# 0             0.2            6  counts_averted  industry wheat  2940.723846
# 1             0.2           11  counts_averted  industry wheat    47.131220
# 2             0.2           15  counts_averted  industry wheat    37.016375
# 3             0.2           20  counts_averted  industry wheat    77.114544
# 4             0.2          141  counts_averted  industry wheat  3576.712185
#
#         draw_6      draw_10      draw_13      draw_16      draw_18  ...  \
# ...

# %%
# 225 rows = 25 locations x 3 coverage levels x 3 measures
25*3*3
# Out:
# /ihme/homes/ndbs/miniconda3/envs/lsff-iron-38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 225
